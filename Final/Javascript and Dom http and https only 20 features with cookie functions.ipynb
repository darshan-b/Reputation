# %% [markdown]
# ***
# ## Table of Contents
# <br>
#     <ol>
#         <h2><a href='#1' style="text-decoration : none; color : #000000;">1. HTTP</a></h2>
#         <ul>
#             <a href='#1.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#1.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#1.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#1.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#1.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a></h2>
#         <ul><a href='#2.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#2.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#2.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>
#
# <br>
#     <ol>
#         <h2><a href='#3' style="text-decoration : none; color : #000000;">3. HTTPS</a></h2>
#         <ul>
#             <a href='#3.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#3.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#3.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#3.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#3.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a></h2>
#         <ul><a href='#4.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#4.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#4.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output,HTML
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from tabulate import tabulate

import keras
from keras.layers import Dense,Dropout
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)

from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split,cross_val_score

from sklearn.preprocessing import MinMaxScaler,StandardScaler,binarize
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE
from sklearn import metrics

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix,accuracy_score,auc,roc_curve,recall_score
from sklearn import metrics
from pandas_ml import ConfusionMatrix


from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
### Function get_params takes as input a grid search model and prints out the best parameters for the model and 
### prints the best accuracy of the model
def get_params(grid,model_name=''):
    print("Best Parameters are :")
    display(pd.DataFrame.from_dict(grid.best_params_, orient='index').reset_index().transpose())

### The function takes as input the model, X and Y data to generate the confusion matrix  
def get_cm(model,a,b):
    y_pred=model.predict(a)
    cm=ConfusionMatrix(b,y_pred)
    return cm
 
### The get accuracy plot takes as input a dataframe and a string for the title of the plot and displays a plot
### The function is primarily for plotting of accuracies for various classifiers for the same split.
def get_accuracy_plot(data,title=''):
    plt.figure(figsize=(12,8))
    plt.plot(data['accuracy'].values, '--o')
    plt.ylabel('Accuracy', fontsize=20)
    plt.xlabel('Classifier', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    plt.xlim([0, 9])
    plt.title(title,size=18,y=1.05)
    plt.xticks(np.arange(10),data.index.get_values(),rotation=90)
    plt.legend(loc='upper right', fontsize=18)
    plt.show()

### Function grid takes as input an estimator, X_train,Y_Train,X_test and Y_test and a string represetning the name of the model
### We perform StratifiedKFold cross validation and grid search to hypertune the parameters of the model     
def grid(kernel,params,x,y,x_test,y_test,model_name=''):
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    grid_search=GridSearchCV(estimator=kernel,param_grid=parameters,scoring='accuracy',cv=kfold,n_jobs=3,verbose=True)
    grid_search.fit(x,y)
    get_params(grid_search,model_name)
    acc_train=accuracy_score(y,grid_search.predict(x))
    print("Accuracy of the ",model_name," model for the training data is:",acc_train)
    print("\nConfusion Matrix for Training data is:")
    cm_train=get_cm(grid_search,x,y)
    display(cm_train)
    acc_test=accuracy_score(y_test,grid_search.predict(x_test))
    print("Accuracy of the ",model_name," model for test data is:",acc_test)
    print("\nConfusion Matrix for test data is:")
    cm_test=get_cm(grid_search,x_test,y_test)
    display(cm_test)
    fpr, tpr, threshold = roc_curve(y_test, grid_search.predict(x_test))
    roc_auc =auc(fpr, tpr)
    return grid_search,cm_train,cm_test,acc_train,acc_test,roc_auc  

### Plot roc curve
def get_roc_curve(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob[:,1]
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy on test data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

def get_roc_curve_deep_learning(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy of Logistic Model on training data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

# %% [markdown]
# ## <a id='1' style="text-decoration : none; color : #000000;"> HTTP</a>
#
# ### <a id='1.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_http.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

display(df.shape)

# df.to_csv('Javascript_dom.csv')

df.head()
# Out:
# (43296, 407)
#                   dom_function_document.adoptNode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_document.captureEvents(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.caretPositionFromPoint(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.caretRangeFromPoint(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.clear(  dom_function_document.close(  \
# domain
# h83.turdizi.com                            0.0                           0.0
# hbgv.wivela.com                            0.0                           0.0
# nus.edu.sg                                 0.0                           0.0
# arabwebpage.com                            0.0                           0.0
# moscatalogue.net                           0.0                           0.0
#
#                   dom_function_document.createAttribute(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createAttributeNS(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.createCDATASection(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createComment(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.createDocumentFragment(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.createElement(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    4.0
# nus.edu.sg                                         1.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   1.0
#
#                   dom_function_document.createElementNS(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createEntityReference(  \
# domain
# h83.turdizi.com                                            0.0
# hbgv.wivela.com                                            0.0
# nus.edu.sg                                                 0.0
# arabwebpage.com                                            0.0
# moscatalogue.net                                           0.0
#
#                   dom_function_document.createEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createNodeIterator(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createProcessingInstruction(  \
# domain
# h83.turdizi.com                                                 0.0
# hbgv.wivela.com                                                 0.0
# nus.edu.sg                                                      0.0
# arabwebpage.com                                                 0.0
# moscatalogue.net                                                0.0
#
#                   dom_function_document.createRange(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTextNode(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          1.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.createTouch(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTouchList(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createTreeWalker(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementFromPoint(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementsFromPoint(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.enableStyleSheetsForSet(  \
# domain
# h83.turdizi.com                                              0.0
# hbgv.wivela.com                                              0.0
# nus.edu.sg                                                   0.0
# arabwebpage.com                                              0.0
# moscatalogue.net                                             0.0
#
#                   dom_function_document.execCommand(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.exitPointerLock(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.getAnimations(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.getElementById(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.getElementByName(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.getElementsByClassName(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             1.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getElementsByTagName(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           3.0
# nus.edu.sg                                                1.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.getElementsByTagNameNS(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getSelection(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.hasFocus(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_document.importNode(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.normalizeDocument(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.open(  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                0.0
# arabwebpage.com                           0.0
# moscatalogue.net                          0.0
#
#                   dom_function_document.queryCommandEnabled(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.queryCommandIndeterm(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.queryCommandValue(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.querySelector(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.querySelectorAll(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.releaseCapture(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.releaseEvent(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.routeEvent(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.write(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           2.0
#
#                   dom_function_document.writeln(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.addEventListener(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     1.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.alert(  dom_function_window.atob(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.back(  dom_function_window.blur(  \
# domain
# h83.turdizi.com                         0.0                        0.0
# hbgv.wivela.com                         0.0                        0.0
# nus.edu.sg                              0.0                        0.0
# arabwebpage.com                         0.0                        0.0
# moscatalogue.net                        0.0                        0.0
#
#                   dom_function_window.btoa(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.cancelAnimationFrame(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_window.cancelIdleCallback(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_window.captureEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearImmediate(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_window.clearInterval(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearTimeout(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.close(  dom_function_window.confirm(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.createImageBitmap(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_window.disableExternalCapture(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.dispatchEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.dump(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.enableExternalCapture(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.fetch(  dom_function_window.find(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.focus(  dom_function_window.forward(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.getAttention(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.getAttentionWithCycleCount(  \
# domain
# h83.turdizi.com                                               0.0
# hbgv.wivela.com                                               0.0
# nus.edu.sg                                                    0.0
# arabwebpage.com                                               0.0
# moscatalogue.net                                              0.0
#
#                   dom_function_window.getComputedStyle(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.getDefaultComputedSyle(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.getSelection(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.home(  dom_function_window.matchMedia(  \
# domain
# h83.turdizi.com                         0.0                              0.0
# hbgv.wivela.com                         0.0                              0.0
# nus.edu.sg                              0.0                              0.0
# arabwebpage.com                         0.0                              0.0
# moscatalogue.net                        0.0                              0.0
#
#                   dom_function_window.maximize(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.minimize(  dom_function_window.moveBy(  \
# domain
# h83.turdizi.com                             0.0                          0.0
# hbgv.wivela.com                             0.0                          0.0
# nus.edu.sg                                  0.0                          0.0
# arabwebpage.com                             0.0                          0.0
# moscatalogue.net                            0.0                          0.0
#
#                   dom_function_window.moveTo(  dom_function_window.open(  \
# domain
# h83.turdizi.com                           0.0                        0.0
# hbgv.wivela.com                           0.0                        0.0
# nus.edu.sg                                0.0                        2.0
# arabwebpage.com                           0.0                        0.0
# moscatalogue.net                          0.0                        0.0
#
#                   dom_function_window.openDialog(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.postMessage(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.print(  dom_function_window.prompt(  \
# domain
# h83.turdizi.com                          0.0                          0.0
# hbgv.wivela.com                          0.0                          0.0
# nus.edu.sg                               0.0                          0.0
# arabwebpage.com                          0.0                          0.0
# moscatalogue.net                         0.0                          0.0
#
#                   dom_function_window.releaseEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.removeEventListener(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.requestAnimationFrame(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.requestIdleCallback(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.resizeBy(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.resizeTo(  dom_function_window.restore(  \
# domain
# h83.turdizi.com                             0.0                           0.0
# hbgv.wivela.com                             0.0                           0.0
# nus.edu.sg                                  0.0                           0.0
# arabwebpage.com                             0.0                           0.0
# moscatalogue.net                            0.0                           0.0
#
#                   dom_function_window.routeEvent(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.scroll(  dom_function_window.scrollBy(  \
# domain
# h83.turdizi.com                           0.0                            0.0
# hbgv.wivela.com                           0.0                            0.0
# nus.edu.sg                                0.0                            0.0
# arabwebpage.com                           0.0                            0.0
# moscatalogue.net                          0.0                            0.0
#
#                   dom_function_window.scrollByLines(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollByPages(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollTo(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.setCursor(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.setImmediate(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setInterval(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.setResizable(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setTimeout(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.sizeToContent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.stop(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.updateCommands(  js_function_.add(  \
# domain
# h83.turdizi.com                                   0.0                0.0
# hbgv.wivela.com                                   0.0                0.0
# nus.edu.sg                                        0.0                0.0
# arabwebpage.com                                   0.0                0.0
# moscatalogue.net                                  0.0                0.0
#
#                   js_function_.all(  js_function_.allTrue(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_.anchor(  js_function_.apply(  \
# domain
# h83.turdizi.com                    0.0                  0.0
# hbgv.wivela.com                    0.0                  6.0
# nus.edu.sg                         0.0                  0.0
# arabwebpage.com                    0.0                  0.0
# moscatalogue.net                   0.0                  0.0
#
#                   js_function_.big(  js_function_.bind(  js_function_.blink(  \
# domain
# h83.turdizi.com                 0.0                 0.0                  0.0
# hbgv.wivela.com                 0.0                 0.0                  0.0
# nus.edu.sg                      0.0                 0.0                  0.0
# arabwebpage.com                 0.0                 0.0                  0.0
# moscatalogue.net                0.0                 0.0                  0.0
#
#                   js_function_.bold(  js_function_.call(  js_function_.catch(  \
# domain
# h83.turdizi.com                  0.0                 0.0                  0.0
# hbgv.wivela.com                  0.0                 4.0                  0.0
# nus.edu.sg                       0.0                 0.0                  0.0
# arabwebpage.com                  0.0                 0.0                  0.0
# moscatalogue.net                 0.0                 0.0                  0.0
#
#                   js_function_.charAt(  js_function_.charCodeAt(  \
# domain
# h83.turdizi.com                    0.0                       0.0
# hbgv.wivela.com                    2.0                       0.0
# nus.edu.sg                         1.0                       0.0
# arabwebpage.com                    0.0                       0.0
# moscatalogue.net                   0.0                       0.0
#
#                   js_function_.clear(  js_function_.codePointAt(  \
# domain
# h83.turdizi.com                   0.0                        0.0
# hbgv.wivela.com                   0.0                        0.0
# nus.edu.sg                        0.0                        0.0
# arabwebpage.com                   0.0                        0.0
# moscatalogue.net                  0.0                        0.0
#
#                   js_function_.compile(  js_function_.concat(  \
# domain
# h83.turdizi.com                     0.0                   0.0
# hbgv.wivela.com                     0.0                   2.0
# nus.edu.sg                          0.0                   0.0
# arabwebpage.com                     0.0                   0.0
# moscatalogue.net                    0.0                   0.0
#
#                   js_function_.construct(  js_function_.copyWithin(  \
# domain
# h83.turdizi.com                       0.0                       0.0
# hbgv.wivela.com                       0.0                       0.0
# nus.edu.sg                            0.0                       0.0
# arabwebpage.com                       0.0                       0.0
# moscatalogue.net                      0.0                       0.0
#
#                   js_function_.defineProperty(  js_function_.delete(  \
# domain
# h83.turdizi.com                            0.0                   0.0
# hbgv.wivela.com                            2.0                   0.0
# nus.edu.sg                                 0.0                   0.0
# arabwebpage.com                            0.0                   0.0
# moscatalogue.net                           0.0                   0.0
#
#                   js_function_.deleteProperty(  js_function_.endWith(  \
# domain
# h83.turdizi.com                            0.0                    0.0
# hbgv.wivela.com                            0.0                    0.0
# nus.edu.sg                                 0.0                    0.0
# arabwebpage.com                            0.0                    0.0
# moscatalogue.net                           0.0                    0.0
#
#                   js_function_.entries(  js_function_.every(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   js_function_.exec(  js_function_.fill(  \
# domain
# h83.turdizi.com                  0.0                 0.0
# hbgv.wivela.com                  0.0                 0.0
# nus.edu.sg                       0.0                 0.0
# arabwebpage.com                  0.0                 0.0
# moscatalogue.net                 0.0                 0.0
#
#                   js_function_.filter(  js_function_.finally(  \
# domain
# h83.turdizi.com                    0.0                    0.0
# hbgv.wivela.com                    0.0                    0.0
# nus.edu.sg                         0.0                    0.0
# arabwebpage.com                    0.0                    0.0
# moscatalogue.net                   0.0                    0.0
#
#                   js_function_.find(  js_function_.findIndex(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  0.0                      0.0
# nus.edu.sg                       6.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_.fixed(  js_function_.flat(  \
# domain
# ...
#
#                   js_function_Object.setPrototypeOf(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   js_function_Promise.all(  js_function_Promise.race(  \
# domain
# h83.turdizi.com                        0.0                        0.0
# hbgv.wivela.com                        0.0                        0.0
# nus.edu.sg                             0.0                        0.0
# arabwebpage.com                        0.0                        0.0
# moscatalogue.net                       0.0                        0.0
#
#                   js_function_Promise.reject(  js_function_Promise.resolve(  \
# domain
# h83.turdizi.com                           0.0                           0.0
# hbgv.wivela.com                           0.0                           0.0
# nus.edu.sg                                0.0                           0.0
# arabwebpage.com                           0.0                           0.0
# moscatalogue.net                          0.0                           0.0
#
#                   js_function_Proxy.revocable(  js_function_Reflect.apply(  \
# domain
# h83.turdizi.com                            0.0                         0.0
# hbgv.wivela.com                            0.0                         0.0
# nus.edu.sg                                 0.0                         0.0
# arabwebpage.com                            0.0                         0.0
# moscatalogue.net                           0.0                         0.0
#
#                   js_function_Reflect.construct(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   js_function_Reflect.defineProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.deleteProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.get(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_Reflect.getPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.has(  js_function_Reflect.isExtensible(  \
# domain
# h83.turdizi.com                        0.0                                0.0
# hbgv.wivela.com                        0.0                                0.0
# nus.edu.sg                             0.0                                0.0
# arabwebpage.com                        0.0                                0.0
# moscatalogue.net                       0.0                                0.0
#
#                   js_function_Reflect.ownKeys(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           0.0
#
#                   js_function_Reflect.preventExtensions(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   js_function_Reflect.set(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.setPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_String.fromCharCode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_String.fromCodePoint(  js_function_String.raw(  \
# domain
# h83.turdizi.com                                 0.0                      0.0
# hbgv.wivela.com                                 0.0                      0.0
# nus.edu.sg                                      0.0                      0.0
# arabwebpage.com                                 0.0                      0.0
# moscatalogue.net                                0.0                      0.0
#
#                   js_function_Symbol.for(  js_function_Symbol.keyFor(  \
# domain
# h83.turdizi.com                       0.0                         0.0
# hbgv.wivela.com                       0.0                         0.0
# nus.edu.sg                            0.0                         0.0
# arabwebpage.com                       0.0                         0.0
# moscatalogue.net                      0.0                         0.0
#
#                   js_function_WebAssembly.compile(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.compileStreaming(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.customerSections(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.exports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.imports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.instantiate(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   js_function_WebAssembly.instantiateStreaming(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_WebAssembly.validate(  js_function_decodeURI(  \
# domain
# h83.turdizi.com                                 0.0                     0.0
# hbgv.wivela.com                                 0.0                     0.0
# nus.edu.sg                                      0.0                     0.0
# arabwebpage.com                                 0.0                     0.0
# moscatalogue.net                                0.0                     0.0
#
#                   js_function_decodeURIComponent(  js_function_encodeURI(  \
# domain
# h83.turdizi.com                               0.0                     0.0
# hbgv.wivela.com                               0.0                     0.0
# nus.edu.sg                                    1.0                     0.0
# arabwebpage.com                               0.0                     0.0
# moscatalogue.net                              0.0                     0.0
#
#                   js_function_encodeURIComponent(  js_function_escape(  \
# domain
# h83.turdizi.com                               0.0                  0.0
# hbgv.wivela.com                               0.0                  0.0
# nus.edu.sg                                    1.0                  0.0
# arabwebpage.com                               0.0                  0.0
# moscatalogue.net                              0.0                  2.0
#
#                   js_function_eval(  js_function_isFinite(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_isNaN(  js_function_parseFloat(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  1.0                      0.0
# nus.edu.sg                       0.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_parseInt(  js_function_undefined(  \
# domain
# h83.turdizi.com                     0.0                     0.0
# hbgv.wivela.com                     0.0                     0.0
# nus.edu.sg                          0.0                     0.0
# arabwebpage.com                     0.0                     0.0
# moscatalogue.net                    0.0                     0.0
#
#                   js_function_unescape(  js_function_uneval(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   number_functions_declared  number_of_cookies  \
# domain
# h83.turdizi.com                         0.0                0.0
# hbgv.wivela.com                        87.0                6.0
# nus.edu.sg                             24.0                4.0
# arabwebpage.com                         7.0                4.0
# moscatalogue.net                        3.0                5.0
#
#                   number_of_http_only_cookies  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                1.0
# arabwebpage.com                           1.0
# moscatalogue.net                          1.0
#
#                   number_of_non_http_only_cookies  number_of_secure_cookies  \
# domain
# h83.turdizi.com                               0.0                       0.0
# hbgv.wivela.com                               6.0                       0.0
# nus.edu.sg                                    3.0                       0.0
# arabwebpage.com                               3.0                       0.0
# moscatalogue.net                              4.0                       1.0
#
#                   number_of_unsecure_cookies  Malicious
# domain
# h83.turdizi.com                          0.0          1
# hbgv.wivela.com                          6.0          1
# nus.edu.sg                               4.0          0
# arabwebpage.com                          4.0          0
# moscatalogue.net                         4.0          0

# %%
js_cols=([col for col in df.columns if (('js' in col) or ('number' in col))])

dom_cols=([col for col in df.columns if 'dom' in col])

X=df[['dom_function_window.setTimeout(','dom_function_window.setInterval(','dom_function_document.createElement(',
     'dom_function_document.write(','dom_function_document.createComment(','dom_function_document.createElementNS(',
      'dom_function_window.addEventListener(','js_function_escape(','js_function_unescape(','js_function_eval(','js_function_.concat(','js_function_.charCodeAt(',
   'js_function_String.fromCharCode(','js_function_.split(','js_function_Number.parseInt(','js_function_.replace(',
   'js_function_.link(','js_function_.exec(','js_function_.search(','js_function_.substring(','number_of_unsecure_cookies',
 'number_of_secure_cookies',
 'number_of_non_http_only_cookies',
 'number_of_http_only_cookies',
 'number_of_cookies']]
y=df.Malicious.values
feature_name = X.columns.tolist()

# %% [markdown]
# ### <a id='1.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (43296, 25)

# %%
feature_name
# Out:
# ['dom_function_window.setTimeout(',
#  'dom_function_window.setInterval(',
#  'dom_function_document.createElement(',
#  'dom_function_document.write(',
#  'dom_function_document.createComment(',
#  'dom_function_document.createElementNS(',
#  'dom_function_window.addEventListener(',
#  'js_function_escape(',
#  'js_function_unescape(',
#  'js_function_eval(',
#  'js_function_.concat(',
#  'js_function_.charCodeAt(',
#  'js_function_String.fromCharCode(',
#  'js_function_.split(',
#  'js_function_Number.parseInt(',
#  'js_function_.replace(',
#  'js_function_.link(',
#  'js_function_.exec(',
#  'js_function_.search(',
#  'js_function_.substring(',
#  'number_of_unsecure_cookies',
#  'number_of_secure_cookies',
#  'number_of_non_http_only_cookies',
#  'number_of_http_only_cookies',
#  'number_of_cookies']

# %% [markdown]
# ### <a id='1.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=25))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.87126111559538
# Predicted  False  True  __all__
# Actual
# False      25772  3869    29641
# True         590  4405     4995
# __all__    26362  8274    34636
# The accuracy of the model on test data is: 0.8736720554272517
# Predicted  False  True  __all__
# Actual
# False       6437   931     7368
# True         163  1129     1292
# __all__     6600  2060     8660

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8584132116872618
# Predicted  False  True  __all__
# Actual
# False      29615    26    29641
# True        4878   117     4995
# __all__    34493   143    34636
# The accuracy of the model on test data is: 0.8527713625866051
# Predicted  False  True  __all__
# Actual
# False       7360     8     7368
# True        1267    25     1292
# __all__     8627    33     8660

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8556126573507333
# Predicted  False  True  __all__
# Actual
# False      29635     6    29641
# True        4995     0     4995
# __all__    34630     6    34636
# The accuracy of the model on test data is: 0.8504618937644342
# Predicted  False  True  __all__
# Actual
# False       7365     3     7368
# True        1292     0     1292
# __all__     8657     3     8660

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8743503868807022
# Predicted  False  True  __all__
# Actual
# False      25738  3903    29641
# True         449  4546     4995
# __all__    26187  8449    34636
# The accuracy of the model on test data is: 0.8763279445727483
# Predicted  False  True  __all__
# Actual
# False       6427   941     7368
# True         130  1162     1292
# __all__     6557  2103     8660

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8670747199445663
# Predicted  False  True  __all__
# Actual
# False      25685  3956    29641
# True         648  4347     4995
# __all__    26333  8303    34636
# The accuracy of the model on test data is: 0.869284064665127
# Predicted  False  True  __all__
# Actual
# False       6411   957     7368
# True         175  1117     1292
# __all__     6586  2074     8660

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8707702968010163
# Predicted  False  True  __all__
# Actual
# False      25774  3867    29641
# True         609  4386     4995
# __all__    26383  8253    34636
# The accuracy of the model on test data is: 0.872863741339492
# Predicted  False  True  __all__
# Actual
# False       6437   931     7368
# True         170  1122     1292
# __all__     6607  2053     8660

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8748123339877584
# Predicted  False  True  __all__
# Actual
# False      25743  3898    29641
# True         438  4557     4995
# __all__    26181  8455    34636
# The accuracy of the model on test data is: 0.8759815242494227
# Predicted  False  True  __all__
# Actual
# False       6423   945     7368
# True         129  1163     1292
# __all__     6552  2108     8660

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8742349001039381
# Predicted  False  True  __all__
# Actual
# False      25729  3912    29641
# True         444  4551     4995
# __all__    26173  8463    34636
# The accuracy of the model on test data is: 0.8745958429561201
# Predicted  False  True  __all__
# Actual
# False       6413   955     7368
# True         131  1161     1292
# __all__     6544  2116     8660

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8600588982561497
# Predicted  False  True  __all__
# Actual
# False      29579    62    29641
# True        4785   210     4995
# __all__    34364   272    34636
# The accuracy of the model on test data is: 0.8543879907621247
# Predicted  False  True  __all__
# Actual
# False       7353    15     7368
# True        1246    46     1292
# __all__     8599    61     8660

# %% [markdown]
# ### <a id='1.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP       TN      FP      FN  \
# index
# Neural Network-1            0.871261  4405.0  25772.0  3869.0   590.0
# KNeighborsClassifier        0.858413   117.0  29615.0    26.0  4878.0
# LogisticRegression          0.855613     0.0  29635.0     6.0  4995.0
# RandomForestClassifier      0.874350  4546.0  25738.0  3903.0   449.0
# AdaBoostClassifier          0.867075  4347.0  25685.0  3956.0   648.0
# GradientBoostingClassifier  0.870770  4386.0  25774.0  3867.0   609.0
# ExtraTreeClassifier         0.874812  4557.0  25743.0  3898.0   438.0
# BaggingClassifier           0.874235  4551.0  25729.0  3912.0   444.0
# VotingClassifier            0.860059   210.0  29579.0    62.0  4785.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.130529  0.118118
# KNeighborsClassifier        0.000877  0.976577
# LogisticRegression          0.000202  1.000000
# RandomForestClassifier      0.131676  0.089890
# AdaBoostClassifier          0.133464  0.129730
# GradientBoostingClassifier  0.130461  0.121922
# ExtraTreeClassifier         0.131507  0.087688
# BaggingClassifier           0.131979  0.088889
# VotingClassifier            0.002092  0.957958
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN     FP      FN       FPR  \
# index
# Neural Network-1            0.873672  1129.0  6437.0  931.0   163.0  0.126357
# KNeighborsClassifier        0.852771    25.0  7360.0    8.0  1267.0  0.001086
# LogisticRegression          0.850462     0.0  7365.0    3.0  1292.0  0.000407
# RandomForestClassifier      0.876328  1162.0  6427.0  941.0   130.0  0.127714
# AdaBoostClassifier          0.869284  1117.0  6411.0  957.0   175.0  0.129886
# GradientBoostingClassifier  0.872864  1122.0  6437.0  931.0   170.0  0.126357
# ExtraTreeClassifier         0.875982  1163.0  6423.0  945.0   129.0  0.128257
# BaggingClassifier           0.874596  1161.0  6413.0  955.0   131.0  0.129615
# VotingClassifier            0.854388    46.0  7353.0   15.0  1246.0  0.002036
#
#                                  FNR       auc
# index
# Neural Network-1            0.126161  0.873741
# KNeighborsClassifier        0.980650  0.509132
# LogisticRegression          1.000000  0.499796
# RandomForestClassifier      0.100619  0.885833
# AdaBoostClassifier          0.135449  0.867333
# GradientBoostingClassifier  0.131579  0.871032
# ExtraTreeClassifier         0.099845  0.885949
# BaggingClassifier           0.101393  0.884496
# VotingClassifier            0.964396  0.516784

# %% [markdown]
# ## <a id='2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a>
#
# #### <a id='2.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=18,random_state=0)
X_pca=pca.fit_transform(scaled_X)

print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_train.shape
# Out:
# 0.9280195657273445
# The train/test split ratio is 80:20
# (34636, 18)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=18))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8705104515464136
# Predicted  False  True  __all__
# Actual
# False      25772  3869    29641
# True         616  4379     4995
# __all__    26388  8248    34636
# The accuracy of the model on test data is: 0.8725173210161663
# Predicted  False  True  __all__
# Actual
# False       6436   932     7368
# True         172  1120     1292
# __all__     6608  2052     8660

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8714632174616006
# Predicted  False  True  __all__
# Actual
# False      25782  3859    29641
# True         593  4402     4995
# __all__    26375  8261    34636
# The accuracy of the model on test data is: 0.8745958429561201
# Predicted  False  True  __all__
# Actual
# False       6440   928     7368
# True         158  1134     1292
# __all__     6598  2062     8660

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8556415290449244
# Predicted  False  True  __all__
# Actual
# False      29636     5    29641
# True        4995     0     4995
# __all__    34631     5    34636
# The accuracy of the model on test data is: 0.8505773672055428
# Predicted  False  True  __all__
# Actual
# False       7366     2     7368
# True        1292     0     1292
# __all__     8658     2     8660

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8744370019632752
# Predicted  False  True  __all__
# Actual
# False      25738  3903    29641
# True         446  4549     4995
# __all__    26184  8452    34636
# The accuracy of the model on test data is: 0.8765588914549653
# Predicted  False  True  __all__
# Actual
# False       6428   940     7368
# True         129  1163     1292
# __all__     6557  2103     8660

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8693555837856566
# Predicted  False  True  __all__
# Actual
# False      25785  3856    29641
# True         669  4326     4995
# __all__    26454  8182    34636
# The accuracy of the model on test data is: 0.8725173210161663
# Predicted  False  True  __all__
# Actual
# False       6443   925     7368
# True         179  1113     1292
# __all__     6622  2038     8660

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8728779304769604
# Predicted  False  True  __all__
# Actual
# False      25759  3882    29641
# True         521  4474     4995
# __all__    26280  8356    34636
# The accuracy of the model on test data is: 0.8740184757505773
# Predicted  False  True  __all__
# Actual
# False       6424   944     7368
# True         147  1145     1292
# __all__     6571  2089     8660

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8748123339877584
# Predicted  False  True  __all__
# Actual
# False      25743  3898    29641
# True         438  4557     4995
# __all__    26181  8455    34636
# The accuracy of the model on test data is: 0.875866050808314
# Predicted  False  True  __all__
# Actual
# False       6422   946     7368
# True         129  1163     1292
# __all__     6551  2109     8660

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8742349001039381
# Predicted  False  True  __all__
# Actual
# False      25730  3911    29641
# True         445  4550     4995
# __all__    26175  8461    34636
# The accuracy of the model on test data is: 0.875635103926097
# Predicted  False  True  __all__
# Actual
# False       6423   945     7368
# True         132  1160     1292
# __all__     6555  2105     8660

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8735708511375447
# Predicted  False  True  __all__
# Actual
# False      25764  3877    29641
# True         502  4493     4995
# __all__    26266  8370    34636
# The accuracy of the model on test data is: 0.8755196304849885
# Predicted  False  True  __all__
# Actual
# False       6435   933     7368
# True         145  1147     1292
# __all__     6580  2080     8660

# %% [markdown]
# ### <a id='2.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP       TN      FP      FN  \
# index
# Neural Network-1            0.870510  4379.0  25772.0  3869.0   616.0
# KNeighborsClassifier        0.871463  4402.0  25782.0  3859.0   593.0
# LogisticRegression          0.855642     0.0  29636.0     5.0  4995.0
# RandomForestClassifier      0.874437  4549.0  25738.0  3903.0   446.0
# AdaBoostClassifier          0.869356  4326.0  25785.0  3856.0   669.0
# GradientBoostingClassifier  0.872878  4474.0  25759.0  3882.0   521.0
# ExtraTreeClassifier         0.874812  4557.0  25743.0  3898.0   438.0
# BaggingClassifier           0.874235  4550.0  25730.0  3911.0   445.0
# VotingClassifier            0.873571  4493.0  25764.0  3877.0   502.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.130529  0.123323
# KNeighborsClassifier        0.130191  0.118719
# LogisticRegression          0.000169  1.000000
# RandomForestClassifier      0.131676  0.089289
# AdaBoostClassifier          0.130090  0.133934
# GradientBoostingClassifier  0.130967  0.104304
# ExtraTreeClassifier         0.131507  0.087688
# BaggingClassifier           0.131946  0.089089
# VotingClassifier            0.130799  0.100501
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN     FP      FN       FPR  \
# index
# Neural Network-1            0.872517  1120.0  6436.0  932.0   172.0  0.126493
# KNeighborsClassifier        0.874596  1134.0  6440.0  928.0   158.0  0.125950
# LogisticRegression          0.850577     0.0  7366.0    2.0  1292.0  0.000271
# RandomForestClassifier      0.876559  1163.0  6428.0  940.0   129.0  0.127579
# AdaBoostClassifier          0.872517  1113.0  6443.0  925.0   179.0  0.125543
# GradientBoostingClassifier  0.874018  1145.0  6424.0  944.0   147.0  0.128122
# ExtraTreeClassifier         0.875866  1163.0  6422.0  946.0   129.0  0.128393
# BaggingClassifier           0.875635  1160.0  6423.0  945.0   132.0  0.128257
# VotingClassifier            0.875520  1147.0  6435.0  933.0   145.0  0.126629
#
#                                  FNR       auc
# index
# Neural Network-1            0.133127  0.870190
# KNeighborsClassifier        0.122291  0.875879
# LogisticRegression          1.000000  0.499864
# RandomForestClassifier      0.099845  0.886288
# AdaBoostClassifier          0.138545  0.867956
# GradientBoostingClassifier  0.113777  0.879051
# ExtraTreeClassifier         0.099845  0.885881
# BaggingClassifier           0.102167  0.884788
# VotingClassifier            0.112229  0.880571

# %% [markdown]
# ### <a id='2.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 1                               0.054980
# 5                               0.054746
# 4                               0.054174
# 16                              0.054118
# 6                               0.053654
# 11                              0.053061
# 0                               0.052497
# 14                              0.052356
# 2                               0.052031
# 12                              0.048887
# 9                               0.047409
# 3                               0.046919
# 18                              0.041592
# 17                              0.035287
# 19                              0.033169
# 21                              0.026012
# 8                               0.024693
# 7                               0.024432
# 23                              0.023191
# 13                              0.022265
# 10                              0.021666
# 20                              0.018639
# 22                              0.018516
# 24                              0.017645
# 15                              0.012505
#
#                                   Features
# 1         dom_function_window.setInterval(
# 5   dom_function_document.createElementNS(
# 4     dom_function_document.createComment(
# 16                      js_function_.link(
# 6    dom_function_window.addEventListener(
# 11                js_function_.charCodeAt(
# 0          dom_function_window.setTimeout(
# 14            js_function_Number.parseInt(
# 2     dom_function_document.createElement(
# 12        js_function_String.fromCharCode(
# 9                        js_function_eval(
# 3             dom_function_document.write(
# 18                    js_function_.search(
# 17                      js_function_.exec(
# 19                 js_function_.substring(
# 21                number_of_secure_cookies
# 8                    js_function_unescape(
# 7                      js_function_escape(
# 23             number_of_http_only_cookies
# 13                     js_function_.split(
# 10                    js_function_.concat(
# 20              number_of_unsecure_cookies
# 22         number_of_non_http_only_cookies
# 24                       number_of_cookies
# 15                   js_function_.replace(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, 25])
plt.xticks(np.arange(25),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %%
### Original Creator : Darshan Bhansali
### HTML code to hide the input cells 
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle code, click <a href="javascript:code_toggle()">here</a>.
