# %% [markdown]
# ***
# ## Table of Contents
# <br>
#     <ol>
#         <h2><a href='#1' style="text-decoration : none; color : #000000;">1. HTTP</a></h2>
#         <ul>
#             <a href='#1.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#1.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#1.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#1.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#1.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a></h2>
#         <ul><a href='#2.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#2.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#2.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>
#
# <br>
#     <ol>
#         <h2><a href='#3' style="text-decoration : none; color : #000000;">3. HTTPS</a></h2>
#         <ul>
#             <a href='#3.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#3.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#3.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#3.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#3.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a></h2>
#         <ul><a href='#4.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#4.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#4.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output,HTML
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from tabulate import tabulate

import keras
from keras.layers import Dense,Dropout
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)

from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split,cross_val_score

from sklearn.preprocessing import MinMaxScaler,StandardScaler,binarize
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE
from sklearn import metrics

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix,accuracy_score,auc,roc_curve,recall_score
from sklearn import metrics
from pandas_ml import ConfusionMatrix


from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
### Function get_params takes as input a grid search model and prints out the best parameters for the model and 
### prints the best accuracy of the model
def get_params(grid,model_name=''):
    print("Best Parameters are :")
    display(pd.DataFrame.from_dict(grid.best_params_, orient='index').reset_index().transpose())

### The function takes as input the model, X and Y data to generate the confusion matrix  
def get_cm(model,a,b):
    y_pred=model.predict(a)
    cm=ConfusionMatrix(b,y_pred)
    return cm
 
### The get accuracy plot takes as input a dataframe and a string for the title of the plot and displays a plot
### The function is primarily for plotting of accuracies for various classifiers for the same split.
def get_accuracy_plot(data,title=''):
    plt.figure(figsize=(12,8))
    plt.plot(data['accuracy'].values, '--o')
    plt.ylabel('Accuracy', fontsize=20)
    plt.xlabel('Classifier', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    plt.xlim([0, 9])
    plt.title(title,size=18,y=1.05)
    plt.xticks(np.arange(10),data.index.get_values(),rotation=90)
    plt.legend(loc='upper right', fontsize=18)
    plt.show()

### Function grid takes as input an estimator, X_train,Y_Train,X_test and Y_test and a string represetning the name of the model
### We perform StratifiedKFold cross validation and grid search to hypertune the parameters of the model     
def grid(kernel,params,x,y,x_test,y_test,model_name=''):
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    grid_search=GridSearchCV(estimator=kernel,param_grid=parameters,scoring='accuracy',cv=kfold,n_jobs=3,verbose=True)
    grid_search.fit(x,y)
    get_params(grid_search,model_name)
    acc_train=accuracy_score(y,grid_search.predict(x))
    print("Accuracy of the ",model_name," model for the training data is:",acc_train)
    print("\nConfusion Matrix for Training data is:")
    cm_train=get_cm(grid_search,x,y)
    display(cm_train)
    acc_test=accuracy_score(y_test,grid_search.predict(x_test))
    print("Accuracy of the ",model_name," model for test data is:",acc_test)
    print("\nConfusion Matrix for test data is:")
    cm_test=get_cm(grid_search,x_test,y_test)
    display(cm_test)
    fpr, tpr, threshold = roc_curve(y_test, grid_search.predict(x_test))
    roc_auc =auc(fpr, tpr)
    return grid_search,cm_train,cm_test,acc_train,acc_test,roc_auc  

### Plot roc curve
def get_roc_curve(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob[:,1]
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy on test data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

def get_roc_curve_deep_learning(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy of Logistic Model on training data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

# %% [markdown]
# ## <a id='1' style="text-decoration : none; color : #000000;"> HTTP</a>
#
# ### <a id='1.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_http.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)


# df.to_csv('Javascript_dom.csv')

df.head()

df_non=df[df.Malicious==0]
df_mal=df[df.Malicious==1]

df_non=df_non.sample(frac=len(df_mal)/len(df_non),random_state=0)
df_u=df_non.append(df_mal)
df_u.Malicious.value_counts() 
X=df_u.loc[:,df.columns!='Malicious']
y=df_u.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df_u.shape)
df_u.head()
# Out:
# Shape after undersampling (12574, 407)
#                         dom_function_document.adoptNode(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_document.captureEvents(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.caretPositionFromPoint(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.caretRangeFromPoint(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_document.clear(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_document.close(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     3.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_document.createAttribute(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createAttributeNS(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.createCDATASection(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_document.createComment(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.createDocumentFragment(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.createElement(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            3.0
# ruhrnachrichten.de                                       3.0
#
#                         dom_function_document.createElementNS(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createEntityReference(  \
# domain
# dns29parks.in                                                    0.0
# tournamentsoftware.com                                           0.0
# newsoku.blog                                                     0.0
# altsantiri.gr                                                    0.0
# ruhrnachrichten.de                                               0.0
#
#                         dom_function_document.createEvent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createNodeIterator(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_document.createProcessingInstruction(  \
# domain
# dns29parks.in                                                         0.0
# tournamentsoftware.com                                                0.0
# newsoku.blog                                                          0.0
# altsantiri.gr                                                         0.0
# ruhrnachrichten.de                                                    0.0
#
#                         dom_function_document.createRange(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createTextNode(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.createTouch(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createTouchList(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createTreeWalker(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.elementFromPoint(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.elementsFromPoint(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.enableStyleSheetsForSet(  \
# domain
# dns29parks.in                                                      0.0
# tournamentsoftware.com                                             0.0
# newsoku.blog                                                       0.0
# altsantiri.gr                                                      0.0
# ruhrnachrichten.de                                                 0.0
#
#                         dom_function_document.execCommand(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.exitPointerLock(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.getAnimations(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.getElementById(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              2.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.getElementByName(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.getElementsByClassName(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            3.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     1.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.getElementsByTagName(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   4.0
# ruhrnachrichten.de                                              3.0
#
#                         dom_function_document.getElementsByTagNameNS(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.getSelection(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_document.hasFocus(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_document.importNode(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_document.normalizeDocument(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.open(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    3.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_document.queryCommandEnabled(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_document.queryCommandIndeterm(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_document.queryCommandValue(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.querySelector(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.querySelectorAll(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.releaseCapture(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.releaseEvent(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_document.routeEvent(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_document.write(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     5.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               4.0
#
#                         dom_function_document.writeln(  \
# domain
# dns29parks.in                                      0.0
# tournamentsoftware.com                             0.0
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         dom_function_window.addEventListener(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             1.0
# ruhrnachrichten.de                                        1.0
#
#                         dom_function_window.alert(  dom_function_window.atob(  \
# domain
# dns29parks.in                                  0.0                        0.0
# tournamentsoftware.com                         0.0                        0.0
# newsoku.blog                                   0.0                        0.0
# altsantiri.gr                                  0.0                        0.0
# ruhrnachrichten.de                             0.0                        0.0
#
#                         dom_function_window.back(  dom_function_window.blur(  \
# domain
# dns29parks.in                                 0.0                        0.0
# tournamentsoftware.com                        0.0                        0.0
# newsoku.blog                                  0.0                        0.0
# altsantiri.gr                                 0.0                        0.0
# ruhrnachrichten.de                            0.0                        0.0
#
#                         dom_function_window.btoa(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.cancelAnimationFrame(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_window.cancelIdleCallback(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_window.captureEvents(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.clearImmediate(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_window.clearInterval(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.clearTimeout(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.close(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.confirm(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.createImageBitmap(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_window.disableExternalCapture(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_window.dispatchEvent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.dump(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.enableExternalCapture(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_window.fetch(  dom_function_window.find(  \
# domain
# dns29parks.in                                  0.0                        0.0
# tournamentsoftware.com                         0.0                        0.0
# newsoku.blog                                   0.0                        0.0
# altsantiri.gr                                  0.0                        0.0
# ruhrnachrichten.de                             0.0                        0.0
#
#                         dom_function_window.focus(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.forward(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.getAttention(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.getAttentionWithCycleCount(  \
# domain
# dns29parks.in                                                       0.0
# tournamentsoftware.com                                              0.0
# newsoku.blog                                                        0.0
# altsantiri.gr                                                       0.0
# ruhrnachrichten.de                                                  0.0
#
#                         dom_function_window.getComputedStyle(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_window.getDefaultComputedSyle(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_window.getSelection(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.home(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.matchMedia(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         dom_function_window.maximize(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.minimize(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.moveBy(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.moveTo(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.open(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            2.0
#
#                         dom_function_window.openDialog(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_window.postMessage(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_window.print(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.prompt(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.releaseEvents(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.removeEventListener(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_window.requestAnimationFrame(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_window.requestIdleCallback(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_window.resizeBy(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.resizeTo(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.restore(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.routeEvent(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_window.scroll(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.scrollBy(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.scrollByLines(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.scrollByPages(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.scrollTo(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.setCursor(  \
# domain
# dns29parks.in                                      0.0
# tournamentsoftware.com                             0.0
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         dom_function_window.setImmediate(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.setInterval(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_window.setResizable(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.setTimeout(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         dom_function_window.sizeToContent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.stop(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.updateCommands(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_.add(  js_function_.all(  \
# domain
# dns29parks.in                         0.0                0.0
# tournamentsoftware.com                2.0                0.0
# newsoku.blog                          1.0                0.0
# altsantiri.gr                         0.0                0.0
# ruhrnachrichten.de                    0.0                0.0
#
#                         js_function_.allTrue(  js_function_.anchor(  \
# domain
# dns29parks.in                             0.0                   0.0
# tournamentsoftware.com                    0.0                   0.0
# newsoku.blog                              0.0                   0.0
# altsantiri.gr                             0.0                   0.0
# ruhrnachrichten.de                        0.0                   0.0
#
#                         js_function_.apply(  js_function_.big(  \
# domain
# dns29parks.in                           0.0                0.0
# tournamentsoftware.com                  0.0                0.0
# newsoku.blog                            2.0                0.0
# ...
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         js_function_Reflect.defineProperty(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.deleteProperty(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.get(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         js_function_Reflect.getPrototypeOf(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.has(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.isExtensible(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_Reflect.ownKeys(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         js_function_Reflect.preventExtensions(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         js_function_Reflect.set(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.setPrototypeOf(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_String.fromCharCode(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_String.fromCodePoint(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_String.raw(  js_function_Symbol.for(  \
# domain
# dns29parks.in                               0.0                      0.0
# tournamentsoftware.com                      0.0                      0.0
# newsoku.blog                                0.0                      0.0
# altsantiri.gr                               0.0                      0.0
# ruhrnachrichten.de                          0.0                      0.0
#
#                         js_function_Symbol.keyFor(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         js_function_WebAssembly.compile(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.compileStreaming(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         js_function_WebAssembly.customerSections(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         js_function_WebAssembly.exports(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.imports(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.instantiate(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         js_function_WebAssembly.instantiateStreaming(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         js_function_WebAssembly.validate(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_decodeURI(  \
# domain
# dns29parks.in                              0.0
# tournamentsoftware.com                     0.0
# newsoku.blog                               0.0
# altsantiri.gr                              0.0
# ruhrnachrichten.de                         0.0
#
#                         js_function_decodeURIComponent(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         js_function_encodeURI(  \
# domain
# dns29parks.in                              0.0
# tournamentsoftware.com                     0.0
# newsoku.blog                               0.0
# altsantiri.gr                              0.0
# ruhrnachrichten.de                         0.0
#
#                         js_function_encodeURIComponent(  js_function_escape(  \
# domain
# dns29parks.in                                       0.0                  0.0
# tournamentsoftware.com                              0.0                  0.0
# newsoku.blog                                        0.0                  0.0
# altsantiri.gr                                       0.0                  0.0
# ruhrnachrichten.de                                  0.0                  0.0
#
#                         js_function_eval(  js_function_isFinite(  \
# domain
# dns29parks.in                         0.0                    0.0
# tournamentsoftware.com                0.0                    0.0
# newsoku.blog                          0.0                    0.0
# altsantiri.gr                         0.0                    0.0
# ruhrnachrichten.de                    0.0                    0.0
#
#                         js_function_isNaN(  js_function_parseFloat(  \
# domain
# dns29parks.in                          0.0                      0.0
# tournamentsoftware.com                 0.0                      0.0
# newsoku.blog                           0.0                      0.0
# altsantiri.gr                          0.0                      0.0
# ruhrnachrichten.de                     0.0                      0.0
#
#                         js_function_parseInt(  js_function_undefined(  \
# domain
# dns29parks.in                             0.0                     0.0
# tournamentsoftware.com                    0.0                     0.0
# newsoku.blog                              0.0                     0.0
# altsantiri.gr                             0.0                     0.0
# ruhrnachrichten.de                        0.0                     0.0
#
#                         js_function_unescape(  js_function_uneval(  \
# domain
# dns29parks.in                             0.0                  0.0
# tournamentsoftware.com                    0.0                  0.0
# newsoku.blog                              0.0                  0.0
# altsantiri.gr                             0.0                  0.0
# ruhrnachrichten.de                        0.0                  0.0
#
#                         number_functions_declared  number_of_cookies  \
# domain
# dns29parks.in                                 0.0                0.0
# tournamentsoftware.com                        0.0                2.0
# newsoku.blog                                  8.0               10.0
# altsantiri.gr                                16.0                4.0
# ruhrnachrichten.de                           14.0               21.0
#
#                         number_of_http_only_cookies  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          1.0
# newsoku.blog                                    1.0
# altsantiri.gr                                   1.0
# ruhrnachrichten.de                              2.0
#
#                         number_of_non_http_only_cookies  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              1.0
# newsoku.blog                                        9.0
# altsantiri.gr                                       3.0
# ruhrnachrichten.de                                 19.0
#
#                         number_of_secure_cookies  number_of_unsecure_cookies  \
# domain
# dns29parks.in                                0.0                         0.0
# tournamentsoftware.com                       0.0                         2.0
# newsoku.blog                                 0.0                        10.0
# altsantiri.gr                                1.0                         3.0
# ruhrnachrichten.de                           0.0                        21.0
#
#                         Malicious
# domain
# dns29parks.in                   0
# tournamentsoftware.com          0
# newsoku.blog                    0
# altsantiri.gr                   0
# ruhrnachrichten.de              0

# %% [markdown]
# ### <a id='1.B' style="text-decoration : none; color : #000000;">B. Feature Selection</a>
#
# <ol>
#     <ul><h4> 1. Correlation</h4></ul>
#     <ul><h4> 2. Chi2 </h4></ul>
#     <ul><h4> 3. Recursive Feature Elimination </h4></ul>
#     <ul><h4> 4. Select From Model </h4></ul>
# </ol>

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)


X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()


rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()


embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()


feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)

# %% [markdown]
# ### <a id='1.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
X=df_u[feature_selection_df[feature_selection_df.Total==4]['Feature']]
y=df_u.Malicious.values
feature_name = X.columns.tolist()

scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (12574, 67)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['number_of_unsecure_cookies',
#  'number_of_secure_cookies',
#  'number_of_non_http_only_cookies',
#  'number_of_http_only_cookies',
#  'number_of_cookies',
#  'js_function_unescape(',
#  'js_function_parseInt(',
#  'js_function_escape(',
#  'js_function_encodeURI(',
#  'js_function_decodeURIComponent(',
#  'js_function_String.fromCharCode(',
#  'js_function_Object.getOwnPropertyNames(',
#  'js_function_Math.round(',
#  'js_function_Math.random(',
#  'js_function_Math.min(',
#  'js_function_Math.max(',
#  'js_function_JSON.parse(',
#  'js_function_Date.now(',
#  'js_function_.trim(',
#  'js_function_.toString(',
#  'js_function_.toLowerCase(',
#  'js_function_.test(',
#  'js_function_.substring(',
#  'js_function_.substr',
#  'js_function_.split(',
#  'js_function_.splice(',
#  'js_function_.shift(',
#  'js_function_.setTime(',
#  'js_function_.search(',
#  'js_function_.reverse(',
#  'js_function_.replace(',
#  'js_function_.push(',
#  'js_function_.propertyIsEnumerable(',
#  'js_function_.min(',
#  'js_function_.match(',
#  'js_function_.keys(',
#  'js_function_.indexOf(',
#  'js_function_.hasOwnProperty(',
#  'js_function_.getYear(',
#  'js_function_.getUTCHours(',
#  'js_function_.getTime(',
#  'js_function_.getMonth(',
#  'js_function_.getMilliseconds(',
#  'js_function_.getHours(',
#  'js_function_.getFullYear(',
#  'js_function_.getDate(',
#  'js_function_.forEach(',
#  'js_function_.find(',
#  'js_function_.filter(',
#  'js_function_.concat(',
#  'js_function_.charAt(',
#  'js_function_.apply(',
#  'dom_function_window.setTimeout(',
#  'dom_function_window.setInterval(',
#  'dom_function_window.matchMedia(',
#  'dom_function_window.getSelection(',
#  'dom_function_window.getComputedStyle(',
#  'dom_function_window.addEventListener(',
#  'dom_function_document.querySelectorAll(',
#  'dom_function_document.open(',
#  'dom_function_document.getElementsByTagName(',
#  'dom_function_document.getElementsByClassName(',
#  'dom_function_document.getElementById(',
#  'dom_function_document.execCommand(',
#  'dom_function_document.createTextNode(',
#  'dom_function_document.createEvent(',
#  'dom_function_document.createElement(']

# %% [markdown]
# ### <a id='1.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8940252510486155
# Predicted  False  True  __all__
# Actual
# False       4281   775     5056
# True         291  4712     5003
# __all__     4572  5487    10059
# The accuracy of the model on test data is: 0.8922465208747515
# Predicted  False  True  __all__
# Actual
# False       1033   198     1231
# True          73  1211     1284
# __all__     1106  1409     2515

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8942240779401531
# Predicted  False  True  __all__
# Actual
# False       4309   747     5056
# True         317  4686     5003
# __all__     4626  5433    10059
# The accuracy of the model on test data is: 0.8858846918489066
# Predicted  False  True  __all__
# Actual
# False       1033   198     1231
# True          89  1195     1284
# __all__     1122  1393     2515

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8477979918480962
# Predicted  False  True  __all__
# Actual
# False       3911  1145     5056
# True         386  4617     5003
# __all__     4297  5762    10059
# The accuracy of the model on test data is: 0.8524850894632207
# Predicted  False  True  __all__
# Actual
# False        945   286     1231
# True          85  1199     1284
# __all__     1030  1485     2515

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9152997315836564
# Predicted  False  True  __all__
# Actual
# False       4353   703     5056
# True         149  4854     5003
# __all__     4502  5557    10059
# The accuracy of the model on test data is: 0.8982107355864811
# Predicted  False  True  __all__
# Actual
# False       1050   181     1231
# True          75  1209     1284
# __all__     1125  1390     2515

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8702654339397554
# Predicted  False  True  __all__
# Actual
# False       4334   722     5056
# True         583  4420     5003
# __all__     4917  5142    10059
# The accuracy of the model on test data is: 0.8675944333996024
# Predicted  False  True  __all__
# Actual
# False       1049   182     1231
# True         151  1133     1284
# __all__     1200  1315     2515

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8916393279650064
# Predicted  False  True  __all__
# Actual
# False       4337   719     5056
# True         371  4632     5003
# __all__     4708  5351    10059
# The accuracy of the model on test data is: 0.8894632206759443
# Predicted  False  True  __all__
# Actual
# False       1048   183     1231
# True          95  1189     1284
# __all__     1143  1372     2515

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9183815488617159
# Predicted  False  True  __all__
# Actual
# False       4360   696     5056
# True         125  4878     5003
# __all__     4485  5574    10059
# The accuracy of the model on test data is: 0.8970178926441352
# Predicted  False  True  __all__
# Actual
# False       1045   186     1231
# True          73  1211     1284
# __all__     1118  1397     2515

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9156973854259867
# Predicted  False  True  __all__
# Actual
# False       4358   698     5056
# True         150  4853     5003
# __all__     4508  5551    10059
# The accuracy of the model on test data is: 0.8922465208747515
# Predicted  False  True  __all__
# Actual
# False       1034   197     1231
# True          74  1210     1284
# __all__     1108  1407     2515

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.9115220200815191
# Predicted  False  True  __all__
# Actual
# False       4315   741     5056
# True         149  4854     5003
# __all__     4464  5595    10059
# The accuracy of the model on test data is: 0.8990059642147117
# Predicted  False  True  __all__
# Actual
# False       1038   193     1231
# True          61  1223     1284
# __all__     1099  1416     2515

# %% [markdown]
# ### <a id='1.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.894025  4712.0  4281.0   775.0  291.0  0.153283
# KNeighborsClassifier        0.894224  4686.0  4309.0   747.0  317.0  0.147745
# LogisticRegression          0.847798  4617.0  3911.0  1145.0  386.0  0.226464
# RandomForestClassifier      0.915300  4854.0  4353.0   703.0  149.0  0.139043
# AdaBoostClassifier          0.870265  4420.0  4334.0   722.0  583.0  0.142801
# GradientBoostingClassifier  0.891639  4632.0  4337.0   719.0  371.0  0.142207
# ExtraTreeClassifier         0.918382  4878.0  4360.0   696.0  125.0  0.137658
# BaggingClassifier           0.915697  4853.0  4358.0   698.0  150.0  0.138054
# VotingClassifier            0.911522  4854.0  4315.0   741.0  149.0  0.146559
#
#                                  FNR
# index
# Neural Network-1            0.058165
# KNeighborsClassifier        0.063362
# LogisticRegression          0.077154
# RandomForestClassifier      0.029782
# AdaBoostClassifier          0.116530
# GradientBoostingClassifier  0.074156
# ExtraTreeClassifier         0.024985
# BaggingClassifier           0.029982
# VotingClassifier            0.029782
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN     FP     FN       FPR  \
# index
# Neural Network-1            0.892247  1211.0  1033.0  198.0   73.0  0.160845
# KNeighborsClassifier        0.885885  1195.0  1033.0  198.0   89.0  0.160845
# LogisticRegression          0.852485  1199.0   945.0  286.0   85.0  0.232331
# RandomForestClassifier      0.898211  1209.0  1050.0  181.0   75.0  0.147035
# AdaBoostClassifier          0.867594  1133.0  1049.0  182.0  151.0  0.147847
# GradientBoostingClassifier  0.889463  1189.0  1048.0  183.0   95.0  0.148660
# ExtraTreeClassifier         0.897018  1211.0  1045.0  186.0   73.0  0.151097
# BaggingClassifier           0.892247  1210.0  1034.0  197.0   74.0  0.160032
# VotingClassifier            0.899006  1223.0  1038.0  193.0   61.0  0.156783
#
#                                  FNR       auc
# index
# Neural Network-1            0.056854  0.891151
# KNeighborsClassifier        0.069315  0.884920
# LogisticRegression          0.066199  0.850735
# RandomForestClassifier      0.058411  0.897277
# AdaBoostClassifier          0.117601  0.867276
# GradientBoostingClassifier  0.073988  0.888676
# ExtraTreeClassifier         0.056854  0.896025
# BaggingClassifier           0.057632  0.891168
# VotingClassifier            0.047508  0.897855

# %% [markdown]
# ## <a id='2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a>
#
# #### <a id='2.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=48,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_pca.shape
# Out:
# 0.9419149025048699
# The train/test split ratio is 80:20
# (12574, 48)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_pca.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8983000298536657
# Predicted  False  True  __all__
# Actual
# False       4278   778     5056
# True         245  4758     5003
# __all__     4523  5536    10059
# The accuracy of the model on test data is: 0.8950298210735587
# Predicted  False  True  __all__
# Actual
# False       1033   198     1231
# True          66  1218     1284
# __all__     1099  1416     2515

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8951187990853962
# Predicted  False  True  __all__
# Actual
# False       4380   676     5056
# True         379  4624     5003
# __all__     4759  5300    10059
# The accuracy of the model on test data is: 0.88389662027833
# Predicted  False  True  __all__
# Actual
# False       1050   181     1231
# True         111  1173     1284
# __all__     1161  1354     2515

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8480962322298439
# Predicted  False  True  __all__
# Actual
# False       3909  1147     5056
# True         381  4622     5003
# __all__     4290  5769    10059
# The accuracy of the model on test data is: 0.8508946322067594
# Predicted  False  True  __all__
# Actual
# False        941   290     1231
# True          85  1199     1284
# __all__     1026  1489     2515

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9150014912019088
# Predicted  False  True  __all__
# Actual
# False       4356   700     5056
# True         155  4848     5003
# __all__     4511  5548    10059
# The accuracy of the model on test data is: 0.8986083499005965
# Predicted  False  True  __all__
# Actual
# False       1056   175     1231
# True          80  1204     1284
# __all__     1136  1379     2515

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8874639626205388
# Predicted  False  True  __all__
# Actual
# False       4293   763     5056
# True         369  4634     5003
# __all__     4662  5397    10059
# The accuracy of the model on test data is: 0.8934393638170974
# Predicted  False  True  __all__
# Actual
# False       1043   188     1231
# True          80  1204     1284
# __all__     1123  1392     2515

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8992941644298638
# Predicted  False  True  __all__
# Actual
# False       4364   692     5056
# True         321  4682     5003
# __all__     4685  5374    10059
# The accuracy of the model on test data is: 0.8950298210735587
# Predicted  False  True  __all__
# Actual
# False       1054   177     1231
# True          87  1197     1284
# __all__     1141  1374     2515

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9183815488617159
# Predicted  False  True  __all__
# Actual
# False       4360   696     5056
# True         125  4878     5003
# __all__     4485  5574    10059
# The accuracy of the model on test data is: 0.8998011928429424
# Predicted  False  True  __all__
# Actual
# False       1052   179     1231
# True          73  1211     1284
# __all__     1125  1390     2515

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.915399145044239
# Predicted  False  True  __all__
# Actual
# False       4358   698     5056
# True         153  4850     5003
# __all__     4511  5548    10059
# The accuracy of the model on test data is: 0.8990059642147117
# Predicted  False  True  __all__
# Actual
# False       1055   176     1231
# True          78  1206     1284
# __all__     1133  1382     2515

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.9115220200815191
# Predicted  False  True  __all__
# Actual
# False       4318   738     5056
# True         152  4851     5003
# __all__     4470  5589    10059
# The accuracy of the model on test data is: 0.9001988071570577
# Predicted  False  True  __all__
# Actual
# False       1043   188     1231
# True          63  1221     1284
# __all__     1106  1409     2515

# %% [markdown]
# ### <a id='2.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.898300  4758.0  4278.0   778.0  245.0  0.153877
# KNeighborsClassifier        0.895119  4624.0  4380.0   676.0  379.0  0.133703
# LogisticRegression          0.848096  4622.0  3909.0  1147.0  381.0  0.226859
# RandomForestClassifier      0.915001  4848.0  4356.0   700.0  155.0  0.138449
# AdaBoostClassifier          0.887464  4634.0  4293.0   763.0  369.0  0.150910
# GradientBoostingClassifier  0.899294  4682.0  4364.0   692.0  321.0  0.136867
# ExtraTreeClassifier         0.918382  4878.0  4360.0   696.0  125.0  0.137658
# BaggingClassifier           0.915399  4850.0  4358.0   698.0  153.0  0.138054
# VotingClassifier            0.911522  4851.0  4318.0   738.0  152.0  0.145965
#
#                                  FNR
# index
# Neural Network-1            0.048971
# KNeighborsClassifier        0.075755
# LogisticRegression          0.076154
# RandomForestClassifier      0.030981
# AdaBoostClassifier          0.073756
# GradientBoostingClassifier  0.064162
# ExtraTreeClassifier         0.024985
# BaggingClassifier           0.030582
# VotingClassifier            0.030382
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN     FP     FN       FPR  \
# index
# Neural Network-1            0.895030  1218.0  1033.0  198.0   66.0  0.160845
# KNeighborsClassifier        0.883897  1173.0  1050.0  181.0  111.0  0.147035
# LogisticRegression          0.850895  1199.0   941.0  290.0   85.0  0.235581
# RandomForestClassifier      0.898608  1204.0  1056.0  175.0   80.0  0.142161
# AdaBoostClassifier          0.893439  1204.0  1043.0  188.0   80.0  0.152721
# GradientBoostingClassifier  0.895030  1197.0  1054.0  177.0   87.0  0.143786
# ExtraTreeClassifier         0.899801  1211.0  1052.0  179.0   73.0  0.145410
# BaggingClassifier           0.899006  1206.0  1055.0  176.0   78.0  0.142973
# VotingClassifier            0.900199  1221.0  1043.0  188.0   63.0  0.152721
#
#                                  FNR       auc
# index
# Neural Network-1            0.051402  0.893877
# KNeighborsClassifier        0.086449  0.883258
# LogisticRegression          0.066199  0.849110
# RandomForestClassifier      0.062305  0.897767
# AdaBoostClassifier          0.062305  0.892487
# GradientBoostingClassifier  0.067757  0.894229
# ExtraTreeClassifier         0.056854  0.898868
# BaggingClassifier           0.060748  0.898140
# VotingClassifier            0.049065  0.899107

# %% [markdown]
# ### <a id='2.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 8                               0.020661
# 63                              0.020522
# 16                              0.020487
# 39                              0.020455
# 6                               0.020443
# 62                              0.020376
# 53                              0.020311
# 52                              0.020255
# 42                              0.020218
# 11                              0.020190
# 17                              0.020169
# 55                              0.020138
# 28                              0.020094
# 47                              0.020024
# 59                              0.020011
# 54                              0.019929
# 32                              0.019819
# 58                              0.019665
# 19                              0.019626
# 36                              0.019622
# 56                              0.019589
# 38                              0.019479
# 13                              0.019350
# 45                              0.019339
# 61                              0.019176
# 57                              0.019130
# 29                              0.018680
# 18                              0.018546
# 9                               0.018377
# 64                              0.018032
# 65                              0.017747
# 10                              0.017712
# 43                              0.017079
# 12                              0.016889
# 31                              0.016206
# 27                              0.015828
# 60                              0.013700
# 5                               0.013596
# 1                               0.013101
# 20                              0.012663
# 3                               0.011630
# 44                              0.011563
# 34                              0.011209
# 37                              0.011028
# 33                              0.010112
# 66                              0.009914
# 22                              0.009892
# 35                              0.009872
# 7                               0.009592
# 41                              0.009538
# 15                              0.009393
# 51                              0.009307
# 14                              0.009140
# 50                              0.008702
# 48                              0.008650
# 26                              0.008522
# 49                              0.008409
# 23                              0.008141
# 21                              0.007624
# 40                              0.007598
# 0                               0.007126
# 2                               0.007049
# 46                              0.006612
# 4                               0.006454
# 30                              0.005575
# 25                              0.004994
# 24                              0.004283
#
#                                          Features
# 8                          js_function_encodeURI(
# 63             dom_function_document.execCommand(
# 16                        js_function_JSON.parse(
# 39                      js_function_.getUTCHours(
# 6                           js_function_parseInt(
# 62          dom_function_document.getElementById(
# 53               dom_function_window.setInterval(
# 52                dom_function_window.setTimeout(
# 42                  js_function_.getMilliseconds(
# 11        js_function_Object.getOwnPropertyNames(
# 17                          js_function_Date.now(
# 55              dom_function_window.getSelection(
# 28                           js_function_.search(
# 47                             js_function_.find(
# 59                    dom_function_document.open(
# 54                dom_function_window.matchMedia(
# 32             js_function_.propertyIsEnumerable(
# 58        dom_function_document.querySelectorAll(
# 19                         js_function_.toString(
# 36                          js_function_.indexOf(
# 56          dom_function_window.getComputedStyle(
# 38                          js_function_.getYear(
# 13                       js_function_Math.random(
# 45                          js_function_.getDate(
# 61  dom_function_document.getElementsByClassName(
# 57          dom_function_window.addEventListener(
# 29                          js_function_.reverse(
# 18                             js_function_.trim(
# 9                 js_function_decodeURIComponent(
# 64          dom_function_document.createTextNode(
# 65             dom_function_document.createEvent(
# 10               js_function_String.fromCharCode(
# 43                         js_function_.getHours(
# 12                        js_function_Math.round(
# 31                             js_function_.push(
# 27                          js_function_.setTime(
# 60    dom_function_document.getElementsByTagName(
# 5                           js_function_unescape(
# 1                        number_of_secure_cookies
# 20                      js_function_.toLowerCase(
# 3                     number_of_http_only_cookies
# 44                      js_function_.getFullYear(
# 34                            js_function_.match(
# 37                   js_function_.hasOwnProperty(
# 33                              js_function_.min(
# 66           dom_function_document.createElement(
# 22                        js_function_.substring(
# 35                             js_function_.keys(
# 7                             js_function_escape(
# 41                         js_function_.getMonth(
# 15                          js_function_Math.max(
# 51                            js_function_.apply(
# 14                          js_function_Math.min(
# 50                           js_function_.charAt(
# 48                           js_function_.filter(
# 26                            js_function_.shift(
# 49                           js_function_.concat(
# 23                            js_function_.substr
# 21                             js_function_.test(
# 40                          js_function_.getTime(
# 0                      number_of_unsecure_cookies
# 2                 number_of_non_http_only_cookies
# 46                          js_function_.forEach(
# 4                               number_of_cookies
# 30                          js_function_.replace(
# 25                           js_function_.splice(
# 24                            js_function_.split(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## <a id='3' style="text-decoration : none; color : #000000;"> HTTPS</a>
#
# ### <a id='3.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_https.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_https.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

df_non=df[df.Malicious==0]
df_mal=df[df.Malicious==1]

df_non=df_non.sample(frac=len(df_mal)/len(df_non),random_state=0)
df_u=df_non.append(df_mal)
df_u.Malicious.value_counts() 
X=df_u.loc[:,df.columns!='Malicious']
y=df_u.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df_u.shape)
df_u.head()
# Out:
# Shape after undersampling (12714, 407)
#                  dom_function_document.adoptNode(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  dom_function_document.captureEvents(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.caretPositionFromPoint(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.caretRangeFromPoint(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_document.clear(  dom_function_document.close(  \
# domain
# spellingbee.com                           0.0                           0.0
# hd-streams.org                            0.0                           0.0
# ebay.at                                   0.0                           0.0
# drhmonegyi.net                            0.0                           0.0
# dhc.co.jp                                 0.0                           0.0
#
#                  dom_function_document.createAttribute(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createAttributeNS(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.createCDATASection(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_document.createComment(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.createDocumentFragment(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.createElement(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    1.0
# ebay.at                                           5.0
# drhmonegyi.net                                    1.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.createElementNS(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createEntityReference(  \
# domain
# spellingbee.com                                           0.0
# hd-streams.org                                            0.0
# ebay.at                                                   0.0
# drhmonegyi.net                                            0.0
# dhc.co.jp                                                 0.0
#
#                  dom_function_document.createEvent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         8.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createNodeIterator(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_document.createProcessingInstruction(  \
# domain
# spellingbee.com                                                0.0
# hd-streams.org                                                 0.0
# ebay.at                                                        0.0
# drhmonegyi.net                                                 0.0
# dhc.co.jp                                                      0.0
#
#                  dom_function_document.createRange(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createTextNode(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.createTouch(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createTouchList(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createTreeWalker(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.elementFromPoint(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.elementsFromPoint(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.enableStyleSheetsForSet(  \
# domain
# spellingbee.com                                             0.0
# hd-streams.org                                              0.0
# ebay.at                                                     0.0
# drhmonegyi.net                                              0.0
# dhc.co.jp                                                   0.0
#
#                  dom_function_document.execCommand(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         2.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.exitPointerLock(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.getAnimations(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.getElementById(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     3.0
# ebay.at                                            4.0
# drhmonegyi.net                                     3.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.getElementByName(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.getElementsByClassName(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    1.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.getElementsByTagName(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           2.0
# dhc.co.jp                                                0.0
#
#                  dom_function_document.getElementsByTagNameNS(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.getSelection(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_document.hasFocus(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      0.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_document.importNode(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_document.normalizeDocument(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.open(  \
# domain
# spellingbee.com                          0.0
# hd-streams.org                           0.0
# ebay.at                                  0.0
# drhmonegyi.net                           0.0
# dhc.co.jp                                0.0
#
#                  dom_function_document.queryCommandEnabled(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_document.queryCommandIndeterm(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_document.queryCommandValue(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.querySelector(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           6.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.querySelectorAll(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.releaseCapture(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.releaseEvent(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_document.routeEvent(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_document.write(  dom_function_document.writeln(  \
# domain
# spellingbee.com                           0.0                             0.0
# hd-streams.org                            0.0                             0.0
# ebay.at                                   0.0                             0.0
# drhmonegyi.net                            0.0                             0.0
# dhc.co.jp                                 0.0                             0.0
#
#                  dom_function_window.addEventListener(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            3.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_window.alert(  dom_function_window.atob(  \
# domain
# spellingbee.com                         0.0                        0.0
# hd-streams.org                          0.0                        0.0
# ebay.at                                 0.0                        0.0
# drhmonegyi.net                          0.0                        0.0
# dhc.co.jp                               0.0                        0.0
#
#                  dom_function_window.back(  dom_function_window.blur(  \
# domain
# spellingbee.com                        0.0                        0.0
# hd-streams.org                         0.0                        0.0
# ebay.at                                0.0                        0.0
# drhmonegyi.net                         0.0                        0.0
# dhc.co.jp                              0.0                        0.0
#
#                  dom_function_window.btoa(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.cancelAnimationFrame(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_window.cancelIdleCallback(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_window.captureEvents(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.clearImmediate(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_window.clearInterval(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.clearTimeout(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.close(  dom_function_window.confirm(  \
# domain
# spellingbee.com                         0.0                           0.0
# hd-streams.org                          0.0                           0.0
# ebay.at                                 0.0                           0.0
# drhmonegyi.net                          0.0                           0.0
# dhc.co.jp                               0.0                           0.0
#
#                  dom_function_window.createImageBitmap(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_window.disableExternalCapture(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_window.dispatchEvent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.dump(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.enableExternalCapture(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_window.fetch(  dom_function_window.find(  \
# domain
# spellingbee.com                         0.0                        0.0
# hd-streams.org                          0.0                        0.0
# ebay.at                                 0.0                        0.0
# drhmonegyi.net                          0.0                        0.0
# dhc.co.jp                               0.0                        0.0
#
#                  dom_function_window.focus(  dom_function_window.forward(  \
# domain
# spellingbee.com                         0.0                           0.0
# hd-streams.org                          0.0                           0.0
# ebay.at                                 0.0                           0.0
# drhmonegyi.net                          0.0                           0.0
# dhc.co.jp                               0.0                           0.0
#
#                  dom_function_window.getAttention(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.getAttentionWithCycleCount(  \
# domain
# spellingbee.com                                              0.0
# hd-streams.org                                               0.0
# ebay.at                                                      0.0
# drhmonegyi.net                                               0.0
# dhc.co.jp                                                    0.0
#
#                  dom_function_window.getComputedStyle(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            2.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_window.getDefaultComputedSyle(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_window.getSelection(  dom_function_window.home(  \
# domain
# spellingbee.com                                0.0                        0.0
# hd-streams.org                                 0.0                        0.0
# ebay.at                                        0.0                        0.0
# drhmonegyi.net                                 0.0                        0.0
# dhc.co.jp                                      0.0                        0.0
#
#                  dom_function_window.matchMedia(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      0.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_window.maximize(  dom_function_window.minimize(  \
# domain
# spellingbee.com                            0.0                            0.0
# hd-streams.org                             0.0                            0.0
# ebay.at                                    0.0                            0.0
# drhmonegyi.net                             0.0                            0.0
# dhc.co.jp                                  0.0                            0.0
#
#                  dom_function_window.moveBy(  dom_function_window.moveTo(  \
# domain
# spellingbee.com                          0.0                          0.0
# hd-streams.org                           0.0                          0.0
# ebay.at                                  0.0                          0.0
# drhmonegyi.net                           0.0                          0.0
# dhc.co.jp                                0.0                          0.0
#
#                  dom_function_window.open(  dom_function_window.openDialog(  \
# domain
# spellingbee.com                        0.0                              0.0
# hd-streams.org                         0.0                              0.0
# ebay.at                                0.0                              0.0
# drhmonegyi.net                         0.0                              0.0
# dhc.co.jp                              0.0                              0.0
#
#                  dom_function_window.postMessage(  dom_function_window.print(  \
# domain
# spellingbee.com                               0.0                         0.0
# hd-streams.org                                0.0                         0.0
# ebay.at                                       0.0                         0.0
# drhmonegyi.net                                0.0                         0.0
# dhc.co.jp                                     0.0                         0.0
#
#                  dom_function_window.prompt(  \
# domain
# spellingbee.com                          0.0
# hd-streams.org                           0.0
# ebay.at                                  0.0
# drhmonegyi.net                           0.0
# dhc.co.jp                                0.0
#
#                  dom_function_window.releaseEvents(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.removeEventListener(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               2.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_window.requestAnimationFrame(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_window.requestIdleCallback(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_window.resizeBy(  dom_function_window.resizeTo(  \
# domain
# spellingbee.com                            0.0                            0.0
# hd-streams.org                             0.0                            0.0
# ebay.at                                    0.0                            0.0
# drhmonegyi.net                             0.0                            0.0
# dhc.co.jp                                  0.0                            0.0
#
#                  dom_function_window.restore(  \
# domain
# spellingbee.com                           0.0
# hd-streams.org                            0.0
# ebay.at                                   0.0
# drhmonegyi.net                            0.0
# dhc.co.jp                                 0.0
#
#                  dom_function_window.routeEvent(  dom_function_window.scroll(  \
# domain
# spellingbee.com                              0.0                          0.0
# hd-streams.org                               0.0                          0.0
# ebay.at                                      0.0                          0.0
# drhmonegyi.net                               0.0                          0.0
# dhc.co.jp                                    0.0                          0.0
#
#                  dom_function_window.scrollBy(  \
# domain
# spellingbee.com                            0.0
# hd-streams.org                             0.0
# ebay.at                                    0.0
# drhmonegyi.net                             0.0
# dhc.co.jp                                  0.0
#
#                  dom_function_window.scrollByLines(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.scrollByPages(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.scrollTo(  \
# domain
# spellingbee.com                            0.0
# hd-streams.org                             0.0
# ebay.at                                    0.0
# drhmonegyi.net                             0.0
# dhc.co.jp                                  0.0
#
#                  dom_function_window.setCursor(  \
# domain
# spellingbee.com                             0.0
# hd-streams.org                              0.0
# ebay.at                                     0.0
# drhmonegyi.net                              0.0
# dhc.co.jp                                   0.0
#
#                  dom_function_window.setImmediate(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.setInterval(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  dom_function_window.setResizable(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.setTimeout(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      2.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_window.sizeToContent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.stop(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.updateCommands(  js_function_.add(  \
# domain
# spellingbee.com                                  0.0                0.0
# hd-streams.org                                   0.0                0.0
# ebay.at                                          0.0                7.0
# drhmonegyi.net                                   0.0                0.0
# dhc.co.jp                                        0.0                0.0
#
#                  js_function_.all(  js_function_.allTrue(  \
# domain
# spellingbee.com                0.0                    0.0
# hd-streams.org                 0.0                    0.0
# ebay.at                        0.0                    0.0
# drhmonegyi.net                 0.0                    0.0
# dhc.co.jp                      0.0                    0.0
#
#                  js_function_.anchor(  js_function_.apply(  js_function_.big(  \
# domain
# spellingbee.com                   0.0                  1.0                0.0
# hd-streams.org                    0.0                  0.0                0.0
# ebay.at                           0.0                 17.0                0.0
# drhmonegyi.net                    0.0                  2.0                0.0
# dhc.co.jp                         0.0                  0.0                0.0
#
#                  js_function_.bind(  js_function_.blink(  js_function_.bold(  \
# domain
# spellingbee.com                 0.0                  0.0                 0.0
# hd-streams.org                  0.0                  0.0                 0.0
# ebay.at                         6.0                  0.0                 0.0
# drhmonegyi.net                  0.0                  0.0                 0.0
# dhc.co.jp                       0.0                  0.0                 0.0
#
#                  js_function_.call(  js_function_.catch(  \
# domain
# spellingbee.com                 0.0                  0.0
# hd-streams.org                  0.0                  0.0
# ebay.at                        39.0                  0.0
# drhmonegyi.net                  0.0                  0.0
# dhc.co.jp                       0.0                  0.0
#
#                  js_function_.charAt(  js_function_.charCodeAt(  \
# domain
# spellingbee.com                   0.0                       0.0
# hd-streams.org                    0.0                       0.0
# ebay.at                          15.0                       0.0
# drhmonegyi.net                    0.0                       0.0
# dhc.co.jp                         0.0                       0.0
#
#                  js_function_.clear(  js_function_.codePointAt(  \
# domain
# spellingbee.com                  0.0                        0.0
# hd-streams.org                   0.0                        0.0
# ebay.at                          0.0                        0.0
# drhmonegyi.net                   0.0                        0.0
# dhc.co.jp                        0.0                        0.0
#
#                  js_function_.compile(  js_function_.concat(  \
# domain
# spellingbee.com                    0.0                   0.0
# hd-streams.org                     0.0                   0.0
# ebay.at                            0.0                  21.0
# drhmonegyi.net                     0.0                   0.0
# dhc.co.jp                          0.0                   0.0
#
#                  js_function_.construct(  js_function_.copyWithin(  \
# domain
# spellingbee.com                      0.0                       0.0
# hd-streams.org                       0.0                       0.0
# ebay.at                              0.0                       0.0
# drhmonegyi.net                       0.0                       0.0
# dhc.co.jp                            0.0                       0.0
#
#                  js_function_.defineProperty(  js_function_.delete(  \
# domain
# spellingbee.com                           0.0                   0.0
# hd-streams.org                            0.0                   0.0
# ebay.at                                  10.0                   0.0
# drhmonegyi.net                            0.0                   0.0
# dhc.co.jp                                 0.0                   0.0
#
#                  js_function_.deleteProperty(  js_function_.endWith(  \
# domain
# spellingbee.com                           0.0                    0.0
# hd-streams.org                            0.0                    0.0
# ebay.at                                   0.0                    0.0
# drhmonegyi.net                            0.0                    0.0
# dhc.co.jp                                 0.0                    0.0
#
#                  js_function_.entries(  js_function_.every(  \
# domain
# spellingbee.com                    0.0                  0.0
# hd-streams.org                     0.0                  0.0
# ebay.at                            2.0                  0.0
# drhmonegyi.net                     0.0                  0.0
# dhc.co.jp                          0.0                  0.0
#
#                  js_function_.exec(  js_function_.fill(  js_function_.filter(  \
# domain
# spellingbee.com                 0.0                 0.0                   0.0
# hd-streams.org                  0.0                 0.0                   0.0
# ebay.at                         0.0                 0.0                  16.0
# drhmonegyi.net                  0.0                 0.0                   0.0
# dhc.co.jp                       0.0                 0.0                   0.0
#
#                  js_function_.finally(  js_function_.find(  \
# domain
# spellingbee.com                    0.0                 0.0
# hd-streams.org                     0.0                 0.0
# ebay.at                            0.0                 3.0
# drhmonegyi.net                     0.0                 0.0
# dhc.co.jp                          0.0                 0.0
#
#                  js_function_.findIndex(  js_function_.fixed(  \
# domain
# spellingbee.com                      0.0                  0.0
# hd-streams.org                       0.0                  0.0
# ebay.at                              0.0                  0.0
# drhmonegyi.net                       0.0                  0.0
# dhc.co.jp                            0.0                  0.0
#
#                  js_function_.flat(  js_function_.flatMap(  \
# domain
# spellingbee.com                 0.0                    0.0
# hd-streams.org                  0.0                    0.0
# ebay.at                         0.0                    0.0
# drhmonegyi.net                  0.0                    0.0
# dhc.co.jp                       0.0                    0.0
#
#                  js_function_.fontcolor(  js_function_.fontsize(  \
# domain
# spellingbee.com                      0.0                     0.0
# hd-streams.org                       0.0                     0.0
# ebay.at                              0.0                     0.0
# drhmonegyi.net                       0.0                     0.0
# dhc.co.jp                            0.0                     0.0
#
#                  js_function_.forEach(  js_function_.formatToParts(  \
# ...
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  js_function_Object.seal(  js_function_Object.setPrototypeOf(  \
# domain
# spellingbee.com                       0.0                                 0.0
# hd-streams.org                        0.0                                 0.0
# ebay.at                               2.0                                 0.0
# drhmonegyi.net                        0.0                                 0.0
# dhc.co.jp                             0.0                                 0.0
#
#                  js_function_Promise.all(  js_function_Promise.race(  \
# domain
# spellingbee.com                       0.0                        0.0
# hd-streams.org                        0.0                        0.0
# ebay.at                               0.0                        0.0
# drhmonegyi.net                        0.0                        0.0
# dhc.co.jp                             0.0                        0.0
#
#                  js_function_Promise.reject(  js_function_Promise.resolve(  \
# domain
# spellingbee.com                          0.0                           0.0
# hd-streams.org                           0.0                           0.0
# ebay.at                                  0.0                           0.0
# drhmonegyi.net                           0.0                           0.0
# dhc.co.jp                                0.0                           0.0
#
#                  js_function_Proxy.revocable(  js_function_Reflect.apply(  \
# domain
# spellingbee.com                           0.0                         0.0
# hd-streams.org                            0.0                         0.0
# ebay.at                                   0.0                         0.0
# drhmonegyi.net                            0.0                         0.0
# dhc.co.jp                                 0.0                         0.0
#
#                  js_function_Reflect.construct(  \
# domain
# spellingbee.com                             0.0
# hd-streams.org                              0.0
# ebay.at                                     0.0
# drhmonegyi.net                              0.0
# dhc.co.jp                                   0.0
#
#                  js_function_Reflect.defineProperty(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.deleteProperty(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.get(  \
# domain
# spellingbee.com                       0.0
# hd-streams.org                        0.0
# ebay.at                               0.0
# drhmonegyi.net                        0.0
# dhc.co.jp                             0.0
#
#                  js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  js_function_Reflect.getPrototypeOf(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.has(  js_function_Reflect.isExtensible(  \
# domain
# spellingbee.com                       0.0                                0.0
# hd-streams.org                        0.0                                0.0
# ebay.at                               0.0                                0.0
# drhmonegyi.net                        0.0                                0.0
# dhc.co.jp                             0.0                                0.0
#
#                  js_function_Reflect.ownKeys(  \
# domain
# spellingbee.com                           0.0
# hd-streams.org                            0.0
# ebay.at                                   0.0
# drhmonegyi.net                            0.0
# dhc.co.jp                                 0.0
#
#                  js_function_Reflect.preventExtensions(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  js_function_Reflect.set(  \
# domain
# spellingbee.com                       0.0
# hd-streams.org                        0.0
# ebay.at                               0.0
# drhmonegyi.net                        0.0
# dhc.co.jp                             0.0
#
#                  js_function_Reflect.setPrototypeOf(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_String.fromCharCode(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_String.fromCodePoint(  js_function_String.raw(  \
# domain
# spellingbee.com                                0.0                      0.0
# hd-streams.org                                 0.0                      0.0
# ebay.at                                        0.0                      0.0
# drhmonegyi.net                                 0.0                      0.0
# dhc.co.jp                                      0.0                      0.0
#
#                  js_function_Symbol.for(  js_function_Symbol.keyFor(  \
# domain
# spellingbee.com                      0.0                         0.0
# hd-streams.org                       0.0                         0.0
# ebay.at                              0.0                         0.0
# drhmonegyi.net                       0.0                         0.0
# dhc.co.jp                            0.0                         0.0
#
#                  js_function_WebAssembly.compile(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.compileStreaming(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  js_function_WebAssembly.customerSections(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  js_function_WebAssembly.exports(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.imports(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.instantiate(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  js_function_WebAssembly.instantiateStreaming(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  js_function_WebAssembly.validate(  js_function_decodeURI(  \
# domain
# spellingbee.com                                0.0                     0.0
# hd-streams.org                                 0.0                     0.0
# ebay.at                                        0.0                     0.0
# drhmonegyi.net                                 0.0                     0.0
# dhc.co.jp                                      0.0                     0.0
#
#                  js_function_decodeURIComponent(  js_function_encodeURI(  \
# domain
# spellingbee.com                              0.0                     0.0
# hd-streams.org                               0.0                     0.0
# ebay.at                                      0.0                     0.0
# drhmonegyi.net                               0.0                     0.0
# dhc.co.jp                                    0.0                     0.0
#
#                  js_function_encodeURIComponent(  js_function_escape(  \
# domain
# spellingbee.com                              0.0                  0.0
# hd-streams.org                               0.0                  0.0
# ebay.at                                      2.0                  0.0
# drhmonegyi.net                               0.0                  0.0
# dhc.co.jp                                    0.0                  0.0
#
#                  js_function_eval(  js_function_isFinite(  js_function_isNaN(  \
# domain
# spellingbee.com                0.0                    0.0                 0.0
# hd-streams.org                 0.0                    0.0                 0.0
# ebay.at                        0.0                    0.0                 0.0
# drhmonegyi.net                 0.0                    0.0                 0.0
# dhc.co.jp                      0.0                    0.0                 0.0
#
#                  js_function_parseFloat(  js_function_parseInt(  \
# domain
# spellingbee.com                      0.0                    0.0
# hd-streams.org                       0.0                    0.0
# ebay.at                              0.0                    3.0
# drhmonegyi.net                       0.0                    0.0
# dhc.co.jp                            0.0                    0.0
#
#                  js_function_undefined(  js_function_unescape(  \
# domain
# spellingbee.com                     0.0                    0.0
# hd-streams.org                      0.0                    0.0
# ebay.at                             0.0                    0.0
# drhmonegyi.net                      0.0                    0.0
# dhc.co.jp                           0.0                    0.0
#
#                  js_function_uneval(  number_functions_declared  \
# domain
# spellingbee.com                  0.0                        5.0
# hd-streams.org                   0.0                        5.0
# ebay.at                          0.0                      614.0
# drhmonegyi.net                   0.0                       17.0
# dhc.co.jp                        0.0                        0.0
#
#                  number_of_cookies  number_of_http_only_cookies  \
# domain
# spellingbee.com                3.0                          0.0
# hd-streams.org                 1.0                          1.0
# ebay.at                        5.0                          1.0
# drhmonegyi.net                 2.0                          1.0
# dhc.co.jp                      0.0                          0.0
#
#                  number_of_non_http_only_cookies  number_of_secure_cookies  \
# domain
# spellingbee.com                              3.0                       0.0
# hd-streams.org                               0.0                       0.0
# ebay.at                                      4.0                       0.0
# drhmonegyi.net                               1.0                       0.0
# dhc.co.jp                                    0.0                       0.0
#
#                  number_of_unsecure_cookies  Malicious
# domain
# spellingbee.com                         3.0          0
# hd-streams.org                          1.0          0
# ebay.at                                 5.0          0
# drhmonegyi.net                          2.0          0
# dhc.co.jp                               0.0          0

# %% [markdown]
# ### <a id='3.B' style="text-decoration : none; color : #000000;">B. Feature Selection</a>
#
# <ol>
#     <ul><h4> 1. Correlation</h4></ul>
#     <ul><h4> 2. Chi2 </h4></ul>
#     <ul><h4> 3. Recursive Feature Elimination </h4></ul>
#     <ul><h4> 4. Select From Model </h4></ul>
# </ol>

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)


X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()


rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()


embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()


feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)

# %% [markdown]
# ### <a id='3.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
X=df_u[feature_selection_df[feature_selection_df.Total==4]['Feature']]
y=df_u.Malicious.values
feature_name = X.columns.tolist()

scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (12714, 65)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['number_of_unsecure_cookies',
#  'number_of_secure_cookies',
#  'number_of_non_http_only_cookies',
#  'number_of_http_only_cookies',
#  'number_of_cookies',
#  'js_function_unescape(',
#  'js_function_parseInt(',
#  'js_function_parseFloat(',
#  'js_function_isFinite(',
#  'js_function_eval(',
#  'js_function_escape(',
#  'js_function_decodeURIComponent(',
#  'js_function_decodeURI(',
#  'js_function_String.fromCharCode(',
#  'js_function_Promise.resolve(',
#  'js_function_Math.random(',
#  'js_function_Math.max(',
#  'js_function_JSON.stringify(',
#  'js_function_JSON.parse(',
#  'js_function_Date.now(',
#  'js_function_.trim(',
#  'js_function_.test(',
#  'js_function_.substring(',
#  'js_function_.substr',
#  'js_function_.split(',
#  'js_function_.splice(',
#  'js_function_.slice(',
#  'js_function_.shift(',
#  'js_function_.setTime(',
#  'js_function_.setDate(',
#  'js_function_.replace(',
#  'js_function_.propertyIsEnumerable(',
#  'js_function_.match(',
#  'js_function_.log(',
#  'js_function_.keys(',
#  'js_function_.join(',
#  'js_function_.hasOwnProperty(',
#  'js_function_.getYear(',
#  'js_function_.getUTCDate(',
#  'js_function_.getTimezoneOffset(',
#  'js_function_.getTime(',
#  'js_function_.getSeconds(',
#  'js_function_.getHours(',
#  'js_function_.getDay(',
#  'js_function_.getDate(',
#  'js_function_.forEach(',
#  'js_function_.find(',
#  'js_function_.filter(',
#  'js_function_.charAt(',
#  'js_function_.all(',
#  'dom_function_window.setTimeout(',
#  'dom_function_window.scrollTo(',
#  'dom_function_window.matchMedia(',
#  'dom_function_window.getComputedStyle(',
#  'dom_function_window.clearTimeout(',
#  'dom_function_window.clearInterval(',
#  'dom_function_window.addEventListener(',
#  'dom_function_document.write(',
#  'dom_function_document.open(',
#  'dom_function_document.getElementsByTagName(',
#  'dom_function_document.getElementsByClassName(',
#  'dom_function_document.getElementById(',
#  'dom_function_document.execCommand(',
#  'dom_function_document.createTextNode(',
#  'dom_function_document.createElement(']

# %% [markdown]
# ### <a id='3.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8163405761654522
# Predicted  False  True  __all__
# Actual
# False       3344  1786     5130
# True          82  4959     5041
# __all__     3426  6745    10171
# The accuracy of the model on test data is: 0.8120330318521432
# Predicted  False  True  __all__
# Actual
# False        784   443     1227
# True          35  1281     1316
# __all__      819  1724     2543

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8191918198800511
# Predicted  False  True  __all__
# Actual
# False       3441  1689     5130
# True         150  4891     5041
# __all__     3591  6580    10171
# The accuracy of the model on test data is: 0.8155721588674794
# Predicted  False  True  __all__
# Actual
# False        803   424     1227
# True          45  1271     1316
# __all__      848  1695     2543

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8086717136958018
# Predicted  False  True  __all__
# Actual
# False       3365  1765     5130
# True         181  4860     5041
# __all__     3546  6625    10171
# The accuracy of the model on test data is: 0.8006291781360598
# Predicted  False  True  __all__
# Actual
# False        777   450     1227
# True          57  1259     1316
# __all__      834  1709     2543

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8290236948186019
# Predicted  False  True  __all__
# Actual
# False       3464  1666     5130
# True          73  4968     5041
# __all__     3537  6634    10171
# The accuracy of the model on test data is: 0.8147856861974047
# Predicted  False  True  __all__
# Actual
# False        802   425     1227
# True          46  1270     1316
# __all__      848  1695     2543

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8101464949365844
# Predicted  False  True  __all__
# Actual
# False       3491  1639     5130
# True         292  4749     5041
# __all__     3783  6388    10171
# The accuracy of the model on test data is: 0.804168305151396
# Predicted  False  True  __all__
# Actual
# False        813   414     1227
# True          84  1232     1316
# __all__      897  1646     2543

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8177170386392685
# Predicted  False  True  __all__
# Actual
# False       3473  1657     5130
# True         197  4844     5041
# __all__     3670  6501    10171
# The accuracy of the model on test data is: 0.809673613841919
# Predicted  False  True  __all__
# Actual
# False        809   418     1227
# True          66  1250     1316
# __all__      875  1668     2543

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.830400157309999
# Predicted  False  True  __all__
# Actual
# False       3467  1663     5130
# True          62  4979     5041
# __all__     3529  6642    10171
# The accuracy of the model on test data is: 0.8159653952025168
# Predicted  False  True  __all__
# Actual
# False        804   423     1227
# True          45  1271     1316
# __all__      849  1694     2543

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8284337823222888
# Predicted  False  True  __all__
# Actual
# False       3462  1668     5130
# True          77  4964     5041
# __all__     3539  6632    10171
# The accuracy of the model on test data is: 0.8124262681871804
# Predicted  False  True  __all__
# Actual
# False        793   434     1227
# True          43  1273     1316
# __all__      836  1707     2543

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8258774948382657
# Predicted  False  True  __all__
# Actual
# False       3463  1667     5130
# True         104  4937     5041
# __all__     3567  6604    10171
# The accuracy of the model on test data is: 0.8183248132127409
# Predicted  False  True  __all__
# Actual
# False        809   418     1227
# True          44  1272     1316
# __all__      853  1690     2543

# %% [markdown]
# ### <a id='3.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.816341  4959.0  3344.0  1786.0   82.0  0.348148
# KNeighborsClassifier        0.819192  4891.0  3441.0  1689.0  150.0  0.329240
# LogisticRegression          0.808672  4860.0  3365.0  1765.0  181.0  0.344055
# RandomForestClassifier      0.829024  4968.0  3464.0  1666.0   73.0  0.324756
# AdaBoostClassifier          0.810146  4749.0  3491.0  1639.0  292.0  0.319493
# GradientBoostingClassifier  0.817717  4844.0  3473.0  1657.0  197.0  0.323002
# ExtraTreeClassifier         0.830400  4979.0  3467.0  1663.0   62.0  0.324172
# BaggingClassifier           0.828434  4964.0  3462.0  1668.0   77.0  0.325146
# VotingClassifier            0.825877  4937.0  3463.0  1667.0  104.0  0.324951
#
#                                  FNR
# index
# Neural Network-1            0.016267
# KNeighborsClassifier        0.029756
# LogisticRegression          0.035906
# RandomForestClassifier      0.014481
# AdaBoostClassifier          0.057925
# GradientBoostingClassifier  0.039080
# ExtraTreeClassifier         0.012299
# BaggingClassifier           0.015275
# VotingClassifier            0.020631
# Comparision Table for Test Accuracies:
#                             accuracy      TP     TN     FP    FN       FPR  \
# index
# Neural Network-1            0.812033  1281.0  784.0  443.0  35.0  0.361043
# KNeighborsClassifier        0.815572  1271.0  803.0  424.0  45.0  0.345558
# LogisticRegression          0.800629  1259.0  777.0  450.0  57.0  0.366748
# RandomForestClassifier      0.814786  1270.0  802.0  425.0  46.0  0.346373
# AdaBoostClassifier          0.804168  1232.0  813.0  414.0  84.0  0.337408
# GradientBoostingClassifier  0.809674  1250.0  809.0  418.0  66.0  0.340668
# ExtraTreeClassifier         0.815965  1271.0  804.0  423.0  45.0  0.344743
# BaggingClassifier           0.812426  1273.0  793.0  434.0  43.0  0.353708
# VotingClassifier            0.818325  1272.0  809.0  418.0  44.0  0.340668
#
#                                  FNR       auc
# index
# Neural Network-1            0.026596  0.806181
# KNeighborsClassifier        0.034195  0.810124
# LogisticRegression          0.043313  0.794969
# RandomForestClassifier      0.034954  0.809336
# AdaBoostClassifier          0.063830  0.799381
# GradientBoostingClassifier  0.050152  0.804590
# ExtraTreeClassifier         0.034195  0.810531
# BaggingClassifier           0.032675  0.806808
# VotingClassifier            0.033435  0.812949

# %% [markdown]
# ## <a id='4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a>
#
# #### <a id='4.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=48,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_pca.shape
# Out:
# 0.9491116725902
# The train/test split ratio is 80:20
# (12714, 48)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_train.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8173237636593073
# Predicted  False  True  __all__
# Actual
# False       3358  1772     5130
# True          86  4955     5041
# __all__     3444  6727    10171
# The accuracy of the model on test data is: 0.8112465591820684
# Predicted  False  True  __all__
# Actual
# False        779   448     1227
# True          32  1284     1316
# __all__      811  1732     2543

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8195850948775931
# Predicted  False  True  __all__
# Actual
# False       3450  1680     5130
# True         155  4886     5041
# __all__     3605  6566    10171
# The accuracy of the model on test data is: 0.8183248132127409
# Predicted  False  True  __all__
# Actual
# False        809   418     1227
# True          44  1272     1316
# __all__      853  1690     2543

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8086717136958018
# Predicted  False  True  __all__
# Actual
# False       3365  1765     5130
# True         181  4860     5041
# __all__     3546  6625    10171
# The accuracy of the model on test data is: 0.8018088871411718
# Predicted  False  True  __all__
# Actual
# False        780   447     1227
# True          57  1259     1316
# __all__      837  1706     2543

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8290236948186019
# Predicted  False  True  __all__
# Actual
# False       3465  1665     5130
# True          74  4967     5041
# __all__     3539  6632    10171
# The accuracy of the model on test data is: 0.8191112858828156
# Predicted  False  True  __all__
# Actual
# False        813   414     1227
# True          46  1270     1316
# __all__      859  1684     2543

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8177170386392685
# Predicted  False  True  __all__
# Actual
# False       3448  1682     5130
# True         172  4869     5041
# __all__     3620  6551    10171
# The accuracy of the model on test data is: 0.8175383405426662
# Predicted  False  True  __all__
# Actual
# False        811   416     1227
# True          48  1268     1316
# __all__      859  1684     2543

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8223380198603873
# Predicted  False  True  __all__
# Actual
# False       3469  1661     5130
# True         146  4895     5041
# __all__     3615  6556    10171
# The accuracy of the model on test data is: 0.8191112858828156
# Predicted  False  True  __all__
# Actual
# False        816   411     1227
# True          49  1267     1316
# __all__      865  1678     2543

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.830400157309999
# Predicted  False  True  __all__
# Actual
# False       3467  1663     5130
# True          62  4979     5041
# __all__     3529  6642    10171
# The accuracy of the model on test data is: 0.8175383405426662
# Predicted  False  True  __all__
# Actual
# False        809   418     1227
# True          46  1270     1316
# __all__      855  1688     2543

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8281388260741324
# Predicted  False  True  __all__
# Actual
# False       3462  1668     5130
# True          80  4961     5041
# __all__     3542  6629    10171
# The accuracy of the model on test data is: 0.8179315768777035
# Predicted  False  True  __all__
# Actual
# False        808   419     1227
# True          44  1272     1316
# __all__      852  1691     2543

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8272539573296628
# Predicted  False  True  __all__
# Actual
# False       3464  1666     5130
# True          91  4950     5041
# __all__     3555  6616    10171
# The accuracy of the model on test data is: 0.8198977585528903
# Predicted  False  True  __all__
# Actual
# False        813   414     1227
# True          44  1272     1316
# __all__      857  1686     2543

# %% [markdown]
# ### <a id='4.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.817324  4955.0  3358.0  1772.0   86.0  0.345419
# KNeighborsClassifier        0.819585  4886.0  3450.0  1680.0  155.0  0.327485
# LogisticRegression          0.808672  4860.0  3365.0  1765.0  181.0  0.344055
# RandomForestClassifier      0.829024  4967.0  3465.0  1665.0   74.0  0.324561
# AdaBoostClassifier          0.817717  4869.0  3448.0  1682.0  172.0  0.327875
# GradientBoostingClassifier  0.822338  4895.0  3469.0  1661.0  146.0  0.323782
# ExtraTreeClassifier         0.830400  4979.0  3467.0  1663.0   62.0  0.324172
# BaggingClassifier           0.828139  4961.0  3462.0  1668.0   80.0  0.325146
# VotingClassifier            0.827254  4950.0  3464.0  1666.0   91.0  0.324756
#
#                                  FNR
# index
# Neural Network-1            0.017060
# KNeighborsClassifier        0.030748
# LogisticRegression          0.035906
# RandomForestClassifier      0.014680
# AdaBoostClassifier          0.034120
# GradientBoostingClassifier  0.028963
# ExtraTreeClassifier         0.012299
# BaggingClassifier           0.015870
# VotingClassifier            0.018052
# Comparision Table for Test Accuracies:
#                             accuracy      TP     TN     FP    FN       FPR  \
# index
# Neural Network-1            0.811247  1284.0  779.0  448.0  32.0  0.365118
# KNeighborsClassifier        0.818325  1272.0  809.0  418.0  44.0  0.340668
# LogisticRegression          0.801809  1259.0  780.0  447.0  57.0  0.364303
# RandomForestClassifier      0.819111  1270.0  813.0  414.0  46.0  0.337408
# AdaBoostClassifier          0.817538  1268.0  811.0  416.0  48.0  0.339038
# GradientBoostingClassifier  0.819111  1267.0  816.0  411.0  49.0  0.334963
# ExtraTreeClassifier         0.817538  1270.0  809.0  418.0  46.0  0.340668
# BaggingClassifier           0.817932  1272.0  808.0  419.0  44.0  0.341483
# VotingClassifier            0.819898  1272.0  813.0  414.0  44.0  0.337408
#
#                                  FNR       auc
# index
# Neural Network-1            0.024316  0.805283
# KNeighborsClassifier        0.033435  0.812949
# LogisticRegression          0.043313  0.796192
# RandomForestClassifier      0.034954  0.813819
# AdaBoostClassifier          0.036474  0.812244
# GradientBoostingClassifier  0.037234  0.813901
# ExtraTreeClassifier         0.034954  0.812189
# BaggingClassifier           0.033435  0.812541
# VotingClassifier            0.033435  0.814579

# %% [markdown]
# ### <a id='4.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 60                              0.020684
# 52                              0.020672
# 46                              0.020560
# 58                              0.020462
# 62                              0.020455
# 19                              0.020435
# 55                              0.020425
# 51                              0.020399
# 12                              0.020371
# 39                              0.020341
# 1                               0.020224
# 20                              0.020207
# 9                               0.020096
# 61                              0.020048
# 14                              0.019960
# 43                              0.019938
# 33                              0.019863
# 31                              0.019801
# 18                              0.019782
# 3                               0.019745
# 41                              0.019527
# 32                              0.019521
# 57                              0.019423
# 6                               0.019087
# 49                              0.019002
# 56                              0.018999
# 8                               0.018875
# 42                              0.018783
# 17                              0.018741
# 53                              0.018528
# 38                              0.018038
# 13                              0.017993
# 63                              0.017363
# 54                              0.016835
# 50                              0.016246
# 37                              0.016239
# 28                              0.015930
# 5                               0.015706
# 11                              0.015543
# 7                               0.014598
# 10                              0.014589
# 29                              0.013881
# 16                              0.013586
# 15                              0.013463
# 59                              0.012375
# 64                              0.010526
# 27                              0.010505
# 40                              0.010466
# 44                              0.009881
# 34                              0.009360
# 48                              0.009283
# 22                              0.009036
# 47                              0.008760
# 45                              0.008597
# 2                               0.007186
# 0                               0.006927
# 26                              0.006882
# 23                              0.006797
# 36                              0.006577
# 4                               0.006303
# 21                              0.005808
# 25                              0.005481
# 30                              0.005229
# 24                              0.004266
# 35                              0.003955
#
#                                          Features
# 60  dom_function_document.getElementsByClassName(
# 52                dom_function_window.matchMedia(
# 46                             js_function_.find(
# 58                    dom_function_document.open(
# 62             dom_function_document.execCommand(
# 19                          js_function_Date.now(
# 55             dom_function_window.clearInterval(
# 51                  dom_function_window.scrollTo(
# 12                         js_function_decodeURI(
# 39                js_function_.getTimezoneOffset(
# 1                        number_of_secure_cookies
# 20                             js_function_.trim(
# 9                               js_function_eval(
# 61          dom_function_document.getElementById(
# 14                   js_function_Promise.resolve(
# 43                           js_function_.getDay(
# 33                              js_function_.log(
# 31             js_function_.propertyIsEnumerable(
# 18                        js_function_JSON.parse(
# 3                     number_of_http_only_cookies
# 41                       js_function_.getSeconds(
# 32                            js_function_.match(
# 57                   dom_function_document.write(
# 6                           js_function_parseInt(
# 49                              js_function_.all(
# 56          dom_function_window.addEventListener(
# 8                           js_function_isFinite(
# 42                         js_function_.getHours(
# 17                    js_function_JSON.stringify(
# 53          dom_function_window.getComputedStyle(
# 38                       js_function_.getUTCDate(
# 13               js_function_String.fromCharCode(
# 63          dom_function_document.createTextNode(
# 54              dom_function_window.clearTimeout(
# 50                dom_function_window.setTimeout(
# 37                          js_function_.getYear(
# 28                          js_function_.setTime(
# 5                           js_function_unescape(
# 11                js_function_decodeURIComponent(
# 7                         js_function_parseFloat(
# 10                            js_function_escape(
# 29                          js_function_.setDate(
# 16                          js_function_Math.max(
# 15                       js_function_Math.random(
# 59    dom_function_document.getElementsByTagName(
# 64           dom_function_document.createElement(
# 27                            js_function_.shift(
# 40                          js_function_.getTime(
# 44                          js_function_.getDate(
# 34                             js_function_.keys(
# 48                           js_function_.charAt(
# 22                        js_function_.substring(
# 47                           js_function_.filter(
# 45                          js_function_.forEach(
# 2                 number_of_non_http_only_cookies
# 0                      number_of_unsecure_cookies
# 26                            js_function_.slice(
# 23                            js_function_.substr
# 36                   js_function_.hasOwnProperty(
# 4                               number_of_cookies
# 21                             js_function_.test(
# 25                           js_function_.splice(
# 30                          js_function_.replace(
# 24                            js_function_.split(
# 35                             js_function_.join(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %%
### Original Creator : Darshan Bhansali
### HTML code to hide the input cells 
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle code, click <a href="javascript:code_toggle()">here</a>.
