# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)
from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE

import warnings
warnings.simplefilter("ignore", DeprecationWarning)
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

# %% [markdown]
# ### Eliminating cases where html_status=="Not success" as they have all null values

# %%
df_alex=pd.read_csv('Javascript_alexa_output.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])

df.drop(['Unnamed: 0'],axis=1,inplace=True)

df = df.sample(frac=1,random_state=867).reset_index(drop=True)

df.fillna(value=0,inplace=True)

display(df.shape)

df=df[df['html_status']=='Success']
df.shape
# Out:
# (46178, 303)
# (43209, 303)

# %% [markdown]
# ### Dropping columns that indicate the html status of domain data collection

# %%
df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

# %%
cols_WebAssembly=[col for col in df.columns if 'js_function_WebAssembly' in col]
cols_Reflect=[col for col in df.columns if 'Reflect' in col]
cols_Object=[col for col in df.columns if 'js_function_Object' in col]
cols_Number=[col for col in df.columns if 'js_function_Number' in col]
cols_Math=[col for col in df.columns if 'js_function_Math' in col]
cols_Atomics=[col for col in df.columns if 'js_function_Atomics' in col]
cols_Promise=[col for col in df.columns if 'Promise' in col]



df['tot_WebAssembly']=df[cols_WebAssembly].sum(axis=1)
df['tot_Reflect']=df[cols_Reflect].sum(axis=1)
df['tot_Object']=df[cols_Object].sum(axis=1)
df['tot_Number']=df[cols_Number].sum(axis=1)
df['tot_Math']=df[cols_Math].sum(axis=1)
df['tot_Atomics']=df[cols_Atomics].sum(axis=1)
df['tot_Promise']=df[cols_Atomics].sum(axis=1)

len(cols_WebAssembly)+len(cols_Reflect)+len(cols_Object)+len(cols_Number)+len(cols_Math)+len(cols_Atomics)+len(cols_Promise)
# Out:
# 97

# %% [markdown]
# #### Columns and nummber of unique values they have

# %%
lst=[]
for col in df.columns:
    lst.append((col,len(df[col].value_counts())))

unique_val_cols=pd.DataFrame(lst)
unique_val_cols.columns=['Column_Name','Num_unique_value']

unique_val_cols.sort_values(by=['Num_unique_value'],inplace=True)
unique_val_cols.head()
# Out:
#                                Column_Name  Num_unique_value
# 305                            tot_Promise                 1
# 185  js_function_Intl.getCanonicalLocales(                 1
# 190                js_function_Math.acosh(                 1
# 192                js_function_Math.asinh(                 1
# 90                   js_function_.ownKeys(                 1

# %%
print("Columns with all same values")
col_1=unique_val_cols[unique_val_cols['Num_unique_value']==1].Column_Name.values

for col in col_1:
    print(df[col].value_counts(),"\n")
# Out:
# Columns with all same values
# 0.0    43209
# Name: tot_Promise, dtype: int64
#
# 0.0    43209
# Name: js_function_Intl.getCanonicalLocales(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.acosh(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.asinh(, dtype: int64
#
# 0.0    43209
# Name: js_function_.ownKeys(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.atanh(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.cbrt(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.cosh(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.expm1(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.fround(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.hypot(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.log1p(, dtype: int64
#
# 0.0    43209
# Name: js_function_.isNan(, dtype: int64
#
# 0.0    43209
# Name: js_function_Math.tanh(, dtype: int64
#
# 0.0    43209
# Name: js_function_Number.parseFloat(, dtype: int64
#
# 0.0    43209
# Name: js_function_Object.isSealed(, dtype: int64
#
# 0.0    43209
# Name: js_function_Proxy.revocable(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.apply(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.xor(, dtype: int64
#
# 0.0    43209
# Name: js_function_.getFloat64(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.wake(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.sub(, dtype: int64
#
# 0.0    43209
# Name: js_function_.throw(, dtype: int64
#
# 0.0    43209
# Name: js_function_.small(, dtype: int64
#
# 0.0    43209
# Name: tot_Atomics, dtype: int64
#
# 0.0    43209
# Name: js_function_.setUint16(, dtype: int64
#
# 0.0    43209
# Name: js_function_Array.of(, dtype: int64
#
# 0.0    43209
# Name: js_function_ArrayBuffer.transfer(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.add(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.and(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.compareExchange(, dtype: int64
#
# 0.0    43209
# Name: js_function_.setInt16(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.exchange(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.isLockFree(, dtype: int64
#
# 0.0    43209
# Name: js_function_.setFloat64(, dtype: int64
#
# 0.0    43209
# Name: js_function_.setFloat32(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.load(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.or(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.store(, dtype: int64
#
# 0.0    43209
# Name: js_function_Atomics.wait(, dtype: int64
#
# 0.0    43209
# Name: js_function_.getFloat32(, dtype: int64
#
# 0.0    43209
# Name: js_function_.grow(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.setPrototypeOf(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.ownKeys(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.preventExtensions(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.set(, dtype: int64
#
# 0.0    43209
# Name: js_function_String.raw(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.compile(, dtype: int64
#
# 0.0    43209
# Name: js_function_.copyWithin(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.compileStreaming(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.customerSections(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.exports(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.imports(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.instantiate(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.instantiateStreaming(, dtype: int64
#
# 0.0    43209
# Name: js_function_WebAssembly.validate(, dtype: int64
#
# 0.0    43209
# Name: js_function_uneval(, dtype: int64
#
# 0.0    43209
# Name: js_function_.big(, dtype: int64
#
# 0.0    43209
# Name: tot_WebAssembly, dtype: int64
#
# 0.0    43209
# Name: js_function_.allTrue(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.isExtensible(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.has(, dtype: int64
#
# 0.0    43209
# Name: js_function_.strike(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.get(, dtype: int64
#
# 0.0    43209
# Name: js_function_.fontsize(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.getOwnPropertyDescriptor(, dtype: int64
#
# 0.0    43209
# Name: js_function_Reflect.getPrototypeOf(, dtype: int64
#
# 0.0    43209
# Name: js_function_.formatToParts(, dtype: int64

# %% [markdown]
# #### Dependent and Target variables

# %%
X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

model = LogisticRegression(random_state=0)
model.fit(X, y)

print("Accuracy score with all of the features")
display(model.score(X,y))
# Out:
# Accuracy score with all of the features
# 0.865375269041172

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9438733317470319
# Columns selected:
#
# Accuracy score
# 0.8658612789002291

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 292                          3.241602e+01
# 96                           1.662403e+01
# 9                            2.238060e-01
# 83                           1.457506e-01
# 29                           1.063540e-01
# 302                          7.032318e-02
# 100                          4.454177e-02
# 144                          3.687286e-02
# 73                           3.668124e-02
# 4                            3.421845e-02
# 106                          3.185962e-02
# 39                           3.114002e-02
# 300                          2.766961e-02
# 138                          2.659665e-02
# 78                           1.539413e-02
# 154                          1.209143e-02
# 157                          9.750285e-03
# 141                          9.541616e-03
# 0                            7.377634e-03
# 133                          7.367418e-03
# 85                           6.887787e-03
# 6                            6.543910e-03
# 288                          5.781490e-03
# 19                           4.572129e-03
# 84                           4.562677e-03
# 232                          4.447221e-03
# 71                           4.141778e-03
# 27                           3.220090e-03
# 36                           3.181371e-03
# 142                          2.830057e-03
# 16                           2.763983e-03
# 25                           2.336533e-03
# 12                           2.285080e-03
# 211                          2.088277e-03
# 11                           1.729932e-03
# 55                           1.722456e-03
# 132                          1.684456e-03
# 282                          1.574426e-03
# 287                          1.450278e-03
# 203                          1.295191e-03
# 137                          1.248658e-03
# 87                           1.160896e-03
# 214                          1.044228e-03
# 93                           1.012370e-03
# 215                          1.005764e-03
# 188                          8.166846e-04
# 79                           7.267070e-04
# 86                           6.722732e-04
# 212                          6.479834e-04
# 286                          6.386347e-04
# 230                          6.184401e-04
# 159                          5.633012e-04
# 158                          4.961517e-04
# 70                           4.502900e-04
# 162                          4.292655e-04
# 244                          4.199295e-04
# 247                          4.104936e-04
# 118                          4.104936e-04
# 53                           3.594450e-04
# 239                          3.594450e-04
# 187                          3.320974e-04
# 136                          3.268039e-04
# 186                          2.854675e-04
# 166                          2.848133e-04
# 213                          2.159704e-04
# 197                          2.117472e-04
# 295                          1.862299e-04
# 297                          1.851518e-04
# 44                           1.650424e-04
# 293                          1.598894e-04
# 280                          1.510275e-04
# 183                          1.338200e-04
# 51                           1.320397e-04
# 40                           1.201462e-04
# 266                          1.074232e-04
# 97                           9.722449e-05
# 13                           6.893615e-05
# 199                          6.484648e-05
# 217                          6.372338e-05
# 10                           5.141330e-05
# 80                           4.817496e-05
# 284                          4.650996e-05
# 219                          3.686735e-05
# 38                           3.280218e-05
# 103                          3.134458e-05
# 269                          3.058494e-05
# 206                          2.995497e-05
# 81                           2.903789e-05
# 164                          2.719559e-05
# 148                          2.626369e-05
# 285                          2.385809e-05
# 163                          2.241440e-05
# 237                          2.046823e-05
# 105                          1.941771e-05
# 1                            1.897400e-05
# 135                          1.700523e-05
# 165                          1.660279e-05
# 72                           1.443910e-05
# 120                          1.434524e-05
# 229                          1.344976e-05
# 52                           1.197575e-05
# 235                          1.197575e-05
# 41                           1.181388e-05
# 45                           9.755648e-06
# 20                           9.094880e-06
# 104                          8.344354e-06
# 107                          8.315769e-06
# 68                           8.243002e-06
# 24                           8.215683e-06
# 56                           6.606053e-06
# 50                           5.253941e-06
# 207                          4.887398e-06
# 88                           4.837506e-06
# 290                          4.572687e-06
# 95                           3.646929e-06
# 26                           2.804057e-06
# 194                          2.473087e-06
# 220                          2.294263e-06
# 251                          2.081242e-06
# 117                          2.012989e-06
# 191                          1.976214e-06
# 54                           1.960603e-06
# 23                           1.859477e-06
# 279                          1.527418e-06
# 150                          1.229671e-06
# 110                          1.138775e-06
# 102                          1.080535e-06
# 281                          1.018145e-06
# 60                           1.013089e-06
# 57                           1.011163e-06
# 294                          1.003744e-06
# 76                           9.615325e-07
# 296                          9.260437e-07
# 111                          9.028126e-07
# 246                          9.024319e-07
# 62                           8.621760e-07
# 234                          8.503106e-07
# 63                           8.169586e-07
# 283                          7.974361e-07
# 59                           7.709161e-07
# 289                          7.708766e-07
# 67                           7.255867e-07
# 64                           6.529270e-07
# 115                          5.942312e-07
# 116                          5.728980e-07
# 193                          5.523969e-07
# 201                          4.917899e-07
# 231                          4.796700e-07
# 49                           3.877164e-07
# 30                           3.366832e-07
# 119                          3.172900e-07
# 149                          3.043014e-07
# 151                          2.928084e-07
# 123                          2.683216e-07
# 17                           2.503055e-07
# 89                           2.438804e-07
# 125                          2.160413e-07
# 248                          2.127252e-07
# 15                           1.949061e-07
# 47                           1.913132e-07
# 65                           1.860838e-07
# 127                          1.592732e-07
# 184                          1.549693e-07
# 66                           1.292248e-07
# 301                          1.166548e-07
# 99                           1.107300e-07
# 94                           1.011999e-07
# 245                          1.011999e-07
# 48                           8.632691e-08
# 114                          8.632691e-08
# 189                          8.525408e-08
# 33                           7.752949e-08
# 131                          6.540938e-08
# 61                           6.434445e-08
# 58                           6.384570e-08
# 92                           5.895300e-08
# 113                          4.915378e-08
# 240                          3.745731e-08
# 182                          3.610929e-08
# 129                          3.003427e-08
# 224                          2.041236e-08
# 250                          1.983387e-08
# 122                          1.830875e-08
# 130                          1.765088e-08
# 98                           1.667523e-08
# 156                          1.561251e-08
# 299                          1.388253e-08
# 74                           1.266779e-08
# 241                          1.266779e-08
# 238                          1.078506e-08
# 255                          1.000031e-08
# 225                          9.421562e-09
# 147                          9.126406e-09
# 242                          8.788508e-09
# 249                          7.471743e-09
# 14                           7.298449e-09
# 140                          7.179125e-09
# 218                          6.845772e-09
# 223                          4.587717e-09
# 82                           4.390946e-09
# 7                            4.143285e-09
# 22                           4.089406e-09
# 152                          2.783978e-09
# 121                          2.667779e-09
# 143                          1.948958e-09
# 208                          1.725922e-09
# 233                          1.335684e-09
# 216                          1.292248e-09
# 46                           1.292248e-09
# 226                          1.089105e-09
# 168                          1.062942e-09
# 126                          4.323899e-10
# 254                          1.966314e-10
# 198                          1.837180e-10
# 124                          1.780173e-10
# 155                          6.695725e-11
# 8                            5.515555e-11
# 222                          2.927237e-11
# 3                            1.546868e-11
# 21                           1.444065e-11
# 256                          1.444065e-11
# 101                          1.068659e-11
# 153                          1.023195e-11
# 146                          6.735128e-12
# 161                          3.337153e-12
# 267                          1.798432e-12
# 160                          1.716030e-12
# 236                          1.317606e-12
# 228                          7.688207e-13
# 270                          7.458653e-13
# 210                          4.779823e-13
# 28                           1.351056e-13
# 32                           9.879226e-14
# 31                           8.326489e-14
# 34                           4.867987e-16
# 77                           1.216997e-16
# 91                           1.185787e-16
# 2                            4.881274e-50
# 5                            1.458755e-51
# 273                          0.000000e+00
# 272                          0.000000e+00
# 303                          0.000000e+00
# 275                          0.000000e+00
# 274                          0.000000e+00
# 109                          0.000000e+00
# 268                          0.000000e+00
# 112                          0.000000e+00
# 271                          0.000000e+00
# 298                          0.000000e+00
# 276                          0.000000e+00
# 277                          0.000000e+00
# 278                          0.000000e+00
# 108                          0.000000e+00
# 18                           0.000000e+00
# 90                           0.000000e+00
# 264                          0.000000e+00
# 75                           0.000000e+00
# 69                           0.000000e+00
# 43                           0.000000e+00
# 42                           0.000000e+00
# 37                           0.000000e+00
# 35                           0.000000e+00
# 291                          0.000000e+00
# 265                          0.000000e+00
# 202                          0.000000e+00
# 263                          0.000000e+00
# 262                          0.000000e+00
# 227                          0.000000e+00
# 175                          0.000000e+00
# 176                          0.000000e+00
# 177                          0.000000e+00
# 221                          0.000000e+00
# 178                          0.000000e+00
# 179                          0.000000e+00
# 180                          0.000000e+00
# 181                          0.000000e+00
# 185                          0.000000e+00
# 190                          0.000000e+00
# 192                          0.000000e+00
# 195                          0.000000e+00
# 196                          0.000000e+00
# 209                          0.000000e+00
# 200                          0.000000e+00
# 205                          0.000000e+00
# 174                          0.000000e+00
# 173                          0.000000e+00
# 172                          0.000000e+00
# 252                          0.000000e+00
# 261                          0.000000e+00
# 260                          0.000000e+00
# 259                          0.000000e+00
# 258                          0.000000e+00
# 257                          0.000000e+00
# 204                          0.000000e+00
# 253                          0.000000e+00
# 128                          0.000000e+00
# 171                          0.000000e+00
# 134                          0.000000e+00
# 139                          0.000000e+00
# 145                          0.000000e+00
# 243                          0.000000e+00
# 167                          0.000000e+00
# 169                          0.000000e+00
# 170                          0.000000e+00
# 304                          0.000000e+00
#
#                                           Features
# 292                      number_functions_declared
# 96                              js_function_.push(
# 9                               js_function_.call(
# 83                               js_function_.log(
# 29                              js_function_.find(
# 302                                       tot_Math
# 100                          js_function_.replace(
# 144                             js_function_.test(
# 73                           js_function_.indexOf(
# 4                              js_function_.apply(
# 106                              js_function_.set(
# 39                               js_function_.get(
# 300                                     tot_Object
# 138                            js_function_.split(
# 78                              js_function_.join(
# 154                      js_function_.toLowerCase(
# 157                         js_function_.toString(
# 141                            js_function_.substr
# 0                                js_function_.add(
# 133                            js_function_.slice(
# 85                             js_function_.match(
# 6                               js_function_.bind(
# 288                          js_function_parseInt(
# 19                    js_function_.defineProperty(
# 84                               js_function_.map(
# 232             js_function_Object.defineProperty(
# 71                    js_function_.hasOwnProperty(
# 27                            js_function_.filter(
# 36                           js_function_.forEach(
# 142                        js_function_.substring(
# 16                            js_function_.concat(
# 25                              js_function_.exec(
# 12                        js_function_.charCodeAt(
# 211                          js_function_Math.max(
# 11                            js_function_.charAt(
# 55                           js_function_.getTime(
# 132                            js_function_.shift(
# 282                js_function_encodeURIComponent(
# 287                        js_function_parseFloat(
# 203                        js_function_Math.floor(
# 137                           js_function_.splice(
# 87                              js_function_.next(
# 214                       js_function_Math.random(
# 93                               js_function_.pop(
# 215                        js_function_Math.round(
# 188                          js_function_Math.abs(
# 79                              js_function_.keys(
# 86                               js_function_.min(
# 212                          js_function_Math.min(
# 286                             js_function_isNaN(
# 230                     js_function_Object.create(
# 159                             js_function_.trim(
# 158                      js_function_.toUpperCase(
# 70                               js_function_.has(
# 162                          js_function_.unshift(
# 244                       js_function_Object.keys(
# 247             js_function_Object.setPrototypeOf(
# 118                   js_function_.setPrototypeOf(
# 53                    js_function_.getPrototypeOf(
# 239             js_function_Object.getPrototypeOf(
# 187                    js_function_JSON.stringify(
# 136                             js_function_.sort(
# 186                        js_function_JSON.parse(
# 166                     js_function_Array.isArray(
# 213                          js_function_Math.pow(
# 197                         js_function_Math.ceil(
# 295                number_of_non_http_only_cookies
# 297                     number_of_unsecure_cookies
# 44                       js_function_.getFullYear(
# 293                              number_of_cookies
# 280                js_function_decodeURIComponent(
# 183                          js_function_Date.now(
# 51                          js_function_.getMonth(
# 40                           js_function_.getDate(
# 266               js_function_String.fromCharCode(
# 97                            js_function_.reduce(
# 13                             js_function_.clear(
# 199                          js_function_Math.cos(
# 217                          js_function_Math.sin(
# 10                             js_function_.catch(
# 80                       js_function_.lastIndexOf(
# 284                              js_function_eval(
# 219                         js_function_Math.sqrt(
# 38                              js_function_.from(
# 103                          js_function_.reverse(
# 269                        js_function_Symbol.for(
# 206                         js_function_Math.imul(
# 81                              js_function_.link(
# 164                           js_function_.values(
# 148                          js_function_.toFixed(
# 285                          js_function_isFinite(
# 163                          js_function_.valueOf(
# 237        js_function_Object.getOwnPropertyNames(
# 105                           js_function_.select(
# 1                                js_function_.all(
# 135                             js_function_.some(
# 165                        js_function_Array.from(
# 72                          js_function_.includes(
# 120                          js_function_.setTime(
# 229                     js_function_Object.assign(
# 52          js_function_.getOwnPropertyDescriptor(
# 235   js_function_Object.getOwnPropertyDescriptor(
# 41                            js_function_.getDay(
# 45                          js_function_.getHours(
# 20                            js_function_.delete(
# 104                           js_function_.search(
# 107                          js_function_.setDate(
# 68                           js_function_.getYear(
# 24                             js_function_.every(
# 56                 js_function_.getTimezoneOffset(
# 50                        js_function_.getMinutes(
# 207                          js_function_Math.log(
# 88                         js_function_.normalize(
# 290                          js_function_unescape(
# 95              js_function_.propertyIsEnumerable(
# 26                              js_function_.fill(
# 194                        js_function_Math.atan2(
# 220                          js_function_Math.tan(
# 251                   js_function_Promise.resolve(
# 117                         js_function_.setMonth(
# 191                         js_function_Math.asin(
# 54                        js_function_.getSeconds(
# 23                           js_function_.entries(
# 279                         js_function_decodeURI(
# 150                           js_function_.toJSON(
# 110                      js_function_.setFullYear(
# 102                           js_function_.return(
# 281                         js_function_encodeURI(
# 60                       js_function_.getUTCHours(
# 57                        js_function_.getUTCDate(
# 294                    number_of_http_only_cookies
# 76                     js_function_.isPrototypeOf(
# 296                       number_of_secure_cookies
# 111                         js_function_.setHours(
# 246                       js_function_Object.seal(
# 62                     js_function_.getUTCMinutes(
# 234                     js_function_Object.freeze(
# 63                       js_function_.getUTCMonth(
# 283                            js_function_escape)
# 59                    js_function_.getUTCFullYear(
# 289                         js_function_undefined(
# 67                          js_function_.getUint8(
# 64                     js_function_.getUTCSeconds(
# 115                  js_function_.setMilliseconds(
# 116                       js_function_.setMinutes(
# 193                         js_function_Math.atan(
# 201                          js_function_Math.exp(
# 231           js_function_Object.defineProperties(
# 49                   js_function_.getMilliseconds(
# 30                         js_function_.findIndex(
# 119                       js_function_.setSeconds(
# 149                      js_function_.toISOString(
# 151                   js_function_.toLocaleString(
# 123                      js_function_.setUTCHours(
# 17                         js_function_.construct(
# 89                                js_function_.of(
# 125                    js_function_.setUTCMinutes(
# 248                       js_function_Promise.all(
# 15                           js_function_.compile(
# 47                          js_function_.getInt32(
# 65                         js_function_.getUint16(
# 127                    js_function_.setUTCSeconds(
# 184                        js_function_Date.parse(
# 66                         js_function_.getUint32(
# 301                                     tot_Number
# 99                            js_function_.repeat(
# 94                 js_function_.preventExtensions(
# 245          js_function_Object.preventExtensions(
# 48                           js_function_.getInt8(
# 114                          js_function_.setInt8(
# 189                         js_function_Math.acos(
# 33                           js_function_.flatMap(
# 131                          js_function_.setYear(
# 61                js_function_.getUTCMilliseconds(
# 58                         js_function_.getUTCDay(
# 92                          js_function_.padStart(
# 113                         js_function_.setInt32(
# 240                         js_function_Object.is(
# 182                          js_function_Date.UTC(
# 129                        js_function_.setUint32(
# 224                  js_function_Number.isInteger(
# 250                    js_function_Promise.reject(
# 122                   js_function_.setUTCFullYear(
# 130                         js_function_.setUint8(
# 98                       js_function_.reduceRight(
# 156                         js_function_.toSource(
# 299                                    tot_Reflect
# 74                      js_function_.isExtensible(
# 241               js_function_Object.isExtensible(
# 238      js_function_Object.getOwnPropertySymbols(
# 255            js_function_Reflect.defineProperty(
# 225                      js_function_Number.isNaN(
# 147                    js_function_.toExponential(
# 242                   js_function_Object.isFrozen(
# 249                      js_function_Promise.race(
# 14                       js_function_.codePointAt(
# 140                         js_function_.subarray(
# 218                         js_function_Math.sinh(
# 223                   js_function_Number.isFinite(
# 82                     js_function_.localeCompare(
# 7                              js_function_.blink(
# 22                           js_function_.endWith(
# 152               js_function_.toLocaleTimeString(
# 121                       js_function_.setUTCDate(
# 143               js_function_.supportedLocalesOf(
# 208                        js_function_Math.log10(
# 233                    js_function_Object.entries(
# 216                         js_function_Math.sign(
# 46                          js_function_.getInt16(
# 226              js_function_Number.isSafeInteger(
# 168                js_function_ArrayBuffer.isView(
# 126                      js_function_.setUTCMonth(
# 254                 js_function_Reflect.construct(
# 198                        js_function_Math.clz32(
# 124               js_function_.setUTCMilliseconds(
# 155                      js_function_.toPrecision(
# 8                               js_function_.bold(
# 222                        js_function_Math.trunc(
# 3                             js_function_.anchor(
# 21                    js_function_.deleteProperty(
# 256            js_function_Reflect.deleteProperty(
# 101                  js_function_.resolvedOptions(
# 153                js_function_.toLocaleUpperCase(
# 146                     js_function_.toDateString(
# 161                        js_function_.trimStart(
# 267              js_function_String.fromCodePoint(
# 160                          js_function_.trimEnd(
# 236  js_function_Object.getOwnPropertyDescriptors(
# 228                   js_function_Number.parseInt(
# 270                     js_function_Symbol.keyFor(
# 210                         js_function_Math.log2(
# 28                           js_function_.finally(
# 32                              js_function_.flat(
# 31                             js_function_.fixed(
# 34                         js_function_.fontcolor(
# 77                           js_function_.italics(
# 91                            js_function_.padEnd(
# 2                            js_function_.allTrue(
# 5                                js_function_.big(
# 273      js_function_WebAssembly.customerSections(
# 272      js_function_WebAssembly.compileStreaming(
# 303                                    tot_Atomics
# 275               js_function_WebAssembly.imports(
# 274               js_function_WebAssembly.exports(
# 109                       js_function_.setFloat64(
# 268                        js_function_String.raw(
# 112                         js_function_.setInt16(
# 271               js_function_WebAssembly.compile(
# 298                                tot_WebAssembly
# 276           js_function_WebAssembly.instantiate(
# 277  js_function_WebAssembly.instantiateStreaming(
# 278              js_function_WebAssembly.validate(
# 108                       js_function_.setFloat32(
# 18                        js_function_.copyWithin(
# 90                           js_function_.ownKeys(
# 264                       js_function_Reflect.set(
# 75                             js_function_.isNan(
# 69                              js_function_.grow(
# 43                        js_function_.getFloat64(
# 42                        js_function_.getFloat32(
# 37                     js_function_.formatToParts(
# 35                          js_function_.fontsize(
# 291                            js_function_uneval(
# 265            js_function_Reflect.setPrototypeOf(
# 202                        js_function_Math.expm1(
# 263         js_function_Reflect.preventExtensions(
# 262                   js_function_Reflect.ownKeys(
# 227                 js_function_Number.parseFloat(
# 175                      js_function_Atomics.load(
# 176                        js_function_Atomics.or(
# 177                     js_function_Atomics.store(
# 221                         js_function_Math.tanh(
# 178                       js_function_Atomics.sub(
# 179                      js_function_Atomics.wait(
# 180                      js_function_Atomics.wake(
# 181                       js_function_Atomics.xor(
# 185          js_function_Intl.getCanonicalLocales(
# 190                        js_function_Math.acosh(
# 192                        js_function_Math.asinh(
# 195                        js_function_Math.atanh(
# 196                         js_function_Math.cbrt(
# 209                        js_function_Math.log1p(
# 200                         js_function_Math.cosh(
# 205                        js_function_Math.hypot(
# 174                js_function_Atomics.isLockFree(
# 173                  js_function_Atomics.exchange(
# 172           js_function_Atomics.compareExchange(
# 252                   js_function_Proxy.revocable(
# 261              js_function_Reflect.isExtensible(
# 260                       js_function_Reflect.has(
# 259            js_function_Reflect.getPrototypeOf(
# 258  js_function_Reflect.getOwnPropertyDescriptor(
# 257                       js_function_Reflect.get(
# 204                       js_function_Math.fround(
# 253                     js_function_Reflect.apply(
# 128                        js_function_.setUint16(
# 171                       js_function_Atomics.and(
# 134                            js_function_.small(
# 139                           js_function_.strike(
# 145                            js_function_.throw(
# 243                   js_function_Object.isSealed(
# 167                          js_function_Array.of(
# 169              js_function_ArrayBuffer.transfer(
# 170                       js_function_Atomics.add(
# 304                                    tot_Promise

# %% [markdown]
# ### Correlation

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 100 selected features

# %% [markdown]
# ### CHI2

# %%
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### RFE

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)

rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### SelectFromModel

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 95 selected features

# %%
# from lightgbm import LGBMClassifier

# lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
#             reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

# embeded_lgb_selector = SelectFromModel(lgbc, threshold='1e-20*mean')
# embeded_lgb_selector.fit(X, y)
# embeded_lgb_support = embeded_lgb_selector.get_support()

# embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
# print(str(len(embeded_lgb_feature)), 'selected features')

# %%
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#                                      Feature  Pearson  Chi-2    RFE  \
# 1                                   tot_Math     True   True   True
# 2                 number_of_unsecure_cookies     True   True   True
# 3                   number_of_secure_cookies     True   True   True
# 4            number_of_non_http_only_cookies     True   True   True
# 5                number_of_http_only_cookies     True   True   True
# 6                          number_of_cookies     True   True   True
# 7                  number_functions_declared     True   True   True
# 8                      js_function_parseInt(     True   True   True
# 9                    js_function_parseFloat(     True   True   True
# 10                        js_function_isNaN(     True   True   True
# 11                         js_function_eval(     True   True   True
# 12           js_function_encodeURIComponent(     True   True   True
# 13           js_function_decodeURIComponent(     True   True   True
# 14          js_function_String.fromCharCode(     True   True   True
# 15                   js_function_Math.round(     True   True   True
# 16                  js_function_Math.random(     True   True   True
# 17                     js_function_Math.min(     True   True   True
# 18                     js_function_Math.max(     True   True   True
# 19                   js_function_Math.floor(     True   True   True
# 20               js_function_JSON.stringify(     True   True   True
# 21                   js_function_JSON.parse(     True   True   True
# 22                     js_function_Date.now(     True   True   True
# 23                        js_function_.trim(     True   True   True
# 24                 js_function_.toUpperCase(     True   True   True
# 25                    js_function_.toString(     True   True   True
# 26                 js_function_.toLowerCase(     True   True   True
# 27                     js_function_.toFixed(     True   True   True
# 28                        js_function_.test(     True   True   True
# 29                   js_function_.substring(     True   True   True
# 30                       js_function_.substr     True   True   True
# 31                       js_function_.split(     True   True   True
# 32                        js_function_.sort(     True   True   True
# 33                       js_function_.shift(     True   True   True
# 34                     js_function_.setTime(     True   True   True
# 35                    js_function_.setHours(     True   True   True
# 36                     js_function_.replace(     True   True   True
# 37                        js_function_.push(     True   True   True
# 38                         js_function_.pop(     True   True   True
# 39                         js_function_.min(     True   True   True
# 40                       js_function_.match(     True   True   True
# 41                         js_function_.map(     True   True   True
# 42                        js_function_.keys(     True   True   True
# 43                        js_function_.join(     True   True   True
# 44                     js_function_.indexOf(     True   True   True
# 45                     js_function_.getYear(     True   True   True
# 46                  js_function_.getUTCDate(     True   True   True
# 47                     js_function_.getTime(     True   True   True
# 48                  js_function_.getSeconds(     True   True   True
# 49                    js_function_.getMonth(     True   True   True
# 50                  js_function_.getMinutes(     True   True   True
# 51                    js_function_.getHours(     True   True   True
# 52                 js_function_.getFullYear(     True   True   True
# 53                      js_function_.getDay(     True   True   True
# 54                     js_function_.getDate(     True   True   True
# 55                     js_function_.forEach(     True   True   True
# 56                        js_function_.exec(     True   True   True
# 57                      js_function_.concat(     True   True   True
# 58                  js_function_.charCodeAt(     True   True   True
# 59                      js_function_.charAt(     True   True   True
# 60                        js_function_.call(     True   True   True
# 61                        js_function_.bind(     True   True   True
# 62                       js_function_.apply(     True   True   True
# 63                         js_function_.add(     True   True   True
# 64                                tot_Object     True   True  False
# 65                     js_function_isFinite(     True   True   True
# 66              js_function_Promise.resolve(     True   True   True
# 67                  js_function_Promise.all(     True   True   True
# 68                  js_function_Object.keys(     True   True   True
# 69   js_function_Object.getOwnPropertyNames(     True   True   True
# 70        js_function_Object.defineProperty(     True   True  False
# 71                    js_function_Math.ceil(     True  False   True
# 72                     js_function_Math.abs(     True   True   True
# 73                js_function_Array.isArray(     True   True   True
# 74                     js_function_.unshift(     True   True  False
# 75                 js_function_.toISOString(     True   True   True
# 76                      js_function_.splice(     True   True  False
# 77                       js_function_.slice(     True   True  False
# 78                  js_function_.setSeconds(     True   True   True
# 79                  js_function_.setMinutes(     True   True   True
# 80                 js_function_.setFullYear(    False   True   True
# 81                     js_function_.setDate(     True   True  False
# 82                      js_function_.select(     True  False   True
# 83                     js_function_.reverse(     True   True  False
# 84                        js_function_.next(     True  False   True
# 85              js_function_.hasOwnProperty(     True   True  False
# 86                         js_function_.has(     True   True  False
# 87               js_function_.getUTCMinutes(     True   True   True
# 88           js_function_.getTimezoneOffset(     True   True  False
# 89             js_function_.getMilliseconds(     True   True   True
# 90                         js_function_.get(     True   True  False
# 91                        js_function_.find(     True  False   True
# 92                      js_function_.filter(     True   True  False
# 93              js_function_.defineProperty(     True   True  False
# 94                     js_function_unescape(     True  False  False
# 95                 js_function_Promise.race(    False   True   True
# 96                js_function_Object.assign(     True   True  False
# 97                      js_function_.toJSON(     True   True  False
# 98                      js_function_.search(    False  False   True
# 99        js_function_.propertyIsEnumerable(    False   True   True
# 100                   js_function_.padStart(    False   True   True
#
#      Random Forest  Total
# 1             True      4
# 2             True      4
# 3             True      4
# 4             True      4
# 5             True      4
# 6             True      4
# 7             True      4
# 8             True      4
# 9             True      4
# 10            True      4
# 11            True      4
# 12            True      4
# 13            True      4
# 14            True      4
# 15            True      4
# 16            True      4
# 17            True      4
# 18            True      4
# 19            True      4
# 20            True      4
# 21            True      4
# 22            True      4
# 23            True      4
# 24            True      4
# 25            True      4
# 26            True      4
# 27            True      4
# 28            True      4
# 29            True      4
# 30            True      4
# 31            True      4
# 32            True      4
# 33            True      4
# 34            True      4
# 35            True      4
# 36            True      4
# 37            True      4
# 38            True      4
# 39            True      4
# 40            True      4
# 41            True      4
# 42            True      4
# 43            True      4
# 44            True      4
# 45            True      4
# 46            True      4
# 47            True      4
# 48            True      4
# 49            True      4
# 50            True      4
# 51            True      4
# 52            True      4
# 53            True      4
# 54            True      4
# 55            True      4
# 56            True      4
# 57            True      4
# 58            True      4
# 59            True      4
# 60            True      4
# 61            True      4
# 62            True      4
# 63            True      4
# 64            True      3
# 65           False      3
# 66           False      3
# 67           False      3
# 68           False      3
# 69           False      3
# 70            True      3
# 71            True      3
# 72           False      3
# 73           False      3
# 74            True      3
# 75           False      3
# 76            True      3
# 77            True      3
# 78           False      3
# 79           False      3
# 80            True      3
# 81            True      3
# 82            True      3
# 83            True      3
# 84            True      3
# 85            True      3
# 86            True      3
# 87           False      3
# 88            True      3
# 89           False      3
# 90            True      3
# 91            True      3
# 92            True      3
# 93            True      3
# 94            True      2
# 95           False      2
# 96           False      2
# 97           False      2
# 98            True      2
# 99           False      2
# 100          False      2

# %%
X=df[feature_selection_df.Feature]
y=df.Malicious.values

model = LogisticRegression()
model.fit(X, y)

print("Accuracy score with top 100 selected features:")
display(model.score(X,y))
# Out:
# Accuracy score with top 100 selected features:
# 0.865166979101576

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9438733317470172
# Columns selected:
#
# Accuracy score
# 0.8658612789002291

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 6                            3.241602e+01
# 36                           1.662403e+01
# 59                           2.238060e-01
# 100                          1.457506e-01
# 90                           1.063540e-01
# 0                            7.032318e-02
# 35                           4.454177e-02
# 27                           3.687286e-02
# 43                           3.668124e-02
# 61                           3.421845e-02
# 121                          3.185962e-02
# 89                           3.114002e-02
# 63                           2.766961e-02
# 30                           2.659665e-02
# 42                           1.539413e-02
# 25                           1.209143e-02
# 24                           9.750285e-03
# 29                           9.541616e-03
# 62                           7.377634e-03
# 76                           7.367418e-03
# 39                           6.887787e-03
# 60                           6.543910e-03
# 7                            5.781490e-03
# 92                           4.572129e-03
# 40                           4.562677e-03
# 69                           4.447221e-03
# 84                           4.141778e-03
# 91                           3.220090e-03
# 54                           3.181371e-03
# 28                           2.830057e-03
# 56                           2.763983e-03
# 55                           2.336533e-03
# 57                           2.285080e-03
# 17                           2.088277e-03
# 58                           1.729932e-03
# 46                           1.722456e-03
# 32                           1.684456e-03
# 11                           1.574426e-03
# 8                            1.450278e-03
# 18                           1.295191e-03
# 75                           1.248658e-03
# 83                           1.160896e-03
# 15                           1.044228e-03
# 37                           1.012370e-03
# 14                           1.005764e-03
# 71                           8.166846e-04
# 41                           7.267070e-04
# 38                           6.722732e-04
# 16                           6.479834e-04
# 9                            6.386347e-04
# 178                          6.184401e-04
# 22                           5.633012e-04
# 23                           4.961517e-04
# 85                           4.502900e-04
# 73                           4.292655e-04
# 67                           4.199295e-04
# 252                          4.104936e-04
# 165                          4.104936e-04
# 278                          3.594450e-04
# 171                          3.594450e-04
# 19                           3.320974e-04
# 31                           3.268039e-04
# 20                           2.854675e-04
# 72                           2.848133e-04
# 114                          2.159704e-04
# 70                           2.117472e-04
# 3                            1.862299e-04
# 1                            1.851518e-04
# 51                           1.650424e-04
# 5                            1.598894e-04
# 12                           1.510275e-04
# 21                           1.338200e-04
# 48                           1.320397e-04
# 53                           1.201462e-04
# 13                           1.074232e-04
# 124                          9.722449e-05
# 299                          6.893615e-05
# 200                          6.484648e-05
# 188                          6.372338e-05
# 130                          5.141330e-05
# 101                          4.817496e-05
# 10                           4.650996e-05
# 186                          3.686735e-05
# 128                          3.280218e-05
# 82                           3.134458e-05
# 147                          3.058494e-05
# 194                          2.995497e-05
# 267                          2.903789e-05
# 228                          2.719559e-05
# 26                           2.626369e-05
# 64                           2.385809e-05
# 116                          2.241440e-05
# 68                           2.046823e-05
# 81                           1.941771e-05
# 131                          1.897400e-05
# 240                          1.700523e-05
# 115                          1.660279e-05
# 271                          1.443910e-05
# 33                           1.434524e-05
# 95                           1.344976e-05
# 174                          1.197575e-05
# 279                          1.197575e-05
# 52                           1.181388e-05
# 50                           9.755648e-06
# 129                          9.094880e-06
# 97                           8.344354e-06
# 80                           8.315769e-06
# 44                           8.243002e-06
# 106                          8.215683e-06
# 87                           6.606053e-06
# 49                           5.253941e-06
# 193                          4.887398e-06
# 265                          4.837506e-06
# 93                           4.572687e-06
# 98                           3.646929e-06
# 291                          2.804057e-06
# 204                          2.473087e-06
# 185                          2.294263e-06
# 65                           2.081242e-06
# 253                          2.012989e-06
# 207                          1.976214e-06
# 47                           1.960603e-06
# 292                          1.859477e-06
# 110                          1.527418e-06
# 96                           1.229671e-06
# 79                           1.138775e-06
# 122                          1.080535e-06
# 109                          1.018145e-06
# 103                          1.013089e-06
# 45                           1.011163e-06
# 4                            1.003744e-06
# 268                          9.615325e-07
# 2                            9.260437e-07
# 34                           9.028126e-07
# 111                          9.024319e-07
# 86                           8.621760e-07
# 175                          8.503106e-07
# 276                          8.169586e-07
# 108                          7.974361e-07
# 126                          7.709161e-07
# 137                          7.708766e-07
# 273                          7.255867e-07
# 125                          6.529270e-07
# 120                          5.942312e-07
# 78                           5.728980e-07
# 205                          5.523969e-07
# 198                          4.917899e-07
# 177                          4.796700e-07
# 88                           3.877164e-07
# 290                          3.366832e-07
# 77                           3.172900e-07
# 74                           3.043014e-07
# 233                          2.928084e-07
# 249                          2.683216e-07
# 296                          2.503055e-07
# 264                          2.438804e-07
# 247                          2.160413e-07
# 66                           2.127252e-07
# 297                          1.949061e-07
# 281                          1.913132e-07
# 275                          1.860838e-07
# 245                          1.592732e-07
# 211                          1.549693e-07
# 274                          1.292248e-07
# 107                          1.166548e-07
# 123                          1.107300e-07
# 261                          1.011999e-07
# 166                          1.011999e-07
# 280                          8.632691e-08
# 254                          8.632691e-08
# 209                          8.525408e-08
# 287                          7.752949e-08
# 119                          6.540938e-08
# 277                          6.434445e-08
# 127                          6.384570e-08
# 99                           5.895300e-08
# 255                          4.915378e-08
# 170                          3.745731e-08
# 212                          3.610929e-08
# 243                          3.003427e-08
# 112                          2.041236e-08
# 164                          1.983387e-08
# 250                          1.830875e-08
# 242                          1.765088e-08
# 260                          1.667523e-08
# 117                          1.561251e-08
# 133                          1.388253e-08
# 270                          1.266779e-08
# 169                          1.266779e-08
# 172                          1.078506e-08
# 160                          1.000031e-08
# 182                          9.421562e-09
# 234                          9.126406e-09
# 168                          8.788508e-09
# 94                           7.471743e-09
# 298                          7.298449e-09
# 238                          7.179125e-09
# 187                          6.845772e-09
# 113                          4.587717e-09
# 266                          4.390946e-09
# 301                          4.143285e-09
# 293                          4.089406e-09
# 118                          2.783978e-09
# 251                          2.667779e-09
# 237                          1.948958e-09
# 192                          1.725922e-09
# 176                          1.335684e-09
# 282                          1.292248e-09
# 189                          1.292248e-09
# 181                          1.089105e-09
# 226                          1.062942e-09
# 246                          4.323899e-10
# 161                          1.966314e-10
# 201                          1.837180e-10
# 248                          1.780173e-10
# 231                          6.695725e-11
# 300                          5.515555e-11
# 183                          2.927237e-11
# 303                          1.546868e-11
# 159                          1.444065e-11
# 294                          1.444065e-11
# 259                          1.068659e-11
# 232                          1.023195e-11
# 235                          6.735128e-12
# 229                          3.337153e-12
# 149                          1.798432e-12
# 230                          1.716030e-12
# 173                          1.317606e-12
# 179                          7.688207e-13
# 146                          7.458653e-13
# 190                          4.779823e-13
# 105                          1.351056e-13
# 288                          9.879226e-14
# 289                          8.326489e-14
# 104                          4.867987e-16
# 102                          1.216997e-16
# 262                          1.185787e-16
# 302                          0.000000e+00
# 295                          0.000000e+00
# 269                          0.000000e+00
# 286                          0.000000e+00
# 272                          0.000000e+00
# 284                          0.000000e+00
# 283                          0.000000e+00
# 256                          0.000000e+00
# 257                          0.000000e+00
# 258                          0.000000e+00
# 263                          0.000000e+00
# 285                          0.000000e+00
# 152                          0.000000e+00
# 244                          0.000000e+00
# 148                          0.000000e+00
# 167                          0.000000e+00
# 163                          0.000000e+00
# 162                          0.000000e+00
# 158                          0.000000e+00
# 157                          0.000000e+00
# 156                          0.000000e+00
# 155                          0.000000e+00
# 154                          0.000000e+00
# 153                          0.000000e+00
# 151                          0.000000e+00
# 150                          0.000000e+00
# 145                          0.000000e+00
# 184                          0.000000e+00
# 144                          0.000000e+00
# 143                          0.000000e+00
# 142                          0.000000e+00
# 141                          0.000000e+00
# 140                          0.000000e+00
# 139                          0.000000e+00
# 138                          0.000000e+00
# 136                          0.000000e+00
# 135                          0.000000e+00
# 134                          0.000000e+00
# 132                          0.000000e+00
# 180                          0.000000e+00
# 191                          0.000000e+00
# 241                          0.000000e+00
# 217                          0.000000e+00
# 239                          0.000000e+00
# 236                          0.000000e+00
# 227                          0.000000e+00
# 225                          0.000000e+00
# 224                          0.000000e+00
# 223                          0.000000e+00
# 222                          0.000000e+00
# 221                          0.000000e+00
# 220                          0.000000e+00
# 219                          0.000000e+00
# 218                          0.000000e+00
# 216                          0.000000e+00
# 195                          0.000000e+00
# 215                          0.000000e+00
# 214                          0.000000e+00
# 213                          0.000000e+00
# 210                          0.000000e+00
# 208                          0.000000e+00
# 206                          0.000000e+00
# 203                          0.000000e+00
# 202                          0.000000e+00
# 199                          0.000000e+00
# 197                          0.000000e+00
# 196                          0.000000e+00
# 304                          0.000000e+00
#
#                                           Features
# 6                        number_functions_declared
# 36                              js_function_.push(
# 59                              js_function_.call(
# 100                              js_function_.log(
# 90                              js_function_.find(
# 0                                         tot_Math
# 35                           js_function_.replace(
# 27                              js_function_.test(
# 43                           js_function_.indexOf(
# 61                             js_function_.apply(
# 121                              js_function_.set(
# 89                               js_function_.get(
# 63                                      tot_Object
# 30                             js_function_.split(
# 42                              js_function_.join(
# 25                       js_function_.toLowerCase(
# 24                          js_function_.toString(
# 29                             js_function_.substr
# 62                               js_function_.add(
# 76                             js_function_.slice(
# 39                             js_function_.match(
# 60                              js_function_.bind(
# 7                            js_function_parseInt(
# 92                    js_function_.defineProperty(
# 40                               js_function_.map(
# 69              js_function_Object.defineProperty(
# 84                    js_function_.hasOwnProperty(
# 91                            js_function_.filter(
# 54                           js_function_.forEach(
# 28                         js_function_.substring(
# 56                            js_function_.concat(
# 55                              js_function_.exec(
# 57                        js_function_.charCodeAt(
# 17                           js_function_Math.max(
# 58                            js_function_.charAt(
# 46                           js_function_.getTime(
# 32                             js_function_.shift(
# 11                 js_function_encodeURIComponent(
# 8                          js_function_parseFloat(
# 18                         js_function_Math.floor(
# 75                            js_function_.splice(
# 83                              js_function_.next(
# 15                        js_function_Math.random(
# 37                               js_function_.pop(
# 14                         js_function_Math.round(
# 71                           js_function_Math.abs(
# 41                              js_function_.keys(
# 38                               js_function_.min(
# 16                           js_function_Math.min(
# 9                               js_function_isNaN(
# 178                     js_function_Object.create(
# 22                              js_function_.trim(
# 23                       js_function_.toUpperCase(
# 85                               js_function_.has(
# 73                           js_function_.unshift(
# 67                        js_function_Object.keys(
# 252                   js_function_.setPrototypeOf(
# 165             js_function_Object.setPrototypeOf(
# 278                   js_function_.getPrototypeOf(
# 171             js_function_Object.getPrototypeOf(
# 19                     js_function_JSON.stringify(
# 31                              js_function_.sort(
# 20                         js_function_JSON.parse(
# 72                      js_function_Array.isArray(
# 114                          js_function_Math.pow(
# 70                          js_function_Math.ceil(
# 3                  number_of_non_http_only_cookies
# 1                       number_of_unsecure_cookies
# 51                       js_function_.getFullYear(
# 5                                number_of_cookies
# 12                 js_function_decodeURIComponent(
# 21                           js_function_Date.now(
# 48                          js_function_.getMonth(
# 53                           js_function_.getDate(
# 13                js_function_String.fromCharCode(
# 124                           js_function_.reduce(
# 299                            js_function_.clear(
# 200                          js_function_Math.cos(
# 188                          js_function_Math.sin(
# 130                            js_function_.catch(
# 101                      js_function_.lastIndexOf(
# 10                               js_function_eval(
# 186                         js_function_Math.sqrt(
# 128                             js_function_.from(
# 82                           js_function_.reverse(
# 147                        js_function_Symbol.for(
# 194                         js_function_Math.imul(
# 267                             js_function_.link(
# 228                           js_function_.values(
# 26                           js_function_.toFixed(
# 64                           js_function_isFinite(
# 116                          js_function_.valueOf(
# 68         js_function_Object.getOwnPropertyNames(
# 81                            js_function_.select(
# 131                              js_function_.all(
# 240                             js_function_.some(
# 115                        js_function_Array.from(
# 271                         js_function_.includes(
# 33                           js_function_.setTime(
# 95                      js_function_Object.assign(
# 174   js_function_Object.getOwnPropertyDescriptor(
# 279         js_function_.getOwnPropertyDescriptor(
# 52                            js_function_.getDay(
# 50                          js_function_.getHours(
# 129                           js_function_.delete(
# 97                            js_function_.search(
# 80                           js_function_.setDate(
# 44                           js_function_.getYear(
# 106                            js_function_.every(
# 87                 js_function_.getTimezoneOffset(
# 49                        js_function_.getMinutes(
# 193                          js_function_Math.log(
# 265                        js_function_.normalize(
# 93                           js_function_unescape(
# 98              js_function_.propertyIsEnumerable(
# 291                             js_function_.fill(
# 204                        js_function_Math.atan2(
# 185                          js_function_Math.tan(
# 65                    js_function_Promise.resolve(
# 253                         js_function_.setMonth(
# 207                         js_function_Math.asin(
# 47                        js_function_.getSeconds(
# 292                          js_function_.entries(
# 110                         js_function_decodeURI(
# 96                            js_function_.toJSON(
# 79                       js_function_.setFullYear(
# 122                           js_function_.return(
# 109                         js_function_encodeURI(
# 103                      js_function_.getUTCHours(
# 45                        js_function_.getUTCDate(
# 4                      number_of_http_only_cookies
# 268                    js_function_.isPrototypeOf(
# 2                         number_of_secure_cookies
# 34                          js_function_.setHours(
# 111                       js_function_Object.seal(
# 86                     js_function_.getUTCMinutes(
# 175                     js_function_Object.freeze(
# 276                      js_function_.getUTCMonth(
# 108                            js_function_escape)
# 126                   js_function_.getUTCFullYear(
# 137                         js_function_undefined(
# 273                         js_function_.getUint8(
# 125                    js_function_.getUTCSeconds(
# 120                  js_function_.setMilliseconds(
# 78                        js_function_.setMinutes(
# 205                         js_function_Math.atan(
# 198                          js_function_Math.exp(
# 177           js_function_Object.defineProperties(
# 88                   js_function_.getMilliseconds(
# 290                        js_function_.findIndex(
# 77                        js_function_.setSeconds(
# 74                       js_function_.toISOString(
# 233                   js_function_.toLocaleString(
# 249                      js_function_.setUTCHours(
# 296                        js_function_.construct(
# 264                               js_function_.of(
# 247                    js_function_.setUTCMinutes(
# 66                        js_function_Promise.all(
# 297                          js_function_.compile(
# 281                         js_function_.getInt32(
# 275                        js_function_.getUint16(
# 245                    js_function_.setUTCSeconds(
# 211                        js_function_Date.parse(
# 274                        js_function_.getUint32(
# 107                                     tot_Number
# 123                           js_function_.repeat(
# 261                js_function_.preventExtensions(
# 166          js_function_Object.preventExtensions(
# 280                          js_function_.getInt8(
# 254                          js_function_.setInt8(
# 209                         js_function_Math.acos(
# 287                          js_function_.flatMap(
# 119                          js_function_.setYear(
# 277               js_function_.getUTCMilliseconds(
# 127                        js_function_.getUTCDay(
# 99                          js_function_.padStart(
# 255                         js_function_.setInt32(
# 170                         js_function_Object.is(
# 212                          js_function_Date.UTC(
# 243                        js_function_.setUint32(
# 112                  js_function_Number.isInteger(
# 164                    js_function_Promise.reject(
# 250                   js_function_.setUTCFullYear(
# 242                         js_function_.setUint8(
# 260                      js_function_.reduceRight(
# 117                         js_function_.toSource(
# 133                                    tot_Reflect
# 270                     js_function_.isExtensible(
# 169               js_function_Object.isExtensible(
# 172      js_function_Object.getOwnPropertySymbols(
# 160            js_function_Reflect.defineProperty(
# 182                      js_function_Number.isNaN(
# 234                    js_function_.toExponential(
# 168                   js_function_Object.isFrozen(
# 94                       js_function_Promise.race(
# 298                      js_function_.codePointAt(
# 238                         js_function_.subarray(
# 187                         js_function_Math.sinh(
# 113                   js_function_Number.isFinite(
# 266                    js_function_.localeCompare(
# 301                            js_function_.blink(
# 293                          js_function_.endWith(
# 118               js_function_.toLocaleTimeString(
# 251                       js_function_.setUTCDate(
# 237               js_function_.supportedLocalesOf(
# 192                        js_function_Math.log10(
# 176                    js_function_Object.entries(
# 282                         js_function_.getInt16(
# 189                         js_function_Math.sign(
# 181              js_function_Number.isSafeInteger(
# 226                js_function_ArrayBuffer.isView(
# 246                      js_function_.setUTCMonth(
# 161                 js_function_Reflect.construct(
# 201                        js_function_Math.clz32(
# 248               js_function_.setUTCMilliseconds(
# 231                      js_function_.toPrecision(
# 300                             js_function_.bold(
# 183                        js_function_Math.trunc(
# 303                           js_function_.anchor(
# 159            js_function_Reflect.deleteProperty(
# 294                   js_function_.deleteProperty(
# 259                  js_function_.resolvedOptions(
# 232                js_function_.toLocaleUpperCase(
# 235                     js_function_.toDateString(
# 229                        js_function_.trimStart(
# 149              js_function_String.fromCodePoint(
# 230                          js_function_.trimEnd(
# 173  js_function_Object.getOwnPropertyDescriptors(
# 179                   js_function_Number.parseInt(
# 146                     js_function_Symbol.keyFor(
# 190                         js_function_Math.log2(
# 105                          js_function_.finally(
# 288                             js_function_.flat(
# 289                            js_function_.fixed(
# 104                        js_function_.fontcolor(
# 102                          js_function_.italics(
# 262                           js_function_.padEnd(
# 302                              js_function_.big(
# 295                       js_function_.copyWithin(
# 269                            js_function_.isNan(
# 286                         js_function_.fontsize(
# 272                             js_function_.grow(
# 284                       js_function_.getFloat32(
# 283                       js_function_.getFloat64(
# 256                         js_function_.setInt16(
# 257                       js_function_.setFloat64(
# 258                       js_function_.setFloat32(
# 263                          js_function_.ownKeys(
# 285                    js_function_.formatToParts(
# 152         js_function_Reflect.preventExtensions(
# 244                        js_function_.setUint16(
# 148                        js_function_String.raw(
# 167                   js_function_Object.isSealed(
# 163                   js_function_Proxy.revocable(
# 162                     js_function_Reflect.apply(
# 158                       js_function_Reflect.get(
# 157  js_function_Reflect.getOwnPropertyDescriptor(
# 156            js_function_Reflect.getPrototypeOf(
# 155                       js_function_Reflect.has(
# 154              js_function_Reflect.isExtensible(
# 153                   js_function_Reflect.ownKeys(
# 151                       js_function_Reflect.set(
# 150            js_function_Reflect.setPrototypeOf(
# 145               js_function_WebAssembly.compile(
# 184                         js_function_Math.tanh(
# 144      js_function_WebAssembly.compileStreaming(
# 143      js_function_WebAssembly.customerSections(
# 142               js_function_WebAssembly.exports(
# 141               js_function_WebAssembly.imports(
# 140           js_function_WebAssembly.instantiate(
# 139  js_function_WebAssembly.instantiateStreaming(
# 138              js_function_WebAssembly.validate(
# 136                            js_function_uneval(
# 135                                    tot_Atomics
# 134                                    tot_Promise
# 132                                tot_WebAssembly
# 180                 js_function_Number.parseFloat(
# 191                        js_function_Math.log1p(
# 241                            js_function_.small(
# 217                     js_function_Atomics.store(
# 239                           js_function_.strike(
# 236                            js_function_.throw(
# 227                          js_function_Array.of(
# 225              js_function_ArrayBuffer.transfer(
# 224                       js_function_Atomics.add(
# 223                       js_function_Atomics.and(
# 222           js_function_Atomics.compareExchange(
# 221                  js_function_Atomics.exchange(
# 220                js_function_Atomics.isLockFree(
# 219                      js_function_Atomics.load(
# 218                        js_function_Atomics.or(
# 216                       js_function_Atomics.sub(
# 195                        js_function_Math.hypot(
# 215                      js_function_Atomics.wait(
# 214                      js_function_Atomics.wake(
# 213                       js_function_Atomics.xor(
# 210          js_function_Intl.getCanonicalLocales(
# 208                        js_function_Math.acosh(
# 206                        js_function_Math.asinh(
# 203                        js_function_Math.atanh(
# 202                         js_function_Math.cbrt(
# 199                         js_function_Math.cosh(
# 197                        js_function_Math.expm1(
# 196                       js_function_Math.fround(
# 304                          js_function_.allTrue(
