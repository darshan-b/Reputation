# %% [markdown]
# ***
# ## Table of Contents
# <br>
#     <ol>
#         <h2><a href='#1' style="text-decoration : none; color : #000000;">1. HTTP</a></h2>
#         <ul>
#             <a href='#1.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#1.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#1.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#1.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#1.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a></h2>
#         <ul><a href='#2.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#2.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#2.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>
#
# <br>
#     <ol>
#         <h2><a href='#3' style="text-decoration : none; color : #000000;">3. HTTPS</a></h2>
#         <ul>
#             <a href='#3.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#3.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#3.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#3.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#3.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a></h2>
#         <ul><a href='#4.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#4.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#4.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output,HTML
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from tabulate import tabulate

import keras
from keras.layers import Dense,Dropout
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)

from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split,cross_val_score

from sklearn.preprocessing import MinMaxScaler,StandardScaler,binarize
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE
from sklearn import metrics

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix,accuracy_score,auc,roc_curve,recall_score
from sklearn import metrics
from pandas_ml import ConfusionMatrix


from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
### Function get_params takes as input a grid search model and prints out the best parameters for the model and 
### prints the best accuracy of the model
def get_params(grid,model_name=''):
    print("Best Parameters are :")
    display(pd.DataFrame.from_dict(grid.best_params_, orient='index').reset_index().transpose())

### The function takes as input the model, X and Y data to generate the confusion matrix  
def get_cm(model,a,b):
    y_pred=model.predict(a)
    cm=ConfusionMatrix(b,y_pred)
    return cm
 
### The get accuracy plot takes as input a dataframe and a string for the title of the plot and displays a plot
### The function is primarily for plotting of accuracies for various classifiers for the same split.
def get_accuracy_plot(data,title=''):
    plt.figure(figsize=(12,8))
    plt.plot(data['accuracy'].values, '--o')
    plt.ylabel('Accuracy', fontsize=20)
    plt.xlabel('Classifier', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    plt.xlim([0, 9])
    plt.title(title,size=18,y=1.05)
    plt.xticks(np.arange(10),data.index.get_values(),rotation=90)
    plt.legend(loc='upper right', fontsize=18)
    plt.show()

### Function grid takes as input an estimator, X_train,Y_Train,X_test and Y_test and a string represetning the name of the model
### We perform StratifiedKFold cross validation and grid search to hypertune the parameters of the model     
def grid(kernel,params,x,y,x_test,y_test,model_name=''):
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    grid_search=GridSearchCV(estimator=kernel,param_grid=parameters,scoring='accuracy',cv=kfold,n_jobs=3,verbose=True)
    grid_search.fit(x,y)
    get_params(grid_search,model_name)
    acc_train=accuracy_score(y,grid_search.predict(x))
    print("Accuracy of the ",model_name," model for the training data is:",acc_train)
    print("\nConfusion Matrix for Training data is:")
    cm_train=get_cm(grid_search,x,y)
    display(cm_train)
    acc_test=accuracy_score(y_test,grid_search.predict(x_test))
    print("Accuracy of the ",model_name," model for test data is:",acc_test)
    print("\nConfusion Matrix for test data is:")
    cm_test=get_cm(grid_search,x_test,y_test)
    display(cm_test)
    fpr, tpr, threshold = roc_curve(y_test, grid_search.predict(x_test))
    roc_auc =auc(fpr, tpr)
    return grid_search,cm_train,cm_test,acc_train,acc_test,roc_auc  

### Plot roc curve
def get_roc_curve(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob[:,1]
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy on test data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

def get_roc_curve_deep_learning(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy of Logistic Model on training data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

# %% [markdown]
# ## <a id='1' style="text-decoration : none; color : #000000;"> HTTP</a>
#
# ### <a id='1.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_http.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)


# df.to_csv('Javascript_dom.csv')

df.head()

 
X=df.loc[:,df.columns!='Malicious']
X.drop(['number_of_unsecure_cookies','number_of_secure_cookies','number_of_non_http_only_cookies','number_of_http_only_cookies',
 'number_of_cookies'],axis=1,inplace=True)
y=df.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df.shape)
df.head()
# Out:
# Shape after undersampling (43296, 407)
#                   dom_function_document.adoptNode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_document.captureEvents(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.caretPositionFromPoint(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.caretRangeFromPoint(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.clear(  dom_function_document.close(  \
# domain
# h83.turdizi.com                            0.0                           0.0
# hbgv.wivela.com                            0.0                           0.0
# nus.edu.sg                                 0.0                           0.0
# arabwebpage.com                            0.0                           0.0
# moscatalogue.net                           0.0                           0.0
#
#                   dom_function_document.createAttribute(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createAttributeNS(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.createCDATASection(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createComment(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.createDocumentFragment(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.createElement(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    4.0
# nus.edu.sg                                         1.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   1.0
#
#                   dom_function_document.createElementNS(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createEntityReference(  \
# domain
# h83.turdizi.com                                            0.0
# hbgv.wivela.com                                            0.0
# nus.edu.sg                                                 0.0
# arabwebpage.com                                            0.0
# moscatalogue.net                                           0.0
#
#                   dom_function_document.createEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createNodeIterator(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createProcessingInstruction(  \
# domain
# h83.turdizi.com                                                 0.0
# hbgv.wivela.com                                                 0.0
# nus.edu.sg                                                      0.0
# arabwebpage.com                                                 0.0
# moscatalogue.net                                                0.0
#
#                   dom_function_document.createRange(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTextNode(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          1.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.createTouch(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTouchList(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createTreeWalker(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementFromPoint(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementsFromPoint(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.enableStyleSheetsForSet(  \
# domain
# h83.turdizi.com                                              0.0
# hbgv.wivela.com                                              0.0
# nus.edu.sg                                                   0.0
# arabwebpage.com                                              0.0
# moscatalogue.net                                             0.0
#
#                   dom_function_document.execCommand(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.exitPointerLock(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.getAnimations(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.getElementById(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.getElementByName(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.getElementsByClassName(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             1.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getElementsByTagName(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           3.0
# nus.edu.sg                                                1.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.getElementsByTagNameNS(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getSelection(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.hasFocus(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_document.importNode(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.normalizeDocument(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.open(  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                0.0
# arabwebpage.com                           0.0
# moscatalogue.net                          0.0
#
#                   dom_function_document.queryCommandEnabled(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.queryCommandIndeterm(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.queryCommandValue(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.querySelector(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.querySelectorAll(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.releaseCapture(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.releaseEvent(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.routeEvent(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.write(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           2.0
#
#                   dom_function_document.writeln(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.addEventListener(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     1.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.alert(  dom_function_window.atob(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.back(  dom_function_window.blur(  \
# domain
# h83.turdizi.com                         0.0                        0.0
# hbgv.wivela.com                         0.0                        0.0
# nus.edu.sg                              0.0                        0.0
# arabwebpage.com                         0.0                        0.0
# moscatalogue.net                        0.0                        0.0
#
#                   dom_function_window.btoa(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.cancelAnimationFrame(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_window.cancelIdleCallback(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_window.captureEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearImmediate(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_window.clearInterval(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearTimeout(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.close(  dom_function_window.confirm(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.createImageBitmap(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_window.disableExternalCapture(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.dispatchEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.dump(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.enableExternalCapture(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.fetch(  dom_function_window.find(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.focus(  dom_function_window.forward(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.getAttention(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.getAttentionWithCycleCount(  \
# domain
# h83.turdizi.com                                               0.0
# hbgv.wivela.com                                               0.0
# nus.edu.sg                                                    0.0
# arabwebpage.com                                               0.0
# moscatalogue.net                                              0.0
#
#                   dom_function_window.getComputedStyle(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.getDefaultComputedSyle(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.getSelection(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.home(  dom_function_window.matchMedia(  \
# domain
# h83.turdizi.com                         0.0                              0.0
# hbgv.wivela.com                         0.0                              0.0
# nus.edu.sg                              0.0                              0.0
# arabwebpage.com                         0.0                              0.0
# moscatalogue.net                        0.0                              0.0
#
#                   dom_function_window.maximize(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.minimize(  dom_function_window.moveBy(  \
# domain
# h83.turdizi.com                             0.0                          0.0
# hbgv.wivela.com                             0.0                          0.0
# nus.edu.sg                                  0.0                          0.0
# arabwebpage.com                             0.0                          0.0
# moscatalogue.net                            0.0                          0.0
#
#                   dom_function_window.moveTo(  dom_function_window.open(  \
# domain
# h83.turdizi.com                           0.0                        0.0
# hbgv.wivela.com                           0.0                        0.0
# nus.edu.sg                                0.0                        2.0
# arabwebpage.com                           0.0                        0.0
# moscatalogue.net                          0.0                        0.0
#
#                   dom_function_window.openDialog(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.postMessage(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.print(  dom_function_window.prompt(  \
# domain
# h83.turdizi.com                          0.0                          0.0
# hbgv.wivela.com                          0.0                          0.0
# nus.edu.sg                               0.0                          0.0
# arabwebpage.com                          0.0                          0.0
# moscatalogue.net                         0.0                          0.0
#
#                   dom_function_window.releaseEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.removeEventListener(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.requestAnimationFrame(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.requestIdleCallback(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.resizeBy(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.resizeTo(  dom_function_window.restore(  \
# domain
# h83.turdizi.com                             0.0                           0.0
# hbgv.wivela.com                             0.0                           0.0
# nus.edu.sg                                  0.0                           0.0
# arabwebpage.com                             0.0                           0.0
# moscatalogue.net                            0.0                           0.0
#
#                   dom_function_window.routeEvent(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.scroll(  dom_function_window.scrollBy(  \
# domain
# h83.turdizi.com                           0.0                            0.0
# hbgv.wivela.com                           0.0                            0.0
# nus.edu.sg                                0.0                            0.0
# arabwebpage.com                           0.0                            0.0
# moscatalogue.net                          0.0                            0.0
#
#                   dom_function_window.scrollByLines(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollByPages(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollTo(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.setCursor(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.setImmediate(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setInterval(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.setResizable(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setTimeout(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.sizeToContent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.stop(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.updateCommands(  js_function_.add(  \
# domain
# h83.turdizi.com                                   0.0                0.0
# hbgv.wivela.com                                   0.0                0.0
# nus.edu.sg                                        0.0                0.0
# arabwebpage.com                                   0.0                0.0
# moscatalogue.net                                  0.0                0.0
#
#                   js_function_.all(  js_function_.allTrue(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_.anchor(  js_function_.apply(  \
# domain
# h83.turdizi.com                    0.0                  0.0
# hbgv.wivela.com                    0.0                  6.0
# nus.edu.sg                         0.0                  0.0
# arabwebpage.com                    0.0                  0.0
# moscatalogue.net                   0.0                  0.0
#
#                   js_function_.big(  js_function_.bind(  js_function_.blink(  \
# domain
# h83.turdizi.com                 0.0                 0.0                  0.0
# hbgv.wivela.com                 0.0                 0.0                  0.0
# nus.edu.sg                      0.0                 0.0                  0.0
# arabwebpage.com                 0.0                 0.0                  0.0
# moscatalogue.net                0.0                 0.0                  0.0
#
#                   js_function_.bold(  js_function_.call(  js_function_.catch(  \
# domain
# h83.turdizi.com                  0.0                 0.0                  0.0
# hbgv.wivela.com                  0.0                 4.0                  0.0
# nus.edu.sg                       0.0                 0.0                  0.0
# arabwebpage.com                  0.0                 0.0                  0.0
# moscatalogue.net                 0.0                 0.0                  0.0
#
#                   js_function_.charAt(  js_function_.charCodeAt(  \
# domain
# h83.turdizi.com                    0.0                       0.0
# hbgv.wivela.com                    2.0                       0.0
# nus.edu.sg                         1.0                       0.0
# arabwebpage.com                    0.0                       0.0
# moscatalogue.net                   0.0                       0.0
#
#                   js_function_.clear(  js_function_.codePointAt(  \
# domain
# h83.turdizi.com                   0.0                        0.0
# hbgv.wivela.com                   0.0                        0.0
# nus.edu.sg                        0.0                        0.0
# arabwebpage.com                   0.0                        0.0
# moscatalogue.net                  0.0                        0.0
#
#                   js_function_.compile(  js_function_.concat(  \
# domain
# h83.turdizi.com                     0.0                   0.0
# hbgv.wivela.com                     0.0                   2.0
# nus.edu.sg                          0.0                   0.0
# arabwebpage.com                     0.0                   0.0
# moscatalogue.net                    0.0                   0.0
#
#                   js_function_.construct(  js_function_.copyWithin(  \
# domain
# h83.turdizi.com                       0.0                       0.0
# hbgv.wivela.com                       0.0                       0.0
# nus.edu.sg                            0.0                       0.0
# arabwebpage.com                       0.0                       0.0
# moscatalogue.net                      0.0                       0.0
#
#                   js_function_.defineProperty(  js_function_.delete(  \
# domain
# h83.turdizi.com                            0.0                   0.0
# hbgv.wivela.com                            2.0                   0.0
# nus.edu.sg                                 0.0                   0.0
# arabwebpage.com                            0.0                   0.0
# moscatalogue.net                           0.0                   0.0
#
#                   js_function_.deleteProperty(  js_function_.endWith(  \
# domain
# h83.turdizi.com                            0.0                    0.0
# hbgv.wivela.com                            0.0                    0.0
# nus.edu.sg                                 0.0                    0.0
# arabwebpage.com                            0.0                    0.0
# moscatalogue.net                           0.0                    0.0
#
#                   js_function_.entries(  js_function_.every(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   js_function_.exec(  js_function_.fill(  \
# domain
# h83.turdizi.com                  0.0                 0.0
# hbgv.wivela.com                  0.0                 0.0
# nus.edu.sg                       0.0                 0.0
# arabwebpage.com                  0.0                 0.0
# moscatalogue.net                 0.0                 0.0
#
#                   js_function_.filter(  js_function_.finally(  \
# domain
# h83.turdizi.com                    0.0                    0.0
# hbgv.wivela.com                    0.0                    0.0
# nus.edu.sg                         0.0                    0.0
# arabwebpage.com                    0.0                    0.0
# moscatalogue.net                   0.0                    0.0
#
#                   js_function_.find(  js_function_.findIndex(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  0.0                      0.0
# nus.edu.sg                       6.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_.fixed(  js_function_.flat(  \
# ...
#
#                   js_function_Object.setPrototypeOf(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   js_function_Promise.all(  js_function_Promise.race(  \
# domain
# h83.turdizi.com                        0.0                        0.0
# hbgv.wivela.com                        0.0                        0.0
# nus.edu.sg                             0.0                        0.0
# arabwebpage.com                        0.0                        0.0
# moscatalogue.net                       0.0                        0.0
#
#                   js_function_Promise.reject(  js_function_Promise.resolve(  \
# domain
# h83.turdizi.com                           0.0                           0.0
# hbgv.wivela.com                           0.0                           0.0
# nus.edu.sg                                0.0                           0.0
# arabwebpage.com                           0.0                           0.0
# moscatalogue.net                          0.0                           0.0
#
#                   js_function_Proxy.revocable(  js_function_Reflect.apply(  \
# domain
# h83.turdizi.com                            0.0                         0.0
# hbgv.wivela.com                            0.0                         0.0
# nus.edu.sg                                 0.0                         0.0
# arabwebpage.com                            0.0                         0.0
# moscatalogue.net                           0.0                         0.0
#
#                   js_function_Reflect.construct(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   js_function_Reflect.defineProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.deleteProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.get(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_Reflect.getPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.has(  js_function_Reflect.isExtensible(  \
# domain
# h83.turdizi.com                        0.0                                0.0
# hbgv.wivela.com                        0.0                                0.0
# nus.edu.sg                             0.0                                0.0
# arabwebpage.com                        0.0                                0.0
# moscatalogue.net                       0.0                                0.0
#
#                   js_function_Reflect.ownKeys(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           0.0
#
#                   js_function_Reflect.preventExtensions(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   js_function_Reflect.set(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.setPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_String.fromCharCode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_String.fromCodePoint(  js_function_String.raw(  \
# domain
# h83.turdizi.com                                 0.0                      0.0
# hbgv.wivela.com                                 0.0                      0.0
# nus.edu.sg                                      0.0                      0.0
# arabwebpage.com                                 0.0                      0.0
# moscatalogue.net                                0.0                      0.0
#
#                   js_function_Symbol.for(  js_function_Symbol.keyFor(  \
# domain
# h83.turdizi.com                       0.0                         0.0
# hbgv.wivela.com                       0.0                         0.0
# nus.edu.sg                            0.0                         0.0
# arabwebpage.com                       0.0                         0.0
# moscatalogue.net                      0.0                         0.0
#
#                   js_function_WebAssembly.compile(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.compileStreaming(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.customerSections(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.exports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.imports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.instantiate(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   js_function_WebAssembly.instantiateStreaming(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_WebAssembly.validate(  js_function_decodeURI(  \
# domain
# h83.turdizi.com                                 0.0                     0.0
# hbgv.wivela.com                                 0.0                     0.0
# nus.edu.sg                                      0.0                     0.0
# arabwebpage.com                                 0.0                     0.0
# moscatalogue.net                                0.0                     0.0
#
#                   js_function_decodeURIComponent(  js_function_encodeURI(  \
# domain
# h83.turdizi.com                               0.0                     0.0
# hbgv.wivela.com                               0.0                     0.0
# nus.edu.sg                                    1.0                     0.0
# arabwebpage.com                               0.0                     0.0
# moscatalogue.net                              0.0                     0.0
#
#                   js_function_encodeURIComponent(  js_function_escape(  \
# domain
# h83.turdizi.com                               0.0                  0.0
# hbgv.wivela.com                               0.0                  0.0
# nus.edu.sg                                    1.0                  0.0
# arabwebpage.com                               0.0                  0.0
# moscatalogue.net                              0.0                  2.0
#
#                   js_function_eval(  js_function_isFinite(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_isNaN(  js_function_parseFloat(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  1.0                      0.0
# nus.edu.sg                       0.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_parseInt(  js_function_undefined(  \
# domain
# h83.turdizi.com                     0.0                     0.0
# hbgv.wivela.com                     0.0                     0.0
# nus.edu.sg                          0.0                     0.0
# arabwebpage.com                     0.0                     0.0
# moscatalogue.net                    0.0                     0.0
#
#                   js_function_unescape(  js_function_uneval(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   number_functions_declared  number_of_cookies  \
# domain
# h83.turdizi.com                         0.0                0.0
# hbgv.wivela.com                        87.0                6.0
# nus.edu.sg                             24.0                4.0
# arabwebpage.com                         7.0                4.0
# moscatalogue.net                        3.0                5.0
#
#                   number_of_http_only_cookies  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                1.0
# arabwebpage.com                           1.0
# moscatalogue.net                          1.0
#
#                   number_of_non_http_only_cookies  number_of_secure_cookies  \
# domain
# h83.turdizi.com                               0.0                       0.0
# hbgv.wivela.com                               6.0                       0.0
# nus.edu.sg                                    3.0                       0.0
# arabwebpage.com                               3.0                       0.0
# moscatalogue.net                              4.0                       1.0
#
#                   number_of_unsecure_cookies  Malicious
# domain
# h83.turdizi.com                          0.0          1
# hbgv.wivela.com                          6.0          1
# nus.edu.sg                               4.0          0
# arabwebpage.com                          4.0          0
# moscatalogue.net                         4.0          0

# %% [markdown]
# ### <a id='1.B' style="text-decoration : none; color : #000000;">B. Feature Selection</a>
#
# <ol>
#     <ul><h4> 1. Correlation</h4></ul>
#     <ul><h4> 2. Chi2 </h4></ul>
#     <ul><h4> 3. Recursive Feature Elimination </h4></ul>
#     <ul><h4> 4. Select From Model </h4></ul>
# </ol>

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)


X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()


rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()


embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()


feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)

# %% [markdown]
# ### <a id='1.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
X=df[feature_selection_df[feature_selection_df.Total==4]['Feature']]

scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
x_train, X_test, y_train, Y_test = train_test_split(X, y,test_size=0.2,random_state=12)

sm = SMOTE(random_state=12, ratio = 1.0)
X_train, Y_train = sm.fit_sample(x_train, y_train)

y=df.Malicious.values
feature_name = X.columns.tolist()

X.shape
# Out:
# The train/test split ratio is 80:20
# (43296, 73)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['number_functions_declared',
#  'js_function_parseInt(',
#  'js_function_isFinite(',
#  'js_function_escape(',
#  'js_function_encodeURIComponent(',
#  'js_function_decodeURIComponent(',
#  'js_function_String.fromCharCode(',
#  'js_function_Object.keys(',
#  'js_function_Object.getOwnPropertyNames(',
#  'js_function_Math.round(',
#  'js_function_Math.random(',
#  'js_function_Math.min(',
#  'js_function_Math.max(',
#  'js_function_Math.floor(',
#  'js_function_JSON.stringify(',
#  'js_function_JSON.parse(',
#  'js_function_Date.now(',
#  'js_function_.trim(',
#  'js_function_.toString(',
#  'js_function_.toLowerCase(',
#  'js_function_.test(',
#  'js_function_.substring(',
#  'js_function_.substr',
#  'js_function_.split(',
#  'js_function_.sort(',
#  'js_function_.shift(',
#  'js_function_.setTime(',
#  'js_function_.setHours(',
#  'js_function_.reverse(',
#  'js_function_.replace(',
#  'js_function_.push(',
#  'js_function_.pop(',
#  'js_function_.min(',
#  'js_function_.match(',
#  'js_function_.map(',
#  'js_function_.keys(',
#  'js_function_.join(',
#  'js_function_.indexOf(',
#  'js_function_.has(',
#  'js_function_.getYear(',
#  'js_function_.getUTCHours(',
#  'js_function_.getUTCDate(',
#  'js_function_.getTime(',
#  'js_function_.getSeconds(',
#  'js_function_.getMonth(',
#  'js_function_.getMinutes(',
#  'js_function_.getMilliseconds(',
#  'js_function_.getHours(',
#  'js_function_.getFullYear(',
#  'js_function_.getDay(',
#  'js_function_.getDate(',
#  'js_function_.get(',
#  'js_function_.forEach(',
#  'js_function_.exec(',
#  'js_function_.concat(',
#  'js_function_.charAt(',
#  'js_function_.bind(',
#  'js_function_.apply(',
#  'js_function_.add(',
#  'dom_function_window.setInterval(',
#  'dom_function_window.matchMedia(',
#  'dom_function_window.getComputedStyle(',
#  'dom_function_window.clearTimeout(',
#  'dom_function_window.addEventListener(',
#  'dom_function_document.querySelectorAll(',
#  'dom_function_document.querySelector(',
#  'dom_function_document.open(',
#  'dom_function_document.getElementsByTagName(',
#  'dom_function_document.getElementsByClassName(',
#  'dom_function_document.getElementById(',
#  'dom_function_document.createTextNode(',
#  'dom_function_document.createEvent(',
#  'dom_function_document.createElement(']

# %% [markdown]
# ### <a id='1.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.9005066711704104
# Predicted  False   True  __all__
# Actual
# False      24449   5156    29605
# True         735  28870    29605
# __all__    25184  34026    59210
# The accuracy of the model on test data is: 0.8435334872979214
# Predicted  False  True  __all__
# Actual
# False       6114  1290     7404
# True          65  1191     1256
# __all__     6179  2481     8660

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.5385070089511906
# Predicted  False  True  __all__
# Actual
# False      28881   724    29605
# True       26601  3004    29605
# __all__    55482  3728    59210
# The accuracy of the model on test data is: 0.836027713625866
# Predicted  False  True  __all__
# Actual
# False       7143   261     7404
# True        1159    97     1256
# __all__     8302   358     8660

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8212126330011822
# Predicted  False   True  __all__
# Actual
# False      20255   9350    29605
# True        1236  28369    29605
# __all__    21491  37719    59210
# The accuracy of the model on test data is: 0.7200923787528868
# Predicted  False  True  __all__
# Actual
# False       5025  2379     7404
# True          45  1211     1256
# __all__     5070  3590     8660

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9077014017902382
# Predicted  False   True  __all__
# Actual
# False      24458   5147    29605
# True         318  29287    29605
# __all__    24776  34434    59210
# The accuracy of the model on test data is: 0.8453810623556582
# Predicted  False  True  __all__
# Actual
# False       6132  1272     7404
# True          67  1189     1256
# __all__     6199  2461     8660

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8584360749873332
# Predicted  False   True  __all__
# Actual
# False      23434   6171    29605
# True        2211  27394    29605
# __all__    25645  33565    59210
# The accuracy of the model on test data is: 0.8137413394919168
# Predicted  False  True  __all__
# Actual
# False       5886  1518     7404
# True          95  1161     1256
# __all__     5981  2679     8660

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8871981084276305
# Predicted  False   True  __all__
# Actual
# False      24183   5422    29605
# True        1257  28348    29605
# __all__    25440  33770    59210
# The accuracy of the model on test data is: 0.8355658198614319
# Predicted  False  True  __all__
# Actual
# False       6057  1347     7404
# True          77  1179     1256
# __all__     6134  2526     8660

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9081911839216349
# Predicted  False   True  __all__
# Actual
# False      24473   5132    29605
# True         304  29301    29605
# __all__    24777  34433    59210
# The accuracy of the model on test data is: 0.8450346420323326
# Predicted  False  True  __all__
# Actual
# False       6129  1275     7404
# True          67  1189     1256
# __all__     6196  2464     8660

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.907549400439115
# Predicted  False   True  __all__
# Actual
# False      24462   5143    29605
# True         331  29274    29605
# __all__    24793  34417    59210
# The accuracy of the model on test data is: 0.8430715935334873
# Predicted  False  True  __all__
# Actual
# False       6113  1291     7404
# True          68  1188     1256
# __all__     6181  2479     8660

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.9077182908292518
# Predicted  False   True  __all__
# Actual
# False      24466   5139    29605
# True         325  29280    29605
# __all__    24791  34419    59210
# The accuracy of the model on test data is: 0.8454965357967668
# Predicted  False  True  __all__
# Actual
# False       6129  1275     7404
# True          63  1193     1256
# __all__     6192  2468     8660

# %% [markdown]
# ### <a id='1.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy       TP       TN      FP       FN  \
# index
# Neural Network-1            0.900507  28870.0  24449.0  5156.0    735.0
# KNeighborsClassifier        0.538507   3004.0  28881.0   724.0  26601.0
# LogisticRegression          0.821213  28369.0  20255.0  9350.0   1236.0
# RandomForestClassifier      0.907701  29287.0  24458.0  5147.0    318.0
# AdaBoostClassifier          0.858436  27394.0  23434.0  6171.0   2211.0
# GradientBoostingClassifier  0.887198  28348.0  24183.0  5422.0   1257.0
# ExtraTreeClassifier         0.908191  29301.0  24473.0  5132.0    304.0
# BaggingClassifier           0.907549  29274.0  24462.0  5143.0    331.0
# VotingClassifier            0.907718  29280.0  24466.0  5139.0    325.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.174160  0.024827
# KNeighborsClassifier        0.024455  0.898531
# LogisticRegression          0.315825  0.041750
# RandomForestClassifier      0.173856  0.010741
# AdaBoostClassifier          0.208445  0.074683
# GradientBoostingClassifier  0.183145  0.042459
# ExtraTreeClassifier         0.173349  0.010269
# BaggingClassifier           0.173721  0.011181
# VotingClassifier            0.173586  0.010978
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN      FP      FN  \
# index
# Neural Network-1            0.843533  1191.0  6114.0  1290.0    65.0
# KNeighborsClassifier        0.836028    97.0  7143.0   261.0  1159.0
# LogisticRegression          0.720092  1211.0  5025.0  2379.0    45.0
# RandomForestClassifier      0.845381  1189.0  6132.0  1272.0    67.0
# AdaBoostClassifier          0.813741  1161.0  5886.0  1518.0    95.0
# GradientBoostingClassifier  0.835566  1179.0  6057.0  1347.0    77.0
# ExtraTreeClassifier         0.845035  1189.0  6129.0  1275.0    67.0
# BaggingClassifier           0.843072  1188.0  6113.0  1291.0    68.0
# VotingClassifier            0.845497  1193.0  6129.0  1275.0    63.0
#
#                                  FPR       FNR       auc
# index
# Neural Network-1            0.174230  0.051752  0.887009
# KNeighborsClassifier        0.035251  0.922771  0.520989
# LogisticRegression          0.321313  0.035828  0.821430
# RandomForestClassifier      0.171799  0.053344  0.887429
# AdaBoostClassifier          0.205024  0.075637  0.859669
# GradientBoostingClassifier  0.181929  0.061306  0.878383
# ExtraTreeClassifier         0.172204  0.053344  0.887226
# BaggingClassifier           0.174365  0.054140  0.885747
# VotingClassifier            0.172204  0.050159  0.888818

# %% [markdown]
# ## <a id='2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a>
#
# #### <a id='2.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

pca=PCA(n_components=48,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
x_train, X_test, y_train, Y_test = train_test_split(X_pca, y,test_size=0.2,random_state=12)

sm = SMOTE(random_state=12, ratio = 1.0)
X_train, Y_train = sm.fit_sample(x_train, y_train)

y=df.Malicious.values
feature_name = X.columns.tolist()


X_pca.shape
# Out:
# 0.921727564822099
# The train/test split ratio is 80:20
# (43296, 48)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_pca.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.88701232899848
# Predicted  False   True  __all__
# Actual
# False      23947   5658    29605
# True        1032  28573    29605
# __all__    24979  34231    59210
# The accuracy of the model on test data is: 0.8309468822170901
# Predicted  False  True  __all__
# Actual
# False       5996  1408     7404
# True          56  1200     1256
# __all__     6052  2608     8660

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.5408714744131059
# Predicted  False  True  __all__
# Actual
# False      29120   485    29605
# True       26700  2905    29605
# __all__    55820  3390    59210
# The accuracy of the model on test data is: 0.8458429561200924
# Predicted  False  True  __all__
# Actual
# False       7234   170     7404
# True        1165    91     1256
# __all__     8399   261     8660

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8152845803073805
# Predicted  False   True  __all__
# Actual
# False      19911   9694    29605
# True        1243  28362    29605
# __all__    21154  38056    59210
# The accuracy of the model on test data is: 0.7073903002309468
# Predicted  False  True  __all__
# Actual
# False       4917  2487     7404
# True          47  1209     1256
# __all__     4964  3696     8660

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9071947306198277
# Predicted  False   True  __all__
# Actual
# False      24457   5148    29605
# True         347  29258    29605
# __all__    24804  34406    59210
# The accuracy of the model on test data is: 0.8451501154734411
# Predicted  False  True  __all__
# Actual
# False       6128  1276     7404
# True          65  1191     1256
# __all__     6193  2467     8660

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8812362776558014
# Predicted  False   True  __all__
# Actual
# False      24381   5224    29605
# True        1808  27797    29605
# __all__    26189  33021    59210
# The accuracy of the model on test data is: 0.8418013856812933
# Predicted  False  True  __all__
# Actual
# False       6117  1287     7404
# True          83  1173     1256
# __all__     6200  2460     8660

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.886961661881439
# Predicted  False   True  __all__
# Actual
# False      24451   5154    29605
# True        1539  28066    29605
# __all__    25990  33220    59210
# The accuracy of the model on test data is: 0.8436489607390301
# Predicted  False  True  __all__
# Actual
# False       6126  1278     7404
# True          76  1180     1256
# __all__     6202  2458     8660

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.9081911839216349
# Predicted  False   True  __all__
# Actual
# False      24473   5132    29605
# True         304  29301    29605
# __all__    24777  34433    59210
# The accuracy of the model on test data is: 0.8438799076212471
# Predicted  False  True  __all__
# Actual
# False       6119  1285     7404
# True          67  1189     1256
# __all__     6186  2474     8660

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.907127174463773
# Predicted  False   True  __all__
# Actual
# False      24458   5147    29605
# True         352  29253    29605
# __all__    24810  34400    59210
# The accuracy of the model on test data is: 0.8441108545034642
# Predicted  False  True  __all__
# Actual
# False       6121  1283     7404
# True          67  1189     1256
# __all__     6188  2472     8660

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.9069751731126499
# Predicted  False   True  __all__
# Actual
# False      24474   5131    29605
# True         377  29228    29605
# __all__    24851  34359    59210
# The accuracy of the model on test data is: 0.8453810623556582
# Predicted  False  True  __all__
# Actual
# False       6128  1276     7404
# True          63  1193     1256
# __all__     6191  2469     8660

# %% [markdown]
# ### <a id='2.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy       TP       TN      FP       FN  \
# index
# Neural Network-1            0.887012  28573.0  23947.0  5658.0   1032.0
# KNeighborsClassifier        0.540871   2905.0  29120.0   485.0  26700.0
# LogisticRegression          0.815285  28362.0  19911.0  9694.0   1243.0
# RandomForestClassifier      0.907195  29258.0  24457.0  5148.0    347.0
# AdaBoostClassifier          0.881236  27797.0  24381.0  5224.0   1808.0
# GradientBoostingClassifier  0.886962  28066.0  24451.0  5154.0   1539.0
# ExtraTreeClassifier         0.908191  29301.0  24473.0  5132.0    304.0
# BaggingClassifier           0.907127  29253.0  24458.0  5147.0    352.0
# VotingClassifier            0.906975  29228.0  24474.0  5131.0    377.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.191116  0.034859
# KNeighborsClassifier        0.016382  0.901875
# LogisticRegression          0.327445  0.041986
# RandomForestClassifier      0.173890  0.011721
# AdaBoostClassifier          0.176457  0.061071
# GradientBoostingClassifier  0.174092  0.051984
# ExtraTreeClassifier         0.173349  0.010269
# BaggingClassifier           0.173856  0.011890
# VotingClassifier            0.173315  0.012734
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN      FP      FN  \
# index
# Neural Network-1            0.830947  1200.0  5996.0  1408.0    56.0
# KNeighborsClassifier        0.845843    91.0  7234.0   170.0  1165.0
# LogisticRegression          0.707390  1209.0  4917.0  2487.0    47.0
# RandomForestClassifier      0.845150  1191.0  6128.0  1276.0    65.0
# AdaBoostClassifier          0.841801  1173.0  6117.0  1287.0    83.0
# GradientBoostingClassifier  0.843649  1180.0  6126.0  1278.0    76.0
# ExtraTreeClassifier         0.843880  1189.0  6119.0  1285.0    67.0
# BaggingClassifier           0.844111  1189.0  6121.0  1283.0    67.0
# VotingClassifier            0.845381  1193.0  6128.0  1276.0    63.0
#
#                                  FPR       FNR       auc
# index
# Neural Network-1            0.190167  0.044586  0.882623
# KNeighborsClassifier        0.022961  0.927548  0.524746
# LogisticRegression          0.335900  0.037420  0.813340
# RandomForestClassifier      0.172339  0.051752  0.887955
# AdaBoostClassifier          0.173825  0.066083  0.880046
# GradientBoostingClassifier  0.172609  0.060510  0.883441
# ExtraTreeClassifier         0.173555  0.053344  0.886551
# BaggingClassifier           0.173285  0.053344  0.886686
# VotingClassifier            0.172339  0.050159  0.888751

# %% [markdown]
# ### <a id='2.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 60                              0.020589
# 66                              0.020516
# 59                              0.020469
# 40                              0.020452
# 64                              0.020356
# 68                              0.020274
# 41                              0.020254
# 63                              0.020246
# 37                              0.019997
# 18                              0.019958
# 71                              0.019952
# 69                              0.019943
# 16                              0.019905
# 6                               0.019890
# 4                               0.019863
# 30                              0.019744
# 61                              0.019723
# 1                               0.019691
# 56                              0.019591
# 28                              0.019429
# 5                               0.019323
# 17                              0.019301
# 46                              0.019204
# 62                              0.019172
# 27                              0.019114
# 51                              0.018796
# 65                              0.018438
# 70                              0.018122
# 55                              0.017934
# 2                               0.017487
# 39                              0.017434
# 8                               0.017194
# 38                              0.016603
# 49                              0.016558
# 58                              0.016287
# 26                              0.015566
# 9                               0.015045
# 13                              0.014844
# 67                              0.013610
# 10                              0.012668
# 3                               0.012550
# 14                              0.010975
# 15                              0.010822
# 33                              0.010522
# 22                              0.010255
# 21                              0.010189
# 45                              0.009544
# 43                              0.009537
# 47                              0.009008
# 72                              0.008879
# 7                               0.008006
# 48                              0.007950
# 32                              0.007949
# 11                              0.007793
# 44                              0.007781
# 53                              0.007413
# 35                              0.007125
# 50                              0.007084
# 42                              0.006999
# 19                              0.006586
# 34                              0.005911
# 20                              0.005041
# 52                              0.005018
# 31                              0.004802
# 12                              0.004739
# 29                              0.004670
# 54                              0.004574
# 24                              0.004527
# 36                              0.004390
# 57                              0.004114
# 25                              0.004078
# 0                               0.003702
# 23                              0.003088
#
#                                          Features
# 60                dom_function_window.matchMedia(
# 66                    dom_function_document.open(
# 59               dom_function_window.setInterval(
# 40                      js_function_.getUTCHours(
# 64        dom_function_document.querySelectorAll(
# 68  dom_function_document.getElementsByClassName(
# 41                       js_function_.getUTCDate(
# 63          dom_function_window.addEventListener(
# 37                          js_function_.indexOf(
# 18                         js_function_.toString(
# 71             dom_function_document.createEvent(
# 69          dom_function_document.getElementById(
# 16                          js_function_Date.now(
# 6                js_function_String.fromCharCode(
# 4                 js_function_encodeURIComponent(
# 30                             js_function_.push(
# 61          dom_function_window.getComputedStyle(
# 1                           js_function_parseInt(
# 56                             js_function_.bind(
# 28                          js_function_.reverse(
# 5                 js_function_decodeURIComponent(
# 17                             js_function_.trim(
# 46                  js_function_.getMilliseconds(
# 62              dom_function_window.clearTimeout(
# 27                         js_function_.setHours(
# 51                              js_function_.get(
# 65           dom_function_document.querySelector(
# 70          dom_function_document.createTextNode(
# 55                           js_function_.charAt(
# 2                           js_function_isFinite(
# 39                          js_function_.getYear(
# 8         js_function_Object.getOwnPropertyNames(
# 38                              js_function_.has(
# 49                           js_function_.getDay(
# 58                              js_function_.add(
# 26                          js_function_.setTime(
# 9                         js_function_Math.round(
# 13                        js_function_Math.floor(
# 67    dom_function_document.getElementsByTagName(
# 10                       js_function_Math.random(
# 3                             js_function_escape(
# 14                    js_function_JSON.stringify(
# 15                        js_function_JSON.parse(
# 33                            js_function_.match(
# 22                            js_function_.substr
# 21                        js_function_.substring(
# 45                       js_function_.getMinutes(
# 43                       js_function_.getSeconds(
# 47                         js_function_.getHours(
# 72           dom_function_document.createElement(
# 7                        js_function_Object.keys(
# 48                      js_function_.getFullYear(
# 32                              js_function_.min(
# 11                          js_function_Math.min(
# 44                         js_function_.getMonth(
# 53                             js_function_.exec(
# 35                             js_function_.keys(
# 50                          js_function_.getDate(
# 42                          js_function_.getTime(
# 19                      js_function_.toLowerCase(
# 34                              js_function_.map(
# 20                             js_function_.test(
# 52                          js_function_.forEach(
# 31                              js_function_.pop(
# 12                          js_function_Math.max(
# 29                          js_function_.replace(
# 54                           js_function_.concat(
# 24                             js_function_.sort(
# 36                             js_function_.join(
# 57                            js_function_.apply(
# 25                            js_function_.shift(
# 0                       number_functions_declared
# 23                            js_function_.split(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## <a id='3' style="text-decoration : none; color : #000000;"> HTTPS</a>
#
# ### <a id='3.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_https.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_https.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)


# df.to_csv('Javascript_dom.csv')

df.head()
X=df.loc[:,df.columns!='Malicious']
X.drop(['number_of_unsecure_cookies','number_of_secure_cookies','number_of_non_http_only_cookies','number_of_http_only_cookies',
 'number_of_cookies'],axis=1,inplace=True)
y=df.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df.shape)
df.head()
# Out:
# Shape after undersampling (44476, 407)
#                                                     dom_function_document.adoptNode(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     dom_function_document.captureEvents(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.caretPositionFromPoint(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.caretRangeFromPoint(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_document.clear(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.close(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.createAttribute(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createAttributeNS(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.createCDATASection(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_document.createComment(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.createDocumentFragment(  \
# domain
# fiverr.com                                                                                    1.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.createElement(  \
# domain
# fiverr.com                                                                           3.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.createElementNS(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createEntityReference(  \
# domain
# fiverr.com                                                                                   0.0
# babynameready.com                                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                           0.0
# fontmeme.com                                                                                 0.0
# vidachok.tv                                                                                  0.0
#
#                                                     dom_function_document.createEvent(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createNodeIterator(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_document.createProcessingInstruction(  \
# domain
# fiverr.com                                                                                        0.0
# babynameready.com                                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                                0.0
# fontmeme.com                                                                                      0.0
# vidachok.tv                                                                                       0.0
#
#                                                     dom_function_document.createRange(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createTextNode(  \
# domain
# fiverr.com                                                                            3.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.createTouch(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createTouchList(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createTreeWalker(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.elementFromPoint(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.elementsFromPoint(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.enableStyleSheetsForSet(  \
# domain
# fiverr.com                                                                                     0.0
# babynameready.com                                                                              0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                             0.0
# fontmeme.com                                                                                   0.0
# vidachok.tv                                                                                    0.0
#
#                                                     dom_function_document.execCommand(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.exitPointerLock(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.getAnimations(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.getElementById(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.getElementByName(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.getElementsByClassName(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.getElementsByTagName(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_document.getElementsByTagNameNS(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.getSelection(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_document.hasFocus(  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     dom_function_document.importNode(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_document.normalizeDocument(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.open(  \
# domain
# fiverr.com                                                                  0.0
# babynameready.com                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                          0.0
# fontmeme.com                                                                0.0
# vidachok.tv                                                                 0.0
#
#                                                     dom_function_document.queryCommandEnabled(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_document.queryCommandIndeterm(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_document.queryCommandValue(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.querySelector(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.querySelectorAll(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.releaseCapture(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.releaseEvent(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_document.routeEvent(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_document.write(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.writeln(  \
# domain
# fiverr.com                                                                     0.0
# babynameready.com                                                              0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                             0.0
# fontmeme.com                                                                   0.0
# vidachok.tv                                                                    0.0
#
#                                                     dom_function_window.addEventListener(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_window.alert(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.atob(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.back(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.blur(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.btoa(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.cancelAnimationFrame(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_window.cancelIdleCallback(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_window.captureEvents(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.clearImmediate(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_window.clearInterval(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.clearTimeout(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_window.close(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.confirm(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_window.createImageBitmap(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_window.disableExternalCapture(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_window.dispatchEvent(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.dump(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.enableExternalCapture(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_window.fetch(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.find(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.focus(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.forward(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_window.getAttention(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_window.getAttentionWithCycleCount(  \
# domain
# fiverr.com                                                                                      0.0
# babynameready.com                                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                              0.0
# fontmeme.com                                                                                    0.0
# vidachok.tv                                                                                     0.0
#
#                                                     dom_function_window.getComputedStyle(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_window.getDefaultComputedSyle(  \
# domain
# fiverr.com                                                                                  0.0
# ...
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.compileStreaming(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     js_function_WebAssembly.customerSections(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     js_function_WebAssembly.exports(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.imports(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.instantiate(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     js_function_WebAssembly.instantiateStreaming(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     js_function_WebAssembly.validate(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     js_function_decodeURI(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_decodeURIComponent(  \
# domain
# fiverr.com                                                                      1.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     js_function_encodeURI(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_encodeURIComponent(  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     js_function_escape(  \
# domain
# fiverr.com                                                          0.0
# babynameready.com                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                  0.0
# fontmeme.com                                                        0.0
# vidachok.tv                                                         3.0
#
#                                                     js_function_eval(  \
# domain
# fiverr.com                                                        0.0
# babynameready.com                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                0.0
# fontmeme.com                                                      0.0
# vidachok.tv                                                       0.0
#
#                                                     js_function_isFinite(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_isNaN(  \
# domain
# fiverr.com                                                         0.0
# babynameready.com                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                 0.0
# fontmeme.com                                                       0.0
# vidachok.tv                                                        0.0
#
#                                                     js_function_parseFloat(  \
# domain
# fiverr.com                                                              0.0
# babynameready.com                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                      0.0
# fontmeme.com                                                            0.0
# vidachok.tv                                                             0.0
#
#                                                     js_function_parseInt(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_undefined(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_unescape(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_uneval(  \
# domain
# fiverr.com                                                          0.0
# babynameready.com                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                  0.0
# fontmeme.com                                                        0.0
# vidachok.tv                                                         0.0
#
#                                                     number_functions_declared  \
# domain
# fiverr.com                                                                3.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              2.0
# vidachok.tv                                                              11.0
#
#                                                     number_of_cookies  \
# domain
# fiverr.com                                                        1.0
# babynameready.com                                                 3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                0.0
# fontmeme.com                                                      3.0
# vidachok.tv                                                       7.0
#
#                                                     number_of_http_only_cookies  \
# domain
# fiverr.com                                                                  1.0
# babynameready.com                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                          0.0
# fontmeme.com                                                                0.0
# vidachok.tv                                                                 2.0
#
#                                                     number_of_non_http_only_cookies  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    3.0
# vidachok.tv                                                                     5.0
#
#                                                     number_of_secure_cookies  \
# domain
# fiverr.com                                                               0.0
# babynameready.com                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                       0.0
# fontmeme.com                                                             0.0
# vidachok.tv                                                              0.0
#
#                                                     number_of_unsecure_cookies  \
# domain
# fiverr.com                                                                 1.0
# babynameready.com                                                          3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               3.0
# vidachok.tv                                                                7.0
#
#                                                     Malicious
# domain
# fiverr.com                                                  0
# babynameready.com                                           0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...          1
# fontmeme.com                                                0
# vidachok.tv                                                 0

# %% [markdown]
# ### <a id='3.B' style="text-decoration : none; color : #000000;">B. Feature Selection</a>
#
# <ol>
#     <ul><h4> 1. Correlation</h4></ul>
#     <ul><h4> 2. Chi2 </h4></ul>
#     <ul><h4> 3. Recursive Feature Elimination </h4></ul>
#     <ul><h4> 4. Select From Model </h4></ul>
# </ol>

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)


X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()


rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)
rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()


embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()


feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)

# %% [markdown]
# ### <a id='3.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
X=df[feature_selection_df[feature_selection_df.Total==4]['Feature']]

scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
x_train, X_test, y_train, Y_test = train_test_split(X, y,test_size=0.2,random_state=12)

sm = SMOTE(random_state=12, ratio = 1.0)
X_train, Y_train = sm.fit_sample(x_train, y_train)

y=df.Malicious.values
feature_name = X.columns.tolist()

X.shape
# Out:
# The train/test split ratio is 80:20
# (44476, 69)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['number_functions_declared',
#  'js_function_parseInt(',
#  'js_function_parseFloat(',
#  'js_function_encodeURIComponent(',
#  'js_function_decodeURIComponent(',
#  'js_function_String.fromCharCode(',
#  'js_function_Object.keys(',
#  'js_function_Math.round(',
#  'js_function_Math.random(',
#  'js_function_Math.max(',
#  'js_function_Math.floor(',
#  'js_function_JSON.stringify(',
#  'js_function_JSON.parse(',
#  'js_function_Date.now(',
#  'js_function_.trim(',
#  'js_function_.toString(',
#  'js_function_.toLowerCase(',
#  'js_function_.test(',
#  'js_function_.substring(',
#  'js_function_.substr',
#  'js_function_.split(',
#  'js_function_.shift(',
#  'js_function_.setTime(',
#  'js_function_.setHours(',
#  'js_function_.reverse(',
#  'js_function_.replace(',
#  'js_function_.push(',
#  'js_function_.pop(',
#  'js_function_.match(',
#  'js_function_.keys(',
#  'js_function_.join(',
#  'js_function_.indexOf(',
#  'js_function_.hasOwnProperty(',
#  'js_function_.getYear(',
#  'js_function_.getUTCDate(',
#  'js_function_.getTime(',
#  'js_function_.getSeconds(',
#  'js_function_.getMonth(',
#  'js_function_.getMinutes(',
#  'js_function_.getMilliseconds(',
#  'js_function_.getHours(',
#  'js_function_.getFullYear(',
#  'js_function_.getDay(',
#  'js_function_.getDate(',
#  'js_function_.get(',
#  'js_function_.forEach(',
#  'js_function_.exec(',
#  'js_function_.concat(',
#  'js_function_.charAt(',
#  'js_function_.bind(',
#  'js_function_.apply(',
#  'js_function_.add(',
#  'dom_function_window.setInterval(',
#  'dom_function_window.scrollTo(',
#  'dom_function_window.matchMedia(',
#  'dom_function_window.getComputedStyle(',
#  'dom_function_window.clearTimeout(',
#  'dom_function_window.clearInterval(',
#  'dom_function_window.addEventListener(',
#  'dom_function_document.querySelectorAll(',
#  'dom_function_document.querySelector(',
#  'dom_function_document.open(',
#  'dom_function_document.getElementsByTagName(',
#  'dom_function_document.getElementsByClassName(',
#  'dom_function_document.getElementById(',
#  'dom_function_document.createTextNode(',
#  'dom_function_document.createEvent(',
#  'dom_function_document.createElementNS(',
#  'dom_function_document.createElement(']

# %% [markdown]
# ### <a id='3.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.816327199973761
# Predicted  False   True  __all__
# Actual
# False      19428  11061    30489
# True         139  30350    30489
# __all__    19567  41411    60978
# The accuracy of the model on test data is: 0.67693345323741
# Predicted  False  True  __all__
# Actual
# False       4795  2835     7630
# True          39  1227     1266
# __all__     4834  4062     8896

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8135885073305127
# Predicted  False   True  __all__
# Actual
# False      19541  10948    30489
# True         419  30070    30489
# __all__    19960  41018    60978
# The accuracy of the model on test data is: 0.6761465827338129
# Predicted  False  True  __all__
# Actual
# False       4800  2830     7630
# True          51  1215     1266
# __all__     4851  4045     8896

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7765095608252156
# Predicted  False   True  __all__
# Actual
# False      17479  13010    30489
# True         618  29871    30489
# __all__    18097  42881    60978
# The accuracy of the model on test data is: 0.6258992805755396
# Predicted  False  True  __all__
# Actual
# False       4340  3290     7630
# True          38  1228     1266
# __all__     4378  4518     8896

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8203614418314802
# Predicted  False   True  __all__
# Actual
# False      19665  10824    30489
# True         130  30359    30489
# __all__    19795  41183    60978
# The accuracy of the model on test data is: 0.6840152877697842
# Predicted  False  True  __all__
# Actual
# False       4867  2763     7630
# True          48  1218     1266
# __all__     4915  3981     8896

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8031585161861655
# Predicted  False   True  __all__
# Actual
# False      19374  11115    30489
# True         888  29601    30489
# __all__    20262  40716    60978
# The accuracy of the model on test data is: 0.6742356115107914
# Predicted  False  True  __all__
# Actual
# False       4788  2842     7630
# True          56  1210     1266
# __all__     4844  4052     8896

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8126865426875266
# Predicted  False   True  __all__
# Actual
# False      19606  10883    30489
# True         539  29950    30489
# __all__    20145  40833    60978
# The accuracy of the model on test data is: 0.6799685251798561
# Predicted  False  True  __all__
# Actual
# False       4842  2788     7630
# True          59  1207     1266
# __all__     4901  3995     8896

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8206074321886582
# Predicted  False   True  __all__
# Actual
# False      19670  10819    30489
# True         120  30369    30489
# __all__    19790  41188    60978
# The accuracy of the model on test data is: 0.6841276978417267
# Predicted  False  True  __all__
# Actual
# False       4868  2762     7630
# True          48  1218     1266
# __all__     4916  3980     8896

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8202302469743186
# Predicted  False   True  __all__
# Actual
# False      19660  10829    30489
# True         133  30356    30489
# __all__    19793  41185    60978
# The accuracy of the model on test data is: 0.6825539568345323
# Predicted  False  True  __all__
# Actual
# False       4855  2775     7630
# True          49  1217     1266
# __all__     4904  3992     8896

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8201974482600282
# Predicted  False   True  __all__
# Actual
# False      19648  10841    30489
# True         123  30366    30489
# __all__    19771  41207    60978
# The accuracy of the model on test data is: 0.6837904676258992
# Predicted  False  True  __all__
# Actual
# False       4864  2766     7630
# True          47  1219     1266
# __all__     4911  3985     8896

# %% [markdown]
# ### <a id='3.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy       TP       TN       FP     FN  \
# index
# Neural Network-1            0.816327  30350.0  19428.0  11061.0  139.0
# KNeighborsClassifier        0.813589  30070.0  19541.0  10948.0  419.0
# LogisticRegression          0.776510  29871.0  17479.0  13010.0  618.0
# RandomForestClassifier      0.820361  30359.0  19665.0  10824.0  130.0
# AdaBoostClassifier          0.803159  29601.0  19374.0  11115.0  888.0
# GradientBoostingClassifier  0.812687  29950.0  19606.0  10883.0  539.0
# ExtraTreeClassifier         0.820607  30369.0  19670.0  10819.0  120.0
# BaggingClassifier           0.820230  30356.0  19660.0  10829.0  133.0
# VotingClassifier            0.820197  30366.0  19648.0  10841.0  123.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.362787  0.004559
# KNeighborsClassifier        0.359080  0.013743
# LogisticRegression          0.426711  0.020270
# RandomForestClassifier      0.355013  0.004264
# AdaBoostClassifier          0.364558  0.029125
# GradientBoostingClassifier  0.356948  0.017679
# ExtraTreeClassifier         0.354849  0.003936
# BaggingClassifier           0.355177  0.004362
# VotingClassifier            0.355571  0.004034
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN      FP    FN       FPR  \
# index
# Neural Network-1            0.676933  1227.0  4795.0  2835.0  39.0  0.371560
# KNeighborsClassifier        0.676147  1215.0  4800.0  2830.0  51.0  0.370904
# LogisticRegression          0.625899  1228.0  4340.0  3290.0  38.0  0.431193
# RandomForestClassifier      0.684015  1218.0  4867.0  2763.0  48.0  0.362123
# AdaBoostClassifier          0.674236  1210.0  4788.0  2842.0  56.0  0.372477
# GradientBoostingClassifier  0.679969  1207.0  4842.0  2788.0  59.0  0.365400
# ExtraTreeClassifier         0.684128  1218.0  4868.0  2762.0  48.0  0.361992
# BaggingClassifier           0.682554  1217.0  4855.0  2775.0  49.0  0.363696
# VotingClassifier            0.683790  1219.0  4864.0  2766.0  47.0  0.362516
#
#                                  FNR       auc
# index
# Neural Network-1            0.030806  0.798817
# KNeighborsClassifier        0.040284  0.794406
# LogisticRegression          0.030016  0.769396
# RandomForestClassifier      0.037915  0.799981
# AdaBoostClassifier          0.044234  0.791645
# GradientBoostingClassifier  0.046603  0.793998
# ExtraTreeClassifier         0.037915  0.800047
# BaggingClassifier           0.038705  0.798800
# VotingClassifier            0.037125  0.800179

# %% [markdown]
# ## <a id='4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a>
#
# #### <a id='4.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

pca=PCA(n_components=48,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
x_train, X_test, y_train, Y_test = train_test_split(X_pca, y,test_size=0.2,random_state=12)

sm = SMOTE(random_state=12, ratio = 1.0)
X_train, Y_train = sm.fit_sample(x_train, y_train)

y=df.Malicious.values
feature_name = X.columns.tolist()


X_pca.shape
# Out:
# 0.9338085833958165
# The train/test split ratio is 80:20
# (44476, 48)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_train.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8131621240447374
# Predicted  False   True  __all__
# Actual
# False      19434  11055    30489
# True         338  30151    30489
# __all__    19772  41206    60978
# The accuracy of the model on test data is: 0.6778327338129496
# Predicted  False  True  __all__
# Actual
# False       4806  2824     7630
# True          42  1224     1266
# __all__     4848  4048     8896

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8148676571878383
# Predicted  False   True  __all__
# Actual
# False      19698  10791    30489
# True         498  29991    30489
# __all__    20196  40782    60978
# The accuracy of the model on test data is: 0.6817670863309353
# Predicted  False  True  __all__
# Actual
# False       4852  2778     7630
# True          53  1213     1266
# __all__     4905  3991     8896

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7745088392535012
# Predicted  False   True  __all__
# Actual
# False      17344  13145    30489
# True         605  29884    30489
# __all__    17949  43029    60978
# The accuracy of the model on test data is: 0.6224145683453237
# Predicted  False  True  __all__
# Actual
# False       4307  3323     7630
# True          36  1230     1266
# __all__     4343  4553     8896

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8199186591885598
# Predicted  False   True  __all__
# Actual
# False      19663  10826    30489
# True         155  30334    30489
# __all__    19818  41160    60978
# The accuracy of the model on test data is: 0.6836780575539568
# Predicted  False  True  __all__
# Actual
# False       4863  2767     7630
# True          47  1219     1266
# __all__     4910  3986     8896

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8067007773295287
# Predicted  False   True  __all__
# Actual
# False      19572  10917    30489
# True         870  29619    30489
# __all__    20442  40536    60978
# The accuracy of the model on test data is: 0.6807553956834532
# Predicted  False  True  __all__
# Actual
# False       4843  2787     7630
# True          53  1213     1266
# __all__     4896  4000     8896

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8104070320443438
# Predicted  False   True  __all__
# Actual
# False      19650  10839    30489
# True         722  29767    30489
# __all__    20372  40606    60978
# The accuracy of the model on test data is: 0.6831160071942446
# Predicted  False  True  __all__
# Actual
# False       4863  2767     7630
# True          52  1214     1266
# __all__     4915  3981     8896

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8206074321886582
# Predicted  False   True  __all__
# Actual
# False      19670  10819    30489
# True         120  30369    30489
# __all__    19790  41188    60978
# The accuracy of the model on test data is: 0.6835656474820144
# Predicted  False  True  __all__
# Actual
# False       4863  2767     7630
# True          48  1218     1266
# __all__     4911  3985     8896

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.819935058545705
# Predicted  False   True  __all__
# Actual
# False      19656  10833    30489
# True         147  30342    30489
# __all__    19803  41175    60978
# The accuracy of the model on test data is: 0.6828911870503597
# Predicted  False  True  __all__
# Actual
# False       4857  2773     7630
# True          48  1218     1266
# __all__     4905  3991     8896

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8197218669028175
# Predicted  False   True  __all__
# Actual
# False      19666  10823    30489
# True         170  30319    30489
# __all__    19836  41142    60978
# The accuracy of the model on test data is: 0.6835656474820144
# Predicted  False  True  __all__
# Actual
# False       4862  2768     7630
# True          47  1219     1266
# __all__     4909  3987     8896

# %% [markdown]
# ### <a id='4.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy       TP       TN       FP     FN  \
# index
# Neural Network-1            0.813162  30151.0  19434.0  11055.0  338.0
# KNeighborsClassifier        0.814868  29991.0  19698.0  10791.0  498.0
# LogisticRegression          0.774509  29884.0  17344.0  13145.0  605.0
# RandomForestClassifier      0.819919  30334.0  19663.0  10826.0  155.0
# AdaBoostClassifier          0.806701  29619.0  19572.0  10917.0  870.0
# GradientBoostingClassifier  0.810407  29767.0  19650.0  10839.0  722.0
# ExtraTreeClassifier         0.820607  30369.0  19670.0  10819.0  120.0
# BaggingClassifier           0.819935  30342.0  19656.0  10833.0  147.0
# VotingClassifier            0.819722  30319.0  19666.0  10823.0  170.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.362590  0.011086
# KNeighborsClassifier        0.353931  0.016334
# LogisticRegression          0.431139  0.019843
# RandomForestClassifier      0.355079  0.005084
# AdaBoostClassifier          0.358064  0.028535
# GradientBoostingClassifier  0.355505  0.023681
# ExtraTreeClassifier         0.354849  0.003936
# BaggingClassifier           0.355308  0.004821
# VotingClassifier            0.354980  0.005576
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN      FP    FN       FPR  \
# index
# Neural Network-1            0.677833  1224.0  4806.0  2824.0  42.0  0.370118
# KNeighborsClassifier        0.681767  1213.0  4852.0  2778.0  53.0  0.364089
# LogisticRegression          0.622415  1230.0  4307.0  3323.0  36.0  0.435518
# RandomForestClassifier      0.683678  1219.0  4863.0  2767.0  47.0  0.362647
# AdaBoostClassifier          0.680755  1213.0  4843.0  2787.0  53.0  0.365269
# GradientBoostingClassifier  0.683116  1214.0  4863.0  2767.0  52.0  0.362647
# ExtraTreeClassifier         0.683566  1218.0  4863.0  2767.0  48.0  0.362647
# BaggingClassifier           0.682891  1218.0  4857.0  2773.0  48.0  0.363434
# VotingClassifier            0.683566  1219.0  4862.0  2768.0  47.0  0.362779
#
#                                  FNR       auc
# index
# Neural Network-1            0.033175  0.798353
# KNeighborsClassifier        0.041864  0.797023
# LogisticRegression          0.028436  0.768023
# RandomForestClassifier      0.037125  0.800114
# AdaBoostClassifier          0.041864  0.796434
# GradientBoostingClassifier  0.041074  0.798139
# ExtraTreeClassifier         0.037915  0.799719
# BaggingClassifier           0.037915  0.799326
# VotingClassifier            0.037125  0.800048

# %% [markdown]
# ### <a id='4.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 63                              0.020739
# 64                              0.020707
# 56                              0.020602
# 54                              0.020533
# 61                              0.020493
# 14                              0.020480
# 53                              0.020354
# 34                              0.020333
# 39                              0.020296
# 59                              0.020268
# 67                              0.020258
# 60                              0.020246
# 26                              0.020098
# 23                              0.020015
# 24                              0.019942
# 58                              0.019804
# 31                              0.019562
# 55                              0.019550
# 51                              0.019475
# 13                              0.019368
# 57                              0.019190
# 66                              0.019082
# 44                              0.019066
# 15                              0.018953
# 65                              0.018925
# 49                              0.018763
# 4                               0.018646
# 10                              0.018489
# 1                               0.018391
# 33                              0.018290
# 52                              0.018128
# 2                               0.017718
# 5                               0.017373
# 3                               0.017231
# 28                              0.016548
# 42                              0.015696
# 22                              0.015302
# 62                              0.014290
# 11                              0.013625
# 7                               0.013530
# 12                              0.013346
# 8                               0.012724
# 36                              0.012530
# 38                              0.011544
# 16                              0.011267
# 40                              0.011018
# 18                              0.010762
# 46                              0.010623
# 35                              0.009900
# 68                              0.008338
# 19                              0.008195
# 48                              0.007889
# 6                               0.007888
# 9                               0.007815
# 29                              0.007429
# 41                              0.007364
# 37                              0.006764
# 43                              0.006691
# 25                              0.006591
# 32                              0.006315
# 27                              0.005542
# 45                              0.005542
# 17                              0.005398
# 47                              0.005314
# 50                              0.005078
# 21                              0.005001
# 30                              0.004573
# 0                               0.003992
# 20                              0.003373
#
#                                          Features
# 63  dom_function_document.getElementsByClassName(
# 64          dom_function_document.getElementById(
# 56              dom_function_window.clearTimeout(
# 54                dom_function_window.matchMedia(
# 61                    dom_function_document.open(
# 14                             js_function_.trim(
# 53                  dom_function_window.scrollTo(
# 34                       js_function_.getUTCDate(
# 39                  js_function_.getMilliseconds(
# 59        dom_function_document.querySelectorAll(
# 67         dom_function_document.createElementNS(
# 60           dom_function_document.querySelector(
# 26                             js_function_.push(
# 23                         js_function_.setHours(
# 24                          js_function_.reverse(
# 58          dom_function_window.addEventListener(
# 31                          js_function_.indexOf(
# 55          dom_function_window.getComputedStyle(
# 51                              js_function_.add(
# 13                          js_function_Date.now(
# 57             dom_function_window.clearInterval(
# 66             dom_function_document.createEvent(
# 44                              js_function_.get(
# 15                         js_function_.toString(
# 65          dom_function_document.createTextNode(
# 49                             js_function_.bind(
# 4                 js_function_decodeURIComponent(
# 10                        js_function_Math.floor(
# 1                           js_function_parseInt(
# 33                          js_function_.getYear(
# 52               dom_function_window.setInterval(
# 2                         js_function_parseFloat(
# 5                js_function_String.fromCharCode(
# 3                 js_function_encodeURIComponent(
# 28                            js_function_.match(
# 42                           js_function_.getDay(
# 22                          js_function_.setTime(
# 62    dom_function_document.getElementsByTagName(
# 11                    js_function_JSON.stringify(
# 7                         js_function_Math.round(
# 12                        js_function_JSON.parse(
# 8                        js_function_Math.random(
# 36                       js_function_.getSeconds(
# 38                       js_function_.getMinutes(
# 16                      js_function_.toLowerCase(
# 40                         js_function_.getHours(
# 18                        js_function_.substring(
# 46                             js_function_.exec(
# 35                          js_function_.getTime(
# 68           dom_function_document.createElement(
# 19                            js_function_.substr
# 48                           js_function_.charAt(
# 6                        js_function_Object.keys(
# 9                           js_function_Math.max(
# 29                             js_function_.keys(
# 41                      js_function_.getFullYear(
# 37                         js_function_.getMonth(
# 43                          js_function_.getDate(
# 25                          js_function_.replace(
# 32                   js_function_.hasOwnProperty(
# 27                              js_function_.pop(
# 45                          js_function_.forEach(
# 17                             js_function_.test(
# 47                           js_function_.concat(
# 50                            js_function_.apply(
# 21                            js_function_.shift(
# 30                             js_function_.join(
# 0                       number_functions_declared
# 20                            js_function_.split(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %%
### Original Creator : Darshan Bhansali
### HTML code to hide the input cells 
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle code, click <a href="javascript:code_toggle()">here</a>.
