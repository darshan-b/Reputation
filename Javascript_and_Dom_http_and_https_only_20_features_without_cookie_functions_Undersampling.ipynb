# %% [markdown]
# ***
# ## Table of Contents
# <br>
#     <ol>
#         <h2><a href='#1' style="text-decoration : none; color : #000000;">1. HTTP</a></h2>
#         <ul>
#             <a href='#1.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#1.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#1.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#1.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#1.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a></h2>
#         <ul><a href='#2.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#2.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#2.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>
#
# <br>
#     <ol>
#         <h2><a href='#3' style="text-decoration : none; color : #000000;">3. HTTPS</a></h2>
#         <ul>
#             <a href='#3.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#3.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#3.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#3.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#3.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a></h2>
#         <ul><a href='#4.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#4.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#4.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output,HTML
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from tabulate import tabulate

import keras
from keras.layers import Dense,Dropout
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)

from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split,cross_val_score

from sklearn.preprocessing import MinMaxScaler,StandardScaler,binarize
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE
from sklearn import metrics

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix,accuracy_score,auc,roc_curve,recall_score
from sklearn import metrics
from pandas_ml import ConfusionMatrix


from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
### Function get_params takes as input a grid search model and prints out the best parameters for the model and 
### prints the best accuracy of the model
def get_params(grid,model_name=''):
    print("Best Parameters are :")
    display(pd.DataFrame.from_dict(grid.best_params_, orient='index').reset_index().transpose())

### The function takes as input the model, X and Y data to generate the confusion matrix  
def get_cm(model,a,b):
    y_pred=model.predict(a)
    cm=ConfusionMatrix(b,y_pred)
    return cm
 
### The get accuracy plot takes as input a dataframe and a string for the title of the plot and displays a plot
### The function is primarily for plotting of accuracies for various classifiers for the same split.
def get_accuracy_plot(data,title=''):
    plt.figure(figsize=(12,8))
    plt.plot(data['accuracy'].values, '--o')
    plt.ylabel('Accuracy', fontsize=20)
    plt.xlabel('Classifier', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    plt.xlim([0, 9])
    plt.title(title,size=18,y=1.05)
    plt.xticks(np.arange(10),data.index.get_values(),rotation=90)
    plt.legend(loc='upper right', fontsize=18)
    plt.show()

### Function grid takes as input an estimator, X_train,Y_Train,X_test and Y_test and a string represetning the name of the model
### We perform StratifiedKFold cross validation and grid search to hypertune the parameters of the model     
def grid(kernel,params,x,y,x_test,y_test,model_name=''):
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    grid_search=GridSearchCV(estimator=kernel,param_grid=parameters,scoring='accuracy',cv=kfold,n_jobs=3,verbose=True)
    grid_search.fit(x,y)
    get_params(grid_search,model_name)
    acc_train=accuracy_score(y,grid_search.predict(x))
    print("Accuracy of the ",model_name," model for the training data is:",acc_train)
    print("\nConfusion Matrix for Training data is:")
    cm_train=get_cm(grid_search,x,y)
    display(cm_train)
    acc_test=accuracy_score(y_test,grid_search.predict(x_test))
    print("Accuracy of the ",model_name," model for test data is:",acc_test)
    print("\nConfusion Matrix for test data is:")
    cm_test=get_cm(grid_search,x_test,y_test)
    display(cm_test)
    fpr, tpr, threshold = roc_curve(y_test, grid_search.predict(x_test))
    roc_auc =auc(fpr, tpr)
    return grid_search,cm_train,cm_test,acc_train,acc_test,roc_auc  

### Plot roc curve
def get_roc_curve(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob[:,1]
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy on test data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

def get_roc_curve_deep_learning(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy of Logistic Model on training data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

# %% [markdown]
# ## <a id='1' style="text-decoration : none; color : #000000;"> HTTP</a>
#
# ### <a id='1.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_http.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)


# df.to_csv('Javascript_dom.csv')

df.head()

df_non=df[df.Malicious==0]
df_mal=df[df.Malicious==1]

df_non=df_non.sample(frac=len(df_mal)/len(df_non),random_state=0)
df_u=df_non.append(df_mal)
df_u.Malicious.value_counts() 

X=df_u[['dom_function_window.setTimeout(','dom_function_window.setInterval(','dom_function_document.createElement(',
     'dom_function_document.write(','dom_function_document.createComment(','dom_function_document.createElementNS(',
      'dom_function_window.addEventListener(','js_function_escape(','js_function_unescape(','js_function_eval(','js_function_.concat(','js_function_.charCodeAt(',
   'js_function_String.fromCharCode(','js_function_.split(','js_function_Number.parseInt(','js_function_.replace(',
   'js_function_.link(','js_function_.exec(','js_function_.search(','js_function_.substring(']]

y=df_u.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df_u.shape)
df_u.head()
# Out:
# Shape after undersampling (12574, 407)
#                         dom_function_document.adoptNode(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_document.captureEvents(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.caretPositionFromPoint(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.caretRangeFromPoint(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_document.clear(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_document.close(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     3.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_document.createAttribute(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createAttributeNS(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.createCDATASection(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_document.createComment(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.createDocumentFragment(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.createElement(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            3.0
# ruhrnachrichten.de                                       3.0
#
#                         dom_function_document.createElementNS(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createEntityReference(  \
# domain
# dns29parks.in                                                    0.0
# tournamentsoftware.com                                           0.0
# newsoku.blog                                                     0.0
# altsantiri.gr                                                    0.0
# ruhrnachrichten.de                                               0.0
#
#                         dom_function_document.createEvent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createNodeIterator(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_document.createProcessingInstruction(  \
# domain
# dns29parks.in                                                         0.0
# tournamentsoftware.com                                                0.0
# newsoku.blog                                                          0.0
# altsantiri.gr                                                         0.0
# ruhrnachrichten.de                                                    0.0
#
#                         dom_function_document.createRange(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createTextNode(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.createTouch(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.createTouchList(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.createTreeWalker(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.elementFromPoint(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.elementsFromPoint(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.enableStyleSheetsForSet(  \
# domain
# dns29parks.in                                                      0.0
# tournamentsoftware.com                                             0.0
# newsoku.blog                                                       0.0
# altsantiri.gr                                                      0.0
# ruhrnachrichten.de                                                 0.0
#
#                         dom_function_document.execCommand(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_document.exitPointerLock(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_document.getAnimations(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.getElementById(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              2.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.getElementByName(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.getElementsByClassName(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            3.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     1.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.getElementsByTagName(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   4.0
# ruhrnachrichten.de                                              3.0
#
#                         dom_function_document.getElementsByTagNameNS(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         dom_function_document.getSelection(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_document.hasFocus(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_document.importNode(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_document.normalizeDocument(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.open(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    3.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_document.queryCommandEnabled(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_document.queryCommandIndeterm(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_document.queryCommandValue(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_document.querySelector(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         dom_function_document.querySelectorAll(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_document.releaseCapture(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_document.releaseEvent(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_document.routeEvent(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_document.write(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     5.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               4.0
#
#                         dom_function_document.writeln(  \
# domain
# dns29parks.in                                      0.0
# tournamentsoftware.com                             0.0
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         dom_function_window.addEventListener(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             1.0
# ruhrnachrichten.de                                        1.0
#
#                         dom_function_window.alert(  dom_function_window.atob(  \
# domain
# dns29parks.in                                  0.0                        0.0
# tournamentsoftware.com                         0.0                        0.0
# newsoku.blog                                   0.0                        0.0
# altsantiri.gr                                  0.0                        0.0
# ruhrnachrichten.de                             0.0                        0.0
#
#                         dom_function_window.back(  dom_function_window.blur(  \
# domain
# dns29parks.in                                 0.0                        0.0
# tournamentsoftware.com                        0.0                        0.0
# newsoku.blog                                  0.0                        0.0
# altsantiri.gr                                 0.0                        0.0
# ruhrnachrichten.de                            0.0                        0.0
#
#                         dom_function_window.btoa(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.cancelAnimationFrame(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         dom_function_window.cancelIdleCallback(  \
# domain
# dns29parks.in                                               0.0
# tournamentsoftware.com                                      0.0
# newsoku.blog                                                0.0
# altsantiri.gr                                               0.0
# ruhrnachrichten.de                                          0.0
#
#                         dom_function_window.captureEvents(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.clearImmediate(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         dom_function_window.clearInterval(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.clearTimeout(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.close(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.confirm(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.createImageBitmap(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         dom_function_window.disableExternalCapture(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_window.dispatchEvent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.dump(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.enableExternalCapture(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_window.fetch(  dom_function_window.find(  \
# domain
# dns29parks.in                                  0.0                        0.0
# tournamentsoftware.com                         0.0                        0.0
# newsoku.blog                                   0.0                        0.0
# altsantiri.gr                                  0.0                        0.0
# ruhrnachrichten.de                             0.0                        0.0
#
#                         dom_function_window.focus(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.forward(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.getAttention(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.getAttentionWithCycleCount(  \
# domain
# dns29parks.in                                                       0.0
# tournamentsoftware.com                                              0.0
# newsoku.blog                                                        0.0
# altsantiri.gr                                                       0.0
# ruhrnachrichten.de                                                  0.0
#
#                         dom_function_window.getComputedStyle(  \
# domain
# dns29parks.in                                             0.0
# tournamentsoftware.com                                    0.0
# newsoku.blog                                              0.0
# altsantiri.gr                                             0.0
# ruhrnachrichten.de                                        0.0
#
#                         dom_function_window.getDefaultComputedSyle(  \
# domain
# dns29parks.in                                                   0.0
# tournamentsoftware.com                                          0.0
# newsoku.blog                                                    0.0
# altsantiri.gr                                                   0.0
# ruhrnachrichten.de                                              0.0
#
#                         dom_function_window.getSelection(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.home(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.matchMedia(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         dom_function_window.maximize(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.minimize(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.moveBy(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.moveTo(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.open(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            2.0
#
#                         dom_function_window.openDialog(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_window.postMessage(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_window.print(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         dom_function_window.prompt(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.releaseEvents(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.removeEventListener(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_window.requestAnimationFrame(  \
# domain
# dns29parks.in                                                  0.0
# tournamentsoftware.com                                         0.0
# newsoku.blog                                                   0.0
# altsantiri.gr                                                  0.0
# ruhrnachrichten.de                                             0.0
#
#                         dom_function_window.requestIdleCallback(  \
# domain
# dns29parks.in                                                0.0
# tournamentsoftware.com                                       0.0
# newsoku.blog                                                 0.0
# altsantiri.gr                                                0.0
# ruhrnachrichten.de                                           0.0
#
#                         dom_function_window.resizeBy(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.resizeTo(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.restore(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         dom_function_window.routeEvent(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  0.0
#
#                         dom_function_window.scroll(  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          0.0
# newsoku.blog                                    0.0
# altsantiri.gr                                   0.0
# ruhrnachrichten.de                              0.0
#
#                         dom_function_window.scrollBy(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.scrollByLines(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.scrollByPages(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.scrollTo(  \
# domain
# dns29parks.in                                     0.0
# tournamentsoftware.com                            0.0
# newsoku.blog                                      0.0
# altsantiri.gr                                     0.0
# ruhrnachrichten.de                                0.0
#
#                         dom_function_window.setCursor(  \
# domain
# dns29parks.in                                      0.0
# tournamentsoftware.com                             0.0
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         dom_function_window.setImmediate(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.setInterval(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         dom_function_window.setResizable(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         dom_function_window.setTimeout(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         dom_function_window.sizeToContent(  \
# domain
# dns29parks.in                                          0.0
# tournamentsoftware.com                                 0.0
# newsoku.blog                                           0.0
# altsantiri.gr                                          0.0
# ruhrnachrichten.de                                     0.0
#
#                         dom_function_window.stop(  \
# domain
# dns29parks.in                                 0.0
# tournamentsoftware.com                        0.0
# newsoku.blog                                  0.0
# altsantiri.gr                                 0.0
# ruhrnachrichten.de                            0.0
#
#                         dom_function_window.updateCommands(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_.add(  js_function_.all(  \
# domain
# dns29parks.in                         0.0                0.0
# tournamentsoftware.com                2.0                0.0
# newsoku.blog                          1.0                0.0
# altsantiri.gr                         0.0                0.0
# ruhrnachrichten.de                    0.0                0.0
#
#                         js_function_.allTrue(  js_function_.anchor(  \
# domain
# dns29parks.in                             0.0                   0.0
# tournamentsoftware.com                    0.0                   0.0
# newsoku.blog                              0.0                   0.0
# altsantiri.gr                             0.0                   0.0
# ruhrnachrichten.de                        0.0                   0.0
#
#                         js_function_.apply(  js_function_.big(  \
# domain
# dns29parks.in                           0.0                0.0
# tournamentsoftware.com                  0.0                0.0
# newsoku.blog                            2.0                0.0
# ...
# newsoku.blog                                       0.0
# altsantiri.gr                                      0.0
# ruhrnachrichten.de                                 0.0
#
#                         js_function_Reflect.defineProperty(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.deleteProperty(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.get(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         js_function_Reflect.getPrototypeOf(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_Reflect.has(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.isExtensible(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_Reflect.ownKeys(  \
# domain
# dns29parks.in                                    0.0
# tournamentsoftware.com                           0.0
# newsoku.blog                                     0.0
# altsantiri.gr                                    0.0
# ruhrnachrichten.de                               0.0
#
#                         js_function_Reflect.preventExtensions(  \
# domain
# dns29parks.in                                              0.0
# tournamentsoftware.com                                     0.0
# newsoku.blog                                               0.0
# altsantiri.gr                                              0.0
# ruhrnachrichten.de                                         0.0
#
#                         js_function_Reflect.set(  \
# domain
# dns29parks.in                                0.0
# tournamentsoftware.com                       0.0
# newsoku.blog                                 0.0
# altsantiri.gr                                0.0
# ruhrnachrichten.de                           0.0
#
#                         js_function_Reflect.setPrototypeOf(  \
# domain
# dns29parks.in                                           0.0
# tournamentsoftware.com                                  0.0
# newsoku.blog                                            0.0
# altsantiri.gr                                           0.0
# ruhrnachrichten.de                                      0.0
#
#                         js_function_String.fromCharCode(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_String.fromCodePoint(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_String.raw(  js_function_Symbol.for(  \
# domain
# dns29parks.in                               0.0                      0.0
# tournamentsoftware.com                      0.0                      0.0
# newsoku.blog                                0.0                      0.0
# altsantiri.gr                               0.0                      0.0
# ruhrnachrichten.de                          0.0                      0.0
#
#                         js_function_Symbol.keyFor(  \
# domain
# dns29parks.in                                  0.0
# tournamentsoftware.com                         0.0
# newsoku.blog                                   0.0
# altsantiri.gr                                  0.0
# ruhrnachrichten.de                             0.0
#
#                         js_function_WebAssembly.compile(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.compileStreaming(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         js_function_WebAssembly.customerSections(  \
# domain
# dns29parks.in                                                 0.0
# tournamentsoftware.com                                        0.0
# newsoku.blog                                                  0.0
# altsantiri.gr                                                 0.0
# ruhrnachrichten.de                                            0.0
#
#                         js_function_WebAssembly.exports(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.imports(  \
# domain
# dns29parks.in                                        0.0
# tournamentsoftware.com                               0.0
# newsoku.blog                                         0.0
# altsantiri.gr                                        0.0
# ruhrnachrichten.de                                   0.0
#
#                         js_function_WebAssembly.instantiate(  \
# domain
# dns29parks.in                                            0.0
# tournamentsoftware.com                                   0.0
# newsoku.blog                                             0.0
# altsantiri.gr                                            0.0
# ruhrnachrichten.de                                       0.0
#
#                         js_function_WebAssembly.instantiateStreaming(  \
# domain
# dns29parks.in                                                     0.0
# tournamentsoftware.com                                            0.0
# newsoku.blog                                                      0.0
# altsantiri.gr                                                     0.0
# ruhrnachrichten.de                                                0.0
#
#                         js_function_WebAssembly.validate(  \
# domain
# dns29parks.in                                         0.0
# tournamentsoftware.com                                0.0
# newsoku.blog                                          0.0
# altsantiri.gr                                         0.0
# ruhrnachrichten.de                                    0.0
#
#                         js_function_decodeURI(  \
# domain
# dns29parks.in                              0.0
# tournamentsoftware.com                     0.0
# newsoku.blog                               0.0
# altsantiri.gr                              0.0
# ruhrnachrichten.de                         0.0
#
#                         js_function_decodeURIComponent(  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              0.0
# newsoku.blog                                        0.0
# altsantiri.gr                                       0.0
# ruhrnachrichten.de                                  1.0
#
#                         js_function_encodeURI(  \
# domain
# dns29parks.in                              0.0
# tournamentsoftware.com                     0.0
# newsoku.blog                               0.0
# altsantiri.gr                              0.0
# ruhrnachrichten.de                         0.0
#
#                         js_function_encodeURIComponent(  js_function_escape(  \
# domain
# dns29parks.in                                       0.0                  0.0
# tournamentsoftware.com                              0.0                  0.0
# newsoku.blog                                        0.0                  0.0
# altsantiri.gr                                       0.0                  0.0
# ruhrnachrichten.de                                  0.0                  0.0
#
#                         js_function_eval(  js_function_isFinite(  \
# domain
# dns29parks.in                         0.0                    0.0
# tournamentsoftware.com                0.0                    0.0
# newsoku.blog                          0.0                    0.0
# altsantiri.gr                         0.0                    0.0
# ruhrnachrichten.de                    0.0                    0.0
#
#                         js_function_isNaN(  js_function_parseFloat(  \
# domain
# dns29parks.in                          0.0                      0.0
# tournamentsoftware.com                 0.0                      0.0
# newsoku.blog                           0.0                      0.0
# altsantiri.gr                          0.0                      0.0
# ruhrnachrichten.de                     0.0                      0.0
#
#                         js_function_parseInt(  js_function_undefined(  \
# domain
# dns29parks.in                             0.0                     0.0
# tournamentsoftware.com                    0.0                     0.0
# newsoku.blog                              0.0                     0.0
# altsantiri.gr                             0.0                     0.0
# ruhrnachrichten.de                        0.0                     0.0
#
#                         js_function_unescape(  js_function_uneval(  \
# domain
# dns29parks.in                             0.0                  0.0
# tournamentsoftware.com                    0.0                  0.0
# newsoku.blog                              0.0                  0.0
# altsantiri.gr                             0.0                  0.0
# ruhrnachrichten.de                        0.0                  0.0
#
#                         number_functions_declared  number_of_cookies  \
# domain
# dns29parks.in                                 0.0                0.0
# tournamentsoftware.com                        0.0                2.0
# newsoku.blog                                  8.0               10.0
# altsantiri.gr                                16.0                4.0
# ruhrnachrichten.de                           14.0               21.0
#
#                         number_of_http_only_cookies  \
# domain
# dns29parks.in                                   0.0
# tournamentsoftware.com                          1.0
# newsoku.blog                                    1.0
# altsantiri.gr                                   1.0
# ruhrnachrichten.de                              2.0
#
#                         number_of_non_http_only_cookies  \
# domain
# dns29parks.in                                       0.0
# tournamentsoftware.com                              1.0
# newsoku.blog                                        9.0
# altsantiri.gr                                       3.0
# ruhrnachrichten.de                                 19.0
#
#                         number_of_secure_cookies  number_of_unsecure_cookies  \
# domain
# dns29parks.in                                0.0                         0.0
# tournamentsoftware.com                       0.0                         2.0
# newsoku.blog                                 0.0                        10.0
# altsantiri.gr                                1.0                         3.0
# ruhrnachrichten.de                           0.0                        21.0
#
#                         Malicious
# domain
# dns29parks.in                   0
# tournamentsoftware.com          0
# newsoku.blog                    0
# altsantiri.gr                   0
# ruhrnachrichten.de              0

# %% [markdown]
# ### <a id='1.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (12574, 20)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['dom_function_window.setTimeout(',
#  'dom_function_window.setInterval(',
#  'dom_function_document.createElement(',
#  'dom_function_document.write(',
#  'dom_function_document.createComment(',
#  'dom_function_document.createElementNS(',
#  'dom_function_window.addEventListener(',
#  'js_function_escape(',
#  'js_function_unescape(',
#  'js_function_eval(',
#  'js_function_.concat(',
#  'js_function_.charCodeAt(',
#  'js_function_String.fromCharCode(',
#  'js_function_.split(',
#  'js_function_Number.parseInt(',
#  'js_function_.replace(',
#  'js_function_.link(',
#  'js_function_.exec(',
#  'js_function_.search(',
#  'js_function_.substring(']

# %% [markdown]
# ### <a id='1.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8238393478358476
# Predicted  False  True  __all__
# Actual
# False       3551  1505     5056
# True         267  4736     5003
# __all__     3818  6241    10059
# The accuracy of the model on test data is: 0.8298210735586481
# Predicted  False  True  __all__
# Actual
# False        865   366     1231
# True          62  1222     1284
# __all__      927  1588     2515

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.5075057162739834
# Predicted  False  True  __all__
# Actual
# False       4988    68     5056
# True        4886   117     5003
# __all__     9874   185    10059
# The accuracy of the model on test data is: 0.48946322067594433
# Predicted  False  True  __all__
# Actual
# False       1213    18     1231
# True        1266    18     1284
# __all__     2479    36     2515

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7786062232826325
# Predicted  False  True  __all__
# Actual
# False       3096  1960     5056
# True         267  4736     5003
# __all__     3363  6696    10059
# The accuracy of the model on test data is: 0.7924453280318091
# Predicted  False  True  __all__
# Actual
# False        768   463     1231
# True          59  1225     1284
# __all__      827  1688     2515

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8313947708519733
# Predicted  False  True  __all__
# Actual
# False       3542  1514     5056
# True         182  4821     5003
# __all__     3724  6335    10059
# The accuracy of the model on test data is: 0.8294234592445328
# Predicted  False  True  __all__
# Actual
# False        855   376     1231
# True          53  1231     1284
# __all__      908  1607     2515

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8076349537727409
# Predicted  False  True  __all__
# Actual
# False       3406  1650     5056
# True         285  4718     5003
# __all__     3691  6368    10059
# The accuracy of the model on test data is: 0.8135188866799204
# Predicted  False  True  __all__
# Actual
# False        827   404     1231
# True          65  1219     1284
# __all__      892  1623     2515

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8239387613082811
# Predicted  False  True  __all__
# Actual
# False       3545  1511     5056
# True         260  4743     5003
# __all__     3805  6254    10059
# The accuracy of the model on test data is: 0.8290258449304175
# Predicted  False  True  __all__
# Actual
# False        860   371     1231
# True          59  1225     1284
# __all__      919  1596     2515

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.832388905457799
# Predicted  False  True  __all__
# Actual
# False       3553  1503     5056
# True         183  4820     5003
# __all__     3736  6323    10059
# The accuracy of the model on test data is: 0.8318091451292247
# Predicted  False  True  __all__
# Actual
# False        862   369     1231
# True          54  1230     1284
# __all__      916  1599     2515

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8313947708519733
# Predicted  False  True  __all__
# Actual
# False       3543  1513     5056
# True         183  4820     5003
# __all__     3726  6333    10059
# The accuracy of the model on test data is: 0.8298210735586481
# Predicted  False  True  __all__
# Actual
# False        856   375     1231
# True          53  1231     1284
# __all__      909  1606     2515

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8290088477979919
# Predicted  False  True  __all__
# Actual
# False       3548  1508     5056
# True         212  4791     5003
# __all__     3760  6299    10059
# The accuracy of the model on test data is: 0.8282306163021869
# Predicted  False  True  __all__
# Actual
# False        855   376     1231
# True          56  1228     1284
# __all__      911  1604     2515

# %% [markdown]
# ### <a id='1.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP      FN  \
# index
# Neural Network-1            0.823839  4736.0  3551.0  1505.0   267.0
# KNeighborsClassifier        0.507506   117.0  4988.0    68.0  4886.0
# LogisticRegression          0.778606  4736.0  3096.0  1960.0   267.0
# RandomForestClassifier      0.831395  4821.0  3542.0  1514.0   182.0
# AdaBoostClassifier          0.807635  4718.0  3406.0  1650.0   285.0
# GradientBoostingClassifier  0.823939  4743.0  3545.0  1511.0   260.0
# ExtraTreeClassifier         0.832389  4820.0  3553.0  1503.0   183.0
# BaggingClassifier           0.831395  4820.0  3543.0  1513.0   183.0
# VotingClassifier            0.829009  4791.0  3548.0  1508.0   212.0
#
#                                  FPR       FNR
# index
# Neural Network-1            0.297666  0.053368
# KNeighborsClassifier        0.013449  0.976614
# LogisticRegression          0.387658  0.053368
# RandomForestClassifier      0.299446  0.036378
# AdaBoostClassifier          0.326345  0.056966
# GradientBoostingClassifier  0.298853  0.051969
# ExtraTreeClassifier         0.297271  0.036578
# BaggingClassifier           0.299248  0.036578
# VotingClassifier            0.298259  0.042375
# Comparision Table for Test Accuracies:
#                             accuracy      TP      TN     FP      FN       FPR  \
# index
# Neural Network-1            0.829821  1222.0   865.0  366.0    62.0  0.297319
# KNeighborsClassifier        0.489463    18.0  1213.0   18.0  1266.0  0.014622
# LogisticRegression          0.792445  1225.0   768.0  463.0    59.0  0.376117
# RandomForestClassifier      0.829423  1231.0   855.0  376.0    53.0  0.305443
# AdaBoostClassifier          0.813519  1219.0   827.0  404.0    65.0  0.328188
# GradientBoostingClassifier  0.829026  1225.0   860.0  371.0    59.0  0.301381
# ExtraTreeClassifier         0.831809  1230.0   862.0  369.0    54.0  0.299756
# BaggingClassifier           0.829821  1231.0   856.0  375.0    53.0  0.304630
# VotingClassifier            0.828231  1228.0   855.0  376.0    56.0  0.305443
#
#                                  FNR       auc
# index
# Neural Network-1            0.048287  0.827197
# KNeighborsClassifier        0.985981  0.499698
# LogisticRegression          0.045950  0.788966
# RandomForestClassifier      0.041277  0.826640
# AdaBoostClassifier          0.050623  0.810594
# GradientBoostingClassifier  0.045950  0.826334
# ExtraTreeClassifier         0.042056  0.829094
# BaggingClassifier           0.041277  0.827046
# VotingClassifier            0.043614  0.825472

# %% [markdown]
# ## <a id='2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a>
#
# #### <a id='2.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=18,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_pca.shape
# Out:
# 0.9687049114640699
# The train/test split ratio is 80:20
# (12574, 18)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_pca.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8247340690107181
# Predicted  False  True  __all__
# Actual
# False       3566  1490     5056
# True         273  4730     5003
# __all__     3839  6220    10059
# The accuracy of the model on test data is: 0.8294234592445328
# Predicted  False  True  __all__
# Actual
# False        865   366     1231
# True          63  1221     1284
# __all__      928  1587     2515

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8261258574410976
# Predicted  False  True  __all__
# Actual
# False       3536  1520     5056
# True         229  4774     5003
# __all__     3765  6294    10059
# The accuracy of the model on test data is: 0.831013916500994
# Predicted  False  True  __all__
# Actual
# False        857   374     1231
# True          51  1233     1284
# __all__      908  1607     2515

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7786062232826325
# Predicted  False  True  __all__
# Actual
# False       3097  1959     5056
# True         268  4735     5003
# __all__     3365  6694    10059
# The accuracy of the model on test data is: 0.7916500994035786
# Predicted  False  True  __all__
# Actual
# False        766   465     1231
# True          59  1225     1284
# __all__      825  1690     2515

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8315935977731385
# Predicted  False  True  __all__
# Actual
# False       3542  1514     5056
# True         180  4823     5003
# __all__     3722  6337    10059
# The accuracy of the model on test data is: 0.8302186878727634
# Predicted  False  True  __all__
# Actual
# False        856   375     1231
# True          52  1232     1284
# __all__      908  1607     2515

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.824634655532359
# Predicted  False  True  __all__
# Actual
# False       3560  1496     5056
# True         268  4735     5003
# __all__     3828  6231    10059
# The accuracy of the model on test data is: 0.8302186878727634
# Predicted  False  True  __all__
# Actual
# False        866   365     1231
# True          62  1222     1284
# __all__      928  1587     2515

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8268217516651755
# Predicted  False  True  __all__
# Actual
# False       3565  1491     5056
# True         251  4752     5003
# __all__     3816  6243    10059
# The accuracy of the model on test data is: 0.8306163021868788
# Predicted  False  True  __all__
# Actual
# False        867   364     1231
# True          62  1222     1284
# __all__      929  1586     2515

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.832388905457799
# Predicted  False  True  __all__
# Actual
# False       3553  1503     5056
# True         183  4820     5003
# __all__     3736  6323    10059
# The accuracy of the model on test data is: 0.8326043737574552
# Predicted  False  True  __all__
# Actual
# False        864   367     1231
# True          54  1230     1284
# __all__      918  1597     2515

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8313947708519733
# Predicted  False  True  __all__
# Actual
# False       3544  1512     5056
# True         184  4819     5003
# __all__     3728  6331    10059
# The accuracy of the model on test data is: 0.8314115308151093
# Predicted  False  True  __all__
# Actual
# False        861   370     1231
# True          54  1230     1284
# __all__      915  1600     2515

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8301023958644
# Predicted  False  True  __all__
# Actual
# False       3551  1505     5056
# True         204  4799     5003
# __all__     3755  6304    10059
# The accuracy of the model on test data is: 0.83220675944334
# Predicted  False  True  __all__
# Actual
# False        862   369     1231
# True          53  1231     1284
# __all__      915  1600     2515

# %% [markdown]
# ### <a id='2.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.824734  4730.0  3566.0  1490.0  273.0  0.294699
# KNeighborsClassifier        0.826126  4774.0  3536.0  1520.0  229.0  0.300633
# LogisticRegression          0.778606  4735.0  3097.0  1959.0  268.0  0.387460
# RandomForestClassifier      0.831594  4823.0  3542.0  1514.0  180.0  0.299446
# AdaBoostClassifier          0.824635  4735.0  3560.0  1496.0  268.0  0.295886
# GradientBoostingClassifier  0.826822  4752.0  3565.0  1491.0  251.0  0.294897
# ExtraTreeClassifier         0.832389  4820.0  3553.0  1503.0  183.0  0.297271
# BaggingClassifier           0.831395  4819.0  3544.0  1512.0  184.0  0.299051
# VotingClassifier            0.830102  4799.0  3551.0  1505.0  204.0  0.297666
#
#                                  FNR
# index
# Neural Network-1            0.054567
# KNeighborsClassifier        0.045773
# LogisticRegression          0.053568
# RandomForestClassifier      0.035978
# AdaBoostClassifier          0.053568
# GradientBoostingClassifier  0.050170
# ExtraTreeClassifier         0.036578
# BaggingClassifier           0.036778
# VotingClassifier            0.040776
# Comparision Table for Test Accuracies:
#                             accuracy      TP     TN     FP    FN       FPR  \
# index
# Neural Network-1            0.829423  1221.0  865.0  366.0  63.0  0.297319
# KNeighborsClassifier        0.831014  1233.0  857.0  374.0  51.0  0.303818
# LogisticRegression          0.791650  1225.0  766.0  465.0  59.0  0.377742
# RandomForestClassifier      0.830219  1232.0  856.0  375.0  52.0  0.304630
# AdaBoostClassifier          0.830219  1222.0  866.0  365.0  62.0  0.296507
# GradientBoostingClassifier  0.830616  1222.0  867.0  364.0  62.0  0.295695
# ExtraTreeClassifier         0.832604  1230.0  864.0  367.0  54.0  0.298132
# BaggingClassifier           0.831412  1230.0  861.0  370.0  54.0  0.300569
# VotingClassifier            0.832207  1231.0  862.0  369.0  53.0  0.299756
#
#                                  FNR       auc
# index
# Neural Network-1            0.049065  0.826808
# KNeighborsClassifier        0.039720  0.828231
# LogisticRegression          0.045950  0.788154
# RandomForestClassifier      0.040498  0.827436
# AdaBoostClassifier          0.048287  0.827603
# GradientBoostingClassifier  0.048287  0.828009
# ExtraTreeClassifier         0.042056  0.829906
# BaggingClassifier           0.042056  0.828688
# VotingClassifier            0.041277  0.829483

# %% [markdown]
# ### <a id='2.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 12                              0.055131
# 9                               0.055108
# 1                               0.054817
# 16                              0.054719
# 18                              0.054667
# 6                               0.054632
# 11                              0.054025
# 5                               0.053744
# 2                               0.053243
# 10                              0.053080
# 4                               0.052341
# 3                               0.050266
# 0                               0.047237
# 19                              0.043752
# 14                              0.041991
# 17                              0.040775
# 8                               0.035556
# 7                               0.030256
# 15                              0.029675
# 13                              0.029429
#
#                                   Features
# 12        js_function_String.fromCharCode(
# 9                        js_function_eval(
# 1         dom_function_window.setInterval(
# 16                      js_function_.link(
# 18                    js_function_.search(
# 6    dom_function_window.addEventListener(
# 11                js_function_.charCodeAt(
# 5   dom_function_document.createElementNS(
# 2     dom_function_document.createElement(
# 10                    js_function_.concat(
# 4     dom_function_document.createComment(
# 3             dom_function_document.write(
# 0          dom_function_window.setTimeout(
# 19                 js_function_.substring(
# 14            js_function_Number.parseInt(
# 17                      js_function_.exec(
# 8                    js_function_unescape(
# 7                      js_function_escape(
# 15                   js_function_.replace(
# 13                     js_function_.split(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## <a id='3' style="text-decoration : none; color : #000000;"> HTTPS</a>
#
# ### <a id='3.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_https.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_https.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

df_non=df[df.Malicious==0]
df_mal=df[df.Malicious==1]

df_non=df_non.sample(frac=len(df_mal)/len(df_non),random_state=0)
df_u=df_non.append(df_mal)
df_u.Malicious.value_counts() 
X=df_u[['dom_function_window.setTimeout(','dom_function_window.setInterval(','dom_function_document.createElement(',
     'dom_function_document.write(','dom_function_document.createComment(','dom_function_document.createElementNS(',
      'dom_function_window.addEventListener(','js_function_escape(','js_function_unescape(','js_function_eval(','js_function_.concat(','js_function_.charCodeAt(',
   'js_function_String.fromCharCode(','js_function_.split(','js_function_Number.parseInt(','js_function_.replace(',
   'js_function_.link(','js_function_.exec(','js_function_.search(','js_function_.substring(']]


y=df_u.Malicious.values
feature_name = X.columns.tolist()
print("Shape after undersampling",df_u.shape)
df_u.head()
# Out:
# Shape after undersampling (12714, 407)
#                  dom_function_document.adoptNode(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  dom_function_document.captureEvents(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.caretPositionFromPoint(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.caretRangeFromPoint(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_document.clear(  dom_function_document.close(  \
# domain
# spellingbee.com                           0.0                           0.0
# hd-streams.org                            0.0                           0.0
# ebay.at                                   0.0                           0.0
# drhmonegyi.net                            0.0                           0.0
# dhc.co.jp                                 0.0                           0.0
#
#                  dom_function_document.createAttribute(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createAttributeNS(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.createCDATASection(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_document.createComment(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.createDocumentFragment(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.createElement(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    1.0
# ebay.at                                           5.0
# drhmonegyi.net                                    1.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.createElementNS(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createEntityReference(  \
# domain
# spellingbee.com                                           0.0
# hd-streams.org                                            0.0
# ebay.at                                                   0.0
# drhmonegyi.net                                            0.0
# dhc.co.jp                                                 0.0
#
#                  dom_function_document.createEvent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         8.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createNodeIterator(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_document.createProcessingInstruction(  \
# domain
# spellingbee.com                                                0.0
# hd-streams.org                                                 0.0
# ebay.at                                                        0.0
# drhmonegyi.net                                                 0.0
# dhc.co.jp                                                      0.0
#
#                  dom_function_document.createRange(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createTextNode(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.createTouch(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.createTouchList(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.createTreeWalker(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.elementFromPoint(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.elementsFromPoint(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.enableStyleSheetsForSet(  \
# domain
# spellingbee.com                                             0.0
# hd-streams.org                                              0.0
# ebay.at                                                     0.0
# drhmonegyi.net                                              0.0
# dhc.co.jp                                                   0.0
#
#                  dom_function_document.execCommand(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         2.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_document.exitPointerLock(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_document.getAnimations(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.getElementById(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     3.0
# ebay.at                                            4.0
# drhmonegyi.net                                     3.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.getElementByName(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.getElementsByClassName(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    1.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.getElementsByTagName(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           2.0
# dhc.co.jp                                                0.0
#
#                  dom_function_document.getElementsByTagNameNS(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  dom_function_document.getSelection(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_document.hasFocus(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      0.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_document.importNode(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_document.normalizeDocument(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.open(  \
# domain
# spellingbee.com                          0.0
# hd-streams.org                           0.0
# ebay.at                                  0.0
# drhmonegyi.net                           0.0
# dhc.co.jp                                0.0
#
#                  dom_function_document.queryCommandEnabled(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_document.queryCommandIndeterm(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_document.queryCommandValue(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_document.querySelector(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           6.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  dom_function_document.querySelectorAll(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_document.releaseCapture(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_document.releaseEvent(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_document.routeEvent(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_document.write(  dom_function_document.writeln(  \
# domain
# spellingbee.com                           0.0                             0.0
# hd-streams.org                            0.0                             0.0
# ebay.at                                   0.0                             0.0
# drhmonegyi.net                            0.0                             0.0
# dhc.co.jp                                 0.0                             0.0
#
#                  dom_function_window.addEventListener(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            3.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_window.alert(  dom_function_window.atob(  \
# domain
# spellingbee.com                         0.0                        0.0
# hd-streams.org                          0.0                        0.0
# ebay.at                                 0.0                        0.0
# drhmonegyi.net                          0.0                        0.0
# dhc.co.jp                               0.0                        0.0
#
#                  dom_function_window.back(  dom_function_window.blur(  \
# domain
# spellingbee.com                        0.0                        0.0
# hd-streams.org                         0.0                        0.0
# ebay.at                                0.0                        0.0
# drhmonegyi.net                         0.0                        0.0
# dhc.co.jp                              0.0                        0.0
#
#                  dom_function_window.btoa(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.cancelAnimationFrame(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  dom_function_window.cancelIdleCallback(  \
# domain
# spellingbee.com                                      0.0
# hd-streams.org                                       0.0
# ebay.at                                              0.0
# drhmonegyi.net                                       0.0
# dhc.co.jp                                            0.0
#
#                  dom_function_window.captureEvents(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.clearImmediate(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  dom_function_window.clearInterval(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.clearTimeout(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.close(  dom_function_window.confirm(  \
# domain
# spellingbee.com                         0.0                           0.0
# hd-streams.org                          0.0                           0.0
# ebay.at                                 0.0                           0.0
# drhmonegyi.net                          0.0                           0.0
# dhc.co.jp                               0.0                           0.0
#
#                  dom_function_window.createImageBitmap(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  dom_function_window.disableExternalCapture(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_window.dispatchEvent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.dump(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.enableExternalCapture(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_window.fetch(  dom_function_window.find(  \
# domain
# spellingbee.com                         0.0                        0.0
# hd-streams.org                          0.0                        0.0
# ebay.at                                 0.0                        0.0
# drhmonegyi.net                          0.0                        0.0
# dhc.co.jp                               0.0                        0.0
#
#                  dom_function_window.focus(  dom_function_window.forward(  \
# domain
# spellingbee.com                         0.0                           0.0
# hd-streams.org                          0.0                           0.0
# ebay.at                                 0.0                           0.0
# drhmonegyi.net                          0.0                           0.0
# dhc.co.jp                               0.0                           0.0
#
#                  dom_function_window.getAttention(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.getAttentionWithCycleCount(  \
# domain
# spellingbee.com                                              0.0
# hd-streams.org                                               0.0
# ebay.at                                                      0.0
# drhmonegyi.net                                               0.0
# dhc.co.jp                                                    0.0
#
#                  dom_function_window.getComputedStyle(  \
# domain
# spellingbee.com                                    0.0
# hd-streams.org                                     0.0
# ebay.at                                            2.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  dom_function_window.getDefaultComputedSyle(  \
# domain
# spellingbee.com                                          0.0
# hd-streams.org                                           0.0
# ebay.at                                                  0.0
# drhmonegyi.net                                           0.0
# dhc.co.jp                                                0.0
#
#                  dom_function_window.getSelection(  dom_function_window.home(  \
# domain
# spellingbee.com                                0.0                        0.0
# hd-streams.org                                 0.0                        0.0
# ebay.at                                        0.0                        0.0
# drhmonegyi.net                                 0.0                        0.0
# dhc.co.jp                                      0.0                        0.0
#
#                  dom_function_window.matchMedia(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      0.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_window.maximize(  dom_function_window.minimize(  \
# domain
# spellingbee.com                            0.0                            0.0
# hd-streams.org                             0.0                            0.0
# ebay.at                                    0.0                            0.0
# drhmonegyi.net                             0.0                            0.0
# dhc.co.jp                                  0.0                            0.0
#
#                  dom_function_window.moveBy(  dom_function_window.moveTo(  \
# domain
# spellingbee.com                          0.0                          0.0
# hd-streams.org                           0.0                          0.0
# ebay.at                                  0.0                          0.0
# drhmonegyi.net                           0.0                          0.0
# dhc.co.jp                                0.0                          0.0
#
#                  dom_function_window.open(  dom_function_window.openDialog(  \
# domain
# spellingbee.com                        0.0                              0.0
# hd-streams.org                         0.0                              0.0
# ebay.at                                0.0                              0.0
# drhmonegyi.net                         0.0                              0.0
# dhc.co.jp                              0.0                              0.0
#
#                  dom_function_window.postMessage(  dom_function_window.print(  \
# domain
# spellingbee.com                               0.0                         0.0
# hd-streams.org                                0.0                         0.0
# ebay.at                                       0.0                         0.0
# drhmonegyi.net                                0.0                         0.0
# dhc.co.jp                                     0.0                         0.0
#
#                  dom_function_window.prompt(  \
# domain
# spellingbee.com                          0.0
# hd-streams.org                           0.0
# ebay.at                                  0.0
# drhmonegyi.net                           0.0
# dhc.co.jp                                0.0
#
#                  dom_function_window.releaseEvents(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.removeEventListener(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               2.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_window.requestAnimationFrame(  \
# domain
# spellingbee.com                                         0.0
# hd-streams.org                                          0.0
# ebay.at                                                 0.0
# drhmonegyi.net                                          0.0
# dhc.co.jp                                               0.0
#
#                  dom_function_window.requestIdleCallback(  \
# domain
# spellingbee.com                                       0.0
# hd-streams.org                                        0.0
# ebay.at                                               0.0
# drhmonegyi.net                                        0.0
# dhc.co.jp                                             0.0
#
#                  dom_function_window.resizeBy(  dom_function_window.resizeTo(  \
# domain
# spellingbee.com                            0.0                            0.0
# hd-streams.org                             0.0                            0.0
# ebay.at                                    0.0                            0.0
# drhmonegyi.net                             0.0                            0.0
# dhc.co.jp                                  0.0                            0.0
#
#                  dom_function_window.restore(  \
# domain
# spellingbee.com                           0.0
# hd-streams.org                            0.0
# ebay.at                                   0.0
# drhmonegyi.net                            0.0
# dhc.co.jp                                 0.0
#
#                  dom_function_window.routeEvent(  dom_function_window.scroll(  \
# domain
# spellingbee.com                              0.0                          0.0
# hd-streams.org                               0.0                          0.0
# ebay.at                                      0.0                          0.0
# drhmonegyi.net                               0.0                          0.0
# dhc.co.jp                                    0.0                          0.0
#
#                  dom_function_window.scrollBy(  \
# domain
# spellingbee.com                            0.0
# hd-streams.org                             0.0
# ebay.at                                    0.0
# drhmonegyi.net                             0.0
# dhc.co.jp                                  0.0
#
#                  dom_function_window.scrollByLines(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.scrollByPages(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.scrollTo(  \
# domain
# spellingbee.com                            0.0
# hd-streams.org                             0.0
# ebay.at                                    0.0
# drhmonegyi.net                             0.0
# dhc.co.jp                                  0.0
#
#                  dom_function_window.setCursor(  \
# domain
# spellingbee.com                             0.0
# hd-streams.org                              0.0
# ebay.at                                     0.0
# drhmonegyi.net                              0.0
# dhc.co.jp                                   0.0
#
#                  dom_function_window.setImmediate(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.setInterval(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  dom_function_window.setResizable(  \
# domain
# spellingbee.com                                0.0
# hd-streams.org                                 0.0
# ebay.at                                        0.0
# drhmonegyi.net                                 0.0
# dhc.co.jp                                      0.0
#
#                  dom_function_window.setTimeout(  \
# domain
# spellingbee.com                              0.0
# hd-streams.org                               0.0
# ebay.at                                      2.0
# drhmonegyi.net                               0.0
# dhc.co.jp                                    0.0
#
#                  dom_function_window.sizeToContent(  \
# domain
# spellingbee.com                                 0.0
# hd-streams.org                                  0.0
# ebay.at                                         0.0
# drhmonegyi.net                                  0.0
# dhc.co.jp                                       0.0
#
#                  dom_function_window.stop(  \
# domain
# spellingbee.com                        0.0
# hd-streams.org                         0.0
# ebay.at                                0.0
# drhmonegyi.net                         0.0
# dhc.co.jp                              0.0
#
#                  dom_function_window.updateCommands(  js_function_.add(  \
# domain
# spellingbee.com                                  0.0                0.0
# hd-streams.org                                   0.0                0.0
# ebay.at                                          0.0                7.0
# drhmonegyi.net                                   0.0                0.0
# dhc.co.jp                                        0.0                0.0
#
#                  js_function_.all(  js_function_.allTrue(  \
# domain
# spellingbee.com                0.0                    0.0
# hd-streams.org                 0.0                    0.0
# ebay.at                        0.0                    0.0
# drhmonegyi.net                 0.0                    0.0
# dhc.co.jp                      0.0                    0.0
#
#                  js_function_.anchor(  js_function_.apply(  js_function_.big(  \
# domain
# spellingbee.com                   0.0                  1.0                0.0
# hd-streams.org                    0.0                  0.0                0.0
# ebay.at                           0.0                 17.0                0.0
# drhmonegyi.net                    0.0                  2.0                0.0
# dhc.co.jp                         0.0                  0.0                0.0
#
#                  js_function_.bind(  js_function_.blink(  js_function_.bold(  \
# domain
# spellingbee.com                 0.0                  0.0                 0.0
# hd-streams.org                  0.0                  0.0                 0.0
# ebay.at                         6.0                  0.0                 0.0
# drhmonegyi.net                  0.0                  0.0                 0.0
# dhc.co.jp                       0.0                  0.0                 0.0
#
#                  js_function_.call(  js_function_.catch(  \
# domain
# spellingbee.com                 0.0                  0.0
# hd-streams.org                  0.0                  0.0
# ebay.at                        39.0                  0.0
# drhmonegyi.net                  0.0                  0.0
# dhc.co.jp                       0.0                  0.0
#
#                  js_function_.charAt(  js_function_.charCodeAt(  \
# domain
# spellingbee.com                   0.0                       0.0
# hd-streams.org                    0.0                       0.0
# ebay.at                          15.0                       0.0
# drhmonegyi.net                    0.0                       0.0
# dhc.co.jp                         0.0                       0.0
#
#                  js_function_.clear(  js_function_.codePointAt(  \
# domain
# spellingbee.com                  0.0                        0.0
# hd-streams.org                   0.0                        0.0
# ebay.at                          0.0                        0.0
# drhmonegyi.net                   0.0                        0.0
# dhc.co.jp                        0.0                        0.0
#
#                  js_function_.compile(  js_function_.concat(  \
# domain
# spellingbee.com                    0.0                   0.0
# hd-streams.org                     0.0                   0.0
# ebay.at                            0.0                  21.0
# drhmonegyi.net                     0.0                   0.0
# dhc.co.jp                          0.0                   0.0
#
#                  js_function_.construct(  js_function_.copyWithin(  \
# domain
# spellingbee.com                      0.0                       0.0
# hd-streams.org                       0.0                       0.0
# ebay.at                              0.0                       0.0
# drhmonegyi.net                       0.0                       0.0
# dhc.co.jp                            0.0                       0.0
#
#                  js_function_.defineProperty(  js_function_.delete(  \
# domain
# spellingbee.com                           0.0                   0.0
# hd-streams.org                            0.0                   0.0
# ebay.at                                  10.0                   0.0
# drhmonegyi.net                            0.0                   0.0
# dhc.co.jp                                 0.0                   0.0
#
#                  js_function_.deleteProperty(  js_function_.endWith(  \
# domain
# spellingbee.com                           0.0                    0.0
# hd-streams.org                            0.0                    0.0
# ebay.at                                   0.0                    0.0
# drhmonegyi.net                            0.0                    0.0
# dhc.co.jp                                 0.0                    0.0
#
#                  js_function_.entries(  js_function_.every(  \
# domain
# spellingbee.com                    0.0                  0.0
# hd-streams.org                     0.0                  0.0
# ebay.at                            2.0                  0.0
# drhmonegyi.net                     0.0                  0.0
# dhc.co.jp                          0.0                  0.0
#
#                  js_function_.exec(  js_function_.fill(  js_function_.filter(  \
# domain
# spellingbee.com                 0.0                 0.0                   0.0
# hd-streams.org                  0.0                 0.0                   0.0
# ebay.at                         0.0                 0.0                  16.0
# drhmonegyi.net                  0.0                 0.0                   0.0
# dhc.co.jp                       0.0                 0.0                   0.0
#
#                  js_function_.finally(  js_function_.find(  \
# domain
# spellingbee.com                    0.0                 0.0
# hd-streams.org                     0.0                 0.0
# ebay.at                            0.0                 3.0
# drhmonegyi.net                     0.0                 0.0
# dhc.co.jp                          0.0                 0.0
#
#                  js_function_.findIndex(  js_function_.fixed(  \
# domain
# spellingbee.com                      0.0                  0.0
# hd-streams.org                       0.0                  0.0
# ebay.at                              0.0                  0.0
# drhmonegyi.net                       0.0                  0.0
# dhc.co.jp                            0.0                  0.0
#
#                  js_function_.flat(  js_function_.flatMap(  \
# domain
# spellingbee.com                 0.0                    0.0
# hd-streams.org                  0.0                    0.0
# ebay.at                         0.0                    0.0
# drhmonegyi.net                  0.0                    0.0
# dhc.co.jp                       0.0                    0.0
#
#                  js_function_.fontcolor(  js_function_.fontsize(  \
# domain
# spellingbee.com                      0.0                     0.0
# hd-streams.org                       0.0                     0.0
# ebay.at                              0.0                     0.0
# drhmonegyi.net                       0.0                     0.0
# dhc.co.jp                            0.0                     0.0
#
#                  js_function_.forEach(  js_function_.formatToParts(  \
# ...
# hd-streams.org                                     0.0
# ebay.at                                            0.0
# drhmonegyi.net                                     0.0
# dhc.co.jp                                          0.0
#
#                  js_function_Object.seal(  js_function_Object.setPrototypeOf(  \
# domain
# spellingbee.com                       0.0                                 0.0
# hd-streams.org                        0.0                                 0.0
# ebay.at                               2.0                                 0.0
# drhmonegyi.net                        0.0                                 0.0
# dhc.co.jp                             0.0                                 0.0
#
#                  js_function_Promise.all(  js_function_Promise.race(  \
# domain
# spellingbee.com                       0.0                        0.0
# hd-streams.org                        0.0                        0.0
# ebay.at                               0.0                        0.0
# drhmonegyi.net                        0.0                        0.0
# dhc.co.jp                             0.0                        0.0
#
#                  js_function_Promise.reject(  js_function_Promise.resolve(  \
# domain
# spellingbee.com                          0.0                           0.0
# hd-streams.org                           0.0                           0.0
# ebay.at                                  0.0                           0.0
# drhmonegyi.net                           0.0                           0.0
# dhc.co.jp                                0.0                           0.0
#
#                  js_function_Proxy.revocable(  js_function_Reflect.apply(  \
# domain
# spellingbee.com                           0.0                         0.0
# hd-streams.org                            0.0                         0.0
# ebay.at                                   0.0                         0.0
# drhmonegyi.net                            0.0                         0.0
# dhc.co.jp                                 0.0                         0.0
#
#                  js_function_Reflect.construct(  \
# domain
# spellingbee.com                             0.0
# hd-streams.org                              0.0
# ebay.at                                     0.0
# drhmonegyi.net                              0.0
# dhc.co.jp                                   0.0
#
#                  js_function_Reflect.defineProperty(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.deleteProperty(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.get(  \
# domain
# spellingbee.com                       0.0
# hd-streams.org                        0.0
# ebay.at                               0.0
# drhmonegyi.net                        0.0
# dhc.co.jp                             0.0
#
#                  js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  js_function_Reflect.getPrototypeOf(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_Reflect.has(  js_function_Reflect.isExtensible(  \
# domain
# spellingbee.com                       0.0                                0.0
# hd-streams.org                        0.0                                0.0
# ebay.at                               0.0                                0.0
# drhmonegyi.net                        0.0                                0.0
# dhc.co.jp                             0.0                                0.0
#
#                  js_function_Reflect.ownKeys(  \
# domain
# spellingbee.com                           0.0
# hd-streams.org                            0.0
# ebay.at                                   0.0
# drhmonegyi.net                            0.0
# dhc.co.jp                                 0.0
#
#                  js_function_Reflect.preventExtensions(  \
# domain
# spellingbee.com                                     0.0
# hd-streams.org                                      0.0
# ebay.at                                             0.0
# drhmonegyi.net                                      0.0
# dhc.co.jp                                           0.0
#
#                  js_function_Reflect.set(  \
# domain
# spellingbee.com                       0.0
# hd-streams.org                        0.0
# ebay.at                               0.0
# drhmonegyi.net                        0.0
# dhc.co.jp                             0.0
#
#                  js_function_Reflect.setPrototypeOf(  \
# domain
# spellingbee.com                                  0.0
# hd-streams.org                                   0.0
# ebay.at                                          0.0
# drhmonegyi.net                                   0.0
# dhc.co.jp                                        0.0
#
#                  js_function_String.fromCharCode(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_String.fromCodePoint(  js_function_String.raw(  \
# domain
# spellingbee.com                                0.0                      0.0
# hd-streams.org                                 0.0                      0.0
# ebay.at                                        0.0                      0.0
# drhmonegyi.net                                 0.0                      0.0
# dhc.co.jp                                      0.0                      0.0
#
#                  js_function_Symbol.for(  js_function_Symbol.keyFor(  \
# domain
# spellingbee.com                      0.0                         0.0
# hd-streams.org                       0.0                         0.0
# ebay.at                              0.0                         0.0
# drhmonegyi.net                       0.0                         0.0
# dhc.co.jp                            0.0                         0.0
#
#                  js_function_WebAssembly.compile(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.compileStreaming(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  js_function_WebAssembly.customerSections(  \
# domain
# spellingbee.com                                        0.0
# hd-streams.org                                         0.0
# ebay.at                                                0.0
# drhmonegyi.net                                         0.0
# dhc.co.jp                                              0.0
#
#                  js_function_WebAssembly.exports(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.imports(  \
# domain
# spellingbee.com                               0.0
# hd-streams.org                                0.0
# ebay.at                                       0.0
# drhmonegyi.net                                0.0
# dhc.co.jp                                     0.0
#
#                  js_function_WebAssembly.instantiate(  \
# domain
# spellingbee.com                                   0.0
# hd-streams.org                                    0.0
# ebay.at                                           0.0
# drhmonegyi.net                                    0.0
# dhc.co.jp                                         0.0
#
#                  js_function_WebAssembly.instantiateStreaming(  \
# domain
# spellingbee.com                                            0.0
# hd-streams.org                                             0.0
# ebay.at                                                    0.0
# drhmonegyi.net                                             0.0
# dhc.co.jp                                                  0.0
#
#                  js_function_WebAssembly.validate(  js_function_decodeURI(  \
# domain
# spellingbee.com                                0.0                     0.0
# hd-streams.org                                 0.0                     0.0
# ebay.at                                        0.0                     0.0
# drhmonegyi.net                                 0.0                     0.0
# dhc.co.jp                                      0.0                     0.0
#
#                  js_function_decodeURIComponent(  js_function_encodeURI(  \
# domain
# spellingbee.com                              0.0                     0.0
# hd-streams.org                               0.0                     0.0
# ebay.at                                      0.0                     0.0
# drhmonegyi.net                               0.0                     0.0
# dhc.co.jp                                    0.0                     0.0
#
#                  js_function_encodeURIComponent(  js_function_escape(  \
# domain
# spellingbee.com                              0.0                  0.0
# hd-streams.org                               0.0                  0.0
# ebay.at                                      2.0                  0.0
# drhmonegyi.net                               0.0                  0.0
# dhc.co.jp                                    0.0                  0.0
#
#                  js_function_eval(  js_function_isFinite(  js_function_isNaN(  \
# domain
# spellingbee.com                0.0                    0.0                 0.0
# hd-streams.org                 0.0                    0.0                 0.0
# ebay.at                        0.0                    0.0                 0.0
# drhmonegyi.net                 0.0                    0.0                 0.0
# dhc.co.jp                      0.0                    0.0                 0.0
#
#                  js_function_parseFloat(  js_function_parseInt(  \
# domain
# spellingbee.com                      0.0                    0.0
# hd-streams.org                       0.0                    0.0
# ebay.at                              0.0                    3.0
# drhmonegyi.net                       0.0                    0.0
# dhc.co.jp                            0.0                    0.0
#
#                  js_function_undefined(  js_function_unescape(  \
# domain
# spellingbee.com                     0.0                    0.0
# hd-streams.org                      0.0                    0.0
# ebay.at                             0.0                    0.0
# drhmonegyi.net                      0.0                    0.0
# dhc.co.jp                           0.0                    0.0
#
#                  js_function_uneval(  number_functions_declared  \
# domain
# spellingbee.com                  0.0                        5.0
# hd-streams.org                   0.0                        5.0
# ebay.at                          0.0                      614.0
# drhmonegyi.net                   0.0                       17.0
# dhc.co.jp                        0.0                        0.0
#
#                  number_of_cookies  number_of_http_only_cookies  \
# domain
# spellingbee.com                3.0                          0.0
# hd-streams.org                 1.0                          1.0
# ebay.at                        5.0                          1.0
# drhmonegyi.net                 2.0                          1.0
# dhc.co.jp                      0.0                          0.0
#
#                  number_of_non_http_only_cookies  number_of_secure_cookies  \
# domain
# spellingbee.com                              3.0                       0.0
# hd-streams.org                               0.0                       0.0
# ebay.at                                      4.0                       0.0
# drhmonegyi.net                               1.0                       0.0
# dhc.co.jp                                    0.0                       0.0
#
#                  number_of_unsecure_cookies  Malicious
# domain
# spellingbee.com                         3.0          0
# hd-streams.org                          1.0          0
# ebay.at                                 5.0          0
# drhmonegyi.net                          2.0          0
# dhc.co.jp                               0.0          0

# %% [markdown]
# ### <a id='3.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (12714, 20)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['dom_function_window.setTimeout(',
#  'dom_function_window.setInterval(',
#  'dom_function_document.createElement(',
#  'dom_function_document.write(',
#  'dom_function_document.createComment(',
#  'dom_function_document.createElementNS(',
#  'dom_function_window.addEventListener(',
#  'js_function_escape(',
#  'js_function_unescape(',
#  'js_function_eval(',
#  'js_function_.concat(',
#  'js_function_.charCodeAt(',
#  'js_function_String.fromCharCode(',
#  'js_function_.split(',
#  'js_function_Number.parseInt(',
#  'js_function_.replace(',
#  'js_function_.link(',
#  'js_function_.exec(',
#  'js_function_.search(',
#  'js_function_.substring(']

# %% [markdown]
# ### <a id='3.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.7715072264632413
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True         120  4921     5041
# __all__     3046  7125    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          34  1282     1316
# __all__      721  1822     2543

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7718021826762363
# Predicted  False  True  __all__
# Actual
# False       2924  2206     5130
# True         115  4926     5041
# __all__     3039  7132    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          34  1282     1316
# __all__      721  1822     2543

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7524333890472913
# Predicted  False  True  __all__
# Actual
# False       2716  2414     5130
# True         104  4937     5041
# __all__     2820  7351    10171
# The accuracy of the model on test data is: 0.7542272906016516
# Predicted  False  True  __all__
# Actual
# False        630   597     1227
# True          28  1288     1316
# __all__      658  1885     2543

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7749483826565726
# Predicted  False  True  __all__
# Actual
# False       2924  2206     5130
# True          83  4958     5041
# __all__     3007  7164    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        685   542     1227
# True          32  1284     1316
# __all__      717  1826     2543

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7642316389735523
# Predicted  False  True  __all__
# Actual
# False       2844  2286     5130
# True         112  4929     5041
# __all__     2956  7215    10171
# The accuracy of the model on test data is: 0.766810853322847
# Predicted  False  True  __all__
# Actual
# False        666   561     1227
# True          32  1284     1316
# __all__      698  1845     2543

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7715072264280798
# Predicted  False  True  __all__
# Actual
# False       2920  2210     5130
# True         114  4927     5041
# __all__     3034  7137    10171
# The accuracy of the model on test data is: 0.7731026346834448
# Predicted  False  True  __all__
# Actual
# False        683   544     1227
# True          33  1283     1316
# __all__      716  1827     2543

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7753416576541147
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True          81  4960     5041
# __all__     3007  7164    10171
# The accuracy of the model on test data is: 0.7746755800235942
# Predicted  False  True  __all__
# Actual
# False        686   541     1227
# True          32  1284     1316
# __all__      718  1825     2543

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.774260151410874
# Predicted  False  True  __all__
# Actual
# False       2921  2209     5130
# True          87  4954     5041
# __all__     3008  7163    10171
# The accuracy of the model on test data is: 0.7731026346834448
# Predicted  False  True  __all__
# Actual
# False        682   545     1227
# True          32  1284     1316
# __all__      714  1829     2543

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.7731786451676335
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True         103  4938     5041
# __all__     3029  7142    10171
# The accuracy of the model on test data is: 0.7738891073535195
# Predicted  False  True  __all__
# Actual
# False        686   541     1227
# True          34  1282     1316
# __all__      720  1823     2543

# %% [markdown]
# ### <a id='3.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.771507  4921.0  2926.0  2204.0  120.0  0.429630
# KNeighborsClassifier        0.771802  4926.0  2924.0  2206.0  115.0  0.430019
# LogisticRegression          0.752433  4937.0  2716.0  2414.0  104.0  0.470565
# RandomForestClassifier      0.774948  4958.0  2924.0  2206.0   83.0  0.430019
# AdaBoostClassifier          0.764232  4929.0  2844.0  2286.0  112.0  0.445614
# GradientBoostingClassifier  0.771507  4927.0  2920.0  2210.0  114.0  0.430799
# ExtraTreeClassifier         0.775342  4960.0  2926.0  2204.0   81.0  0.429630
# BaggingClassifier           0.774260  4954.0  2921.0  2209.0   87.0  0.430604
# VotingClassifier            0.773179  4938.0  2926.0  2204.0  103.0  0.429630
#
#                                  FNR
# index
# Neural Network-1            0.023805
# KNeighborsClassifier        0.022813
# LogisticRegression          0.020631
# RandomForestClassifier      0.016465
# AdaBoostClassifier          0.022218
# GradientBoostingClassifier  0.022615
# ExtraTreeClassifier         0.016068
# BaggingClassifier           0.017258
# VotingClassifier            0.020432
# Comparision Table for Test Accuracies:
#                             accuracy      TP     TN     FP    FN       FPR  \
# index
# Neural Network-1            0.774282  1282.0  687.0  540.0  34.0  0.440098
# KNeighborsClassifier        0.774282  1282.0  687.0  540.0  34.0  0.440098
# LogisticRegression          0.754227  1288.0  630.0  597.0  28.0  0.486553
# RandomForestClassifier      0.774282  1284.0  685.0  542.0  32.0  0.441728
# AdaBoostClassifier          0.766811  1284.0  666.0  561.0  32.0  0.457213
# GradientBoostingClassifier  0.773103  1283.0  683.0  544.0  33.0  0.443358
# ExtraTreeClassifier         0.774676  1284.0  686.0  541.0  32.0  0.440913
# BaggingClassifier           0.773103  1284.0  682.0  545.0  32.0  0.444173
# VotingClassifier            0.773889  1282.0  686.0  541.0  34.0  0.440913
#
#                                  FNR       auc
# index
# Neural Network-1            0.025836  0.767033
# KNeighborsClassifier        0.025836  0.767033
# LogisticRegression          0.021277  0.746085
# RandomForestClassifier      0.024316  0.766978
# AdaBoostClassifier          0.024316  0.759236
# GradientBoostingClassifier  0.025076  0.765783
# ExtraTreeClassifier         0.024316  0.767386
# BaggingClassifier           0.024316  0.765756
# VotingClassifier            0.025836  0.766626

# %% [markdown]
# ## <a id='4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a>
#
# #### <a id='4.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=18,random_state=0)
X_pca=pca.fit_transform(scaled_X)
print(sum(pca.explained_variance_ratio_))
print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_pca.shape
# Out:
# 0.9860924235928878
# The train/test split ratio is 80:20
# (12714, 18)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=X_train.shape[1]))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.7719005014607834
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True         116  4925     5041
# __all__     3042  7129    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          34  1282     1316
# __all__      721  1822     2543

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7725887326713204
# Predicted  False  True  __all__
# Actual
# False       2932  2198     5130
# True         115  4926     5041
# __all__     3047  7124    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          34  1282     1316
# __all__      721  1822     2543

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7524333890472913
# Predicted  False  True  __all__
# Actual
# False       2716  2414     5130
# True         104  4937     5041
# __all__     2820  7351    10171
# The accuracy of the model on test data is: 0.7542272906016516
# Predicted  False  True  __all__
# Actual
# False        631   596     1227
# True          29  1287     1316
# __all__      660  1883     2543

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7749483826565726
# Predicted  False  True  __all__
# Actual
# False       2924  2206     5130
# True          83  4958     5041
# __all__     3007  7164    10171
# The accuracy of the model on test data is: 0.7750688163586316
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          32  1284     1316
# __all__      719  1824     2543

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7717038639268509
# Predicted  False  True  __all__
# Actual
# False       2923  2207     5130
# True         115  4926     5041
# __all__     3038  7133    10171
# The accuracy of the model on test data is: 0.7738891073535195
# Predicted  False  True  __all__
# Actual
# False        686   541     1227
# True          34  1282     1316
# __all__      720  1823     2543

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7733752826664044
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True         101  4940     5041
# __all__     3027  7144    10171
# The accuracy of the model on test data is: 0.7746755800235942
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          33  1283     1316
# __all__      720  1823     2543

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.7753416576541147
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True          81  4960     5041
# __all__     3007  7164    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        685   542     1227
# True          32  1284     1316
# __all__      717  1826     2543

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.774260151410874
# Predicted  False  True  __all__
# Actual
# False       2921  2209     5130
# True          87  4954     5041
# __all__     3008  7163    10171
# The accuracy of the model on test data is: 0.7742823436885569
# Predicted  False  True  __all__
# Actual
# False        685   542     1227
# True          32  1284     1316
# __all__      717  1826     2543

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.7743584701602596
# Predicted  False  True  __all__
# Actual
# False       2926  2204     5130
# True          91  4950     5041
# __all__     3017  7154    10171
# The accuracy of the model on test data is: 0.7750688163586316
# Predicted  False  True  __all__
# Actual
# False        687   540     1227
# True          32  1284     1316
# __all__      719  1824     2543

# %% [markdown]
# ### <a id='4.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy      TP      TN      FP     FN       FPR  \
# index
# Neural Network-1            0.771901  4925.0  2926.0  2204.0  116.0  0.429630
# KNeighborsClassifier        0.772589  4926.0  2932.0  2198.0  115.0  0.428460
# LogisticRegression          0.752433  4937.0  2716.0  2414.0  104.0  0.470565
# RandomForestClassifier      0.774948  4958.0  2924.0  2206.0   83.0  0.430019
# AdaBoostClassifier          0.771704  4926.0  2923.0  2207.0  115.0  0.430214
# GradientBoostingClassifier  0.773375  4940.0  2926.0  2204.0  101.0  0.429630
# ExtraTreeClassifier         0.775342  4960.0  2926.0  2204.0   81.0  0.429630
# BaggingClassifier           0.774260  4954.0  2921.0  2209.0   87.0  0.430604
# VotingClassifier            0.774358  4950.0  2926.0  2204.0   91.0  0.429630
#
#                                  FNR
# index
# Neural Network-1            0.023011
# KNeighborsClassifier        0.022813
# LogisticRegression          0.020631
# RandomForestClassifier      0.016465
# AdaBoostClassifier          0.022813
# GradientBoostingClassifier  0.020036
# ExtraTreeClassifier         0.016068
# BaggingClassifier           0.017258
# VotingClassifier            0.018052
# Comparision Table for Test Accuracies:
#                             accuracy      TP     TN     FP    FN       FPR  \
# index
# Neural Network-1            0.774282  1282.0  687.0  540.0  34.0  0.440098
# KNeighborsClassifier        0.774282  1282.0  687.0  540.0  34.0  0.440098
# LogisticRegression          0.754227  1287.0  631.0  596.0  29.0  0.485738
# RandomForestClassifier      0.775069  1284.0  687.0  540.0  32.0  0.440098
# AdaBoostClassifier          0.773889  1282.0  686.0  541.0  34.0  0.440913
# GradientBoostingClassifier  0.774676  1283.0  687.0  540.0  33.0  0.440098
# ExtraTreeClassifier         0.774282  1284.0  685.0  542.0  32.0  0.441728
# BaggingClassifier           0.774282  1284.0  685.0  542.0  32.0  0.441728
# VotingClassifier            0.775069  1284.0  687.0  540.0  32.0  0.440098
#
#                                  FNR       auc
# index
# Neural Network-1            0.025836  0.767033
# KNeighborsClassifier        0.025836  0.767033
# LogisticRegression          0.022036  0.746113
# RandomForestClassifier      0.024316  0.767793
# AdaBoostClassifier          0.025836  0.766626
# GradientBoostingClassifier  0.025076  0.767413
# ExtraTreeClassifier         0.024316  0.766978
# BaggingClassifier           0.024316  0.766978
# VotingClassifier            0.024316  0.767793

# %% [markdown]
# ### <a id='4.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 12                          5.536699e-02
# 1                           5.533449e-02
# 9                           5.515954e-02
# 19                          5.487525e-02
# 17                          5.483781e-02
# 4                           5.463968e-02
# 11                          5.384626e-02
# 7                           5.358673e-02
# 6                           5.276405e-02
# 0                           5.265736e-02
# 16                          5.178463e-02
# 10                          5.087226e-02
# 2                           5.050371e-02
# 8                           4.847434e-02
# 18                          4.786445e-02
# 3                           4.631547e-02
# 5                           4.293626e-02
# 15                          3.795901e-02
# 13                          2.466615e-02
# 14                          2.277837e-33
#
#                                   Features
# 12        js_function_String.fromCharCode(
# 1         dom_function_window.setInterval(
# 9                        js_function_eval(
# 19                 js_function_.substring(
# 17                      js_function_.exec(
# 4     dom_function_document.createComment(
# 11                js_function_.charCodeAt(
# 7                      js_function_escape(
# 6    dom_function_window.addEventListener(
# 0          dom_function_window.setTimeout(
# 16                      js_function_.link(
# 10                    js_function_.concat(
# 2     dom_function_document.createElement(
# 8                    js_function_unescape(
# 18                    js_function_.search(
# 3             dom_function_document.write(
# 5   dom_function_document.createElementNS(
# 15                   js_function_.replace(
# 13                     js_function_.split(
# 14            js_function_Number.parseInt(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, X.shape[1]])
plt.xticks(np.arange(X.shape[1]),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %%
### Original Creator : Darshan Bhansali
### HTML code to hide the input cells 
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle code, click <a href="javascript:code_toggle()">here</a>.
