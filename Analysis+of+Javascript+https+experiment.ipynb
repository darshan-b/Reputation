# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)
from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE

import warnings
warnings.simplefilter("ignore", DeprecationWarning)
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

# %% [markdown]
# ### Eliminating cases where html_status=="Not success" as they have all null values

# %%
df_alex=pd.read_csv('Javascript_alexa_output.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])

df.drop(['Unnamed: 0'],axis=1,inplace=True)

df = df.sample(frac=1,random_state=867).reset_index(drop=True)

df.fillna(value=0,inplace=True)

display(df.shape)

df=df[df['html_status']=='Success']
df.shape
# Out:
# (45700, 303)
# (42968, 303)

# %% [markdown]
# ### Dropping columns that indicate the html status of domain data collection

# %%
df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

# %%
cols_WebAssembly=[col for col in df.columns if 'js_function_WebAssembly' in col]
cols_Reflect=[col for col in df.columns if 'Reflect' in col]
cols_Object=[col for col in df.columns if 'js_function_Object' in col]
cols_Number=[col for col in df.columns if 'js_function_Number' in col]
cols_Math=[col for col in df.columns if 'js_function_Math' in col]
cols_Atomics=[col for col in df.columns if 'js_function_Atomics' in col]
cols_Promise=[col for col in df.columns if 'Promise' in col]



df['tot_WebAssembly']=df[cols_WebAssembly].sum(axis=1)
df['tot_Reflect']=df[cols_Reflect].sum(axis=1)
df['tot_Object']=df[cols_Object].sum(axis=1)
df['tot_Number']=df[cols_Number].sum(axis=1)
df['tot_Math']=df[cols_Math].sum(axis=1)
df['tot_Atomics']=df[cols_Atomics].sum(axis=1)
df['tot_Promise']=df[cols_Atomics].sum(axis=1)

len(cols_WebAssembly)+len(cols_Reflect)+len(cols_Object)+len(cols_Number)+len(cols_Math)+len(cols_Atomics)+len(cols_Promise)
# Out:
# 97

# %% [markdown]
# #### Columns and nummber of unique values they have

# %%
lst=[]
for col in df.columns:
    lst.append((col,len(df[col].value_counts())))

unique_val_cols=pd.DataFrame(lst)
unique_val_cols.columns=['Column_Name','Num_unique_value']

unique_val_cols.sort_values(by=['Num_unique_value'],inplace=True)
unique_val_cols.head()
# Out:
#                       Column_Name  Num_unique_value
# 305                   tot_Promise                 1
# 177    js_function_Atomics.store(                 1
# 243  js_function_Object.isSealed(                 1
# 108      js_function_.setFloat32(                 1
# 109      js_function_.setFloat64(                 1

# %%
print("Columns with all same values")
col_1=unique_val_cols[unique_val_cols['Num_unique_value']==1].Column_Name.values

for col in col_1:
    print(df[col].value_counts(),"\n")
# Out:
# Columns with all same values
# 0.0    42968
# Name: tot_Promise, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.store(, dtype: int64
#
# 0.0    42968
# Name: js_function_Object.isSealed(, dtype: int64
#
# 0.0    42968
# Name: js_function_.setFloat32(, dtype: int64
#
# 0.0    42968
# Name: js_function_.setFloat64(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.or(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.load(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.sub(, dtype: int64
#
# 0.0    42968
# Name: js_function_Proxy.revocable(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.apply(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.isLockFree(, dtype: int64
#
# 0.0    42968
# Name: js_function_.getFloat64(, dtype: int64
#
# 0.0    42968
# Name: js_function_.getFloat32(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.exchange(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.compareExchange(, dtype: int64
#
# 0.0    42968
# Name: js_function_.setInt16(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.wait(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.wake(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.xor(, dtype: int64
#
# 0.0    42968
# Name: js_function_.italics(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.hypot(, dtype: int64
#
# 0.0    42968
# Name: js_function_.isNan(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.fround(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.expm1(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.tanh(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.cosh(, dtype: int64
#
# 0.0    42968
# Name: js_function_.strike(, dtype: int64
#
# 0.0    42968
# Name: js_function_.grow(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.cbrt(, dtype: int64
#
# 0.0    42968
# Name: js_function_.ownKeys(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.atanh(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.asinh(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.acosh(, dtype: int64
#
# 0.0    42968
# Name: js_function_Intl.getCanonicalLocales(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.getOwnPropertyDescriptor(, dtype: int64
#
# 0.0    42968
# Name: js_function_.formatToParts(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.get(, dtype: int64
#
# 0.0    42968
# Name: js_function_.fontsize(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.getPrototypeOf(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.compileStreaming(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.customerSections(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.exports(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.imports(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.instantiate(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.instantiateStreaming(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.validate(, dtype: int64
#
# 0.0    42968
# Name: js_function_uneval(, dtype: int64
#
# 0.0    42968
# Name: js_function_.small(, dtype: int64
#
# 0.0    42968
# Name: js_function_.big(, dtype: int64
#
# 0.0    42968
# Name: tot_WebAssembly, dtype: int64
#
# 0.0    42968
# Name: tot_Atomics, dtype: int64
#
# 0.0    42968
# Name: js_function_.allTrue(, dtype: int64
#
# 0.0    42968
# Name: js_function_.throw(, dtype: int64
#
# 0.0    42968
# Name: js_function_.copyWithin(, dtype: int64
#
# 0.0    42968
# Name: js_function_String.raw(, dtype: int64
#
# 0.0    42968
# Name: js_function_WebAssembly.compile(, dtype: int64
#
# 0.0    42968
# Name: js_function_Math.log1p(, dtype: int64
#
# 0.0    42968
# Name: js_function_Array.of(, dtype: int64
#
# 0.0    42968
# Name: js_function_.fontcolor(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.setPrototypeOf(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.set(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.and(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.preventExtensions(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.ownKeys(, dtype: int64
#
# 0.0    42968
# Name: js_function_.flat(, dtype: int64
#
# 0.0    42968
# Name: js_function_Atomics.add(, dtype: int64
#
# 0.0    42968
# Name: js_function_.setUint16(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.has(, dtype: int64
#
# 0.0    42968
# Name: js_function_ArrayBuffer.transfer(, dtype: int64
#
# 0.0    42968
# Name: js_function_Reflect.isExtensible(, dtype: int64

# %% [markdown]
# #### Dependent and Target variables

# %%
X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

model = LogisticRegression(random_state=0)
model.fit(X, y)

print("Accuracy score with all of the features")
display(model.score(X,y))
# Out:
# Accuracy score with all of the features
# 0.8698566374976727

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9417721915529939
# Columns selected:
#
# Accuracy score
# 0.8700195494321356

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 292                          3.181697e+01
# 96                           1.710937e+01
# 9                            2.372004e-01
# 83                           1.920854e-01
# 29                           1.528904e-01
# 302                          8.971389e-02
# 100                          3.943011e-02
# 4                            3.783191e-02
# 300                          3.590346e-02
# 73                           3.416923e-02
# 144                          3.351930e-02
# 39                           3.069438e-02
# 138                          2.812862e-02
# 78                           1.720070e-02
# 106                          1.417274e-02
# 157                          1.148185e-02
# 154                          1.141377e-02
# 141                          9.413811e-03
# 133                          7.595423e-03
# 85                           7.481872e-03
# 19                           6.739189e-03
# 232                          6.612021e-03
# 0                            6.007702e-03
# 6                            5.995644e-03
# 71                           4.056516e-03
# 84                           3.884958e-03
# 16                           3.714110e-03
# 36                           3.672767e-03
# 27                           3.144964e-03
# 142                          2.762220e-03
# 211                          2.471823e-03
# 288                          2.235449e-03
# 12                           2.234256e-03
# 25                           2.153157e-03
# 11                           2.025152e-03
# 132                          1.757895e-03
# 55                           1.545431e-03
# 282                          1.229132e-03
# 203                          1.200855e-03
# 214                          1.137039e-03
# 87                           1.089348e-03
# 287                          1.086773e-03
# 93                           1.064954e-03
# 137                          1.062369e-03
# 206                          1.033705e-03
# 215                          1.015702e-03
# 86                           8.780044e-04
# 212                          8.410794e-04
# 188                          7.899354e-04
# 79                           7.603066e-04
# 70                           7.354458e-04
# 230                          7.130479e-04
# 247                          5.008412e-04
# 118                          5.008412e-04
# 244                          4.921000e-04
# 159                          4.617258e-04
# 239                          4.610862e-04
# 53                           4.610862e-04
# 166                          4.013944e-04
# 162                          3.669238e-04
# 136                          3.229749e-04
# 187                          3.207162e-04
# 158                          2.613971e-04
# 186                          2.553926e-04
# 213                          2.437403e-04
# 197                          2.180185e-04
# 44                           1.720434e-04
# 40                           1.520094e-04
# 97                           1.499902e-04
# 286                          1.451930e-04
# 51                           1.377142e-04
# 280                          1.207852e-04
# 266                          1.177516e-04
# 183                          1.046854e-04
# 295                          9.341003e-05
# 297                          8.944632e-05
# 10                           8.525064e-05
# 293                          7.060452e-05
# 38                           6.247921e-05
# 217                          6.224664e-05
# 13                           5.795206e-05
# 199                          5.571455e-05
# 81                           4.946055e-05
# 284                          4.638123e-05
# 80                           4.514799e-05
# 164                          4.214182e-05
# 269                          4.194398e-05
# 219                          3.437409e-05
# 148                          3.248737e-05
# 163                          3.056103e-05
# 103                          2.570957e-05
# 1                            2.540016e-05
# 165                          2.472265e-05
# 135                          2.468242e-05
# 104                          2.422181e-05
# 105                          2.218025e-05
# 72                           2.167859e-05
# 237                          2.062889e-05
# 285                          1.791424e-05
# 41                           1.502679e-05
# 120                          1.438186e-05
# 68                           1.386028e-05
# 107                          1.243731e-05
# 229                          1.193213e-05
# 52                           1.107607e-05
# 235                          1.107607e-05
# 45                           9.232223e-06
# 26                           8.353340e-06
# 20                           8.100272e-06
# 56                           8.007934e-06
# 24                           7.966156e-06
# 95                           6.318573e-06
# 207                          5.567976e-06
# 88                           5.274045e-06
# 50                           4.875514e-06
# 290                          4.300580e-06
# 23                           3.602688e-06
# 117                          2.949563e-06
# 251                          2.548071e-06
# 191                          2.457647e-06
# 194                          2.374913e-06
# 220                          2.206631e-06
# 60                           2.028921e-06
# 246                          2.006222e-06
# 110                          1.929711e-06
# 54                           1.925622e-06
# 76                           1.785724e-06
# 294                          1.593243e-06
# 62                           1.531776e-06
# 57                           1.510446e-06
# 63                           1.275565e-06
# 283                          1.216074e-06
# 150                          1.195862e-06
# 111                          1.176116e-06
# 296                          1.112934e-06
# 64                           1.085595e-06
# 279                          1.065023e-06
# 102                          9.683971e-07
# 289                          9.451073e-07
# 67                           9.375628e-07
# 59                           9.327917e-07
# 234                          7.412463e-07
# 281                          7.369306e-07
# 115                          6.934357e-07
# 231                          6.626859e-07
# 116                          6.033963e-07
# 193                          5.341946e-07
# 123                          4.368093e-07
# 201                          4.072075e-07
# 49                           4.048291e-07
# 30                           3.961762e-07
# 119                          3.545743e-07
# 149                          3.255804e-07
# 125                          2.756824e-07
# 248                          2.727301e-07
# 65                           2.600957e-07
# 17                           2.521055e-07
# 89                           2.416530e-07
# 127                          2.107043e-07
# 47                           1.886927e-07
# 66                           1.806220e-07
# 184                          1.629813e-07
# 15                           1.582019e-07
# 151                          1.529796e-07
# 301                          1.497126e-07
# 245                          1.451810e-07
# 94                           1.451810e-07
# 99                           1.341357e-07
# 58                           1.116222e-07
# 92                           1.010898e-07
# 240                          9.140270e-08
# 48                           8.558586e-08
# 114                          8.558586e-08
# 131                          7.871293e-08
# 182                          7.850613e-08
# 140                          6.925328e-08
# 61                           5.133417e-08
# 113                          3.218073e-08
# 224                          2.786320e-08
# 129                          2.218088e-08
# 122                          2.101623e-08
# 189                          1.787556e-08
# 98                           1.783548e-08
# 225                          1.708077e-08
# 238                          1.460330e-08
# 130                          1.399142e-08
# 156                          1.371642e-08
# 147                          1.280107e-08
# 242                          1.230489e-08
# 14                           1.031236e-08
# 299                          1.025859e-08
# 168                          8.540559e-09
# 249                          8.256330e-09
# 255                          6.451671e-09
# 218                          6.451671e-09
# 198                          6.436491e-09
# 33                           5.899317e-09
# 7                            5.519293e-09
# 82                           4.148300e-09
# 241                          3.385953e-09
# 74                           3.385953e-09
# 143                          2.658339e-09
# 250                          2.592436e-09
# 208                          2.405006e-09
# 152                          2.120957e-09
# 223                          2.005900e-09
# 216                          1.806220e-09
# 46                           1.806220e-09
# 233                          1.705781e-09
# 226                          1.477804e-09
# 121                          1.033372e-09
# 254                          2.764219e-10
# 126                          1.011709e-10
# 228                          4.154811e-11
# 8                            2.236811e-11
# 21                           1.880476e-11
# 256                          1.880476e-11
# 153                          1.272755e-11
# 22                           4.921520e-12
# 101                          2.948187e-12
# 267                          2.468398e-12
# 161                          2.226151e-12
# 3                            1.957889e-12
# 160                          1.663077e-12
# 236                          1.565211e-12
# 124                          1.454754e-12
# 210                          8.216232e-13
# 270                          5.620566e-13
# 222                          3.366815e-13
# 155                          3.328303e-13
# 146                          2.657468e-13
# 227                          1.327097e-13
# 31                           9.843926e-14
# 91                           1.931453e-14
# 28                           3.685832e-16
# 5                            1.415253e-52
# 2                            5.616620e-53
# 205                          0.000000e+00
# 275                          0.000000e+00
# 274                          0.000000e+00
# 273                          0.000000e+00
# 277                          0.000000e+00
# 272                          0.000000e+00
# 271                          0.000000e+00
# 108                          0.000000e+00
# 268                          0.000000e+00
# 276                          0.000000e+00
# 69                           0.000000e+00
# 278                          0.000000e+00
# 90                           0.000000e+00
# 77                           0.000000e+00
# 75                           0.000000e+00
# 265                          0.000000e+00
# 43                           0.000000e+00
# 42                           0.000000e+00
# 37                           0.000000e+00
# 35                           0.000000e+00
# 34                           0.000000e+00
# 291                          0.000000e+00
# 32                           0.000000e+00
# 18                           0.000000e+00
# 298                          0.000000e+00
# 303                          0.000000e+00
# 109                          0.000000e+00
# 112                          0.000000e+00
# 264                          0.000000e+00
# 263                          0.000000e+00
# 174                          0.000000e+00
# 175                          0.000000e+00
# 176                          0.000000e+00
# 177                          0.000000e+00
# 221                          0.000000e+00
# 178                          0.000000e+00
# 179                          0.000000e+00
# 180                          0.000000e+00
# 181                          0.000000e+00
# 185                          0.000000e+00
# 190                          0.000000e+00
# 192                          0.000000e+00
# 195                          0.000000e+00
# 196                          0.000000e+00
# 209                          0.000000e+00
# 200                          0.000000e+00
# 202                          0.000000e+00
# 173                          0.000000e+00
# 172                          0.000000e+00
# 171                          0.000000e+00
# 253                          0.000000e+00
# 262                          0.000000e+00
# 261                          0.000000e+00
# 260                          0.000000e+00
# 259                          0.000000e+00
# 258                          0.000000e+00
# 257                          0.000000e+00
# 204                          0.000000e+00
# 252                          0.000000e+00
# 170                          0.000000e+00
# 128                          0.000000e+00
# 134                          0.000000e+00
# 139                          0.000000e+00
# 145                          0.000000e+00
# 243                          0.000000e+00
# 167                          0.000000e+00
# 169                          0.000000e+00
# 304                          0.000000e+00
#
#                                           Features
# 292                      number_functions_declared
# 96                              js_function_.push(
# 9                               js_function_.call(
# 83                               js_function_.log(
# 29                              js_function_.find(
# 302                                       tot_Math
# 100                          js_function_.replace(
# 4                              js_function_.apply(
# 300                                     tot_Object
# 73                           js_function_.indexOf(
# 144                             js_function_.test(
# 39                               js_function_.get(
# 138                            js_function_.split(
# 78                              js_function_.join(
# 106                              js_function_.set(
# 157                         js_function_.toString(
# 154                      js_function_.toLowerCase(
# 141                            js_function_.substr
# 133                            js_function_.slice(
# 85                             js_function_.match(
# 19                    js_function_.defineProperty(
# 232             js_function_Object.defineProperty(
# 0                                js_function_.add(
# 6                               js_function_.bind(
# 71                    js_function_.hasOwnProperty(
# 84                               js_function_.map(
# 16                            js_function_.concat(
# 36                           js_function_.forEach(
# 27                            js_function_.filter(
# 142                        js_function_.substring(
# 211                          js_function_Math.max(
# 288                          js_function_parseInt(
# 12                        js_function_.charCodeAt(
# 25                              js_function_.exec(
# 11                            js_function_.charAt(
# 132                            js_function_.shift(
# 55                           js_function_.getTime(
# 282                js_function_encodeURIComponent(
# 203                        js_function_Math.floor(
# 214                       js_function_Math.random(
# 87                              js_function_.next(
# 287                        js_function_parseFloat(
# 93                               js_function_.pop(
# 137                           js_function_.splice(
# 206                         js_function_Math.imul(
# 215                        js_function_Math.round(
# 86                               js_function_.min(
# 212                          js_function_Math.min(
# 188                          js_function_Math.abs(
# 79                              js_function_.keys(
# 70                               js_function_.has(
# 230                     js_function_Object.create(
# 247             js_function_Object.setPrototypeOf(
# 118                   js_function_.setPrototypeOf(
# 244                       js_function_Object.keys(
# 159                             js_function_.trim(
# 239             js_function_Object.getPrototypeOf(
# 53                    js_function_.getPrototypeOf(
# 166                     js_function_Array.isArray(
# 162                          js_function_.unshift(
# 136                             js_function_.sort(
# 187                    js_function_JSON.stringify(
# 158                      js_function_.toUpperCase(
# 186                        js_function_JSON.parse(
# 213                          js_function_Math.pow(
# 197                         js_function_Math.ceil(
# 44                       js_function_.getFullYear(
# 40                           js_function_.getDate(
# 97                            js_function_.reduce(
# 286                             js_function_isNaN(
# 51                          js_function_.getMonth(
# 280                js_function_decodeURIComponent(
# 266               js_function_String.fromCharCode(
# 183                          js_function_Date.now(
# 295                number_of_non_http_only_cookies
# 297                     number_of_unsecure_cookies
# 10                             js_function_.catch(
# 293                              number_of_cookies
# 38                              js_function_.from(
# 217                          js_function_Math.sin(
# 13                             js_function_.clear(
# 199                          js_function_Math.cos(
# 81                              js_function_.link(
# 284                              js_function_eval(
# 80                       js_function_.lastIndexOf(
# 164                           js_function_.values(
# 269                        js_function_Symbol.for(
# 219                         js_function_Math.sqrt(
# 148                          js_function_.toFixed(
# 163                          js_function_.valueOf(
# 103                          js_function_.reverse(
# 1                                js_function_.all(
# 165                        js_function_Array.from(
# 135                             js_function_.some(
# 104                           js_function_.search(
# 105                           js_function_.select(
# 72                          js_function_.includes(
# 237        js_function_Object.getOwnPropertyNames(
# 285                          js_function_isFinite(
# 41                            js_function_.getDay(
# 120                          js_function_.setTime(
# 68                           js_function_.getYear(
# 107                          js_function_.setDate(
# 229                     js_function_Object.assign(
# 52          js_function_.getOwnPropertyDescriptor(
# 235   js_function_Object.getOwnPropertyDescriptor(
# 45                          js_function_.getHours(
# 26                              js_function_.fill(
# 20                            js_function_.delete(
# 56                 js_function_.getTimezoneOffset(
# 24                             js_function_.every(
# 95              js_function_.propertyIsEnumerable(
# 207                          js_function_Math.log(
# 88                         js_function_.normalize(
# 50                        js_function_.getMinutes(
# 290                          js_function_unescape(
# 23                           js_function_.entries(
# 117                         js_function_.setMonth(
# 251                   js_function_Promise.resolve(
# 191                         js_function_Math.asin(
# 194                        js_function_Math.atan2(
# 220                          js_function_Math.tan(
# 60                       js_function_.getUTCHours(
# 246                       js_function_Object.seal(
# 110                      js_function_.setFullYear(
# 54                        js_function_.getSeconds(
# 76                     js_function_.isPrototypeOf(
# 294                    number_of_http_only_cookies
# 62                     js_function_.getUTCMinutes(
# 57                        js_function_.getUTCDate(
# 63                       js_function_.getUTCMonth(
# 283                            js_function_escape)
# 150                           js_function_.toJSON(
# 111                         js_function_.setHours(
# 296                       number_of_secure_cookies
# 64                     js_function_.getUTCSeconds(
# 279                         js_function_decodeURI(
# 102                           js_function_.return(
# 289                         js_function_undefined(
# 67                          js_function_.getUint8(
# 59                    js_function_.getUTCFullYear(
# 234                     js_function_Object.freeze(
# 281                         js_function_encodeURI(
# 115                  js_function_.setMilliseconds(
# 231           js_function_Object.defineProperties(
# 116                       js_function_.setMinutes(
# 193                         js_function_Math.atan(
# 123                      js_function_.setUTCHours(
# 201                          js_function_Math.exp(
# 49                   js_function_.getMilliseconds(
# 30                         js_function_.findIndex(
# 119                       js_function_.setSeconds(
# 149                      js_function_.toISOString(
# 125                    js_function_.setUTCMinutes(
# 248                       js_function_Promise.all(
# 65                         js_function_.getUint16(
# 17                         js_function_.construct(
# 89                                js_function_.of(
# 127                    js_function_.setUTCSeconds(
# 47                          js_function_.getInt32(
# 66                         js_function_.getUint32(
# 184                        js_function_Date.parse(
# 15                           js_function_.compile(
# 151                   js_function_.toLocaleString(
# 301                                     tot_Number
# 245          js_function_Object.preventExtensions(
# 94                 js_function_.preventExtensions(
# 99                            js_function_.repeat(
# 58                         js_function_.getUTCDay(
# 92                          js_function_.padStart(
# 240                         js_function_Object.is(
# 48                           js_function_.getInt8(
# 114                          js_function_.setInt8(
# 131                          js_function_.setYear(
# 182                          js_function_Date.UTC(
# 140                         js_function_.subarray(
# 61                js_function_.getUTCMilliseconds(
# 113                         js_function_.setInt32(
# 224                  js_function_Number.isInteger(
# 129                        js_function_.setUint32(
# 122                   js_function_.setUTCFullYear(
# 189                         js_function_Math.acos(
# 98                       js_function_.reduceRight(
# 225                      js_function_Number.isNaN(
# 238      js_function_Object.getOwnPropertySymbols(
# 130                         js_function_.setUint8(
# 156                         js_function_.toSource(
# 147                    js_function_.toExponential(
# 242                   js_function_Object.isFrozen(
# 14                       js_function_.codePointAt(
# 299                                    tot_Reflect
# 168                js_function_ArrayBuffer.isView(
# 249                      js_function_Promise.race(
# 255            js_function_Reflect.defineProperty(
# 218                         js_function_Math.sinh(
# 198                        js_function_Math.clz32(
# 33                           js_function_.flatMap(
# 7                              js_function_.blink(
# 82                     js_function_.localeCompare(
# 241               js_function_Object.isExtensible(
# 74                      js_function_.isExtensible(
# 143               js_function_.supportedLocalesOf(
# 250                    js_function_Promise.reject(
# 208                        js_function_Math.log10(
# 152               js_function_.toLocaleTimeString(
# 223                   js_function_Number.isFinite(
# 216                         js_function_Math.sign(
# 46                          js_function_.getInt16(
# 233                    js_function_Object.entries(
# 226              js_function_Number.isSafeInteger(
# 121                       js_function_.setUTCDate(
# 254                 js_function_Reflect.construct(
# 126                      js_function_.setUTCMonth(
# 228                   js_function_Number.parseInt(
# 8                               js_function_.bold(
# 21                    js_function_.deleteProperty(
# 256            js_function_Reflect.deleteProperty(
# 153                js_function_.toLocaleUpperCase(
# 22                           js_function_.endWith(
# 101                  js_function_.resolvedOptions(
# 267              js_function_String.fromCodePoint(
# 161                        js_function_.trimStart(
# 3                             js_function_.anchor(
# 160                          js_function_.trimEnd(
# 236  js_function_Object.getOwnPropertyDescriptors(
# 124               js_function_.setUTCMilliseconds(
# 210                         js_function_Math.log2(
# 270                     js_function_Symbol.keyFor(
# 222                        js_function_Math.trunc(
# 155                      js_function_.toPrecision(
# 146                     js_function_.toDateString(
# 227                 js_function_Number.parseFloat(
# 31                             js_function_.fixed(
# 91                            js_function_.padEnd(
# 28                           js_function_.finally(
# 5                                js_function_.big(
# 2                            js_function_.allTrue(
# 205                        js_function_Math.hypot(
# 275               js_function_WebAssembly.imports(
# 274               js_function_WebAssembly.exports(
# 273      js_function_WebAssembly.customerSections(
# 277  js_function_WebAssembly.instantiateStreaming(
# 272      js_function_WebAssembly.compileStreaming(
# 271               js_function_WebAssembly.compile(
# 108                       js_function_.setFloat32(
# 268                        js_function_String.raw(
# 276           js_function_WebAssembly.instantiate(
# 69                              js_function_.grow(
# 278              js_function_WebAssembly.validate(
# 90                           js_function_.ownKeys(
# 77                           js_function_.italics(
# 75                             js_function_.isNan(
# 265            js_function_Reflect.setPrototypeOf(
# 43                        js_function_.getFloat64(
# 42                        js_function_.getFloat32(
# 37                     js_function_.formatToParts(
# 35                          js_function_.fontsize(
# 34                         js_function_.fontcolor(
# 291                            js_function_uneval(
# 32                              js_function_.flat(
# 18                        js_function_.copyWithin(
# 298                                tot_WebAssembly
# 303                                    tot_Atomics
# 109                       js_function_.setFloat64(
# 112                         js_function_.setInt16(
# 264                       js_function_Reflect.set(
# 263         js_function_Reflect.preventExtensions(
# 174                js_function_Atomics.isLockFree(
# 175                      js_function_Atomics.load(
# 176                        js_function_Atomics.or(
# 177                     js_function_Atomics.store(
# 221                         js_function_Math.tanh(
# 178                       js_function_Atomics.sub(
# 179                      js_function_Atomics.wait(
# 180                      js_function_Atomics.wake(
# 181                       js_function_Atomics.xor(
# 185          js_function_Intl.getCanonicalLocales(
# 190                        js_function_Math.acosh(
# 192                        js_function_Math.asinh(
# 195                        js_function_Math.atanh(
# 196                         js_function_Math.cbrt(
# 209                        js_function_Math.log1p(
# 200                         js_function_Math.cosh(
# 202                        js_function_Math.expm1(
# 173                  js_function_Atomics.exchange(
# 172           js_function_Atomics.compareExchange(
# 171                       js_function_Atomics.and(
# 253                     js_function_Reflect.apply(
# 262                   js_function_Reflect.ownKeys(
# 261              js_function_Reflect.isExtensible(
# 260                       js_function_Reflect.has(
# 259            js_function_Reflect.getPrototypeOf(
# 258  js_function_Reflect.getOwnPropertyDescriptor(
# 257                       js_function_Reflect.get(
# 204                       js_function_Math.fround(
# 252                   js_function_Proxy.revocable(
# 170                       js_function_Atomics.add(
# 128                        js_function_.setUint16(
# 134                            js_function_.small(
# 139                           js_function_.strike(
# 145                            js_function_.throw(
# 243                   js_function_Object.isSealed(
# 167                          js_function_Array.of(
# 169              js_function_ArrayBuffer.transfer(
# 304                                    tot_Promise

# %% [markdown]
# ### Correlation

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-100:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# 100 selected features

# %% [markdown]
# ### CHI2

# %%
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=100)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### RFE

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=100, step=10, verbose=False)
rfe_selector.fit(X_norm, y)

rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 100 selected features

# %% [markdown]
# ### SelectFromModel

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100), threshold='23*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 124 selected features

# %%
# from lightgbm import LGBMClassifier

# lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
#             reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

# embeded_lgb_selector = SelectFromModel(lgbc, threshold='1e-20*mean')
# embeded_lgb_selector.fit(X, y)
# embeded_lgb_support = embeded_lgb_selector.get_support()

# embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
# print(str(len(embeded_lgb_feature)), 'selected features')

# %%
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#                                      Feature  Pearson  Chi-2    RFE  \
# 1                                 tot_Object     True   True   True
# 2                                   tot_Math     True   True   True
# 3                 number_of_unsecure_cookies     True   True   True
# 4                   number_of_secure_cookies     True   True   True
# 5            number_of_non_http_only_cookies     True   True   True
# 6                number_of_http_only_cookies     True   True   True
# 7                          number_of_cookies     True   True   True
# 8                  number_functions_declared     True   True   True
# 9                      js_function_parseInt(     True   True   True
# 10                   js_function_parseFloat(     True   True   True
# 11                     js_function_isFinite(     True   True   True
# 12                         js_function_eval(     True   True   True
# 13           js_function_encodeURIComponent(     True   True   True
# 14           js_function_decodeURIComponent(     True   True   True
# 15                    js_function_decodeURI(     True   True   True
# 16          js_function_String.fromCharCode(     True   True   True
# 17                  js_function_Promise.all(     True   True   True
# 18                  js_function_Object.keys(     True   True   True
# 19   js_function_Object.getOwnPropertyNames(     True   True   True
# 20        js_function_Object.defineProperty(     True   True   True
# 21                   js_function_Math.round(     True   True   True
# 22                  js_function_Math.random(     True   True   True
# 23                     js_function_Math.min(     True   True   True
# 24                     js_function_Math.max(     True   True   True
# 25                   js_function_Math.floor(     True   True   True
# 26               js_function_JSON.stringify(     True   True   True
# 27                   js_function_JSON.parse(     True   True   True
# 28                     js_function_Date.now(     True   True   True
# 29                        js_function_.trim(     True   True   True
# 30                    js_function_.toString(     True   True   True
# 31                 js_function_.toLowerCase(     True   True   True
# 32                        js_function_.test(     True   True   True
# 33                   js_function_.substring(     True   True   True
# 34                       js_function_.substr     True   True   True
# 35                       js_function_.split(     True   True   True
# 36                      js_function_.splice(     True   True   True
# 37                        js_function_.sort(     True   True   True
# 38                       js_function_.shift(     True   True   True
# 39                     js_function_.setTime(     True   True   True
# 40                    js_function_.setHours(     True   True   True
# 41                     js_function_.setDate(     True   True   True
# 42                      js_function_.select(     True   True   True
# 43                      js_function_.search(     True   True   True
# 44                     js_function_.reverse(     True   True   True
# 45                     js_function_.replace(     True   True   True
# 46                        js_function_.push(     True   True   True
# 47        js_function_.propertyIsEnumerable(     True   True   True
# 48                         js_function_.pop(     True   True   True
# 49                        js_function_.next(     True   True   True
# 50                         js_function_.min(     True   True   True
# 51                       js_function_.match(     True   True   True
# 52                         js_function_.map(     True   True   True
# 53                        js_function_.keys(     True   True   True
# 54                        js_function_.join(     True   True   True
# 55                     js_function_.indexOf(     True   True   True
# 56              js_function_.hasOwnProperty(     True   True   True
# 57                         js_function_.has(     True   True   True
# 58                     js_function_.getYear(     True   True   True
# 59               js_function_.getUTCMinutes(     True   True   True
# 60           js_function_.getTimezoneOffset(     True   True   True
# 61                     js_function_.getTime(     True   True   True
# 62                  js_function_.getSeconds(     True   True   True
# 63                    js_function_.getMonth(     True   True   True
# 64             js_function_.getMilliseconds(     True   True   True
# 65                    js_function_.getHours(     True   True   True
# 66                 js_function_.getFullYear(     True   True   True
# 67                      js_function_.getDay(     True   True   True
# 68                     js_function_.getDate(     True   True   True
# 69                         js_function_.get(     True   True   True
# 70                     js_function_.forEach(     True   True   True
# 71              js_function_.defineProperty(     True   True   True
# 72                      js_function_.concat(     True   True   True
# 73                  js_function_.charCodeAt(     True   True   True
# 74                      js_function_.charAt(     True   True   True
# 75                        js_function_.call(     True   True   True
# 76                       js_function_.apply(     True   True   True
# 77                         js_function_.all(     True   True   True
# 78                         js_function_.add(     True   True   True
# 79              js_function_Promise.resolve(     True   True   True
# 80                js_function_Object.assign(     True   True  False
# 81                     js_function_Math.abs(     True   True  False
# 82                js_function_Array.isArray(     True   True  False
# 83                     js_function_.unshift(     True   True  False
# 84                 js_function_.toISOString(     True   True   True
# 85                       js_function_.slice(     True   True  False
# 86                      js_function_.return(     True   True   True
# 87                      js_function_.reduce(    False   True   True
# 88                 js_function_.getUTCHours(     True   True  False
# 89                  js_function_.getUTCDate(     True   True  False
# 90                  js_function_.getMinutes(     True  False   True
# 91                      js_function_.filter(     True   True  False
# 92                        js_function_.exec(     True   True  False
# 93                        js_function_.bind(     True   True  False
# 94                        js_function_isNaN(     True  False  False
# 95                       js_function_escape)    False  False   True
# 96                 js_function_Promise.race(    False   True   True
# 97                    js_function_Math.ceil(     True  False  False
# 98                 js_function_.toUpperCase(     True  False  False
# 99                      js_function_.toJSON(     True   True  False
# 100                    js_function_.toFixed(     True  False  False
#
#      Random Forest  Total
# 1             True      4
# 2             True      4
# 3             True      4
# 4             True      4
# 5             True      4
# 6             True      4
# 7             True      4
# 8             True      4
# 9             True      4
# 10            True      4
# 11            True      4
# 12            True      4
# 13            True      4
# 14            True      4
# 15            True      4
# 16            True      4
# 17            True      4
# 18            True      4
# 19            True      4
# 20            True      4
# 21            True      4
# 22            True      4
# 23            True      4
# 24            True      4
# 25            True      4
# 26            True      4
# 27            True      4
# 28            True      4
# 29            True      4
# 30            True      4
# 31            True      4
# 32            True      4
# 33            True      4
# 34            True      4
# 35            True      4
# 36            True      4
# 37            True      4
# 38            True      4
# 39            True      4
# 40            True      4
# 41            True      4
# 42            True      4
# 43            True      4
# 44            True      4
# 45            True      4
# 46            True      4
# 47            True      4
# 48            True      4
# 49            True      4
# 50            True      4
# 51            True      4
# 52            True      4
# 53            True      4
# 54            True      4
# 55            True      4
# 56            True      4
# 57            True      4
# 58            True      4
# 59            True      4
# 60            True      4
# 61            True      4
# 62            True      4
# 63            True      4
# 64            True      4
# 65            True      4
# 66            True      4
# 67            True      4
# 68            True      4
# 69            True      4
# 70            True      4
# 71            True      4
# 72            True      4
# 73            True      4
# 74            True      4
# 75            True      4
# 76            True      4
# 77            True      4
# 78            True      4
# 79           False      3
# 80            True      3
# 81            True      3
# 82            True      3
# 83            True      3
# 84           False      3
# 85            True      3
# 86           False      3
# 87            True      3
# 88            True      3
# 89            True      3
# 90            True      3
# 91            True      3
# 92            True      3
# 93            True      3
# 94            True      2
# 95            True      2
# 96           False      2
# 97            True      2
# 98            True      2
# 99           False      2
# 100           True      2

# %%
X=df[feature_selection_df.Feature]
y=df.Malicious.values

model = LogisticRegression()
model.fit(X, y)

print("Accuracy score with top 100 selected features:")
display(model.score(X,y))
# Out:
# Accuracy score with top 100 selected features:
# 0.8698799106311674

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9417721915529831
# Columns selected:
#
# Accuracy score
# 0.8700195494321356

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 7                            3.181697e+01
# 45                           1.710937e+01
# 74                           2.372004e-01
# 106                          1.920854e-01
# 109                          1.528904e-01
# 1                            8.971389e-02
# 44                           3.943011e-02
# 75                           3.783191e-02
# 0                            3.590346e-02
# 54                           3.416923e-02
# 31                           3.351930e-02
# 68                           3.069438e-02
# 34                           2.812862e-02
# 53                           1.720070e-02
# 130                          1.417274e-02
# 29                           1.148185e-02
# 30                           1.141377e-02
# 33                           9.413811e-03
# 84                           7.595423e-03
# 50                           7.481872e-03
# 70                           6.739189e-03
# 19                           6.612021e-03
# 77                           6.007702e-03
# 92                           5.995644e-03
# 55                           4.056516e-03
# 51                           3.884958e-03
# 71                           3.714110e-03
# 69                           3.672767e-03
# 90                           3.144964e-03
# 32                           2.762220e-03
# 23                           2.471823e-03
# 8                            2.235449e-03
# 72                           2.234256e-03
# 91                           2.153157e-03
# 73                           2.025152e-03
# 37                           1.757895e-03
# 60                           1.545431e-03
# 12                           1.229132e-03
# 24                           1.200855e-03
# 21                           1.137039e-03
# 48                           1.089348e-03
# 9                            1.086773e-03
# 47                           1.064954e-03
# 35                           1.062369e-03
# 205                          1.033705e-03
# 20                           1.015702e-03
# 49                           8.780044e-04
# 22                           8.410794e-04
# 80                           7.899354e-04
# 52                           7.603066e-04
# 56                           7.354458e-04
# 115                          7.130479e-04
# 128                          5.008412e-04
# 176                          5.008412e-04
# 17                           4.921000e-04
# 28                           4.617258e-04
# 182                          4.610862e-04
# 136                          4.610862e-04
# 81                           4.013944e-04
# 82                           3.669238e-04
# 36                           3.229749e-04
# 25                           3.207162e-04
# 97                           2.613971e-04
# 26                           2.553926e-04
# 116                          2.437403e-04
# 96                           2.180185e-04
# 65                           1.720434e-04
# 67                           1.520094e-04
# 86                           1.499902e-04
# 93                           1.451930e-04
# 62                           1.377142e-04
# 13                           1.207852e-04
# 15                           1.177516e-04
# 27                           1.046854e-04
# 4                            9.341003e-05
# 2                            8.944632e-05
# 141                          8.525064e-05
# 6                            7.060452e-05
# 138                          6.247921e-05
# 199                          6.224664e-05
# 140                          5.795206e-05
# 117                          5.571455e-05
# 269                          4.946055e-05
# 11                           4.638123e-05
# 132                          4.514799e-05
# 121                          4.214182e-05
# 159                          4.194398e-05
# 197                          3.437409e-05
# 99                           3.248737e-05
# 122                          3.056103e-05
# 43                           2.570957e-05
# 76                           2.540016e-05
# 120                          2.472265e-05
# 126                          2.468242e-05
# 42                           2.422181e-05
# 41                           2.218025e-05
# 133                          2.167859e-05
# 18                           2.062889e-05
# 10                           1.791424e-05
# 66                           1.502679e-05
# 38                           1.438186e-05
# 57                           1.386028e-05
# 40                           1.243731e-05
# 79                           1.193213e-05
# 114                          1.107607e-05
# 137                          1.107607e-05
# 64                           9.232223e-06
# 139                          8.353340e-06
# 296                          8.100272e-06
# 59                           8.007934e-06
# 292                          7.966156e-06
# 46                           6.318573e-06
# 204                          5.567976e-06
# 105                          5.274045e-06
# 89                           4.875514e-06
# 110                          4.300580e-06
# 293                          3.602688e-06
# 129                          2.949563e-06
# 78                           2.548071e-06
# 217                          2.457647e-06
# 214                          2.374913e-06
# 196                          2.206631e-06
# 87                           2.028921e-06
# 113                          2.006222e-06
# 103                          1.929711e-06
# 61                           1.925622e-06
# 107                          1.785724e-06
# 5                            1.593243e-06
# 58                           1.531776e-06
# 88                           1.510446e-06
# 134                          1.275565e-06
# 94                           1.216074e-06
# 98                           1.195862e-06
# 39                           1.176116e-06
# 3                            1.112934e-06
# 108                          1.085595e-06
# 14                           1.065023e-06
# 85                           9.683971e-07
# 149                          9.451073e-07
# 274                          9.375628e-07
# 135                          9.327917e-07
# 185                          7.412463e-07
# 111                          7.369306e-07
# 102                          6.934357e-07
# 187                          6.626859e-07
# 101                          6.033963e-07
# 215                          5.341946e-07
# 254                          4.368093e-07
# 209                          4.072075e-07
# 63                           4.048291e-07
# 290                          3.961762e-07
# 100                          3.545743e-07
# 83                           3.255804e-07
# 252                          2.756824e-07
# 16                           2.727301e-07
# 276                          2.600957e-07
# 298                          2.521055e-07
# 267                          2.416530e-07
# 250                          2.107043e-07
# 280                          1.886927e-07
# 275                          1.806220e-07
# 118                          1.629813e-07
# 299                          1.582019e-07
# 124                          1.529796e-07
# 146                          1.497126e-07
# 177                          1.451810e-07
# 264                          1.451810e-07
# 131                          1.341357e-07
# 278                          1.116222e-07
# 104                          1.010898e-07
# 181                          9.140270e-08
# 279                          8.558586e-08
# 257                          8.558586e-08
# 127                          7.871293e-08
# 119                          7.850613e-08
# 125                          6.925328e-08
# 277                          5.133417e-08
# 258                          3.218073e-08
# 192                          2.786320e-08
# 248                          2.218088e-08
# 255                          2.101623e-08
# 219                          1.787556e-08
# 263                          1.783548e-08
# 191                          1.708077e-08
# 183                          1.460330e-08
# 247                          1.399142e-08
# 123                          1.371642e-08
# 241                          1.280107e-08
# 179                          1.230489e-08
# 300                          1.031236e-08
# 144                          1.025859e-08
# 234                          8.540559e-09
# 95                           8.256330e-09
# 198                          6.451671e-09
# 172                          6.451671e-09
# 211                          6.436491e-09
# 287                          5.899317e-09
# 142                          5.519293e-09
# 268                          4.148300e-09
# 180                          3.385953e-09
# 272                          3.385953e-09
# 244                          2.658339e-09
# 112                          2.592436e-09
# 203                          2.405006e-09
# 240                          2.120957e-09
# 193                          2.005900e-09
# 281                          1.806220e-09
# 200                          1.806220e-09
# 186                          1.705781e-09
# 190                          1.477804e-09
# 256                          1.033372e-09
# 173                          2.764219e-10
# 251                          1.011709e-10
# 188                          4.154811e-11
# 301                          2.236811e-11
# 171                          1.880476e-11
# 295                          1.880476e-11
# 239                          1.272755e-11
# 294                          4.921520e-12
# 262                          2.948187e-12
# 161                          2.468398e-12
# 236                          2.226151e-12
# 303                          1.957889e-12
# 237                          1.663077e-12
# 184                          1.565211e-12
# 253                          1.454754e-12
# 201                          8.216232e-13
# 158                          5.620566e-13
# 194                          3.366815e-13
# 238                          3.328303e-13
# 242                          2.657468e-13
# 189                          1.327097e-13
# 289                          9.843926e-14
# 265                          1.931453e-14
# 291                          3.685832e-16
# 286                          0.000000e+00
# 297                          0.000000e+00
# 273                          0.000000e+00
# 282                          0.000000e+00
# 283                          0.000000e+00
# 271                          0.000000e+00
# 270                          0.000000e+00
# 284                          0.000000e+00
# 302                          0.000000e+00
# 260                          0.000000e+00
# 266                          0.000000e+00
# 288                          0.000000e+00
# 285                          0.000000e+00
# 259                          0.000000e+00
# 261                          0.000000e+00
# 152                          0.000000e+00
# 249                          0.000000e+00
# 162                          0.000000e+00
# 178                          0.000000e+00
# 175                          0.000000e+00
# 174                          0.000000e+00
# 170                          0.000000e+00
# 169                          0.000000e+00
# 168                          0.000000e+00
# 167                          0.000000e+00
# 166                          0.000000e+00
# 165                          0.000000e+00
# 164                          0.000000e+00
# 163                          0.000000e+00
# 160                          0.000000e+00
# 246                          0.000000e+00
# 157                          0.000000e+00
# 156                          0.000000e+00
# 155                          0.000000e+00
# 154                          0.000000e+00
# 153                          0.000000e+00
# 151                          0.000000e+00
# 150                          0.000000e+00
# 148                          0.000000e+00
# 147                          0.000000e+00
# 145                          0.000000e+00
# 143                          0.000000e+00
# 195                          0.000000e+00
# 202                          0.000000e+00
# 206                          0.000000e+00
# 207                          0.000000e+00
# 245                          0.000000e+00
# 243                          0.000000e+00
# 235                          0.000000e+00
# 233                          0.000000e+00
# 232                          0.000000e+00
# 231                          0.000000e+00
# 230                          0.000000e+00
# 229                          0.000000e+00
# 228                          0.000000e+00
# 227                          0.000000e+00
# 226                          0.000000e+00
# 225                          0.000000e+00
# 224                          0.000000e+00
# 223                          0.000000e+00
# 222                          0.000000e+00
# 221                          0.000000e+00
# 220                          0.000000e+00
# 218                          0.000000e+00
# 216                          0.000000e+00
# 213                          0.000000e+00
# 212                          0.000000e+00
# 210                          0.000000e+00
# 208                          0.000000e+00
# 304                          0.000000e+00
#
#                                           Features
# 7                        number_functions_declared
# 45                              js_function_.push(
# 74                              js_function_.call(
# 106                              js_function_.log(
# 109                             js_function_.find(
# 1                                         tot_Math
# 44                           js_function_.replace(
# 75                             js_function_.apply(
# 0                                       tot_Object
# 54                           js_function_.indexOf(
# 31                              js_function_.test(
# 68                               js_function_.get(
# 34                             js_function_.split(
# 53                              js_function_.join(
# 130                              js_function_.set(
# 29                          js_function_.toString(
# 30                       js_function_.toLowerCase(
# 33                             js_function_.substr
# 84                             js_function_.slice(
# 50                             js_function_.match(
# 70                    js_function_.defineProperty(
# 19              js_function_Object.defineProperty(
# 77                               js_function_.add(
# 92                              js_function_.bind(
# 55                    js_function_.hasOwnProperty(
# 51                               js_function_.map(
# 71                            js_function_.concat(
# 69                           js_function_.forEach(
# 90                            js_function_.filter(
# 32                         js_function_.substring(
# 23                           js_function_Math.max(
# 8                            js_function_parseInt(
# 72                        js_function_.charCodeAt(
# 91                              js_function_.exec(
# 73                            js_function_.charAt(
# 37                             js_function_.shift(
# 60                           js_function_.getTime(
# 12                 js_function_encodeURIComponent(
# 24                         js_function_Math.floor(
# 21                        js_function_Math.random(
# 48                              js_function_.next(
# 9                          js_function_parseFloat(
# 47                               js_function_.pop(
# 35                            js_function_.splice(
# 205                         js_function_Math.imul(
# 20                         js_function_Math.round(
# 49                               js_function_.min(
# 22                           js_function_Math.min(
# 80                           js_function_Math.abs(
# 52                              js_function_.keys(
# 56                               js_function_.has(
# 115                     js_function_Object.create(
# 128                   js_function_.setPrototypeOf(
# 176             js_function_Object.setPrototypeOf(
# 17                        js_function_Object.keys(
# 28                              js_function_.trim(
# 182             js_function_Object.getPrototypeOf(
# 136                   js_function_.getPrototypeOf(
# 81                      js_function_Array.isArray(
# 82                           js_function_.unshift(
# 36                              js_function_.sort(
# 25                     js_function_JSON.stringify(
# 97                       js_function_.toUpperCase(
# 26                         js_function_JSON.parse(
# 116                          js_function_Math.pow(
# 96                          js_function_Math.ceil(
# 65                       js_function_.getFullYear(
# 67                           js_function_.getDate(
# 86                            js_function_.reduce(
# 93                              js_function_isNaN(
# 62                          js_function_.getMonth(
# 13                 js_function_decodeURIComponent(
# 15                js_function_String.fromCharCode(
# 27                           js_function_Date.now(
# 4                  number_of_non_http_only_cookies
# 2                       number_of_unsecure_cookies
# 141                            js_function_.catch(
# 6                                number_of_cookies
# 138                             js_function_.from(
# 199                          js_function_Math.sin(
# 140                            js_function_.clear(
# 117                          js_function_Math.cos(
# 269                             js_function_.link(
# 11                               js_function_eval(
# 132                      js_function_.lastIndexOf(
# 121                           js_function_.values(
# 159                        js_function_Symbol.for(
# 197                         js_function_Math.sqrt(
# 99                           js_function_.toFixed(
# 122                          js_function_.valueOf(
# 43                           js_function_.reverse(
# 76                               js_function_.all(
# 120                        js_function_Array.from(
# 126                             js_function_.some(
# 42                            js_function_.search(
# 41                            js_function_.select(
# 133                         js_function_.includes(
# 18         js_function_Object.getOwnPropertyNames(
# 10                           js_function_isFinite(
# 66                            js_function_.getDay(
# 38                           js_function_.setTime(
# 57                           js_function_.getYear(
# 40                           js_function_.setDate(
# 79                      js_function_Object.assign(
# 114   js_function_Object.getOwnPropertyDescriptor(
# 137         js_function_.getOwnPropertyDescriptor(
# 64                          js_function_.getHours(
# 139                             js_function_.fill(
# 296                           js_function_.delete(
# 59                 js_function_.getTimezoneOffset(
# 292                            js_function_.every(
# 46              js_function_.propertyIsEnumerable(
# 204                          js_function_Math.log(
# 105                        js_function_.normalize(
# 89                        js_function_.getMinutes(
# 110                          js_function_unescape(
# 293                          js_function_.entries(
# 129                         js_function_.setMonth(
# 78                    js_function_Promise.resolve(
# 217                         js_function_Math.asin(
# 214                        js_function_Math.atan2(
# 196                          js_function_Math.tan(
# 87                       js_function_.getUTCHours(
# 113                       js_function_Object.seal(
# 103                      js_function_.setFullYear(
# 61                        js_function_.getSeconds(
# 107                    js_function_.isPrototypeOf(
# 5                      number_of_http_only_cookies
# 58                     js_function_.getUTCMinutes(
# 88                        js_function_.getUTCDate(
# 134                      js_function_.getUTCMonth(
# 94                             js_function_escape)
# 98                            js_function_.toJSON(
# 39                          js_function_.setHours(
# 3                         number_of_secure_cookies
# 108                    js_function_.getUTCSeconds(
# 14                          js_function_decodeURI(
# 85                            js_function_.return(
# 149                         js_function_undefined(
# 274                         js_function_.getUint8(
# 135                   js_function_.getUTCFullYear(
# 185                     js_function_Object.freeze(
# 111                         js_function_encodeURI(
# 102                  js_function_.setMilliseconds(
# 187           js_function_Object.defineProperties(
# 101                       js_function_.setMinutes(
# 215                         js_function_Math.atan(
# 254                      js_function_.setUTCHours(
# 209                          js_function_Math.exp(
# 63                   js_function_.getMilliseconds(
# 290                        js_function_.findIndex(
# 100                       js_function_.setSeconds(
# 83                       js_function_.toISOString(
# 252                    js_function_.setUTCMinutes(
# 16                        js_function_Promise.all(
# 276                        js_function_.getUint16(
# 298                        js_function_.construct(
# 267                               js_function_.of(
# 250                    js_function_.setUTCSeconds(
# 280                         js_function_.getInt32(
# 275                        js_function_.getUint32(
# 118                        js_function_Date.parse(
# 299                          js_function_.compile(
# 124                   js_function_.toLocaleString(
# 146                                     tot_Number
# 177          js_function_Object.preventExtensions(
# 264                js_function_.preventExtensions(
# 131                           js_function_.repeat(
# 278                        js_function_.getUTCDay(
# 104                         js_function_.padStart(
# 181                         js_function_Object.is(
# 279                          js_function_.getInt8(
# 257                          js_function_.setInt8(
# 127                          js_function_.setYear(
# 119                          js_function_Date.UTC(
# 125                         js_function_.subarray(
# 277               js_function_.getUTCMilliseconds(
# 258                         js_function_.setInt32(
# 192                  js_function_Number.isInteger(
# 248                        js_function_.setUint32(
# 255                   js_function_.setUTCFullYear(
# 219                         js_function_Math.acos(
# 263                      js_function_.reduceRight(
# 191                      js_function_Number.isNaN(
# 183      js_function_Object.getOwnPropertySymbols(
# 247                         js_function_.setUint8(
# 123                         js_function_.toSource(
# 241                    js_function_.toExponential(
# 179                   js_function_Object.isFrozen(
# 300                      js_function_.codePointAt(
# 144                                    tot_Reflect
# 234                js_function_ArrayBuffer.isView(
# 95                       js_function_Promise.race(
# 198                         js_function_Math.sinh(
# 172            js_function_Reflect.defineProperty(
# 211                        js_function_Math.clz32(
# 287                          js_function_.flatMap(
# 142                            js_function_.blink(
# 268                    js_function_.localeCompare(
# 180               js_function_Object.isExtensible(
# 272                     js_function_.isExtensible(
# 244               js_function_.supportedLocalesOf(
# 112                    js_function_Promise.reject(
# 203                        js_function_Math.log10(
# 240               js_function_.toLocaleTimeString(
# 193                   js_function_Number.isFinite(
# 281                         js_function_.getInt16(
# 200                         js_function_Math.sign(
# 186                    js_function_Object.entries(
# 190              js_function_Number.isSafeInteger(
# 256                       js_function_.setUTCDate(
# 173                 js_function_Reflect.construct(
# 251                      js_function_.setUTCMonth(
# 188                   js_function_Number.parseInt(
# 301                             js_function_.bold(
# 171            js_function_Reflect.deleteProperty(
# 295                   js_function_.deleteProperty(
# 239                js_function_.toLocaleUpperCase(
# 294                          js_function_.endWith(
# 262                  js_function_.resolvedOptions(
# 161              js_function_String.fromCodePoint(
# 236                        js_function_.trimStart(
# 303                           js_function_.anchor(
# 237                          js_function_.trimEnd(
# 184  js_function_Object.getOwnPropertyDescriptors(
# 253               js_function_.setUTCMilliseconds(
# 201                         js_function_Math.log2(
# 158                     js_function_Symbol.keyFor(
# 194                        js_function_Math.trunc(
# 238                      js_function_.toPrecision(
# 242                     js_function_.toDateString(
# 189                 js_function_Number.parseFloat(
# 289                            js_function_.fixed(
# 265                           js_function_.padEnd(
# 291                          js_function_.finally(
# 286                        js_function_.fontcolor(
# 297                       js_function_.copyWithin(
# 273                             js_function_.grow(
# 282                       js_function_.getFloat64(
# 283                       js_function_.getFloat32(
# 271                            js_function_.isNan(
# 270                          js_function_.italics(
# 284                    js_function_.formatToParts(
# 302                              js_function_.big(
# 260                       js_function_.setFloat64(
# 266                          js_function_.ownKeys(
# 288                             js_function_.flat(
# 285                         js_function_.fontsize(
# 259                         js_function_.setInt16(
# 261                       js_function_.setFloat32(
# 152           js_function_WebAssembly.instantiate(
# 249                        js_function_.setUint16(
# 162            js_function_Reflect.setPrototypeOf(
# 178                   js_function_Object.isSealed(
# 175                   js_function_Proxy.revocable(
# 174                     js_function_Reflect.apply(
# 170                       js_function_Reflect.get(
# 169  js_function_Reflect.getOwnPropertyDescriptor(
# 168            js_function_Reflect.getPrototypeOf(
# 167                       js_function_Reflect.has(
# 166              js_function_Reflect.isExtensible(
# 165                   js_function_Reflect.ownKeys(
# 164         js_function_Reflect.preventExtensions(
# 163                       js_function_Reflect.set(
# 160                        js_function_String.raw(
# 246                            js_function_.small(
# 157               js_function_WebAssembly.compile(
# 156      js_function_WebAssembly.compileStreaming(
# 155      js_function_WebAssembly.customerSections(
# 154               js_function_WebAssembly.exports(
# 153               js_function_WebAssembly.imports(
# 151  js_function_WebAssembly.instantiateStreaming(
# 150              js_function_WebAssembly.validate(
# 148                            js_function_uneval(
# 147                                    tot_Atomics
# 145                                    tot_Promise
# 143                                tot_WebAssembly
# 195                         js_function_Math.tanh(
# 202                        js_function_Math.log1p(
# 206                        js_function_Math.hypot(
# 207                       js_function_Math.fround(
# 245                           js_function_.strike(
# 243                            js_function_.throw(
# 235                          js_function_Array.of(
# 233              js_function_ArrayBuffer.transfer(
# 232                       js_function_Atomics.add(
# 231                       js_function_Atomics.and(
# 230           js_function_Atomics.compareExchange(
# 229                  js_function_Atomics.exchange(
# 228                js_function_Atomics.isLockFree(
# 227                      js_function_Atomics.load(
# 226                        js_function_Atomics.or(
# 225                     js_function_Atomics.store(
# 224                       js_function_Atomics.sub(
# 223                      js_function_Atomics.wait(
# 222                      js_function_Atomics.wake(
# 221                       js_function_Atomics.xor(
# 220          js_function_Intl.getCanonicalLocales(
# 218                        js_function_Math.acosh(
# 216                        js_function_Math.asinh(
# 213                        js_function_Math.atanh(
# 212                         js_function_Math.cbrt(
# 210                         js_function_Math.cosh(
# 208                        js_function_Math.expm1(
# 304                          js_function_.allTrue(
