# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)
from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
import time

from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE

import warnings
warnings.simplefilter("ignore", DeprecationWarning)
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

# %% [markdown]
# ### Eliminating cases where html_status=="Not success" as they have all null values

# %%
df_alex=pd.read_csv('Document_alexa_http.csv',low_memory=False)
df_virus=pd.read_csv('Document_malicious_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])

df.drop(['Unnamed: 0'],axis=1,inplace=True)

df = df.sample(frac=1,random_state=867).reset_index(drop=True)

df.fillna(value=0,inplace=True)

display(df.shape)

df=df[df['html_status']=='Success']
df.shape
# Out:
# (45684, 119)
# (36305, 119)

# %% [markdown]
# ### Dropping columns that indicate the html status of domain data collection

# %%
df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

# %%
cols_document=[col for col in df.columns if 'document' in col]
df['tot_document']=df[cols_document].sum(axis=1)

cols_window=[col for col in df.columns if 'window' in col]
df['tot_window']=df[cols_window].sum(axis=1)

# %% [markdown]
# #### Columns and nummber of unique values they have

# %%
lst=[]
for col in df.columns:
    lst.append((col,len(df[col].value_counts())))

unique_val_cols=pd.DataFrame(lst)
unique_val_cols.columns=['Column_Name','Num_unique_value']

unique_val_cols.sort_values(by=['Num_unique_value'],inplace=True)
unique_val_cols.head()
# Out:
#                                     Column_Name  Num_unique_value
# 0              dom_function_document.adoptNode(                 1
# 71            dom_function_window.getAttention(                 1
# 36     dom_function_document.normalizeDocument(                 1
# 98           dom_function_window.scrollByPages(                 1
# 39  dom_function_document.queryCommandIndeterm(                 1

# %%
print("Columns with all same values")
col_1=unique_val_cols[unique_val_cols['Num_unique_value']==1].Column_Name.values

for col in col_1:
    print(df[col].value_counts(),"\n")
# Out:
# Columns with all same values
# 0.0    36305
# Name: dom_function_document.adoptNode(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.getAttention(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.normalizeDocument(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.scrollByPages(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.queryCommandIndeterm(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.queryCommandValue(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.scrollByLines(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.routeEvent(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.releaseCapture(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.releaseEvent(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.routeEvent(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.restore(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.resizeBy(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.requestIdleCallback(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.releaseEvents(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.back(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.openDialog(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.cancelIdleCallback(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.moveBy(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.minimize(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.maximize(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.home(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.getDefaultComputedSyle(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.createImageBitmap(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.disableExternalCapture(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.getAttentionWithCycleCount(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.dump(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.enableExternalCapture(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.setCursor(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.getElementsByTagNameNS(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.forward(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.createTouchList(, dtype: int64
#
# 0.0    36305
# Name: tot_Reflect, dtype: int64
#
# 0.0    36305
# Name: tot_Math, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.createEntityReference(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.setResizable(, dtype: int64
#
# 0.0    36305
# Name: tot_WebAssembly, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.createCDATASection(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.createAttributeNS(, dtype: int64
#
# 0.0    36305
# Name: tot_Atomics, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.updateCommands(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.createTouch(, dtype: int64
#
# 0.0    36305
# Name: tot_Object, dtype: int64
#
# 0.0    36305
# Name: tot_Number, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.clear(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.enableStyleSheetsForSet(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.exitPointerLock(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.getAnimations(, dtype: int64
#
# 0.0    36305
# Name: dom_function_window.sizeToContent(, dtype: int64
#
# 0.0    36305
# Name: dom_function_document.getElementByName(, dtype: int64
#
# 0.0    36305
# Name: tot_Promise, dtype: int64

# %% [markdown]
# #### Dependent and Target variables

# %%
X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

X=df.loc[:,df.columns!='Malicious']
y=df.Malicious.values
feature_name = X.columns.tolist()

model = LogisticRegression(random_state=0)
model.fit(X, y)

print("Accuracy score with all of the features")
display(model.score(X,y))
# Out:
# Accuracy score with all of the features
# 0.857209750723041

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9654018781166578
# Columns selected:
#
# Accuracy score
# 0.8569893954000827

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 108                          2.633851e+01
# 121                          1.259782e+01
# 46                           1.101065e+01
# 28                           5.240352e-02
# 82                           3.340251e-04
# 31                           8.794608e-05
# 104                          3.760054e-05
# 11                           3.086893e-05
# 111                          2.341362e-05
# 48                           2.099716e-05
# 113                          1.704602e-05
# 122                          1.095519e-05
# 41                           7.611773e-06
# 109                          7.223587e-06
# 30                           6.877949e-06
# 88                           6.325977e-06
# 110                          4.627182e-06
# 73                           3.380725e-06
# 47                           2.503323e-06
# 18                           2.121009e-06
# 75                           2.106292e-06
# 112                          2.076507e-06
# 59                           1.529159e-06
# 14                           1.102743e-06
# 89                           6.458151e-07
# 37                           5.715486e-07
# 17                           5.318659e-07
# 58                           5.268544e-07
# 25                           4.013064e-07
# 5                            3.992731e-07
# 10                           3.939714e-07
# 60                           2.986422e-07
# 61                           1.497746e-07
# 102                          1.497348e-07
# 77                           1.263514e-07
# 42                           1.251157e-07
# 50                           8.733547e-08
# 99                           8.524281e-08
# 34                           6.653230e-08
# 54                           3.125557e-08
# 12                           2.834472e-08
# 9                            1.814635e-08
# 52                           1.658370e-08
# 84                           1.380529e-08
# 64                           1.205508e-08
# 38                           8.803992e-09
# 21                           8.803992e-09
# 81                           8.054774e-09
# 6                            4.935728e-09
# 85                           3.840158e-09
# 92                           3.457092e-09
# 96                           3.005163e-09
# 16                           2.714847e-09
# 95                           1.989011e-09
# 33                           1.702451e-09
# 69                           1.570634e-09
# 67                           1.540954e-09
# 101                          7.360623e-10
# 35                           7.358908e-10
# 49                           7.101839e-10
# 1                            4.674311e-10
# 2                            2.699498e-10
# 3                            2.699498e-10
# 86                           2.047223e-10
# 56                           1.584648e-10
# 106                          1.286430e-10
# 53                           1.232847e-10
# 23                           1.103439e-10
# 22                           2.854130e-11
# 57                           2.400081e-12
# 68                           2.006274e-12
# 15                           3.112333e-15
# 0                            4.271499e-36
# 8                            1.582251e-63
# 4                            7.411572e-64
# 7                            3.815377e-65
# 20                           0.000000e+00
# 100                          0.000000e+00
# 45                           0.000000e+00
# 44                           0.000000e+00
# 103                          0.000000e+00
# 43                           0.000000e+00
# 105                          0.000000e+00
# 29                           0.000000e+00
# 107                          0.000000e+00
# 40                           0.000000e+00
# 39                           0.000000e+00
# 74                           0.000000e+00
# 32                           0.000000e+00
# 114                          0.000000e+00
# 115                          0.000000e+00
# 116                          0.000000e+00
# 117                          0.000000e+00
# 118                          0.000000e+00
# 119                          0.000000e+00
# 120                          0.000000e+00
# 36                           0.000000e+00
# 27                           0.000000e+00
# 98                           0.000000e+00
# 97                           0.000000e+00
# 26                           0.000000e+00
# 19                           0.000000e+00
# 76                           0.000000e+00
# 72                           0.000000e+00
# 71                           0.000000e+00
# 79                           0.000000e+00
# 80                           0.000000e+00
# 70                           0.000000e+00
# 66                           0.000000e+00
# 83                           0.000000e+00
# 65                           0.000000e+00
# 63                           0.000000e+00
# 62                           0.000000e+00
# 87                           0.000000e+00
# 55                           0.000000e+00
# 13                           0.000000e+00
# 90                           0.000000e+00
# 91                           0.000000e+00
# 51                           0.000000e+00
# 93                           0.000000e+00
# 94                           0.000000e+00
# 24                           0.000000e+00
# 78                           0.000000e+00
#
#                                               Features
# 108                          number_functions_declared
# 121                                       tot_document
# 46                        dom_function_document.write(
# 28               dom_function_document.getElementById(
# 82                           dom_function_window.open(
# 31         dom_function_document.getElementsByTagName(
# 104                    dom_function_window.setTimeout(
# 11                dom_function_document.createElement(
# 111                    number_of_non_http_only_cookies
# 48               dom_function_window.addEventListener(
# 113                         number_of_unsecure_cookies
# 122                                         tot_window
# 41                dom_function_document.querySelector(
# 109                                  number_of_cookies
# 30       dom_function_document.getElementsByClassName(
# 88            dom_function_window.removeEventListener(
# 110                        number_of_http_only_cookies
# 73               dom_function_window.getComputedStyle(
# 47                      dom_function_document.writeln(
# 18               dom_function_document.createTextNode(
# 75                   dom_function_window.getSelection(
# 112                           number_of_secure_cookies
# 59                   dom_function_window.clearTimeout(
# 14                  dom_function_document.createEvent(
# 89          dom_function_window.requestAnimationFrame(
# 37                         dom_function_document.open(
# 17                  dom_function_document.createRange(
# 58                  dom_function_window.clearInterval(
# 25                  dom_function_document.execCommand(
# 5                         dom_function_document.close(
# 10       dom_function_document.createDocumentFragment(
# 60                          dom_function_window.close(
# 61                        dom_function_window.confirm(
# 102                   dom_function_window.setInterval(
# 77                     dom_function_window.matchMedia(
# 42             dom_function_document.querySelectorAll(
# 50                           dom_function_window.atob(
# 99                       dom_function_window.scrollTo(
# 34                     dom_function_document.hasFocus(
# 54           dom_function_window.cancelAnimationFrame(
# 12              dom_function_document.createElementNS(
# 9                 dom_function_document.createComment(
# 52                           dom_function_window.blur(
# 84                    dom_function_window.postMessage(
# 64                  dom_function_window.dispatchEvent(
# 38          dom_function_document.queryCommandEnabled(
# 21             dom_function_document.createTreeWalker(
# 81                         dom_function_window.moveTo(
# 6               dom_function_document.createAttribute(
# 85                          dom_function_window.print(
# 92                       dom_function_window.resizeTo(
# 96                       dom_function_window.scrollBy(
# 16   dom_function_document.createProcessingInstruct...
# 95                         dom_function_window.scroll(
# 33                 dom_function_document.getSelection(
# 69                          dom_function_window.focus(
# 67                          dom_function_window.fetch(
# 101                  dom_function_window.setImmediate(
# 35                   dom_function_document.importNode(
# 49                          dom_function_window.alert(
# 1                 dom_function_document.captureEvents(
# 2        dom_function_document.caretPositionFromPoint(
# 3           dom_function_document.caretRangeFromPoint(
# 86                         dom_function_window.prompt(
# 56                  dom_function_window.captureEvents(
# 106                          dom_function_window.stop(
# 53                           dom_function_window.btoa(
# 23            dom_function_document.elementsFromPoint(
# 22             dom_function_document.elementFromPoint(
# 57                 dom_function_window.clearImmediate(
# 68                           dom_function_window.find(
# 15           dom_function_document.createNodeIterator(
# 0                     dom_function_document.adoptNode(
# 8            dom_function_document.createCDATASection(
# 4                         dom_function_document.clear(
# 7             dom_function_document.createAttributeNS(
# 20              dom_function_document.createTouchList(
# 100                     dom_function_window.setCursor(
# 45                   dom_function_document.routeEvent(
# 44                 dom_function_document.releaseEvent(
# 103                  dom_function_window.setResizable(
# 43               dom_function_document.releaseCapture(
# 105                 dom_function_window.sizeToContent(
# 29             dom_function_document.getElementByName(
# 107                dom_function_window.updateCommands(
# 40            dom_function_document.queryCommandValue(
# 39         dom_function_document.queryCommandIndeterm(
# 74         dom_function_window.getDefaultComputedSyle(
# 32       dom_function_document.getElementsByTagNameNS(
# 114                                    tot_WebAssembly
# 115                                        tot_Reflect
# 116                                         tot_Object
# 117                                         tot_Number
# 118                                           tot_Math
# 119                                        tot_Atomics
# 120                                        tot_Promise
# 36            dom_function_document.normalizeDocument(
# 27                dom_function_document.getAnimations(
# 98                  dom_function_window.scrollByPages(
# 97                  dom_function_window.scrollByLines(
# 26              dom_function_document.exitPointerLock(
# 19                  dom_function_document.createTouch(
# 76                           dom_function_window.home(
# 72     dom_function_window.getAttentionWithCycleCount(
# 71                   dom_function_window.getAttention(
# 79                       dom_function_window.minimize(
# 80                         dom_function_window.moveBy(
# 70                        dom_function_window.forward(
# 66          dom_function_window.enableExternalCapture(
# 83                     dom_function_window.openDialog(
# 65                           dom_function_window.dump(
# 63         dom_function_window.disableExternalCapture(
# 62              dom_function_window.createImageBitmap(
# 87                  dom_function_window.releaseEvents(
# 55             dom_function_window.cancelIdleCallback(
# 13        dom_function_document.createEntityReference(
# 90            dom_function_window.requestIdleCallback(
# 91                       dom_function_window.resizeBy(
# 51                           dom_function_window.back(
# 93                        dom_function_window.restore(
# 94                     dom_function_window.routeEvent(
# 24      dom_function_document.enableStyleSheetsForSet(
# 78                       dom_function_window.maximize(

# %% [markdown]
# ### Correlation

# %%
def cor_selector(X, y):
    cor_list = []
    # calculate the correlation with y for each feature
    for i in X.columns.tolist():
        cor = np.corrcoef(X[i], y)[0, 1]
        cor_list.append(cor)
    # replace NaN with 0
    cor_list = [0 if np.isnan(i) else i for i in cor_list]
    # feature name
    cor_feature = X.iloc[:,np.argsort(np.abs(cor_list))[-50:]].columns.tolist()
    # feature selection? 0 for not select, 1 for select
    cor_support = [True if i in cor_feature else False for i in feature_name]
    return cor_support, cor_feature


cor_support, cor_feature = cor_selector(X, y)
print(str(len(cor_feature)), 'selected features')
# Out:
# 50 selected features
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3183: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# /nethomes/darshan/anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3184: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %% [markdown]
# ### CHI2

# %%
X_norm = MinMaxScaler().fit_transform(X)
chi_selector = SelectKBest(chi2, k=50)
chi_selector.fit(X_norm, y)
chi_support = chi_selector.get_support()
chi_feature = X.loc[:,chi_support].columns.tolist()
print(str(len(chi_feature)), 'selected features')
# Out:
# 50 selected features

# %% [markdown]
# ### RFE

# %%
rfe_selector = RFE(estimator=LogisticRegression(), n_features_to_select=50, step=10, verbose=False)
rfe_selector.fit(X_norm, y)

rfe_support = rfe_selector.get_support()
rfe_feature = X.loc[:,rfe_support].columns.tolist()
print(str(len(rfe_feature)), 'selected features')
# Out:
# 50 selected features

# %% [markdown]
# ### SelectFromModel

# %%
embeded_rf_selector = SelectFromModel(RandomForestClassifier(n_estimators=100,random_state=0), threshold='30*median')
embeded_rf_selector.fit(X, y)
embeded_rf_support = embeded_rf_selector.get_support()
embeded_rf_feature = X.loc[:,embeded_rf_support].columns.tolist()
print(str(len(embeded_rf_feature)), 'selected features')
# Out:
# 53 selected features

# %%
# from lightgbm import LGBMClassifier

# lgbc=LGBMClassifier(n_estimators=500, learning_rate=0.05, num_leaves=32, colsample_bytree=0.2,
#             reg_alpha=3, reg_lambda=1, min_split_gain=0.01, min_child_weight=40)

# embeded_lgb_selector = SelectFromModel(lgbc, threshold='1e-20*mean')
# embeded_lgb_selector.fit(X, y)
# embeded_lgb_support = embeded_lgb_selector.get_support()

# embeded_lgb_feature = X.loc[:,embeded_lgb_support].columns.tolist()
# print(str(len(embeded_lgb_feature)), 'selected features')

# %%
feature_selection_df = pd.DataFrame({'Feature':feature_name, 'Pearson':cor_support, 'Chi-2':chi_support, 'RFE':rfe_support,
                                    'Random Forest':embeded_rf_support})
# count the selected times for each feature
feature_selection_df['Total'] = np.sum(feature_selection_df, axis=1)
# display the top 100
feature_selection_df = feature_selection_df.sort_values(['Total','Feature'] , ascending=False)
feature_selection_df.index = range(1, len(feature_selection_df)+1)
feature_selection_df.head(100)
# Out:
#                                              Feature  Pearson  Chi-2    RFE  \
# 1                                         tot_window     True   True   True
# 2                                       tot_document     True   True   True
# 3                         number_of_unsecure_cookies     True   True   True
# 4                           number_of_secure_cookies     True   True   True
# 5                    number_of_non_http_only_cookies     True   True   True
# 6                        number_of_http_only_cookies     True   True   True
# 7                                  number_of_cookies     True   True   True
# 8                          number_functions_declared     True   True   True
# 9                          dom_function_window.stop(     True   True   True
# 10                   dom_function_window.setTimeout(     True   True   True
# 11                  dom_function_window.setInterval(     True   True   True
# 12                     dom_function_window.scrollTo(     True   True   True
# 13                       dom_function_window.scroll(     True   True   True
# 14        dom_function_window.requestAnimationFrame(     True   True   True
# 15          dom_function_window.removeEventListener(     True   True   True
# 16                         dom_function_window.open(     True   True   True
# 17                   dom_function_window.matchMedia(     True   True   True
# 18                 dom_function_window.getSelection(     True   True   True
# 19             dom_function_window.getComputedStyle(     True   True   True
# 20                        dom_function_window.focus(     True   True   True
# 21                        dom_function_window.close(     True   True   True
# 22                 dom_function_window.clearTimeout(     True   True   True
# 23                dom_function_window.clearInterval(     True   True   True
# 24               dom_function_window.clearImmediate(     True   True   True
# 25                         dom_function_window.btoa(     True   True   True
# 26                         dom_function_window.blur(     True   True   True
# 27                        dom_function_window.alert(     True   True   True
# 28             dom_function_window.addEventListener(     True   True   True
# 29           dom_function_document.querySelectorAll(     True   True   True
# 30              dom_function_document.querySelector(     True   True   True
# 31                       dom_function_document.open(     True   True   True
# 32       dom_function_document.getElementsByTagName(     True   True   True
# 33     dom_function_document.getElementsByClassName(     True   True   True
# 34             dom_function_document.getElementById(     True   True   True
# 35                dom_function_document.execCommand(     True   True   True
# 36             dom_function_document.createTextNode(     True   True   True
# 37                dom_function_document.createEvent(     True   True   True
# 38            dom_function_document.createElementNS(     True   True   True
# 39              dom_function_document.createElement(     True   True   True
# 40                      dom_function_document.close(     True   True   True
# 41                  dom_function_window.postMessage(     True   True   True
# 42                dom_function_window.dispatchEvent(     True   True  False
# 43                         dom_function_window.atob(     True  False   True
# 44                      dom_function_document.write(     True  False   True
# 45                   dom_function_document.hasFocus(     True   True  False
# 46                dom_function_document.createRange(     True  False   True
# 47     dom_function_document.createDocumentFragment(     True   True  False
# 48              dom_function_document.createComment(     True   True  False
# 49              dom_function_document.captureEvents(    False   True   True
# 50                dom_function_window.captureEvents(    False  False   True
# 51                    dom_function_document.writeln(    False  False   True
# 52           dom_function_document.elementFromPoint(    False   True   True
# 53            dom_function_document.createAttribute(     True   True  False
# 54                     dom_function_window.scrollBy(     True  False  False
# 55                     dom_function_window.resizeTo(    False  False   True
# 56                        dom_function_window.print(    False  False  False
# 57                       dom_function_window.moveTo(    False  False   True
# 58                        dom_function_window.fetch(    False   True  False
# 59                      dom_function_window.confirm(    False  False  False
# 60         dom_function_window.cancelAnimationFrame(    False  False  False
# 61          dom_function_document.elementsFromPoint(    False   True  False
# 62                                   tot_WebAssembly    False  False  False
# 63                                       tot_Reflect    False  False  False
# 64                                       tot_Promise    False  False  False
# 65                                        tot_Object    False  False  False
# 66                                        tot_Number    False  False  False
# 67                                          tot_Math    False  False  False
# 68                                       tot_Atomics    False  False  False
# 69               dom_function_window.updateCommands(    False  False  False
# 70                dom_function_window.sizeToContent(    False  False  False
# 71                 dom_function_window.setResizable(    False  False  False
# 72                 dom_function_window.setImmediate(    False  False  False
# 73                    dom_function_window.setCursor(    False  False  False
# 74                dom_function_window.scrollByPages(    False  False  False
# 75                dom_function_window.scrollByLines(    False  False  False
# 76                   dom_function_window.routeEvent(    False  False  False
# 77                      dom_function_window.restore(    False  False  False
# 78                     dom_function_window.resizeBy(    False  False  False
# 79          dom_function_window.requestIdleCallback(    False  False  False
# 80                dom_function_window.releaseEvents(    False  False  False
# 81                       dom_function_window.prompt(    False  False  False
# 82                   dom_function_window.openDialog(    False  False  False
# 83                       dom_function_window.moveBy(    False  False  False
# 84                     dom_function_window.minimize(    False  False  False
# 85                     dom_function_window.maximize(    False  False  False
# 86                         dom_function_window.home(    False  False  False
# 87       dom_function_window.getDefaultComputedSyle(    False  False  False
# 88   dom_function_window.getAttentionWithCycleCount(    False  False  False
# 89                 dom_function_window.getAttention(    False  False  False
# 90                      dom_function_window.forward(    False  False  False
# 91                         dom_function_window.find(    False  False  False
# 92        dom_function_window.enableExternalCapture(    False  False  False
# 93                         dom_function_window.dump(    False  False  False
# 94       dom_function_window.disableExternalCapture(    False  False  False
# 95            dom_function_window.createImageBitmap(    False  False  False
# 96           dom_function_window.cancelIdleCallback(    False  False  False
# 97                         dom_function_window.back(    False  False  False
# 98                 dom_function_document.routeEvent(    False  False  False
# 99               dom_function_document.releaseEvent(    False  False  False
# 100            dom_function_document.releaseCapture(    False  False  False
#
#      Random Forest  Total
# 1             True      4
# 2             True      4
# 3             True      4
# 4             True      4
# 5             True      4
# 6             True      4
# 7             True      4
# 8             True      4
# 9             True      4
# 10            True      4
# 11            True      4
# 12            True      4
# 13            True      4
# 14            True      4
# 15            True      4
# 16            True      4
# 17            True      4
# 18            True      4
# 19            True      4
# 20            True      4
# 21            True      4
# 22            True      4
# 23            True      4
# 24            True      4
# 25            True      4
# 26            True      4
# 27            True      4
# 28            True      4
# 29            True      4
# 30            True      4
# 31            True      4
# 32            True      4
# 33            True      4
# 34            True      4
# 35            True      4
# 36            True      4
# 37            True      4
# 38            True      4
# 39            True      4
# 40            True      4
# 41           False      3
# 42            True      3
# 43            True      3
# 44            True      3
# 45            True      3
# 46            True      3
# 47            True      3
# 48            True      3
# 49            True      3
# 50            True      2
# 51            True      2
# 52           False      2
# 53           False      2
# 54           False      1
# 55           False      1
# 56            True      1
# 57           False      1
# 58           False      1
# 59            True      1
# 60            True      1
# 61           False      1
# 62           False      0
# 63           False      0
# 64           False      0
# 65           False      0
# 66           False      0
# 67           False      0
# 68           False      0
# 69           False      0
# 70           False      0
# 71           False      0
# 72           False      0
# 73           False      0
# 74           False      0
# 75           False      0
# 76           False      0
# 77           False      0
# 78           False      0
# 79           False      0
# 80           False      0
# 81           False      0
# 82           False      0
# 83           False      0
# 84           False      0
# 85           False      0
# 86           False      0
# 87           False      0
# 88           False      0
# 89           False      0
# 90           False      0
# 91           False      0
# 92           False      0
# 93           False      0
# 94           False      0
# 95           False      0
# 96           False      0
# 97           False      0
# 98           False      0
# 99           False      0
# 100          False      0

# %%
X=df[feature_selection_df.Feature]
y=df.Malicious.values

model = LogisticRegression()
model.fit(X, y)

print("Accuracy score with top 100 selected features:")
display(model.score(X,y))
# Out:
# Accuracy score with top 100 selected features:
# 0.857209750723041

# %%
pca=PCA(n_components=2,random_state=0)

pca.fit_transform(X,y)

print("Explained variance with 2 features",sum(pca.explained_variance_ratio_))

X_pca=pca.transform(X)

model = LogisticRegression(random_state=0)
model.fit(X_pca, y)

print("Columns selected:\n")
# display(b.columns[:-1][fit.support_])
print("Accuracy score")
display(model.score(X_pca,y))
# Out:
# Explained variance with 2 features 0.9654018781166525
# Columns selected:
#
# Accuracy score
# 0.8569893954000827

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']*100
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#      % Variance explained by each feature  \
# 7                            2.633851e+01
# 1                            1.259782e+01
# 43                           1.101065e+01
# 33                           5.240352e-02
# 15                           3.340251e-04
# 31                           8.794608e-05
# 9                            3.760054e-05
# 38                           3.086893e-05
# 4                            2.341362e-05
# 27                           2.099716e-05
# 2                            1.704602e-05
# 0                            1.095519e-05
# 29                           7.611773e-06
# 6                            7.223587e-06
# 32                           6.877949e-06
# 14                           6.325977e-06
# 5                            4.627182e-06
# 18                           3.380725e-06
# 50                           2.503323e-06
# 35                           2.121009e-06
# 17                           2.106292e-06
# 3                            2.076507e-06
# 21                           1.529159e-06
# 36                           1.102743e-06
# 13                           6.458151e-07
# 30                           5.715486e-07
# 45                           5.318659e-07
# 22                           5.268544e-07
# 34                           4.013064e-07
# 39                           3.992731e-07
# 46                           3.939714e-07
# 20                           2.986422e-07
# 58                           1.497746e-07
# 10                           1.497348e-07
# 16                           1.263514e-07
# 28                           1.251157e-07
# 42                           8.733547e-08
# 11                           8.524281e-08
# 44                           6.653230e-08
# 59                           3.125557e-08
# 37                           2.834472e-08
# 47                           1.814635e-08
# 25                           1.658370e-08
# 40                           1.380529e-08
# 41                           1.205508e-08
# 102                          8.803992e-09
# 111                          8.803992e-09
# 56                           8.054774e-09
# 52                           4.935728e-09
# 55                           3.840158e-09
# 54                           3.457092e-09
# 53                           3.005163e-09
# 114                          2.714847e-09
# 12                           1.989011e-09
# 105                          1.702451e-09
# 19                           1.570634e-09
# 57                           1.540954e-09
# 71                           7.360623e-10
# 104                          7.358908e-10
# 26                           7.101839e-10
# 48                           4.674311e-10
# 120                          2.699498e-10
# 121                          2.699498e-10
# 80                           2.047223e-10
# 49                           1.584648e-10
# 8                            1.286430e-10
# 24                           1.232847e-10
# 60                           1.103439e-10
# 51                           2.854130e-11
# 23                           2.400081e-12
# 90                           2.006274e-12
# 115                          3.112333e-15
# 97                           0.000000e+00
# 96                           0.000000e+00
# 98                           0.000000e+00
# 99                           0.000000e+00
# 100                          0.000000e+00
# 101                          0.000000e+00
# 95                           0.000000e+00
# 103                          0.000000e+00
# 106                          0.000000e+00
# 93                           0.000000e+00
# 119                          0.000000e+00
# 107                          0.000000e+00
# 108                          0.000000e+00
# 109                          0.000000e+00
# 110                          0.000000e+00
# 112                          0.000000e+00
# 113                          0.000000e+00
# 116                          0.000000e+00
# 117                          0.000000e+00
# 118                          0.000000e+00
# 94                           0.000000e+00
# 61                           0.000000e+00
# 92                           0.000000e+00
# 75                           0.000000e+00
# 62                           0.000000e+00
# 63                           0.000000e+00
# 64                           0.000000e+00
# 65                           0.000000e+00
# 66                           0.000000e+00
# 67                           0.000000e+00
# 68                           0.000000e+00
# 69                           0.000000e+00
# 70                           0.000000e+00
# 72                           0.000000e+00
# 73                           0.000000e+00
# 74                           0.000000e+00
# 76                           0.000000e+00
# 91                           0.000000e+00
# 77                           0.000000e+00
# 78                           0.000000e+00
# 79                           0.000000e+00
# 81                           0.000000e+00
# 82                           0.000000e+00
# 83                           0.000000e+00
# 84                           0.000000e+00
# 85                           0.000000e+00
# 86                           0.000000e+00
# 87                           0.000000e+00
# 88                           0.000000e+00
# 89                           0.000000e+00
# 122                          0.000000e+00
#
#                                               Features
# 7                            number_functions_declared
# 1                                         tot_document
# 43                        dom_function_document.write(
# 33               dom_function_document.getElementById(
# 15                           dom_function_window.open(
# 31         dom_function_document.getElementsByTagName(
# 9                      dom_function_window.setTimeout(
# 38                dom_function_document.createElement(
# 4                      number_of_non_http_only_cookies
# 27               dom_function_window.addEventListener(
# 2                           number_of_unsecure_cookies
# 0                                           tot_window
# 29                dom_function_document.querySelector(
# 6                                    number_of_cookies
# 32       dom_function_document.getElementsByClassName(
# 14            dom_function_window.removeEventListener(
# 5                          number_of_http_only_cookies
# 18               dom_function_window.getComputedStyle(
# 50                      dom_function_document.writeln(
# 35               dom_function_document.createTextNode(
# 17                   dom_function_window.getSelection(
# 3                             number_of_secure_cookies
# 21                   dom_function_window.clearTimeout(
# 36                  dom_function_document.createEvent(
# 13          dom_function_window.requestAnimationFrame(
# 30                         dom_function_document.open(
# 45                  dom_function_document.createRange(
# 22                  dom_function_window.clearInterval(
# 34                  dom_function_document.execCommand(
# 39                        dom_function_document.close(
# 46       dom_function_document.createDocumentFragment(
# 20                          dom_function_window.close(
# 58                        dom_function_window.confirm(
# 10                    dom_function_window.setInterval(
# 16                     dom_function_window.matchMedia(
# 28             dom_function_document.querySelectorAll(
# 42                           dom_function_window.atob(
# 11                       dom_function_window.scrollTo(
# 44                     dom_function_document.hasFocus(
# 59           dom_function_window.cancelAnimationFrame(
# 37              dom_function_document.createElementNS(
# 47                dom_function_document.createComment(
# 25                           dom_function_window.blur(
# 40                    dom_function_window.postMessage(
# 41                  dom_function_window.dispatchEvent(
# 102         dom_function_document.queryCommandEnabled(
# 111            dom_function_document.createTreeWalker(
# 56                         dom_function_window.moveTo(
# 52              dom_function_document.createAttribute(
# 55                          dom_function_window.print(
# 54                       dom_function_window.resizeTo(
# 53                       dom_function_window.scrollBy(
# 114  dom_function_document.createProcessingInstruct...
# 12                         dom_function_window.scroll(
# 105                dom_function_document.getSelection(
# 19                          dom_function_window.focus(
# 57                          dom_function_window.fetch(
# 71                   dom_function_window.setImmediate(
# 104                  dom_function_document.importNode(
# 26                          dom_function_window.alert(
# 48                dom_function_document.captureEvents(
# 120         dom_function_document.caretRangeFromPoint(
# 121      dom_function_document.caretPositionFromPoint(
# 80                         dom_function_window.prompt(
# 49                  dom_function_window.captureEvents(
# 8                            dom_function_window.stop(
# 24                           dom_function_window.btoa(
# 60            dom_function_document.elementsFromPoint(
# 51             dom_function_document.elementFromPoint(
# 23                 dom_function_window.clearImmediate(
# 90                           dom_function_window.find(
# 115          dom_function_document.createNodeIterator(
# 97                   dom_function_document.routeEvent(
# 96                           dom_function_window.back(
# 98                 dom_function_document.releaseEvent(
# 99               dom_function_document.releaseCapture(
# 100           dom_function_document.queryCommandValue(
# 101        dom_function_document.queryCommandIndeterm(
# 95             dom_function_window.cancelIdleCallback(
# 103           dom_function_document.normalizeDocument(
# 106      dom_function_document.getElementsByTagNameNS(
# 93         dom_function_window.disableExternalCapture(
# 119                       dom_function_document.clear(
# 107            dom_function_document.getElementByName(
# 108               dom_function_document.getAnimations(
# 109             dom_function_document.exitPointerLock(
# 110     dom_function_document.enableStyleSheetsForSet(
# 112             dom_function_document.createTouchList(
# 113                 dom_function_document.createTouch(
# 116       dom_function_document.createEntityReference(
# 117          dom_function_document.createCDATASection(
# 118           dom_function_document.createAttributeNS(
# 94              dom_function_window.createImageBitmap(
# 61                                     tot_WebAssembly
# 92                           dom_function_window.dump(
# 75                     dom_function_window.routeEvent(
# 62                                         tot_Reflect
# 63                                         tot_Promise
# 64                                          tot_Object
# 65                                          tot_Number
# 66                                            tot_Math
# 67                                         tot_Atomics
# 68                 dom_function_window.updateCommands(
# 69                  dom_function_window.sizeToContent(
# 70                   dom_function_window.setResizable(
# 72                      dom_function_window.setCursor(
# 73                  dom_function_window.scrollByPages(
# 74                  dom_function_window.scrollByLines(
# 76                        dom_function_window.restore(
# 91          dom_function_window.enableExternalCapture(
# 77                       dom_function_window.resizeBy(
# 78            dom_function_window.requestIdleCallback(
# 79                  dom_function_window.releaseEvents(
# 81                     dom_function_window.openDialog(
# 82                         dom_function_window.moveBy(
# 83                       dom_function_window.minimize(
# 84                       dom_function_window.maximize(
# 85                           dom_function_window.home(
# 86         dom_function_window.getDefaultComputedSyle(
# 87     dom_function_window.getAttentionWithCycleCount(
# 88                   dom_function_window.getAttention(
# 89                        dom_function_window.forward(
# 122                   dom_function_document.adoptNode(
