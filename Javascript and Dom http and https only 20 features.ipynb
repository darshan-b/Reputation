# %% [markdown]
# ***
# ## Table of Contents
# <br>
#     <ol>
#         <h2><a href='#1' style="text-decoration : none; color : #000000;">1. HTTP</a></h2>
#         <ul>
#             <a href='#1.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#1.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#1.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#1.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#1.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a></h2>
#         <ul><a href='#2.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#2.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#2.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>
#
# <br>
#     <ol>
#         <h2><a href='#3' style="text-decoration : none; color : #000000;">3. HTTPS</a></h2>
#         <ul>
#             <a href='#3.A' style="text-decoration : none; color : #000000;"><h3>A. Loading Data </h3></a>
#         </ul>
#         <ul>
#             <a href='#3.B' style="text-decoration : none; color : #000000;"><h3>B. Feature Selection </h3></a>
#             </ul>
#         <ul>
#             <a href='#3.C' style="text-decoration : none; color : #000000;"><h3>C. Splitting Training and Test Data For Selected Features </h3></a>
#            </ul>
#         <ul>
#             <a href='#3.D' style="text-decoration : none; color : #000000;"><h3>D. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#3.E' style="text-decoration : none; color : #000000;"><h3>E. Results </h3></a>
#             </ul>
#      </ol>
#      <br>
#       <ol>
#         <h2><a href='#4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a></h2>
#         <ul><a href='#4.A' style="text-decoration : none; color : #000000;"><h3>A. Classification using different methods </h3></a>
#             </ul>
#             <ul>
#             <a href='#4.B' style="text-decoration : none; color : #000000;"><h3>B. Results </h3></a>
#             </ul>
#             <ul>
#              <a href='#4.C' style="text-decoration : none; color : #000000;"><h3> C. % variance eplained by selected features</h3> </a> </ul>
#      </ol>
# <br>

# %%
import pandas as pd
import numpy as np
import os
import json
from pandas.io.json import json_normalize
from IPython.display import display,clear_output,HTML
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from tabulate import tabulate

import keras
from keras.layers import Dense,Dropout
from keras.models import Sequential
from keras.wrappers.scikit_learn import KerasClassifier

# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows',305)

from sklearn.feature_selection import SelectKBest,chi2,RFE,RFECV,f_regression,SelectFromModel
from sklearn.linear_model import LogisticRegression,RandomizedLasso,LinearRegression, Ridge,Lasso
from sklearn.ensemble import ExtraTreesClassifier,RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold,GridSearchCV,train_test_split,cross_val_score

from sklearn.preprocessing import MinMaxScaler,StandardScaler,binarize
from sklearn.ensemble import RandomForestRegressor
from minepy import MINE
from sklearn import metrics

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix,accuracy_score,auc,roc_curve,recall_score
from sklearn import metrics
from pandas_ml import ConfusionMatrix


from imblearn.over_sampling import SMOTE
# Out:
# Using TensorFlow backend.

# %%
### Function get_params takes as input a grid search model and prints out the best parameters for the model and 
### prints the best accuracy of the model
def get_params(grid,model_name=''):
    print("Best Parameters are :")
    display(pd.DataFrame.from_dict(grid.best_params_, orient='index').reset_index().transpose())

### The function takes as input the model, X and Y data to generate the confusion matrix  
def get_cm(model,a,b):
    y_pred=model.predict(a)
    cm=ConfusionMatrix(b,y_pred)
    return cm
 
### The get accuracy plot takes as input a dataframe and a string for the title of the plot and displays a plot
### The function is primarily for plotting of accuracies for various classifiers for the same split.
def get_accuracy_plot(data,title=''):
    plt.figure(figsize=(12,8))
    plt.plot(data['accuracy'].values, '--o')
    plt.ylabel('Accuracy', fontsize=20)
    plt.xlabel('Classifier', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=18)
    plt.tick_params(axis='both', which='minor', labelsize=12)
    plt.xlim([0, 9])
    plt.title(title,size=18,y=1.05)
    plt.xticks(np.arange(10),data.index.get_values(),rotation=90)
    plt.legend(loc='upper right', fontsize=18)
    plt.show()

### Function grid takes as input an estimator, X_train,Y_Train,X_test and Y_test and a string represetning the name of the model
### We perform StratifiedKFold cross validation and grid search to hypertune the parameters of the model     
def grid(kernel,params,x,y,x_test,y_test,model_name=''):
    kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=0)
    grid_search=GridSearchCV(estimator=kernel,param_grid=parameters,scoring='accuracy',cv=kfold,n_jobs=3,verbose=True)
    grid_search.fit(x,y)
    get_params(grid_search,model_name)
    acc_train=accuracy_score(y,grid_search.predict(x))
    print("Accuracy of the ",model_name," model for the training data is:",acc_train)
    print("\nConfusion Matrix for Training data is:")
    cm_train=get_cm(grid_search,x,y)
    display(cm_train)
    acc_test=accuracy_score(y_test,grid_search.predict(x_test))
    print("Accuracy of the ",model_name," model for test data is:",acc_test)
    print("\nConfusion Matrix for test data is:")
    cm_test=get_cm(grid_search,x_test,y_test)
    display(cm_test)
    fpr, tpr, threshold = roc_curve(y_test, grid_search.predict(x_test))
    roc_auc =auc(fpr, tpr)
    return grid_search,cm_train,cm_test,acc_train,acc_test,roc_auc  

### Plot roc curve
def get_roc_curve(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob[:,1]
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy on test data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

def get_roc_curve_deep_learning(model,x_test,y_test):
    prob=model.predict_proba(x_test)
    preds=prob
    fpr, tpr, threshold = roc_curve(y_test, preds)
    roc_auc =auc(fpr, tpr)
    plt.figure(figsize=(10,8))
    plt.title('Receiver Operating Characteristic')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show()
    i = np.arange(len(tpr)) 
    roc = pd.DataFrame({'fpr' : pd.Series(fpr, index=i),'tpr' : pd.Series(tpr, index = i), '1-fpr' : pd.Series(1-fpr, index = i), 'tf' : pd.Series(tpr - (1-fpr), index = i), 'thresholds' : pd.Series(threshold, index = i)})
    threshold=roc.ix[(roc.tf-0).abs().argsort()[:1]]['thresholds'].values[0]
    print("Optimal Threshold is",threshold)
    y_pred_class=binarize(preds.reshape(1,-1),threshold)[0]
    accuracy=accuracy_score(y_test,y_pred_class)
    print("Accuracy of Logistic Model on training data is:",accuracy)
    cm=ConfusionMatrix(y_test,y_pred_class)
    display(cm)
    return cm,accuracy,threshold,roc_auc

# %% [markdown]
# ## <a id='1' style="text-decoration : none; color : #000000;"> HTTP</a>
#
# ### <a id='1.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_http.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_http.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

display(df.shape)

# df.to_csv('Javascript_dom.csv')

df.head()
# Out:
# (43296, 407)
#                   dom_function_document.adoptNode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_document.captureEvents(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.caretPositionFromPoint(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.caretRangeFromPoint(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.clear(  dom_function_document.close(  \
# domain
# h83.turdizi.com                            0.0                           0.0
# hbgv.wivela.com                            0.0                           0.0
# nus.edu.sg                                 0.0                           0.0
# arabwebpage.com                            0.0                           0.0
# moscatalogue.net                           0.0                           0.0
#
#                   dom_function_document.createAttribute(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createAttributeNS(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.createCDATASection(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createComment(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.createDocumentFragment(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.createElement(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    4.0
# nus.edu.sg                                         1.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   1.0
#
#                   dom_function_document.createElementNS(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createEntityReference(  \
# domain
# h83.turdizi.com                                            0.0
# hbgv.wivela.com                                            0.0
# nus.edu.sg                                                 0.0
# arabwebpage.com                                            0.0
# moscatalogue.net                                           0.0
#
#                   dom_function_document.createEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createNodeIterator(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_document.createProcessingInstruction(  \
# domain
# h83.turdizi.com                                                 0.0
# hbgv.wivela.com                                                 0.0
# nus.edu.sg                                                      0.0
# arabwebpage.com                                                 0.0
# moscatalogue.net                                                0.0
#
#                   dom_function_document.createRange(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTextNode(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          1.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.createTouch(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.createTouchList(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.createTreeWalker(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementFromPoint(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.elementsFromPoint(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.enableStyleSheetsForSet(  \
# domain
# h83.turdizi.com                                              0.0
# hbgv.wivela.com                                              0.0
# nus.edu.sg                                                   0.0
# arabwebpage.com                                              0.0
# moscatalogue.net                                             0.0
#
#                   dom_function_document.execCommand(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_document.exitPointerLock(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_document.getAnimations(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.getElementById(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     1.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.getElementByName(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.getElementsByClassName(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             1.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getElementsByTagName(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           3.0
# nus.edu.sg                                                1.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.getElementsByTagNameNS(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   dom_function_document.getSelection(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.hasFocus(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_document.importNode(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.normalizeDocument(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.open(  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                0.0
# arabwebpage.com                           0.0
# moscatalogue.net                          0.0
#
#                   dom_function_document.queryCommandEnabled(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_document.queryCommandIndeterm(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_document.queryCommandValue(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_document.querySelector(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   dom_function_document.querySelectorAll(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_document.releaseCapture(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_document.releaseEvent(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_document.routeEvent(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_document.write(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           2.0
#
#                   dom_function_document.writeln(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.addEventListener(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     1.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.alert(  dom_function_window.atob(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.back(  dom_function_window.blur(  \
# domain
# h83.turdizi.com                         0.0                        0.0
# hbgv.wivela.com                         0.0                        0.0
# nus.edu.sg                              0.0                        0.0
# arabwebpage.com                         0.0                        0.0
# moscatalogue.net                        0.0                        0.0
#
#                   dom_function_window.btoa(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.cancelAnimationFrame(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   dom_function_window.cancelIdleCallback(  \
# domain
# h83.turdizi.com                                       0.0
# hbgv.wivela.com                                       0.0
# nus.edu.sg                                            0.0
# arabwebpage.com                                       0.0
# moscatalogue.net                                      0.0
#
#                   dom_function_window.captureEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearImmediate(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   dom_function_window.clearInterval(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.clearTimeout(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.close(  dom_function_window.confirm(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.createImageBitmap(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   dom_function_window.disableExternalCapture(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.dispatchEvent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.dump(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.enableExternalCapture(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.fetch(  dom_function_window.find(  \
# domain
# h83.turdizi.com                          0.0                        0.0
# hbgv.wivela.com                          0.0                        0.0
# nus.edu.sg                               0.0                        0.0
# arabwebpage.com                          0.0                        0.0
# moscatalogue.net                         0.0                        0.0
#
#                   dom_function_window.focus(  dom_function_window.forward(  \
# domain
# h83.turdizi.com                          0.0                           0.0
# hbgv.wivela.com                          0.0                           0.0
# nus.edu.sg                               0.0                           0.0
# arabwebpage.com                          0.0                           0.0
# moscatalogue.net                         0.0                           0.0
#
#                   dom_function_window.getAttention(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.getAttentionWithCycleCount(  \
# domain
# h83.turdizi.com                                               0.0
# hbgv.wivela.com                                               0.0
# nus.edu.sg                                                    0.0
# arabwebpage.com                                               0.0
# moscatalogue.net                                              0.0
#
#                   dom_function_window.getComputedStyle(  \
# domain
# h83.turdizi.com                                     0.0
# hbgv.wivela.com                                     0.0
# nus.edu.sg                                          0.0
# arabwebpage.com                                     0.0
# moscatalogue.net                                    0.0
#
#                   dom_function_window.getDefaultComputedSyle(  \
# domain
# h83.turdizi.com                                           0.0
# hbgv.wivela.com                                           0.0
# nus.edu.sg                                                0.0
# arabwebpage.com                                           0.0
# moscatalogue.net                                          0.0
#
#                   dom_function_window.getSelection(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.home(  dom_function_window.matchMedia(  \
# domain
# h83.turdizi.com                         0.0                              0.0
# hbgv.wivela.com                         0.0                              0.0
# nus.edu.sg                              0.0                              0.0
# arabwebpage.com                         0.0                              0.0
# moscatalogue.net                        0.0                              0.0
#
#                   dom_function_window.maximize(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.minimize(  dom_function_window.moveBy(  \
# domain
# h83.turdizi.com                             0.0                          0.0
# hbgv.wivela.com                             0.0                          0.0
# nus.edu.sg                                  0.0                          0.0
# arabwebpage.com                             0.0                          0.0
# moscatalogue.net                            0.0                          0.0
#
#                   dom_function_window.moveTo(  dom_function_window.open(  \
# domain
# h83.turdizi.com                           0.0                        0.0
# hbgv.wivela.com                           0.0                        0.0
# nus.edu.sg                                0.0                        2.0
# arabwebpage.com                           0.0                        0.0
# moscatalogue.net                          0.0                        0.0
#
#                   dom_function_window.openDialog(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.postMessage(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.print(  dom_function_window.prompt(  \
# domain
# h83.turdizi.com                          0.0                          0.0
# hbgv.wivela.com                          0.0                          0.0
# nus.edu.sg                               0.0                          0.0
# arabwebpage.com                          0.0                          0.0
# moscatalogue.net                         0.0                          0.0
#
#                   dom_function_window.releaseEvents(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.removeEventListener(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.requestAnimationFrame(  \
# domain
# h83.turdizi.com                                          0.0
# hbgv.wivela.com                                          0.0
# nus.edu.sg                                               0.0
# arabwebpage.com                                          0.0
# moscatalogue.net                                         0.0
#
#                   dom_function_window.requestIdleCallback(  \
# domain
# h83.turdizi.com                                        0.0
# hbgv.wivela.com                                        0.0
# nus.edu.sg                                             0.0
# arabwebpage.com                                        0.0
# moscatalogue.net                                       0.0
#
#                   dom_function_window.resizeBy(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.resizeTo(  dom_function_window.restore(  \
# domain
# h83.turdizi.com                             0.0                           0.0
# hbgv.wivela.com                             0.0                           0.0
# nus.edu.sg                                  0.0                           0.0
# arabwebpage.com                             0.0                           0.0
# moscatalogue.net                            0.0                           0.0
#
#                   dom_function_window.routeEvent(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.scroll(  dom_function_window.scrollBy(  \
# domain
# h83.turdizi.com                           0.0                            0.0
# hbgv.wivela.com                           0.0                            0.0
# nus.edu.sg                                0.0                            0.0
# arabwebpage.com                           0.0                            0.0
# moscatalogue.net                          0.0                            0.0
#
#                   dom_function_window.scrollByLines(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollByPages(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.scrollTo(  \
# domain
# h83.turdizi.com                             0.0
# hbgv.wivela.com                             0.0
# nus.edu.sg                                  0.0
# arabwebpage.com                             0.0
# moscatalogue.net                            0.0
#
#                   dom_function_window.setCursor(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   dom_function_window.setImmediate(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setInterval(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   dom_function_window.setResizable(  \
# domain
# h83.turdizi.com                                 0.0
# hbgv.wivela.com                                 0.0
# nus.edu.sg                                      0.0
# arabwebpage.com                                 0.0
# moscatalogue.net                                0.0
#
#                   dom_function_window.setTimeout(  \
# domain
# h83.turdizi.com                               0.0
# hbgv.wivela.com                               0.0
# nus.edu.sg                                    0.0
# arabwebpage.com                               0.0
# moscatalogue.net                              0.0
#
#                   dom_function_window.sizeToContent(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   dom_function_window.stop(  \
# domain
# h83.turdizi.com                         0.0
# hbgv.wivela.com                         0.0
# nus.edu.sg                              0.0
# arabwebpage.com                         0.0
# moscatalogue.net                        0.0
#
#                   dom_function_window.updateCommands(  js_function_.add(  \
# domain
# h83.turdizi.com                                   0.0                0.0
# hbgv.wivela.com                                   0.0                0.0
# nus.edu.sg                                        0.0                0.0
# arabwebpage.com                                   0.0                0.0
# moscatalogue.net                                  0.0                0.0
#
#                   js_function_.all(  js_function_.allTrue(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_.anchor(  js_function_.apply(  \
# domain
# h83.turdizi.com                    0.0                  0.0
# hbgv.wivela.com                    0.0                  6.0
# nus.edu.sg                         0.0                  0.0
# arabwebpage.com                    0.0                  0.0
# moscatalogue.net                   0.0                  0.0
#
#                   js_function_.big(  js_function_.bind(  js_function_.blink(  \
# domain
# h83.turdizi.com                 0.0                 0.0                  0.0
# hbgv.wivela.com                 0.0                 0.0                  0.0
# nus.edu.sg                      0.0                 0.0                  0.0
# arabwebpage.com                 0.0                 0.0                  0.0
# moscatalogue.net                0.0                 0.0                  0.0
#
#                   js_function_.bold(  js_function_.call(  js_function_.catch(  \
# domain
# h83.turdizi.com                  0.0                 0.0                  0.0
# hbgv.wivela.com                  0.0                 4.0                  0.0
# nus.edu.sg                       0.0                 0.0                  0.0
# arabwebpage.com                  0.0                 0.0                  0.0
# moscatalogue.net                 0.0                 0.0                  0.0
#
#                   js_function_.charAt(  js_function_.charCodeAt(  \
# domain
# h83.turdizi.com                    0.0                       0.0
# hbgv.wivela.com                    2.0                       0.0
# nus.edu.sg                         1.0                       0.0
# arabwebpage.com                    0.0                       0.0
# moscatalogue.net                   0.0                       0.0
#
#                   js_function_.clear(  js_function_.codePointAt(  \
# domain
# h83.turdizi.com                   0.0                        0.0
# hbgv.wivela.com                   0.0                        0.0
# nus.edu.sg                        0.0                        0.0
# arabwebpage.com                   0.0                        0.0
# moscatalogue.net                  0.0                        0.0
#
#                   js_function_.compile(  js_function_.concat(  \
# domain
# h83.turdizi.com                     0.0                   0.0
# hbgv.wivela.com                     0.0                   2.0
# nus.edu.sg                          0.0                   0.0
# arabwebpage.com                     0.0                   0.0
# moscatalogue.net                    0.0                   0.0
#
#                   js_function_.construct(  js_function_.copyWithin(  \
# domain
# h83.turdizi.com                       0.0                       0.0
# hbgv.wivela.com                       0.0                       0.0
# nus.edu.sg                            0.0                       0.0
# arabwebpage.com                       0.0                       0.0
# moscatalogue.net                      0.0                       0.0
#
#                   js_function_.defineProperty(  js_function_.delete(  \
# domain
# h83.turdizi.com                            0.0                   0.0
# hbgv.wivela.com                            2.0                   0.0
# nus.edu.sg                                 0.0                   0.0
# arabwebpage.com                            0.0                   0.0
# moscatalogue.net                           0.0                   0.0
#
#                   js_function_.deleteProperty(  js_function_.endWith(  \
# domain
# h83.turdizi.com                            0.0                    0.0
# hbgv.wivela.com                            0.0                    0.0
# nus.edu.sg                                 0.0                    0.0
# arabwebpage.com                            0.0                    0.0
# moscatalogue.net                           0.0                    0.0
#
#                   js_function_.entries(  js_function_.every(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   js_function_.exec(  js_function_.fill(  \
# domain
# h83.turdizi.com                  0.0                 0.0
# hbgv.wivela.com                  0.0                 0.0
# nus.edu.sg                       0.0                 0.0
# arabwebpage.com                  0.0                 0.0
# moscatalogue.net                 0.0                 0.0
#
#                   js_function_.filter(  js_function_.finally(  \
# domain
# h83.turdizi.com                    0.0                    0.0
# hbgv.wivela.com                    0.0                    0.0
# nus.edu.sg                         0.0                    0.0
# arabwebpage.com                    0.0                    0.0
# moscatalogue.net                   0.0                    0.0
#
#                   js_function_.find(  js_function_.findIndex(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  0.0                      0.0
# nus.edu.sg                       6.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_.fixed(  js_function_.flat(  \
# domain
# ...
#
#                   js_function_Object.setPrototypeOf(  \
# domain
# h83.turdizi.com                                  0.0
# hbgv.wivela.com                                  0.0
# nus.edu.sg                                       0.0
# arabwebpage.com                                  0.0
# moscatalogue.net                                 0.0
#
#                   js_function_Promise.all(  js_function_Promise.race(  \
# domain
# h83.turdizi.com                        0.0                        0.0
# hbgv.wivela.com                        0.0                        0.0
# nus.edu.sg                             0.0                        0.0
# arabwebpage.com                        0.0                        0.0
# moscatalogue.net                       0.0                        0.0
#
#                   js_function_Promise.reject(  js_function_Promise.resolve(  \
# domain
# h83.turdizi.com                           0.0                           0.0
# hbgv.wivela.com                           0.0                           0.0
# nus.edu.sg                                0.0                           0.0
# arabwebpage.com                           0.0                           0.0
# moscatalogue.net                          0.0                           0.0
#
#                   js_function_Proxy.revocable(  js_function_Reflect.apply(  \
# domain
# h83.turdizi.com                            0.0                         0.0
# hbgv.wivela.com                            0.0                         0.0
# nus.edu.sg                                 0.0                         0.0
# arabwebpage.com                            0.0                         0.0
# moscatalogue.net                           0.0                         0.0
#
#                   js_function_Reflect.construct(  \
# domain
# h83.turdizi.com                              0.0
# hbgv.wivela.com                              0.0
# nus.edu.sg                                   0.0
# arabwebpage.com                              0.0
# moscatalogue.net                             0.0
#
#                   js_function_Reflect.defineProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.deleteProperty(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.get(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.getOwnPropertyDescriptor(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_Reflect.getPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_Reflect.has(  js_function_Reflect.isExtensible(  \
# domain
# h83.turdizi.com                        0.0                                0.0
# hbgv.wivela.com                        0.0                                0.0
# nus.edu.sg                             0.0                                0.0
# arabwebpage.com                        0.0                                0.0
# moscatalogue.net                       0.0                                0.0
#
#                   js_function_Reflect.ownKeys(  \
# domain
# h83.turdizi.com                            0.0
# hbgv.wivela.com                            0.0
# nus.edu.sg                                 0.0
# arabwebpage.com                            0.0
# moscatalogue.net                           0.0
#
#                   js_function_Reflect.preventExtensions(  \
# domain
# h83.turdizi.com                                      0.0
# hbgv.wivela.com                                      0.0
# nus.edu.sg                                           0.0
# arabwebpage.com                                      0.0
# moscatalogue.net                                     0.0
#
#                   js_function_Reflect.set(  \
# domain
# h83.turdizi.com                        0.0
# hbgv.wivela.com                        0.0
# nus.edu.sg                             0.0
# arabwebpage.com                        0.0
# moscatalogue.net                       0.0
#
#                   js_function_Reflect.setPrototypeOf(  \
# domain
# h83.turdizi.com                                   0.0
# hbgv.wivela.com                                   0.0
# nus.edu.sg                                        0.0
# arabwebpage.com                                   0.0
# moscatalogue.net                                  0.0
#
#                   js_function_String.fromCharCode(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_String.fromCodePoint(  js_function_String.raw(  \
# domain
# h83.turdizi.com                                 0.0                      0.0
# hbgv.wivela.com                                 0.0                      0.0
# nus.edu.sg                                      0.0                      0.0
# arabwebpage.com                                 0.0                      0.0
# moscatalogue.net                                0.0                      0.0
#
#                   js_function_Symbol.for(  js_function_Symbol.keyFor(  \
# domain
# h83.turdizi.com                       0.0                         0.0
# hbgv.wivela.com                       0.0                         0.0
# nus.edu.sg                            0.0                         0.0
# arabwebpage.com                       0.0                         0.0
# moscatalogue.net                      0.0                         0.0
#
#                   js_function_WebAssembly.compile(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.compileStreaming(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.customerSections(  \
# domain
# h83.turdizi.com                                         0.0
# hbgv.wivela.com                                         0.0
# nus.edu.sg                                              0.0
# arabwebpage.com                                         0.0
# moscatalogue.net                                        0.0
#
#                   js_function_WebAssembly.exports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.imports(  \
# domain
# h83.turdizi.com                                0.0
# hbgv.wivela.com                                0.0
# nus.edu.sg                                     0.0
# arabwebpage.com                                0.0
# moscatalogue.net                               0.0
#
#                   js_function_WebAssembly.instantiate(  \
# domain
# h83.turdizi.com                                    0.0
# hbgv.wivela.com                                    0.0
# nus.edu.sg                                         0.0
# arabwebpage.com                                    0.0
# moscatalogue.net                                   0.0
#
#                   js_function_WebAssembly.instantiateStreaming(  \
# domain
# h83.turdizi.com                                             0.0
# hbgv.wivela.com                                             0.0
# nus.edu.sg                                                  0.0
# arabwebpage.com                                             0.0
# moscatalogue.net                                            0.0
#
#                   js_function_WebAssembly.validate(  js_function_decodeURI(  \
# domain
# h83.turdizi.com                                 0.0                     0.0
# hbgv.wivela.com                                 0.0                     0.0
# nus.edu.sg                                      0.0                     0.0
# arabwebpage.com                                 0.0                     0.0
# moscatalogue.net                                0.0                     0.0
#
#                   js_function_decodeURIComponent(  js_function_encodeURI(  \
# domain
# h83.turdizi.com                               0.0                     0.0
# hbgv.wivela.com                               0.0                     0.0
# nus.edu.sg                                    1.0                     0.0
# arabwebpage.com                               0.0                     0.0
# moscatalogue.net                              0.0                     0.0
#
#                   js_function_encodeURIComponent(  js_function_escape(  \
# domain
# h83.turdizi.com                               0.0                  0.0
# hbgv.wivela.com                               0.0                  0.0
# nus.edu.sg                                    1.0                  0.0
# arabwebpage.com                               0.0                  0.0
# moscatalogue.net                              0.0                  2.0
#
#                   js_function_eval(  js_function_isFinite(  \
# domain
# h83.turdizi.com                 0.0                    0.0
# hbgv.wivela.com                 0.0                    0.0
# nus.edu.sg                      0.0                    0.0
# arabwebpage.com                 0.0                    0.0
# moscatalogue.net                0.0                    0.0
#
#                   js_function_isNaN(  js_function_parseFloat(  \
# domain
# h83.turdizi.com                  0.0                      0.0
# hbgv.wivela.com                  1.0                      0.0
# nus.edu.sg                       0.0                      0.0
# arabwebpage.com                  0.0                      0.0
# moscatalogue.net                 0.0                      0.0
#
#                   js_function_parseInt(  js_function_undefined(  \
# domain
# h83.turdizi.com                     0.0                     0.0
# hbgv.wivela.com                     0.0                     0.0
# nus.edu.sg                          0.0                     0.0
# arabwebpage.com                     0.0                     0.0
# moscatalogue.net                    0.0                     0.0
#
#                   js_function_unescape(  js_function_uneval(  \
# domain
# h83.turdizi.com                     0.0                  0.0
# hbgv.wivela.com                     0.0                  0.0
# nus.edu.sg                          0.0                  0.0
# arabwebpage.com                     0.0                  0.0
# moscatalogue.net                    0.0                  0.0
#
#                   number_functions_declared  number_of_cookies  \
# domain
# h83.turdizi.com                         0.0                0.0
# hbgv.wivela.com                        87.0                6.0
# nus.edu.sg                             24.0                4.0
# arabwebpage.com                         7.0                4.0
# moscatalogue.net                        3.0                5.0
#
#                   number_of_http_only_cookies  \
# domain
# h83.turdizi.com                           0.0
# hbgv.wivela.com                           0.0
# nus.edu.sg                                1.0
# arabwebpage.com                           1.0
# moscatalogue.net                          1.0
#
#                   number_of_non_http_only_cookies  number_of_secure_cookies  \
# domain
# h83.turdizi.com                               0.0                       0.0
# hbgv.wivela.com                               6.0                       0.0
# nus.edu.sg                                    3.0                       0.0
# arabwebpage.com                               3.0                       0.0
# moscatalogue.net                              4.0                       1.0
#
#                   number_of_unsecure_cookies  Malicious
# domain
# h83.turdizi.com                          0.0          1
# hbgv.wivela.com                          6.0          1
# nus.edu.sg                               4.0          0
# arabwebpage.com                          4.0          0
# moscatalogue.net                         4.0          0

# %%
js_cols=([col for col in df.columns if (('js' in col) or ('number' in col))])

dom_cols=([col for col in df.columns if 'dom' in col])

X=df[['dom_function_window.setTimeout(','dom_function_window.setInterval(','dom_function_document.createElement(',
     'dom_function_document.write(','dom_function_document.createComment(','dom_function_document.createElementNS(',
      'dom_function_window.addEventListener(','js_function_escape(','js_function_unescape(','js_function_eval(','js_function_.concat(','js_function_.charCodeAt(',
   'js_function_String.fromCharCode(','js_function_.split(','js_function_Number.parseInt(','js_function_.replace(',
   'js_function_.link(','js_function_.exec(','js_function_.search(','js_function_.substring(']]
y=df.Malicious.values
feature_name = X.columns.tolist()

# %% [markdown]
# ### <a id='1.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (43296, 20)

# %% [markdown]
# #### C.1 List of features selected

# %%
feature_name
# Out:
# ['dom_function_window.setTimeout(',
#  'dom_function_window.setInterval(',
#  'dom_function_document.createElement(',
#  'dom_function_document.write(',
#  'dom_function_document.createComment(',
#  'dom_function_document.createElementNS(',
#  'dom_function_window.addEventListener(',
#  'js_function_escape(',
#  'js_function_unescape(',
#  'js_function_eval(',
#  'js_function_.concat(',
#  'js_function_.charCodeAt(',
#  'js_function_String.fromCharCode(',
#  'js_function_.split(',
#  'js_function_Number.parseInt(',
#  'js_function_.replace(',
#  'js_function_.link(',
#  'js_function_.exec(',
#  'js_function_.search(',
#  'js_function_.substring(']

# %% [markdown]
# ### <a id='1.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=20))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8570851137544752
# Predicted  False  True  __all__
# Actual
# False      29640     1    29641
# True        4949    46     4995
# __all__    34589    47    34636
# The accuracy of the model on test data is: 0.8516166281755196
# Predicted  False  True  __all__
# Actual
# False       7367     1     7368
# True        1284     8     1292
# __all__     8651     9     8660

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8575759325557224
# Predicted  False  True  __all__
# Actual
# False      29630    11    29641
# True        4922    73     4995
# __all__    34552    84    34636
# The accuracy of the model on test data is: 0.851270207852194
# Predicted  False  True  __all__
# Actual
# False       7361     7     7368
# True        1281    11     1292
# __all__     8642    18     8660

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8557858875158795
# Predicted      0  1  __all__
# Actual
# 0          29641  0    29641
# 1           4995  0     4995
# __all__    34636  0    34636
# The accuracy of the model on test data is: 0.8508083140877598
# Predicted     0  1  __all__
# Actual
# 0          7368  0     7368
# 1          1292  0     1292
# __all__    8660  0     8660
# 29641
# 0
# 0
# 29641
# 4995
# 0
# 0
# 4995
# 1.0
# 0.0
# 0.0
# 1.0
# 7368
# 0
# 0
# 7368
# 1292
# 0
# 0
# 1292
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8585286984640259
# Predicted  False  True  __all__
# Actual
# False      29634     7    29641
# True        4893   102     4995
# __all__    34527   109    34636
# The accuracy of the model on test data is: 0.8519630484988453
# Predicted  False  True  __all__
# Actual
# False       7363     5     7368
# True        1277    15     1292
# __all__     8640    20     8660

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8542268160295646
# Predicted  False  True  __all__
# Actual
# False      29564    77    29641
# True        4972    23     4995
# __all__    34536   100    34636
# The accuracy of the model on test data is: 0.8488452655889146
# Predicted  False  True  __all__
# Actual
# False       7347    21     7368
# True        1288     4     1292
# __all__     8635    25     8660

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8574893174731493
# Predicted  False  True  __all__
# Actual
# False      29638     3    29641
# True        4933    62     4995
# __all__    34571    65    34636
# The accuracy of the model on test data is: 0.8515011547344111
# Predicted  False  True  __all__
# Actual
# False       7365     3     7368
# True        1283     9     1292
# __all__     8648    12     8660

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.858788543711745
# Predicted  False  True  __all__
# Actual
# False      29637     4    29641
# True        4887   108     4995
# __all__    34524   112    34636
# The accuracy of the model on test data is: 0.8513856812933025
# Predicted  False  True  __all__
# Actual
# False       7359     9     7368
# True        1278    14     1292
# __all__     8637    23     8660

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8584998267698348
# Predicted  False  True  __all__
# Actual
# False      29630    11    29641
# True        4890   105     4995
# __all__    34520   116    34636
# The accuracy of the model on test data is: 0.851270207852194
# Predicted  False  True  __all__
# Actual
# False       7359     9     7368
# True        1279    13     1292
# __all__     8638    22     8660

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8579512645802055
# Predicted  False  True  __all__
# Actual
# False      29638     3    29641
# True        4917    78     4995
# __all__    34555    81    34636
# The accuracy of the model on test data is: 0.8517321016166282
# Predicted  False  True  __all__
# Actual
# False       7364     4     7368
# True        1280    12     1292
# __all__     8644    16     8660

# %% [markdown]
# ### <a id='1.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy            TP            TN           FP  \
# index
# Neural Network-1            0.857085     46.000000  29640.000000     1.000000
# KNeighborsClassifier        0.857576     73.000000  29630.000000    11.000000
# LogisticRegression          0.855786  25366.349492   4274.650508  4274.650508
# RandomForestClassifier      0.858529    102.000000  29634.000000     7.000000
# AdaBoostClassifier          0.854227     23.000000  29564.000000    77.000000
# GradientBoostingClassifier  0.857489     62.000000  29638.000000     3.000000
# ExtraTreeClassifier         0.858789    108.000000  29637.000000     4.000000
# BaggingClassifier           0.858500    105.000000  29630.000000    11.000000
# VotingClassifier            0.857951     78.000000  29638.000000     3.000000
#
#                                      FN       FPR       FNR
# index
# Neural Network-1            4949.000000  0.000034  0.990791
# KNeighborsClassifier        4922.000000  0.000371  0.985385
# LogisticRegression           720.349492  0.855786  0.144214
# RandomForestClassifier      4893.000000  0.000236  0.979580
# AdaBoostClassifier          4972.000000  0.002598  0.995395
# GradientBoostingClassifier  4933.000000  0.000101  0.987588
# ExtraTreeClassifier         4887.000000  0.000135  0.978378
# BaggingClassifier           4890.000000  0.000371  0.978979
# VotingClassifier            4917.000000  0.000101  0.984384
# Comparision Table for Test Accuracies:
#                             accuracy           TP           TN           FP  \
# index
# Neural Network-1            0.851617     8.000000  7367.000000     1.000000
# KNeighborsClassifier        0.851270    11.000000  7361.000000     7.000000
# LogisticRegression          0.850808  6268.755658  1099.244342  1099.244342
# RandomForestClassifier      0.851963    15.000000  7363.000000     5.000000
# AdaBoostClassifier          0.848845     4.000000  7347.000000    21.000000
# GradientBoostingClassifier  0.851501     9.000000  7365.000000     3.000000
# ExtraTreeClassifier         0.851386    14.000000  7359.000000     9.000000
# BaggingClassifier           0.851270    13.000000  7359.000000     9.000000
# VotingClassifier            0.851732    12.000000  7364.000000     4.000000
#
#                                      FN       FPR       FNR       auc
# index
# Neural Network-1            1284.000000  0.000136  0.993808  0.503028
# KNeighborsClassifier        1281.000000  0.000950  0.991486  0.503782
# LogisticRegression           192.755658  0.850808  0.149192  0.500000
# RandomForestClassifier      1277.000000  0.000679  0.988390  0.505466
# AdaBoostClassifier          1288.000000  0.002850  0.996904  0.500123
# GradientBoostingClassifier  1283.000000  0.000407  0.993034  0.503279
# ExtraTreeClassifier         1278.000000  0.001221  0.989164  0.504807
# BaggingClassifier           1279.000000  0.001221  0.989938  0.504420
# VotingClassifier            1280.000000  0.000543  0.990712  0.504373

# %% [markdown]
# ## <a id='2' style="text-decoration : none; color : #000000;">2. HTTP with PCA</a>
#
# #### <a id='2.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=15,random_state=0)
X_pca=pca.fit_transform(scaled_X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_train.shape
# Out:
# The train/test split ratio is 80:20
# (34636, 15)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=15))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8574893174731493
# Predicted  False  True  __all__
# Actual
# False      29637     4    29641
# True        4932    63     4995
# __all__    34569    67    34636
# The accuracy of the model on test data is: 0.8516166281755196
# Predicted  False  True  __all__
# Actual
# False       7366     2     7368
# True        1283     9     1292
# __all__     8649    11     8660

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8576625476382954
# Predicted  False  True  __all__
# Actual
# False      29632     9    29641
# True        4921    74     4995
# __all__    34553    83    34636
# The accuracy of the model on test data is: 0.8515011547344111
# Predicted  False  True  __all__
# Actual
# False       7363     5     7368
# True        1281    11     1292
# __all__     8644    16     8660

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8557858875158795
# Predicted      0  1  __all__
# Actual
# 0          29641  0    29641
# 1           4995  0     4995
# __all__    34636  0    34636
# The accuracy of the model on test data is: 0.8508083140877598
# Predicted     0  1  __all__
# Actual
# 0          7368  0     7368
# 1          1292  0     1292
# __all__    8660  0     8660
# 29641
# 0
# 0
# 29641
# 4995
# 0
# 0
# 4995
# 1.0
# 0.0
# 0.0
# 1.0
# 7368
# 0
# 0
# 7368
# 1292
# 0
# 0
# 1292
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8585286984640259
# Predicted  False  True  __all__
# Actual
# False      29634     7    29641
# True        4893   102     4995
# __all__    34527   109    34636
# The accuracy of the model on test data is: 0.8519630484988453
# Predicted  False  True  __all__
# Actual
# False       7363     5     7368
# True        1277    15     1292
# __all__     8640    20     8660

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8558147592100704
# Predicted  False  True  __all__
# Actual
# False      29641     0    29641
# True        4994     1     4995
# __all__    34635     1    34636
# The accuracy of the model on test data is: 0.8508083140877598
# Predicted     0  1  __all__
# Actual
# 0          7368  0     7368
# 1          1292  0     1292
# __all__    8660  0     8660
# 7368
# 0
# 0
# 7368
# 1292
# 0
# 0
# 1292
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8584420833814528
# Predicted  False  True  __all__
# Actual
# False      29638     3    29641
# True        4900    95     4995
# __all__    34538    98    34636
# The accuracy of the model on test data is: 0.8513856812933025
# Predicted  False  True  __all__
# Actual
# False       7360     8     7368
# True        1279    13     1292
# __all__     8639    21     8660

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.858788543711745
# Predicted  False  True  __all__
# Actual
# False      29637     4    29641
# True        4887   108     4995
# __all__    34524   112    34636
# The accuracy of the model on test data is: 0.851270207852194
# Predicted  False  True  __all__
# Actual
# False       7358    10     7368
# True        1278    14     1292
# __all__     8636    24     8660

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8584998267698348
# Predicted  False  True  __all__
# Actual
# False      29630    11    29641
# True        4890   105     4995
# __all__    34520   116    34636
# The accuracy of the model on test data is: 0.851270207852194
# Predicted  False  True  __all__
# Actual
# False       7360     8     7368
# True        1280    12     1292
# __all__     8640    20     8660

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8584709550756439
# Predicted  False  True  __all__
# Actual
# False      29638     3    29641
# True        4899    96     4995
# __all__    34537    99    34636
# The accuracy of the model on test data is: 0.8518475750577367
# Predicted  False  True  __all__
# Actual
# False       7363     5     7368
# True        1278    14     1292
# __all__     8641    19     8660

# %% [markdown]
# ### <a id='2.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy            TP            TN           FP  \
# index
# Neural Network-1            0.857489     63.000000  29637.000000     4.000000
# KNeighborsClassifier        0.857663     74.000000  29632.000000     9.000000
# LogisticRegression          0.855786  25366.349492   4274.650508  4274.650508
# RandomForestClassifier      0.858529    102.000000  29634.000000     7.000000
# AdaBoostClassifier          0.855815      1.000000  29641.000000     0.000000
# GradientBoostingClassifier  0.858442     95.000000  29638.000000     3.000000
# ExtraTreeClassifier         0.858789    108.000000  29637.000000     4.000000
# BaggingClassifier           0.858500    105.000000  29630.000000    11.000000
# VotingClassifier            0.858471     96.000000  29638.000000     3.000000
#
#                                      FN       FPR       FNR
# index
# Neural Network-1            4932.000000  0.000135  0.987387
# KNeighborsClassifier        4921.000000  0.000304  0.985185
# LogisticRegression           720.349492  0.855786  0.144214
# RandomForestClassifier      4893.000000  0.000236  0.979580
# AdaBoostClassifier          4994.000000  0.000000  0.999800
# GradientBoostingClassifier  4900.000000  0.000101  0.980981
# ExtraTreeClassifier         4887.000000  0.000135  0.978378
# BaggingClassifier           4890.000000  0.000371  0.978979
# VotingClassifier            4899.000000  0.000101  0.980781
# Comparision Table for Test Accuracies:
#                             accuracy           TP           TN           FP  \
# index
# Neural Network-1            0.851617     9.000000  7366.000000     2.000000
# KNeighborsClassifier        0.851501    11.000000  7363.000000     5.000000
# LogisticRegression          0.850808  6268.755658  1099.244342  1099.244342
# RandomForestClassifier      0.851963    15.000000  7363.000000     5.000000
# AdaBoostClassifier          0.850808  6268.755658  1099.244342  1099.244342
# GradientBoostingClassifier  0.851386    13.000000  7360.000000     8.000000
# ExtraTreeClassifier         0.851270    14.000000  7358.000000    10.000000
# BaggingClassifier           0.851270    12.000000  7360.000000     8.000000
# VotingClassifier            0.851848    14.000000  7363.000000     5.000000
#
#                                      FN       FPR       FNR       auc
# index
# Neural Network-1            1283.000000  0.000271  0.993034  0.503347
# KNeighborsClassifier        1281.000000  0.000679  0.991486  0.503918
# LogisticRegression           192.755658  0.850808  0.149192  0.500000
# RandomForestClassifier      1277.000000  0.000679  0.988390  0.505466
# AdaBoostClassifier           192.755658  0.850808  0.149192  0.500000
# GradientBoostingClassifier  1279.000000  0.001086  0.989938  0.504488
# ExtraTreeClassifier         1278.000000  0.001357  0.989164  0.504739
# BaggingClassifier           1280.000000  0.001086  0.990712  0.504101
# VotingClassifier            1278.000000  0.000679  0.989164  0.505079

# %% [markdown]
# ### <a id='2.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 1                               0.065323
# 16                              0.064064
# 0                               0.063888
# 6                               0.061651
# 14                              0.060760
# 11                              0.060118
# 9                               0.055558
# 4                               0.053877
# 5                               0.053630
# 12                              0.051313
# 3                               0.051264
# 2                               0.048572
# 18                              0.044346
# 19                              0.036668
# 17                              0.035955
# 8                               0.029886
# 7                               0.029489
# 10                              0.025764
# 13                              0.025603
# 15                              0.015604
#
#                                   Features
# 1         dom_function_window.setInterval(
# 16                      js_function_.link(
# 0          dom_function_window.setTimeout(
# 6    dom_function_window.addEventListener(
# 14            js_function_Number.parseInt(
# 11                js_function_.charCodeAt(
# 9                        js_function_eval(
# 4     dom_function_document.createComment(
# 5   dom_function_document.createElementNS(
# 12        js_function_String.fromCharCode(
# 3             dom_function_document.write(
# 2     dom_function_document.createElement(
# 18                    js_function_.search(
# 19                 js_function_.substring(
# 17                      js_function_.exec(
# 8                    js_function_unescape(
# 7                      js_function_escape(
# 10                    js_function_.concat(
# 13                     js_function_.split(
# 15                   js_function_.replace(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, 20])
plt.xticks(np.arange(20),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## <a id='3' style="text-decoration : none; color : #000000;"> HTTPS</a>
#
# ### <a id='3.A' style="text-decoration : none; color : #000000;">A. Loading Data</a>

# %%
df_alex=pd.read_csv('Javascript_alexa_output_final_https.csv',low_memory=False)
df_virus=pd.read_csv('Javascript_malicious_output_final_https.csv',low_memory=False)

df_alex['Malicious']=0
df_virus['Malicious']=1

df=pd.concat([df_alex,df_virus])
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df = df.sample(frac=1,random_state=867).reset_index(drop=True)
df.fillna(value=0,inplace=True)
df=df[df['html_status']=='Success']


### Dropping columns that indicate the html status of domain data collection

df.drop(['html_status','html_status_strerror','html_status_message'],axis=1,inplace=True)
df.set_index(['domain'],inplace=True)

display(df.shape)

# df.to_csv('Javascript_dom.csv')

df.head()
# Out:
# (44476, 407)
#                                                     dom_function_document.adoptNode(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     dom_function_document.captureEvents(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.caretPositionFromPoint(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.caretRangeFromPoint(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_document.clear(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.close(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.createAttribute(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createAttributeNS(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.createCDATASection(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_document.createComment(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.createDocumentFragment(  \
# domain
# fiverr.com                                                                                    1.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.createElement(  \
# domain
# fiverr.com                                                                           3.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.createElementNS(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createEntityReference(  \
# domain
# fiverr.com                                                                                   0.0
# babynameready.com                                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                           0.0
# fontmeme.com                                                                                 0.0
# vidachok.tv                                                                                  0.0
#
#                                                     dom_function_document.createEvent(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createNodeIterator(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_document.createProcessingInstruction(  \
# domain
# fiverr.com                                                                                        0.0
# babynameready.com                                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                                0.0
# fontmeme.com                                                                                      0.0
# vidachok.tv                                                                                       0.0
#
#                                                     dom_function_document.createRange(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createTextNode(  \
# domain
# fiverr.com                                                                            3.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.createTouch(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.createTouchList(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.createTreeWalker(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.elementFromPoint(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.elementsFromPoint(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.enableStyleSheetsForSet(  \
# domain
# fiverr.com                                                                                     0.0
# babynameready.com                                                                              0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                             0.0
# fontmeme.com                                                                                   0.0
# vidachok.tv                                                                                    0.0
#
#                                                     dom_function_document.execCommand(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_document.exitPointerLock(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_document.getAnimations(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.getElementById(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.getElementByName(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.getElementsByClassName(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.getElementsByTagName(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_document.getElementsByTagNameNS(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     dom_function_document.getSelection(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_document.hasFocus(  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     dom_function_document.importNode(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_document.normalizeDocument(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.open(  \
# domain
# fiverr.com                                                                  0.0
# babynameready.com                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                          0.0
# fontmeme.com                                                                0.0
# vidachok.tv                                                                 0.0
#
#                                                     dom_function_document.queryCommandEnabled(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_document.queryCommandIndeterm(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_document.queryCommandValue(  \
# domain
# fiverr.com                                                                               0.0
# babynameready.com                                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                       0.0
# fontmeme.com                                                                             0.0
# vidachok.tv                                                                              0.0
#
#                                                     dom_function_document.querySelector(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     dom_function_document.querySelectorAll(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_document.releaseCapture(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_document.releaseEvent(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_document.routeEvent(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_document.write(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_document.writeln(  \
# domain
# fiverr.com                                                                     0.0
# babynameready.com                                                              0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                             0.0
# fontmeme.com                                                                   0.0
# vidachok.tv                                                                    0.0
#
#                                                     dom_function_window.addEventListener(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_window.alert(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.atob(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.back(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.blur(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.btoa(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.cancelAnimationFrame(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     dom_function_window.cancelIdleCallback(  \
# domain
# fiverr.com                                                                              0.0
# babynameready.com                                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                      0.0
# fontmeme.com                                                                            0.0
# vidachok.tv                                                                             0.0
#
#                                                     dom_function_window.captureEvents(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.clearImmediate(  \
# domain
# fiverr.com                                                                          0.0
# babynameready.com                                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                  0.0
# fontmeme.com                                                                        0.0
# vidachok.tv                                                                         0.0
#
#                                                     dom_function_window.clearInterval(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.clearTimeout(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_window.close(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.confirm(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_window.createImageBitmap(  \
# domain
# fiverr.com                                                                             0.0
# babynameready.com                                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                     0.0
# fontmeme.com                                                                           0.0
# vidachok.tv                                                                            0.0
#
#                                                     dom_function_window.disableExternalCapture(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                          0.0
# fontmeme.com                                                                                0.0
# vidachok.tv                                                                                 0.0
#
#                                                     dom_function_window.dispatchEvent(  \
# domain
# fiverr.com                                                                         0.0
# babynameready.com                                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                 0.0
# fontmeme.com                                                                       0.0
# vidachok.tv                                                                        0.0
#
#                                                     dom_function_window.dump(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.enableExternalCapture(  \
# domain
# fiverr.com                                                                                 0.0
# babynameready.com                                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                         0.0
# fontmeme.com                                                                               0.0
# vidachok.tv                                                                                0.0
#
#                                                     dom_function_window.fetch(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.find(  \
# domain
# fiverr.com                                                                0.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              0.0
# vidachok.tv                                                               0.0
#
#                                                     dom_function_window.focus(  \
# domain
# fiverr.com                                                                 0.0
# babynameready.com                                                          0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               0.0
# vidachok.tv                                                                0.0
#
#                                                     dom_function_window.forward(  \
# domain
# fiverr.com                                                                   0.0
# babynameready.com                                                            0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                           0.0
# fontmeme.com                                                                 0.0
# vidachok.tv                                                                  0.0
#
#                                                     dom_function_window.getAttention(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     dom_function_window.getAttentionWithCycleCount(  \
# domain
# fiverr.com                                                                                      0.0
# babynameready.com                                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                              0.0
# fontmeme.com                                                                                    0.0
# vidachok.tv                                                                                     0.0
#
#                                                     dom_function_window.getComputedStyle(  \
# domain
# fiverr.com                                                                            0.0
# babynameready.com                                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                    0.0
# fontmeme.com                                                                          0.0
# vidachok.tv                                                                           0.0
#
#                                                     dom_function_window.getDefaultComputedSyle(  \
# domain
# fiverr.com                                                                                  0.0
# babynameready.com                                                                           0.0
# ...
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.compileStreaming(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     js_function_WebAssembly.customerSections(  \
# domain
# fiverr.com                                                                                0.0
# babynameready.com                                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                        0.0
# fontmeme.com                                                                              0.0
# vidachok.tv                                                                               0.0
#
#                                                     js_function_WebAssembly.exports(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.imports(  \
# domain
# fiverr.com                                                                       0.0
# babynameready.com                                                                0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                               0.0
# fontmeme.com                                                                     0.0
# vidachok.tv                                                                      0.0
#
#                                                     js_function_WebAssembly.instantiate(  \
# domain
# fiverr.com                                                                           0.0
# babynameready.com                                                                    0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                   0.0
# fontmeme.com                                                                         0.0
# vidachok.tv                                                                          0.0
#
#                                                     js_function_WebAssembly.instantiateStreaming(  \
# domain
# fiverr.com                                                                                    0.0
# babynameready.com                                                                             0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                            0.0
# fontmeme.com                                                                                  0.0
# vidachok.tv                                                                                   0.0
#
#                                                     js_function_WebAssembly.validate(  \
# domain
# fiverr.com                                                                        0.0
# babynameready.com                                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                                0.0
# fontmeme.com                                                                      0.0
# vidachok.tv                                                                       0.0
#
#                                                     js_function_decodeURI(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_decodeURIComponent(  \
# domain
# fiverr.com                                                                      1.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     js_function_encodeURI(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_encodeURIComponent(  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    0.0
# vidachok.tv                                                                     0.0
#
#                                                     js_function_escape(  \
# domain
# fiverr.com                                                          0.0
# babynameready.com                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                  0.0
# fontmeme.com                                                        0.0
# vidachok.tv                                                         3.0
#
#                                                     js_function_eval(  \
# domain
# fiverr.com                                                        0.0
# babynameready.com                                                 0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                0.0
# fontmeme.com                                                      0.0
# vidachok.tv                                                       0.0
#
#                                                     js_function_isFinite(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_isNaN(  \
# domain
# fiverr.com                                                         0.0
# babynameready.com                                                  0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                 0.0
# fontmeme.com                                                       0.0
# vidachok.tv                                                        0.0
#
#                                                     js_function_parseFloat(  \
# domain
# fiverr.com                                                              0.0
# babynameready.com                                                       0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                      0.0
# fontmeme.com                                                            0.0
# vidachok.tv                                                             0.0
#
#                                                     js_function_parseInt(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_undefined(  \
# domain
# fiverr.com                                                             0.0
# babynameready.com                                                      0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                     0.0
# fontmeme.com                                                           0.0
# vidachok.tv                                                            0.0
#
#                                                     js_function_unescape(  \
# domain
# fiverr.com                                                            0.0
# babynameready.com                                                     0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                    0.0
# fontmeme.com                                                          0.0
# vidachok.tv                                                           0.0
#
#                                                     js_function_uneval(  \
# domain
# fiverr.com                                                          0.0
# babynameready.com                                                   0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                  0.0
# fontmeme.com                                                        0.0
# vidachok.tv                                                         0.0
#
#                                                     number_functions_declared  \
# domain
# fiverr.com                                                                3.0
# babynameready.com                                                         0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                        0.0
# fontmeme.com                                                              2.0
# vidachok.tv                                                              11.0
#
#                                                     number_of_cookies  \
# domain
# fiverr.com                                                        1.0
# babynameready.com                                                 3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                0.0
# fontmeme.com                                                      3.0
# vidachok.tv                                                       7.0
#
#                                                     number_of_http_only_cookies  \
# domain
# fiverr.com                                                                  1.0
# babynameready.com                                                           0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                          0.0
# fontmeme.com                                                                0.0
# vidachok.tv                                                                 2.0
#
#                                                     number_of_non_http_only_cookies  \
# domain
# fiverr.com                                                                      0.0
# babynameready.com                                                               3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                              0.0
# fontmeme.com                                                                    3.0
# vidachok.tv                                                                     5.0
#
#                                                     number_of_secure_cookies  \
# domain
# fiverr.com                                                               0.0
# babynameready.com                                                        0.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                       0.0
# fontmeme.com                                                             0.0
# vidachok.tv                                                              0.0
#
#                                                     number_of_unsecure_cookies  \
# domain
# fiverr.com                                                                 1.0
# babynameready.com                                                          3.0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...                         0.0
# fontmeme.com                                                               3.0
# vidachok.tv                                                                7.0
#
#                                                     Malicious
# domain
# fiverr.com                                                  0
# babynameready.com                                           0
# signon.telstra.com.au.vidafamiliayalgomas.com/l...          1
# fontmeme.com                                                0
# vidachok.tv                                                 0

# %%
js_cols=([col for col in df.columns if (('js' in col) or ('number' in col))])

dom_cols=([col for col in df.columns if 'dom' in col])

X=df[['dom_function_window.setTimeout(','dom_function_window.setInterval(','dom_function_document.createElement(',
     'dom_function_document.write(','dom_function_document.createComment(','dom_function_document.createElementNS(',
      'dom_function_window.addEventListener(','js_function_escape(','js_function_unescape(','js_function_eval(','js_function_.concat(','js_function_.charCodeAt(',
   'js_function_String.fromCharCode(','js_function_.split(','js_function_Number.parseInt(','js_function_.replace(',
   'js_function_.link(','js_function_.exec(','js_function_.search(','js_function_.substring(']]
y=df.Malicious.values
feature_name = X.columns.tolist()

# %% [markdown]
# ### <a id='3.C' style="text-decoration : none; color : #000000;"> C. Splitting Training and Test Data For Selected Features </a>

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(scaled_X,y,random_state=0,test_size=0.2)

X.shape
# Out:
# The train/test split ratio is 80:20
# (44476, 20)

# %% [markdown]
# ### <a id='3.D' style="text-decoration : none; color : #000000;"> D. Classification using different methods </a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %% [markdown]
# #### D.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=20))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8573636874849706
# Predicted  False  True  __all__
# Actual
# False      30505     1    30506
# True        5074     0     5074
# __all__    35579     1    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### D.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8573917931422147
# Predicted      0  1  __all__
# Actual
# 0          30506  0    30506
# 1           5074  0     5074
# __all__    35580  0    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 30506
# 0
# 0
# 30506
# 5074
# 0
# 0
# 5074
# 1.0
# 0.0
# 0.0
# 1.0
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### D.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8573636874648679
# Predicted  False  True  __all__
# Actual
# False      30505     1    30506
# True        5074     0     5074
# __all__    35579     1    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### D.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8580944350758853
# Predicted  False  True  __all__
# Actual
# False      30504     2    30506
# True        5047    27     5074
# __all__    35551    29    35580
# The accuracy of the model on test data is: 0.8554406474820144
# Predicted  False  True  __all__
# Actual
# False       7610     3     7613
# True        1283     0     1283
# __all__     8893     3     8896

# %% [markdown]
# #### D.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8571388420460934
# Predicted  False  True  __all__
# Actual
# False      30497     9    30506
# True        5074     0     5074
# __all__    35571     9    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### D.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.857504215851602
# Predicted  False  True  __all__
# Actual
# False      30506     0    30506
# True        5070     4     5074
# __all__    35576     4    35580
# The accuracy of the model on test data is: 0.8555530575539568
# Predicted  False  True  __all__
# Actual
# False       7611     2     7613
# True        1283     0     1283
# __all__     8894     2     8896

# %% [markdown]
# #### D.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8582349634626194
# Predicted  False  True  __all__
# Actual
# False      30505     1    30506
# True        5043    31     5074
# __all__    35548    32    35580
# The accuracy of the model on test data is: 0.8552158273381295
# Predicted  False  True  __all__
# Actual
# False       7606     7     7613
# True        1281     2     1283
# __all__     8887     9     8896

# %% [markdown]
# #### D.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8580944350758853
# Predicted  False  True  __all__
# Actual
# False      30503     3    30506
# True        5046    28     5074
# __all__    35549    31    35580
# The accuracy of the model on test data is: 0.8555530575539568
# Predicted  False  True  __all__
# Actual
# False       7608     5     7613
# True        1280     3     1283
# __all__     8888     8     8896

# %% [markdown]
# #### D.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8575885328836425
# Predicted  False  True  __all__
# Actual
# False      30506     0    30506
# True        5067     7     5074
# __all__    35573     7    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted  False  True  __all__
# Actual
# False       7612     1     7613
# True        1282     1     1283
# __all__     8894     2     8896

# %% [markdown]
# ### <a id='3.E' style="text-decoration : none; color : #000000;"> E. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy            TP            TN           FP  \
# index
# Neural Network-1            0.857364      0.000000  30505.000000     1.000000
# KNeighborsClassifier        0.857392  26155.594042   4350.405958  4350.405958
# LogisticRegression          0.857364      0.000000  30505.000000     1.000000
# RandomForestClassifier      0.858094     27.000000  30504.000000     2.000000
# AdaBoostClassifier          0.857139      0.000000  30497.000000     9.000000
# GradientBoostingClassifier  0.857504      4.000000  30506.000000     0.000000
# ExtraTreeClassifier         0.858235     31.000000  30505.000000     1.000000
# BaggingClassifier           0.858094     28.000000  30503.000000     3.000000
# VotingClassifier            0.857589      7.000000  30506.000000     0.000000
#
#                                      FN       FPR       FNR
# index
# Neural Network-1            5074.000000  0.000033  1.000000
# KNeighborsClassifier         723.594042  0.857392  0.142608
# LogisticRegression          5074.000000  0.000033  1.000000
# RandomForestClassifier      5047.000000  0.000066  0.994679
# AdaBoostClassifier          5074.000000  0.000295  1.000000
# GradientBoostingClassifier  5070.000000  0.000000  0.999212
# ExtraTreeClassifier         5043.000000  0.000033  0.993890
# BaggingClassifier           5046.000000  0.000098  0.994482
# VotingClassifier            5067.000000  0.000000  0.998620
# Comparision Table for Test Accuracies:
#                             accuracy           TP           TN           FP  \
# index
# Neural Network-1            0.855778  6515.036983  1097.963017  1097.963017
# KNeighborsClassifier        0.855778  6515.036983  1097.963017  1097.963017
# LogisticRegression          0.855778  6515.036983  1097.963017  1097.963017
# RandomForestClassifier      0.855441     0.000000  7610.000000     3.000000
# AdaBoostClassifier          0.855778  6515.036983  1097.963017  1097.963017
# GradientBoostingClassifier  0.855553     0.000000  7611.000000     2.000000
# ExtraTreeClassifier         0.855216     2.000000  7606.000000     7.000000
# BaggingClassifier           0.855553     3.000000  7608.000000     5.000000
# VotingClassifier            0.855778     1.000000  7612.000000     1.000000
#
#                                      FN       FPR       FNR       auc
# index
# Neural Network-1             185.036983  0.855778  0.144222  0.500000
# KNeighborsClassifier         185.036983  0.855778  0.144222  0.500000
# LogisticRegression           185.036983  0.855778  0.144222  0.500000
# RandomForestClassifier      1283.000000  0.000394  1.000000  0.499803
# AdaBoostClassifier           185.036983  0.855778  0.144222  0.500000
# GradientBoostingClassifier  1283.000000  0.000263  1.000000  0.499869
# ExtraTreeClassifier         1281.000000  0.000919  0.998441  0.500320
# BaggingClassifier           1280.000000  0.000657  0.997662  0.500841
# VotingClassifier            1282.000000  0.000131  0.999221  0.500324

# %% [markdown]
# ## <a id='4' style="text-decoration : none; color : #000000;">4. HTTPS with PCA</a>
#
# #### <a id='4.A' style="text-decoration : none; color : #000000;"> A. Classification using different methods</a>

# %%
## Table to store training and test measures
table_80_50_train=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR'])
table_80_50_test=pd.DataFrame(columns=['accuracy','TP','TN','FP','FN','FPR','FNR','auc'])

# %%
scaler=StandardScaler()
scaled_X=scaler.fit_transform(X)
pca=PCA(n_components=15,random_state=0)
X_pca=pca.fit_transform(scaled_X)

print("The train/test split ratio is 80:20")
X_train, X_test, Y_train, Y_test = train_test_split(X_pca,y,random_state=0,test_size=0.2)

X_train.shape
# Out:
# The train/test split ratio is 80:20
# (35580, 15)

# %% [markdown]
# #### A.1. Deep Learning

# %%
np.random.seed(0)
deep_learning=Sequential()
deep_learning.add(Dense(units=64,activation='relu',use_bias=True,kernel_initializer='uniform',input_dim=15))
deep_learning.add(Dense(units=128,activation='relu',use_bias=True,kernel_initializer='uniform'))
deep_learning.add(Dense(units=1,activation='sigmoid',use_bias=True,kernel_initializer='uniform'))
deep_learning.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
deep_learning.fit(X_train,Y_train,batch_size=20,epochs=20,verbose=False)

acc_train=deep_learning.evaluate(X_train,Y_train,verbose=False)[1]
print("The accuracy of the model on training data is:",acc_train)
cm_train=ConfusionMatrix(Y_train,deep_learning.predict_classes(X_train,batch_size=1,verbose=False).reshape(1,len(X_train))[0])
cm_test=ConfusionMatrix(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
display(cm_train)
acc_test=accuracy_score(Y_test,deep_learning.predict_classes(X_test,batch_size=1,verbose=False))
print("The accuracy of the model on test data is:",acc_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test, deep_learning.predict_classes(X_test,batch_size=1,verbose=False).reshape(1,len(X_test))[0])
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[0]=([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[0]=([acc_test,cm_test.TP,cm_test.TN,cm_test.FP,cm_test.FN,cm_test.FPR,cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is: 0.8573917931623175
# Predicted      0  1  __all__
# Actual
# 0          30506  0    30506
# 1           5074  0     5074
# __all__    35580  0    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 30506
# 0
# 0
# 30506
# 5074
# 0
# 0
# 5074
# 1.0
# 0.0
# 0.0
# 1.0
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.2. KNN

# %%
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
acc_train=knn.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",knn.score(X_train,Y_train))
cm_train=get_cm(knn,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,knn.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(knn,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,knn.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[1]= ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[1] = ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8573917931422147
# Predicted  False  True  __all__
# Actual
# False      30505     1    30506
# True        5073     1     5074
# __all__    35578     2    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.3. Logistics

# %%
logistic=LogisticRegression()
logistic.fit(X_train,Y_train)
acc_train=logistic.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",logistic.score(X_train,Y_train))
cm_train=get_cm(logistic,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,logistic.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(logistic,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,logistic.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[2]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[2] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8573917931422147
# Predicted      0  1  __all__
# Actual
# 0          30506  0    30506
# 1           5074  0     5074
# __all__    35580  0    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 30506
# 0
# 0
# 30506
# 5074
# 0
# 0
# 5074
# 1.0
# 0.0
# 0.0
# 1.0
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.4. Random Forest Classifier

# %%
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
acc_train=rf.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",rf.score(X_train,Y_train))
cm_train=get_cm(rf,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,rf.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(rf,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,rf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[3]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[3] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8580944350758853
# Predicted  False  True  __all__
# Actual
# False      30504     2    30506
# True        5047    27     5074
# __all__    35551    29    35580
# The accuracy of the model on test data is: 0.8555530575539568
# Predicted  False  True  __all__
# Actual
# False       7611     2     7613
# True        1283     0     1283
# __all__     8894     2     8896

# %% [markdown]
# #### A.5. AdaBoost Classifier

# %%
ada=AdaBoostClassifier()
ada.fit(X_train,Y_train)
acc_train=ada.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ada.score(X_train,Y_train))
cm_train=get_cm(ada,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ada.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ada,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ada.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[4]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[4] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8573917931422147
# Predicted      0  1  __all__
# Actual
# 0          30506  0    30506
# 1           5074  0     5074
# __all__    35580  0    35580
# The accuracy of the model on test data is: 0.8557778776978417
# Predicted     0  1  __all__
# Actual
# 0          7613  0     7613
# 1          1283  0     1283
# __all__    8896  0     8896
# 30506
# 0
# 0
# 30506
# 5074
# 0
# 0
# 5074
# 1.0
# 0.0
# 0.0
# 1.0
# 7613
# 0
# 0
# 7613
# 1283
# 0
# 0
# 1283
# 1.0
# 0.0
# 0.0
# 1.0

# %% [markdown]
# #### A.6. GradientBoosting Classifier

# %%
gbc=GradientBoostingClassifier()
gbc.fit(X_train,Y_train)
acc_train=gbc.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",gbc.score(X_train,Y_train))
cm_train=get_cm(gbc,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,gbc.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(gbc,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,gbc.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[5]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[5] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8581225407532321
# Predicted  False  True  __all__
# Actual
# False      30501     5    30506
# True        5043    31     5074
# __all__    35544    36    35580
# The accuracy of the model on test data is: 0.8549910071942446
# Predicted  False  True  __all__
# Actual
# False       7602    11     7613
# True        1279     4     1283
# __all__     8881    15     8896

# %% [markdown]
# #### A.7. Extra Tree Classifier

# %%
ext_tree=ExtraTreesClassifier()
ext_tree.fit(X_train,Y_train)
acc_train=ext_tree.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",ext_tree.score(X_train,Y_train))
cm_train=get_cm(ext_tree,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,ext_tree.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(ext_tree,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,ext_tree.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[6]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[6] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8582349634626194
# Predicted  False  True  __all__
# Actual
# False      30505     1    30506
# True        5043    31     5074
# __all__    35548    32    35580
# The accuracy of the model on test data is: 0.8553282374100719
# Predicted  False  True  __all__
# Actual
# False       7607     6     7613
# True        1281     2     1283
# __all__     8888     8     8896

# %% [markdown]
# #### A.8. Bagging Classifier

# %%
bagging=BaggingClassifier()
bagging.fit(X_train,Y_train)
acc_train=bagging.score(X_train,Y_train)
print("The accuracy of the model on training data is: ",bagging.score(X_train,Y_train))
cm_train=get_cm(bagging,X_train,Y_train)
display(cm_train)
acc_test=accuracy_score(Y_test,bagging.predict(X_test))
print("The accuracy of the model on test data is:",acc_test)
cm_test=get_cm(bagging,X_test,Y_test)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,bagging.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[7]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[7] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is:  0.8580382237211917
# Predicted  False  True  __all__
# Actual
# False      30503     3    30506
# True        5048    26     5074
# __all__    35551    29    35580
# The accuracy of the model on test data is: 0.8555530575539568
# Predicted  False  True  __all__
# Actual
# False       7609     4     7613
# True        1281     2     1283
# __all__     8890     6     8896

# %% [markdown]
# #### A.9. Voting Classifier

# %%
eclf = VotingClassifier(estimators=[('knn', knn), ('logistic', logistic),('rf',rf),('ada',ada),('gbc',gbc),
                                    ('ext_tree',ext_tree),('bagging',bagging)], voting='soft')

eclf.fit(X_train,Y_train.reshape(1,len(Y_train))[0])
acc_train=eclf.score(X_train,Y_train)
pred=eclf.predict(X_test)
cm_train=get_cm(eclf,X_train,Y_train.reshape(1,len(Y_train))[0])
print("The accuracy of the model on training data is :",acc_train)
display(cm_train)
acc_test=accuracy_score(Y_test.reshape(1,len(Y_test))[0],pred)
print("The accuracy of the model on test data is:",acc_test)
cm_test=ConfusionMatrix(Y_test.reshape(1,len(Y_test))[0],pred)
display(cm_test)
fpr, tpr, threshold = roc_curve(Y_test,eclf.predict(X_test))
auc=metrics.auc(fpr, tpr)

table_80_50_train.loc[8]=   ([acc_train,cm_train.TP,cm_train.TN,cm_train.FP,cm_train.FN,cm_train.FPR,cm_train.FNR])
table_80_50_test.loc[8] =   ([acc_test ,cm_test.TP, cm_test.TN, cm_test.FP, cm_test.FN, cm_test.FPR, cm_test.FNR,auc])
# Out:
# The accuracy of the model on training data is : 0.8580663293985386
# Predicted  False  True  __all__
# Actual
# False      30506     0    30506
# True        5050    24     5074
# __all__    35556    24    35580
# The accuracy of the model on test data is: 0.8554406474820144
# Predicted  False  True  __all__
# Actual
# False       7608     5     7613
# True        1281     2     1283
# __all__     8889     7     8896

# %% [markdown]
# ### <a id='4.B' style="text-decoration : none; color : #000000;"> B. Results </a>

# %%
table_80_50_train['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']
table_80_50_test['index']=['Neural Network-1','KNeighborsClassifier','LogisticRegression','RandomForestClassifier','AdaBoostClassifier',
                           'GradientBoostingClassifier','ExtraTreeClassifier','BaggingClassifier','VotingClassifier']

table_80_50_test.set_index(['index'],drop=True,inplace=True)
table_80_50_train.set_index(['index'],drop=True,inplace=True)

print("Comparision Table for Training Accuracies:")
display(table_80_50_train)

print("Comparision Table for Test Accuracies:")
display(table_80_50_test)
# Out:
# Comparision Table for Training Accuracies:
#                             accuracy            TP            TN           FP  \
# index
# Neural Network-1            0.857392  26155.594042   4350.405958  4350.405958
# KNeighborsClassifier        0.857392      1.000000  30505.000000     1.000000
# LogisticRegression          0.857392  26155.594042   4350.405958  4350.405958
# RandomForestClassifier      0.858094     27.000000  30504.000000     2.000000
# AdaBoostClassifier          0.857392  26155.594042   4350.405958  4350.405958
# GradientBoostingClassifier  0.858123     31.000000  30501.000000     5.000000
# ExtraTreeClassifier         0.858235     31.000000  30505.000000     1.000000
# BaggingClassifier           0.858038     26.000000  30503.000000     3.000000
# VotingClassifier            0.858066     24.000000  30506.000000     0.000000
#
#                                      FN       FPR       FNR
# index
# Neural Network-1             723.594042  0.857392  0.142608
# KNeighborsClassifier        5073.000000  0.000033  0.999803
# LogisticRegression           723.594042  0.857392  0.142608
# RandomForestClassifier      5047.000000  0.000066  0.994679
# AdaBoostClassifier           723.594042  0.857392  0.142608
# GradientBoostingClassifier  5043.000000  0.000164  0.993890
# ExtraTreeClassifier         5043.000000  0.000033  0.993890
# BaggingClassifier           5048.000000  0.000098  0.994876
# VotingClassifier            5050.000000  0.000000  0.995270
# Comparision Table for Test Accuracies:
#                             accuracy           TP           TN           FP  \
# index
# Neural Network-1            0.855778  6515.036983  1097.963017  1097.963017
# KNeighborsClassifier        0.855778  6515.036983  1097.963017  1097.963017
# LogisticRegression          0.855778  6515.036983  1097.963017  1097.963017
# RandomForestClassifier      0.855553     0.000000  7611.000000     2.000000
# AdaBoostClassifier          0.855778  6515.036983  1097.963017  1097.963017
# GradientBoostingClassifier  0.854991     4.000000  7602.000000    11.000000
# ExtraTreeClassifier         0.855328     2.000000  7607.000000     6.000000
# BaggingClassifier           0.855553     2.000000  7609.000000     4.000000
# VotingClassifier            0.855441     2.000000  7608.000000     5.000000
#
#                                      FN       FPR       FNR       auc
# index
# Neural Network-1             185.036983  0.855778  0.144222  0.500000
# KNeighborsClassifier         185.036983  0.855778  0.144222  0.500000
# LogisticRegression           185.036983  0.855778  0.144222  0.500000
# RandomForestClassifier      1283.000000  0.000263  1.000000  0.499869
# AdaBoostClassifier           185.036983  0.855778  0.144222  0.500000
# GradientBoostingClassifier  1279.000000  0.001445  0.996882  0.500836
# ExtraTreeClassifier         1281.000000  0.000788  0.998441  0.500385
# BaggingClassifier           1281.000000  0.000525  0.998441  0.500517
# VotingClassifier            1281.000000  0.000657  0.998441  0.500451

# %% [markdown]
# ### <a id='4.C' style="text-decoration : none; color : #000000;"> C. % variance eplained by selected features </a>

# %%
pca_inv_data = pca.components_
lst=[]
lst.append((np.square(pca_inv_data.std(axis=0)),X.columns))
pca_df=pd.DataFrame(np.square(pca_inv_data.std(axis=0)))
pca_df['features']=X.columns
pca_df.columns=['% Variance explained by each feature','Features']
pca_df['% Variance explained by each feature']=pca_df['% Variance explained by each feature']
pca_df.sort_values(by='% Variance explained by each feature',ascending=False,inplace=True)
pca_df
# Out:
#     % Variance explained by each feature  \
# 16                              0.066416
# 14                              0.065381
# 1                               0.064571
# 0                               0.064552
# 9                               0.062892
# 18                              0.062582
# 2                               0.061629
# 12                              0.060721
# 6                               0.058691
# 3                               0.053218
# 19                              0.049909
# 11                              0.041720
# 5                               0.033376
# 17                              0.032670
# 4                               0.031743
# 8                               0.030171
# 7                               0.028791
# 10                              0.024643
# 13                              0.022541
# 15                              0.017117
#
#                                   Features
# 16                      js_function_.link(
# 14            js_function_Number.parseInt(
# 1         dom_function_window.setInterval(
# 0          dom_function_window.setTimeout(
# 9                        js_function_eval(
# 18                    js_function_.search(
# 2     dom_function_document.createElement(
# 12        js_function_String.fromCharCode(
# 6    dom_function_window.addEventListener(
# 3             dom_function_document.write(
# 19                 js_function_.substring(
# 11                js_function_.charCodeAt(
# 5   dom_function_document.createElementNS(
# 17                      js_function_.exec(
# 4     dom_function_document.createComment(
# 8                    js_function_unescape(
# 7                      js_function_escape(
# 10                    js_function_.concat(
# 13                     js_function_.split(
# 15                   js_function_.replace(

# %%
sns.set_style('white')
plt.figure(1, figsize=(10, 8))
plt.clf()
plt.plot(pca.explained_variance_,'--o', linewidth=2)
plt.axis('tight')
plt.xlabel('Number of Components',size=14)
plt.xticks(size=12)
plt.ylabel('% Explained Variance',size=14)
plt.yticks(size=12)
plt.title('% Variance Explained by Principal Components',size=14,y=1.05)
plt.legend()
### Comment to save the plot
# plt.savefig('A1.jpeg',dpi=1200)
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))
plt.plot(np.square(pca_inv_data.std(axis=0)), '--o')
plt.legend(loc='lower right')
plt.ylabel('% Variance explained by each Feature ', fontsize=20)
plt.xlabel('Features', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=18)
plt.tick_params(axis='both', which='minor', labelsize=12)
plt.xlim([0, 20])
plt.xticks(np.arange(20),feature_name,rotation=90)
plt.title('Variance explained by each feature along the components of Principal Components',size=18,y=1.05)
plt.legend(loc='upper right', fontsize=18)
# plt.savefig('B.jpeg',dpi=1200,bbox_inches = 'tight')
plt.show()

# %%
### Original Creator : Darshan Bhansali
### HTML code to hide the input cells 
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
To toggle code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# To toggle code, click <a href="javascript:code_toggle()">here</a>.
